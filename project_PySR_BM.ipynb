# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanrajs/sciml_project/blob/main/project_PySR_BM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Symbolic Regression

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi
# Out:
# Installing Julia 1.8.5 on the current Colab Runtime...
# 2023-12-04 05:13:45 URL:https://julialang-s3.julialang.org/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz [130873886/130873886] -> "/tmp/julia.tar.gz" [1]
# Installing PyCall.jl...
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed VersionParsing ── v1.3.0
#    Installed MacroTools ────── v0.5.11
#    Installed Parsers ───────── v2.8.0
#    Installed Conda ─────────── v1.10.0
#    Installed PyCall ────────── v1.96.2
#    Installed Preferences ───── v1.4.1
#    Installed PrecompileTools ─ v1.2.0
#    Installed JSON ──────────── v0.21.4
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [438e738f] + PyCall v1.96.2
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [8f4d0f93] + Conda v1.10.0
#   [682c06a0] + JSON v0.21.4
#   [1914dd2f] + MacroTools v0.5.11
#   [69de0a69] + Parsers v2.8.0
#   [aea7be01] + PrecompileTools v1.2.0
#   [21216c6a] + Preferences v1.4.1
#   [438e738f] + PyCall v1.96.2
#   [81def892] + VersionParsing v1.3.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b27032c2] + LibCURL v0.6.3
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [fa267f1f] + TOML v1.0.0
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.0+0
#   [14a3606d] + MozillaCACerts_jll v2022.2.1
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [83775a58] + Zlib_jll v1.2.12+3
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
# Success

# %% [markdown]
# Install PySR and PyTorch-Lightning:

# %%
# %pip install -Uq pysr pytorch_lightning --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 45.6 MB/s eta 0:00:00

# %%
from julia import Julia

julia = Julia(compiled_modules=False, threads="auto")
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()

# %%
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 22.04.3 LTS
#   uname: Linux 5.15.120+ #1 SMP Wed Aug 30 11:19:59 UTC 2023 x86_64 x86_64
#   CPU: Intel(R) Xeon(R) CPU @ 2.30GHz:
#               speed         user         nice          sys         idle          irq
#        #1  2299 MHz        732 s          0 s        137 s        820 s          0 s
#        #2  2299 MHz        878 s          0 s        155 s        658 s          0 s
#   Memory: 12.6783447265625 GB (11510.1015625 MB free)
#   Uptime: 176.74 sec
#   Load Avg:  2.07  0.98  0.39
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, haswell)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/lib64-nvidia
#   JULIA_PROJECT = @pysr-0.16.3
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.10.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#     Updating registry at `~/.julia/registries/General.toml`
#      Cloning git-repo `https://github.com/MilesCranmer/SymbolicRegression.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Tricks ─────────────────────────── v0.1.8
#    Installed ScientificTypesBase ────────────── v3.0.0
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed DiffRules ──────────────────────── v1.15.1
#    Installed DynamicExpressions ─────────────── v0.13.1
#    Installed LayoutPointers ─────────────────── v0.1.15
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed MLJModelInterface ──────────────── v1.9.3
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed VectorizationBase ──────────────── v0.21.65
#    Installed StatisticalTraits ──────────────── v3.2.0
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed CPUSummary ─────────────────────── v0.2.4
#    Installed PDMats ─────────────────────────── v0.11.30
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed DataAPI ────────────────────────── v1.15.0
#    Installed SpecialFunctions ───────────────── v2.3.1
#    Installed Optim ──────────────────────────── v1.7.6
#    Installed StaticArraysCore ───────────────── v1.4.2
#    Installed JLLWrappers ────────────────────── v1.5.0
#    Installed Setfield ───────────────────────── v1.1.1
#    Installed IrrationalConstants ────────────── v0.2.2
#    Installed StaticArrays ───────────────────── v1.7.0
#    Installed LoopVectorization ──────────────── v0.12.166
#    Installed NaNMath ────────────────────────── v1.0.2
#    Installed HostCPUFeatures ────────────────── v0.1.16
#    Installed ConstructionBase ───────────────── v1.5.4
#    Installed OrderedCollections ─────────────── v1.6.3
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed ChainRulesCore ─────────────────── v1.18.0
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed NLSolversBase ──────────────────── v7.8.3
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed ArrayInterface ─────────────────── v7.5.1
#    Installed FillArrays ─────────────────────── v1.8.0
#    Installed ForwardDiff ────────────────────── v0.10.36
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed LineSearches ───────────────────── v7.2.0
#    Installed DataStructures ─────────────────── v0.18.15
#    Installed ProgressBars ───────────────────── v1.5.1
#    Installed CommonSubexpressions ───────────── v0.3.0
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed Static ─────────────────────────── v0.8.8
#    Installed SLEEFPirates ───────────────────── v0.6.42
#    Installed StatsAPI ───────────────────────── v1.7.0
#    Installed Requires ───────────────────────── v1.3.0
#    Installed LogExpFunctions ────────────────── v0.3.26
#    Installed PackageExtensionCompat ─────────── v1.0.2
#    Installed Compat ─────────────────────────── v4.10.1
#    Installed OpenSpecFun_jll ────────────────── v0.5.5+0
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed ClusterManagers ────────────────── v0.4.5
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed StaticArrayInterface ───────────── v1.4.1
#    Installed InverseFunctions ───────────────── v0.1.12
#    Installed DynamicQuantities ──────────────── v0.6.3
#    Installed Missings ───────────────────────── v1.1.0
#    Installed SortingAlgorithms ──────────────── v1.2.0
#    Installed ChangesOfVariables ─────────────── v0.1.8
#    Installed StatsBase ──────────────────────── v0.34.2
#    Installed LossFunctions ──────────────────── v0.11.1
#    Installed DocStringExtensions ────────────── v0.9.3
#    Installed FiniteDiff ─────────────────────── v2.21.1
#    Installed Adapt ──────────────────────────── v3.7.1
#    Installed OffsetArrays ───────────────────── v1.12.10
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [34f1f09b] + ClusterManagers v0.4.5
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [79e6a3ab] + Adapt v3.7.1
# ⌅ [4fba245c] + ArrayInterface v7.5.1
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [2a0fbf3d] + CPUSummary v0.2.4
#   [d360d2e6] + ChainRulesCore v1.18.0
#   [9e997f8a] + ChangesOfVariables v0.1.8
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [34f1f09b] + ClusterManagers v0.4.5
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.10.1
#   [187b0558] + ConstructionBase v1.5.4
#   [adafc99b] + CpuId v0.3.1
#   [9a962f9c] + DataAPI v1.15.0
#   [864edb3b] + DataStructures v0.18.15
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [ffbed154] + DocStringExtensions v0.9.3
#   [a40a106e] + DynamicExpressions v0.13.1
# ⌅ [06fc5a27] + DynamicQuantities v0.6.3
#   [1a297f60] + FillArrays v1.8.0
#   [6a86dc24] + FiniteDiff v2.21.1
#   [f6369f11] + ForwardDiff v0.10.36
#   [3e5b6fbb] + HostCPUFeatures v0.1.16
#   [615f187c] + IfElse v0.1.1
#   [3587e190] + InverseFunctions v0.1.12
#   [92d709cd] + IrrationalConstants v0.2.2
#   [692b3bcd] + JLLWrappers v1.5.0
#   [10f19ff3] + LayoutPointers v0.1.15
#   [d3d80556] + LineSearches v7.2.0
#   [2ab3a3ac] + LogExpFunctions v0.3.26
#   [bdcacae8] + LoopVectorization v0.12.166
#   [30fc2ffe] + LossFunctions v0.11.1
#   [e80e1ace] + MLJModelInterface v1.9.3
#   [d125e4d3] + ManualMemory v0.1.8
#   [e1d29d7a] + Missings v1.1.0
#   [d41bc354] + NLSolversBase v7.8.3
#   [77ba4419] + NaNMath v1.0.2
#   [6fe1bfb0] + OffsetArrays v1.12.10
# ⌅ [429524aa] + Optim v1.7.6
#   [bac558e1] + OrderedCollections v1.6.3
#   [90014a1f] + PDMats v0.11.30
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [d96e819e] + Parameters v0.12.3
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [49802e3a] + ProgressBars v1.5.1
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.3.0
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.42
#   [30f210dd] + ScientificTypesBase v3.0.0
#   [efcf1570] + Setfield v1.1.1
#   [a2af1166] + SortingAlgorithms v1.2.0
#   [276daf66] + SpecialFunctions v2.3.1
#   [aedffcd0] + Static v0.8.8
#   [0d7ed370] + StaticArrayInterface v1.4.1
#   [90137ffa] + StaticArrays v1.7.0
#   [1e83bf80] + StaticArraysCore v1.4.2
#   [64bff920] + StatisticalTraits v3.2.0
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.2
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#   [8290d209] + ThreadingUtilities v0.5.2
#   [410a4b4d] + Tricks v0.1.8
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.65
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [56ddb016] + Logging
#   [44cfe95a] + Pkg v1.8.0
#   [3fa0cd96] + REPL
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [a4e569a6] + Tar v1.10.1
#   [8dfed614] + Test
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [3f19e933] + p7zip_jll v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:118: UserWarning: It is recommended to restart Python after installing PySR's dependencies, so that the Julia environment is properly initialized.
#   warnings.warn(

# %%
import sympy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bhushanrajs/sciml_project/main/analysis_data.csv')

tx_girders = {'Tx28' : {'D' : 28.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 6.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx34' : {'D' : 34.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 12.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx40' : {'D' : 40.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 18.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx46' : {'D' : 46.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 22.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx54' : {'D' : 54.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 30.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx62' : {'D' : 62.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 37.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx70' : {'D' : 70.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 45.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx84' : {'D' : 84.0, 'b1' : 58.0, 'b2' : 8.0, 'b3' : 38.0, 'b4' : 3.0, 'b5' : 3.0, 'd1' : 4.0, 'd2' : 3.5, 'd3' : 3.0, 'd4' : 55.75, 'd5' : 3.0, 'd6' : 6.0, 'd7' : 8.75}
              }

# bridge geometry data
L = df['L']/12 # span length in ft.
S = df['S']/12 # girder spacing in ft.
w_oh = df['w_oh']/12 # overhang width in ft.
ts = df['ts_U']/12 # thickness of overhang in ft.
girder = df['Girder Type']
D = []
for _, girder_type in girder.items():
  D.append(tx_girders[girder_type]['D'])
df['D'] = D

# intensity of railing dead load in kip/ft
b_rail = df['b_rail_left'] # width of railing
q_rail = (df['q_rail_left'] * b_rail * 12)/1000

# max bending moment in exterior girder G1 & interior girder G2 in kip-ft
bm1 = df['G1 - max_bm']/(1000*12)
bm2 = df['G2 - max_bm']/(1000*12)
bm3 = df['G3 - max_bm']/(1000*12)
bm4 = df['G4 - max_bm']/(1000*12)

# reaction in girders G1 & G2 in kip. (only A1 taken due to symmetry)
r1 = df['G1-A1-Y']/1000
r2 = df['G2-A1-Y']/1000
r3 = df['G3-A1-Y']/1000
r4 = df['G4-A1-Y']/1000

# line analysis with full railing load assumed to be applied on a girder
bm_line = q_rail * (L - 2*9/12)**2 / 8
r_line = q_rail * L / 2


# normalizing bending moments with respect to line analysis
n_bm1 = bm1 / bm_line
n_bm2 = bm2 / bm_line
n_bm3 = bm3 / bm_line
n_bm4 = bm4 / bm_line

# normalizing vertical reactions with respect to line analysis
n_r1 = r1 / r_line
n_r2 = r2 / r_line
n_r3 = r3 / r_line
n_r4 = r4 / r_line

# add the distribution factors to the dataframe
df['n_bm1'] = n_bm1
df['n_bm2'] = n_bm2
df['n_bm3'] = n_bm3
df['n_bm4'] = n_bm4
df['n_r1'] = n_r1
df['n_r2'] = n_r2
df['n_r3'] = n_r3
df['n_r4'] = n_r4

# %%
# sample data from leve rule
# n_r1 = (w_oh + S) / S

# %%
X = np.stack((L, w_oh, S), axis=-1)
y = n_bm2

# %%
# Learn equations
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# model = PySRRegressor(
#     niterations=30,
#     binary_operators=['+', '-', '*', '/', '^'],
#     unary_operators=["square", "cube", "sqrt"],
#     **default_pysr_params
# )

model = PySRRegressor(
    niterations=50,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    **default_pysr_params
)

model.fit(X, y)

print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# WARNING: using StaticArrays.setindex in module FiniteDiff conflicts with an existing identifier.
# Started!
#
# Expressions evaluated per second: 4.700e+03
# Head worker occupation: 9.6%
# Progress: 14 / 1500 total iterations (0.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.951e-03  1.594e+01  y = 0.3203
# 4           2.096e-03  1.141e-01  y = (square(0.59217) ^ 1.187)
# 5           1.521e-03  3.205e-01  y = sqrt(inv(x₂ + x₁))
# 7           1.410e-03  3.769e-02  y = inv(sqrt(x₂ + (x₁ ^ 1.3337)))
# 9           1.404e-03  2.169e-03  y = sqrt(inv((physics(2.4004, x₂) + x₂) + x₁))
# 11          1.398e-03  2.136e-03  y = sqrt(inv((physics(1.9246, x₂ - x₁) + x₂) + x₁))
# 14          1.168e-03  5.989e-02  y = square(0.59217 + (physics(-0.45884, x₀ * ((0.04672 ^ 0.482...
#                                   46) / x₂)) / -1.7503))
# 15          8.867e-04  2.759e-01  y = square(0.59217 + (physics(-0.45884, square(x₀ * ((0.04672 ...
#                                   ^ 0.48246) / x₂))) / -1.7503))
# 17          7.518e-04  8.247e-02  y = square(0.59217 + (physics(-0.45884, square(x₀ * ((0.04672 ...
#                                   ^ 0.48246) / x₂))) / (-1.7503 * 0.84552)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.900e+04
# Head worker occupation: 3.3%
# Progress: 84 / 1500 total iterations (5.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.410e-03  3.769e-02  y = inv(sqrt(x₂ + (x₁ ^ 1.3337)))
# 8           1.404e-03  4.257e-03  y = sqrt(inv(x₂ + (x₁ / cube(0.90602))))
# 9           1.332e-03  5.327e-02  y = sqrt(inv((x₂ + x₁) + physics(x₂, x₀)))
# 11          9.700e-04  1.584e-01  y = (x₀ / (((x₀ + x₂) / 0.39173) + (x₂ / 0.19911)))
# 12          8.022e-04  1.900e-01  y = (x₀ / (((x₀ + square(x₁)) / 0.39173) + (x₂ / 0.19911)))
# 15          7.469e-04  2.379e-02  y = (x₀ / ((x₀ / 0.39173) + (x₂ * (-1.4959 * (-0.86717 * (x₁ +...
#                                    x₁))))))
# 17          6.660e-04  5.736e-02  y = (x₀ / ((x₀ / 0.39173) + (x₂ * (-1.4959 * (-0.86717 * ((x₁ ...
#                                   + 0.63926) + x₁))))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.530e+04
# Head worker occupation: 2.5%
# Progress: 157 / 1500 total iterations (10.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.404e-03  3.998e-02  y = inv(sqrt(x₂ + (x₁ * 1.3337)))
# 8           1.288e-03  8.647e-02  y = ((x₀ - x₂) / (x₀ / square(-0.57073)))
# 10          1.272e-03  6.028e-03  y = sqrt(inv((x₂ + x₁) + square(physics(x₂, x₀))))
# 11          9.700e-04  2.713e-01  y = (x₀ / (((x₀ + x₂) / 0.39173) + (x₂ / 0.19911)))
# 12          8.022e-04  1.900e-01  y = (x₀ / (((x₀ + square(x₁)) / 0.39173) + (x₂ / 0.19911)))
# 14          7.993e-04  1.820e-03  y = (x₀ / (((x₀ + square(x₁ + 0.17921)) / 0.39173) + (x₂ / 0.1...
#                                   9911)))
# 15          7.469e-04  6.772e-02  y = (x₀ / ((x₀ / 0.39173) + (x₂ * (-1.4959 * (-0.86717 * (x₁ +...
#                                    x₁))))))
# 17          6.660e-04  5.736e-02  y = (x₀ / ((x₀ / 0.39173) + (x₂ * (-1.4959 * (-0.86717 * ((x₁ ...
#                                   + 0.63926) + x₁))))))
# 19          6.654e-04  4.385e-04  y = (x₀ / (((x₀ / 0.39173) + -0.21312) + (x₂ * (-1.4959 * (-0....
#                                   86717 * ((x₁ + 0.63926) + x₁))))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.380e+04
# Head worker occupation: 2.4%
# Progress: 196 / 1500 total iterations (13.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.404e-03  3.998e-02  y = inv(sqrt(x₂ + (x₁ * 1.3337)))
# 8           1.288e-03  8.647e-02  y = ((x₀ - x₂) / (x₀ / square(-0.57073)))
# 10          1.271e-03  6.521e-03  y = ((x₀ - x₂) / ((x₀ - 0.77891) / square(-0.57073)))
# 11          9.700e-04  2.703e-01  y = (x₀ / (((x₀ + x₂) / 0.39173) + (x₂ / 0.19911)))
# 12          8.022e-04  1.900e-01  y = (x₀ / (((x₀ + square(x₁)) / 0.39173) + (x₂ / 0.19911)))
# 14          6.814e-04  8.157e-02  y = (x₀ / ((x₀ / 0.39173) + (x₂ * (cube(-1.4959) * (-0.86717 *...
#                                    x₁)))))
# 17          6.660e-04  7.649e-03  y = (x₀ / ((x₀ / 0.39173) + (x₂ * (-1.4959 * (-0.86717 * ((x₁ ...
#                                   + 0.63926) + x₁))))))
# 19          6.654e-04  4.385e-04  y = (x₀ / (((x₀ / 0.39173) + -0.21312) + (x₂ * (-1.4959 * (-0....
#                                   86717 * ((x₁ + 0.63926) + x₁))))))
# 20          6.634e-04  2.983e-03  y = (x₀ / ((x₀ / 0.39173) + (x₂ * (cube(-1.4959) * (-0.86717 *...
#                                    ((x₂ / (x₀ / 0.58774)) + x₁))))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.810e+04
# Head worker occupation: 2.1%
# Progress: 261 / 1500 total iterations (17.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.259e-03  9.450e-02  y = ((x₀ - x₂) / (x₀ / 0.32804))
# 9           7.191e-04  2.800e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.37701))
# 11          7.148e-04  3.039e-03  y = (x₀ / (((x₀ + (x₂ * x₁)) / 0.37701) - 1.1454))
# 12          7.142e-04  7.918e-04  y = (x₀ / (((x₀ + (x₂ * x₁)) / 0.37701) - cube(1.1454)))
# 13          6.009e-04  1.728e-01  y = (((x₀ - x₂) - x₁) / ((x₀ / 0.39173) + (x₂ * x₁)))
# 17          5.677e-04  1.419e-02  y = (((x₀ - x₂) - (x₂ - square(1.6355))) / ((x₀ / 0.39173) + c...
#                                   ube(x₁ - 0.52513)))
# 20          5.671e-04  3.471e-04  y = (((x₀ - x₂) - (x₂ - ((1.6355 + 0.56571) + 0.51769))) / ((x...
#                                   ₀ / 0.39173) + cube(x₁ - 0.52513)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.890e+04
# Head worker occupation: 1.9%
# Progress: 328 / 1500 total iterations (21.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.221e-03  1.096e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 9           7.082e-04  2.726e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 11          7.001e-04  5.758e-03  y = ((x₀ - 0.3833) / ((x₀ + (x₂ * x₁)) / 0.3833))
# 12          6.756e-04  3.562e-02  y = ((x₀ - (x₂ * sqrt(x₁))) / ((x₀ + x₁) / 0.39173))
# 13          5.363e-04  2.308e-01  y = (((x₀ - (x₂ * (x₁ * 0.45437))) - x₂) / (x₀ / 0.39173))
# 16          5.199e-04  1.035e-02  y = ((x₀ - (square(x₁) + (square(physics(sqrt(x₂), -2.9744)) /...
#                                    0.85253))) / (x₀ / 0.39173))
# 20          5.152e-04  2.279e-03  y = ((x₀ - (square(x₁) + square(physics(sqrt((x₂ + physics(-0....
#                                   88117, x₁)) - -0.1509), -2.9744)))) / (x₀ / 0.39173))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+04
# Head worker occupation: 1.9%
# Progress: 379 / 1500 total iterations (25.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.221e-03  1.096e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 9           7.082e-04  2.726e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.914e-04  2.395e-02  y = ((x₀ - (x₂ + square(x₁))) / (x₀ / 0.37701))
# 12          6.756e-04  1.160e-02  y = ((x₀ - (x₂ * sqrt(x₁))) / ((x₀ + x₁) / 0.39173))
# 13          5.363e-04  2.308e-01  y = (((x₀ - (x₂ * (x₁ * 0.45437))) - x₂) / (x₀ / 0.39173))
# 16          5.164e-04  1.265e-02  y = ((x₀ - (square(x₁) + (square(physics(sqrt(x₂), 3.0188)) / ...
#                                   0.85253))) / (x₀ / 0.39173))
# 20          5.152e-04  5.523e-04  y = ((x₀ - (square(x₁) + square(physics(sqrt((x₂ + physics(-0....
#                                   88117, x₁)) - -0.1509), -2.9744)))) / (x₀ / 0.39173))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.880e+04
# Head worker occupation: 1.9%
# Progress: 449 / 1500 total iterations (29.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.221e-03  1.096e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 9           7.082e-04  2.726e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.914e-04  2.395e-02  y = ((x₀ - (x₂ + square(x₁))) / (x₀ / 0.37701))
# 11          6.734e-04  2.635e-02  y = (x₀ / ((x₀ + (x₂ * (x₁ + 0.46776))) / 0.39173))
# 12          4.983e-04  3.012e-01  y = ((x₀ - (x₂ * sqrt(sqrt(cube(x₁))))) / (x₀ / 0.38955))
# 15          4.895e-04  5.916e-03  y = ((((x₀ - (x₂ * (x₁ * 0.45437))) + 0.7783) - x₂) / (x₀ / 0....
#                                   39173))
# 18          4.887e-04  5.744e-04  y = ((x₀ - ((x₂ * (sqrt(sqrt(square(x₁))) + (0.26364 ^ x₂))) /...
#                                    0.79453)) / (x₀ / 0.39173))
# 20          4.875e-04  1.172e-03  y = ((x₀ - ((x₂ * sqrt(square(sqrt(x₁)) + sqrt(inv(x₂ * x₀))))...
#                                    / 0.79453)) / (x₀ / 0.39173))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.000e+04
# Head worker occupation: 1.8%
# Progress: 517 / 1500 total iterations (34.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.221e-03  1.096e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.74539))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.914e-04  2.395e-02  y = ((x₀ - (x₂ + square(x₁))) / (x₀ / 0.37701))
# 11          6.372e-04  8.158e-02  y = (x₀ / ((x₀ + ((x₂ * x₁) + x₂)) / 0.41125))
# 12          4.983e-04  2.460e-01  y = ((x₀ - (x₂ * sqrt(sqrt(cube(x₁))))) / (x₀ / 0.38955))
# 13          4.905e-04  1.572e-02  y = (((x₀ - (x₂ * (x₁ * 0.39173))) - x₂) / (x₀ / 0.39173))
# 14          4.904e-04  2.902e-04  y = ((x₀ - (x₂ * (sqrt(sqrt(square(x₁))) / 0.79765))) / (x₀ / ...
#                                   0.39173))
# 15          4.825e-04  1.626e-02  y = ((((x₀ - (x₂ * (x₁ * 0.45437))) + 1.4604) - x₂) / (x₀ / 0....
#                                   39173))
# 17          4.807e-04  1.781e-03  y = ((((x₀ - (x₂ * (x₁ * 0.45437))) - -0.98401) - x₂) / ((x₀ /...
#                                    0.39173) - 1.3949))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.910e+04
# Head worker occupation: 1.8%
# Progress: 573 / 1500 total iterations (38.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.653e-03  7.794e-02  y = (inv(x₂) - -0.17195)
# 5           1.521e-03  8.330e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.221e-03  1.096e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.74539))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.914e-04  2.395e-02  y = ((x₀ - (x₂ + square(x₁))) / (x₀ / 0.37701))
# 11          6.372e-04  8.158e-02  y = (x₀ / ((x₀ + ((x₂ * x₁) + x₂)) / 0.41125))
# 12          4.983e-04  2.460e-01  y = ((x₀ - (x₂ * sqrt(sqrt(cube(x₁))))) / (x₀ / 0.38955))
# 13          4.905e-04  1.572e-02  y = (((x₀ - (x₂ * (x₁ * 0.39173))) - x₂) / (x₀ / 0.39173))
# 14          4.904e-04  2.902e-04  y = ((x₀ - (x₂ * (sqrt(sqrt(square(x₁))) / 0.79765))) / (x₀ / ...
#                                   0.39173))
# 15          4.814e-04  1.845e-02  y = ((((x₀ - -1.2011) - (x₂ * (x₁ * 0.45437))) - x₂) / (x₀ / 0...
#                                   .39173))
# 17          4.806e-04  8.245e-04  y = ((((x₀ - (x₂ * (x₁ * 0.45437))) - -0.98401) - x₂) / ((x₀ /...
#                                    0.39173) + -1.0066))
# 18          4.806e-04  8.744e-05  y = ((((x₀ - (x₂ * (x₁ * 0.45437))) - -0.98401) - x₂) / ((x₀ /...
#                                    0.39173) - sqrt(1.3949)))
# 19          4.784e-04  4.474e-03  y = (((x₀ + -2.3012) - ((x₂ * sqrt(sqrt(cube(x₁)))) - x₁)) / (...
#                                   (x₀ / 0.38955) + inv(1.982)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.080e+04
# Head worker occupation: 1.7%
# Progress: 643 / 1500 total iterations (42.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.653e-03  7.794e-02  y = (inv(x₂) - -0.17195)
# 5           1.521e-03  8.330e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.221e-03  1.096e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.74539))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.914e-04  2.395e-02  y = ((x₀ - (x₂ + square(x₁))) / (x₀ / 0.37701))
# 11          6.063e-04  1.314e-01  y = ((x₀ - ((x₂ * x₁) * 0.67386)) / (x₀ / 0.38018))
# 12          4.983e-04  1.962e-01  y = ((x₀ - (x₂ * sqrt(sqrt(cube(x₁))))) / (x₀ / 0.38955))
# 13          4.905e-04  1.572e-02  y = (((x₀ - (x₂ * (x₁ * 0.39173))) - x₂) / (x₀ / 0.39173))
# 14          4.904e-04  2.902e-04  y = ((x₀ - (x₂ * (sqrt(sqrt(square(x₁))) / 0.79765))) / (x₀ / ...
#                                   0.39173))
# 15          4.814e-04  1.845e-02  y = ((((x₀ - -1.2011) - (x₂ * (x₁ * 0.45437))) - x₂) / (x₀ / 0...
#                                   .39173))
# 16          4.783e-04  6.477e-03  y = (((x₀ + -2.3012) - ((x₂ * sqrt(sqrt(cube(x₁)))) - x₁)) / (...
#                                   x₀ / 0.38955))
# 19          4.781e-04  1.353e-04  y = (((x₀ + -2.3012) - ((x₂ * sqrt(sqrt(cube(x₁)))) - x₁)) / (...
#                                   (x₀ / 0.38955) + inv(x₁)))
# 20          4.780e-04  3.282e-04  y = (((x₀ + -2.3012) - ((x₂ * sqrt(sqrt(cube(x₁)))) - x₁)) / (...
#                                   (x₀ / 0.38955) + square(inv(x₁))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.050e+04
# Head worker occupation: 1.7%
# Progress: 706 / 1500 total iterations (47.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.653e-03  7.794e-02  y = (inv(x₂) - -0.17195)
# 5           1.521e-03  8.330e-02  y = sqrt(inv(x₂ + x₁))
# 7           1.221e-03  1.096e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.74539))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.914e-04  2.395e-02  y = ((x₀ - (x₂ + square(x₁))) / (x₀ / 0.37701))
# 11          6.063e-04  1.314e-01  y = ((x₀ - ((x₂ * x₁) * 0.67386)) / (x₀ / 0.38018))
# 12          4.983e-04  1.962e-01  y = ((x₀ - (x₂ * sqrt(sqrt(cube(x₁))))) / (x₀ / 0.38955))
# 13          4.905e-04  1.572e-02  y = (((x₀ - (x₂ * (x₁ * 0.39173))) - x₂) / (x₀ / 0.39173))
# 14          4.904e-04  2.902e-04  y = ((x₀ - (x₂ * (sqrt(sqrt(square(x₁))) / 0.79765))) / (x₀ / ...
#                                   0.39173))
# 15          4.814e-04  1.845e-02  y = ((((x₀ - -1.2011) - (x₂ * (x₁ * 0.45437))) - x₂) / (x₀ / 0...
#                                   .39173))
# 16          4.783e-04  6.477e-03  y = (((x₀ + -2.3012) - ((x₂ * sqrt(sqrt(cube(x₁)))) - x₁)) / (...
#                                   x₀ / 0.38955))
# 19          4.704e-04  5.552e-03  y = ((x₀ - ((x₂ * sqrt(square(1.0064) / physics(-0.67123, x₁))...
#                                   ) - 0.83771)) / ((x₀ / 0.38955) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.760e+04
# Head worker occupation: 1.7%
# Progress: 758 / 1500 total iterations (50.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.653e-03  7.794e-02  y = (inv(x₂) - -0.17195)
# 5           1.521e-03  8.330e-02  y = sqrt(inv(x₂ + x₁))
# 6           1.432e-03  6.020e-02  y = sqrt(physics(0.96328, x₁ + x₂))
# 7           1.221e-03  1.591e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.74539))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.914e-04  2.395e-02  y = ((x₀ - (x₂ + square(x₁))) / (x₀ / 0.37701))
# 11          6.063e-04  1.314e-01  y = ((x₀ - ((x₂ * x₁) * 0.67386)) / (x₀ / 0.38018))
# 12          4.966e-04  1.996e-01  y = ((x₀ - (x₂ * (sqrt(x₁) ^ 1.4927))) / (x₀ / 0.38955))
# 13          4.905e-04  1.233e-02  y = (((x₀ - (x₂ * (x₁ * 0.39173))) - x₂) / (x₀ / 0.39173))
# 14          4.904e-04  2.902e-04  y = ((x₀ - (x₂ * (sqrt(sqrt(square(x₁))) / 0.79765))) / (x₀ / ...
#                                   0.39173))
# 15          4.814e-04  1.845e-02  y = ((((x₀ - -1.2011) - (x₂ * (x₁ * 0.45437))) - x₂) / (x₀ / 0...
#                                   .39173))
# 16          4.783e-04  6.477e-03  y = (((x₀ + -2.3012) - ((x₂ * sqrt(sqrt(cube(x₁)))) - x₁)) / (...
#                                   x₀ / 0.38955))
# 18          4.780e-04  3.609e-04  y = ((((x₀ + x₁) - ((x₂ * sqrt(sqrt(cube(x₁)))) - -1.9679)) - ...
#                                   0.38955) / (x₀ / 0.38955))
# 19          4.704e-04  1.593e-02  y = ((x₀ - ((x₂ * sqrt(square(1.0064) / physics(-0.67123, x₁))...
#                                   ) - 0.83771)) / ((x₀ / 0.38955) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.850e+04
# Head worker occupation: 1.6%
# Progress: 822 / 1500 total iterations (54.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.653e-03  7.794e-02  y = (inv(x₂) - -0.17195)
# 5           1.521e-03  8.330e-02  y = sqrt(inv(x₂ + x₁))
# 6           1.432e-03  6.020e-02  y = sqrt(physics(0.96328, x₁ + x₂))
# 7           1.221e-03  1.591e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.914e-04  2.395e-02  y = ((x₀ - (x₂ + square(x₁))) / (x₀ / 0.37701))
# 11          6.063e-04  1.314e-01  y = ((x₀ - ((x₂ * x₁) * 0.67386)) / (x₀ / 0.38018))
# 12          4.933e-04  2.062e-01  y = ((x₀ - (x₂ * (sqrt(x₁) ^ 1.4494))) / (x₀ / 0.38955))
# 13          4.905e-04  5.694e-03  y = (((x₀ - (x₂ * (x₁ * 0.39173))) - x₂) / (x₀ / 0.39173))
# 14          4.904e-04  2.902e-04  y = ((x₀ - (x₂ * (sqrt(sqrt(square(x₁))) / 0.79765))) / (x₀ / ...
#                                   0.39173))
# 15          4.814e-04  1.845e-02  y = ((((x₀ - -1.2011) - (x₂ * (x₁ * 0.45437))) - x₂) / (x₀ / 0...
#                                   .39173))
# 16          4.783e-04  6.477e-03  y = (((x₀ + -2.3012) - ((x₂ * sqrt(sqrt(cube(x₁)))) - x₁)) / (...
#                                   x₀ / 0.38955))
# 18          4.780e-04  3.609e-04  y = ((((x₀ + x₁) - ((x₂ * sqrt(sqrt(cube(x₁)))) - -1.9679)) - ...
#                                   0.38955) / (x₀ / 0.38955))
# 19          4.690e-04  1.902e-02  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁))) - sqrt...
#                                   (0.83771))) / ((x₀ / 0.38955) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.640e+04
# Head worker occupation: 1.6%
# Progress: 867 / 1500 total iterations (57.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.653e-03  7.794e-02  y = (inv(x₂) - -0.17195)
# 5           1.521e-03  8.330e-02  y = sqrt(inv(x₂ + x₁))
# 6           1.430e-03  6.183e-02  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.914e-04  2.395e-02  y = ((x₀ - (x₂ + square(x₁))) / (x₀ / 0.37701))
# 11          5.704e-04  1.923e-01  y = ((x₀ - ((x₂ * x₁) * 0.70819)) / (x₀ / 0.38018))
# 12          4.933e-04  1.453e-01  y = ((x₀ - (x₂ * (sqrt(x₁) ^ 1.4494))) / (x₀ / 0.38955))
# 13          4.900e-04  6.780e-03  y = ((x₀ - (x₂ * sqrt(x₁ / square(0.78108)))) / (x₀ / 0.38955)...
#                                   )
# 15          4.718e-04  1.887e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 18          4.693e-04  1.812e-03  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁))) - 0.83...
#                                   771)) / ((x₀ / 0.38955) - x₂))
# 19          4.690e-04  6.857e-04  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁))) - sqrt...
#                                   (0.83771))) / ((x₀ / 0.38955) - x₂))
# 20          4.681e-04  1.805e-03  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁ ^ 0.9914)...
#                                   )) - 0.83771)) / ((x₀ / 0.38955) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.440e+04
# Head worker occupation: 1.6%
# Progress: 920 / 1500 total iterations (61.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.653e-03  7.794e-02  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₁ + x₂) ^ -0.51337)
# 6           1.430e-03  3.308e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.261e-04  1.231e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.3625))
# 11          5.704e-04  9.311e-02  y = ((x₀ - ((x₂ * x₁) * 0.70819)) / (x₀ / 0.38018))
# 12          4.933e-04  1.453e-01  y = ((x₀ - (x₂ * (sqrt(x₁) ^ 1.4494))) / (x₀ / 0.38955))
# 13          4.878e-04  1.123e-02  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 15          4.718e-04  1.665e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 18          4.693e-04  1.812e-03  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁))) - 0.83...
#                                   771)) / ((x₀ / 0.38955) - x₂))
# 19          4.690e-04  6.857e-04  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁))) - sqrt...
#                                   (0.83771))) / ((x₀ / 0.38955) - x₂))
# 20          4.681e-04  1.805e-03  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁ ^ 0.9914)...
#                                   )) - 0.83771)) / ((x₀ / 0.38955) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.700e+04
# Head worker occupation: 1.6%
# Progress: 987 / 1500 total iterations (65.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.261e-04  1.231e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.3625))
# 11          5.704e-04  9.311e-02  y = ((x₀ - ((x₂ * x₁) * 0.70819)) / (x₀ / 0.38018))
# 12          4.933e-04  1.453e-01  y = ((x₀ - (x₂ * (sqrt(x₁) ^ 1.4494))) / (x₀ / 0.38955))
# 13          4.878e-04  1.123e-02  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 15          4.718e-04  1.665e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 17          4.695e-04  2.495e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - -0.073307) - squa...
#                                   re(x₁)) / (x₀ / 0.36477))
# 18          4.693e-04  4.458e-04  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁))) - 0.83...
#                                   771)) / ((x₀ / 0.38955) - x₂))
# 19          4.690e-04  6.857e-04  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁))) - sqrt...
#                                   (0.83771))) / ((x₀ / 0.38955) - x₂))
# 20          4.681e-04  1.805e-03  y = ((x₀ - ((x₂ * sqrt(1.0064 / physics(-0.67123, x₁ ^ 0.9914)...
#                                   )) - 0.83771)) / ((x₀ / 0.38955) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.450e+04
# Head worker occupation: 1.6%
# Progress: 1024 / 1500 total iterations (68.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.261e-04  1.231e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.3625))
# 11          5.704e-04  9.311e-02  y = ((x₀ - ((x₂ * x₁) * 0.70819)) / (x₀ / 0.38018))
# 12          4.933e-04  1.453e-01  y = ((x₀ - (x₂ * (sqrt(x₁) ^ 1.4494))) / (x₀ / 0.38955))
# 13          4.878e-04  1.123e-02  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 15          4.718e-04  1.665e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 17          4.621e-04  1.046e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + (x₁ + 0.64326)) - square...
#                                   (x₁)) / (x₀ / 0.36477))
# 20          4.600e-04  1.516e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁)) - -1.4241) - ...
#                                   square(x₁)) / ((x₀ / 0.36477) - -0.42648))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.420e+04
# Head worker occupation: 1.5%
# Progress: 1081 / 1500 total iterations (72.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.261e-04  1.231e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.3625))
# 11          5.704e-04  9.311e-02  y = ((x₀ - ((x₂ * x₁) * 0.70819)) / (x₀ / 0.38018))
# 12          4.933e-04  1.453e-01  y = ((x₀ - (x₂ * (sqrt(x₁) ^ 1.4494))) / (x₀ / 0.38955))
# 13          4.878e-04  1.123e-02  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 15          4.718e-04  1.665e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 17          4.621e-04  1.046e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + (x₁ + 0.64326)) - square...
#                                   (x₁)) / (x₀ / 0.36477))
# 18          4.588e-04  7.166e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁)) - -1.4241) - ...
#                                   square(x₁)) / (x₀ / 0.36477))
# 20          4.586e-04  2.006e-04  y = (((((x₀ - physics(x₂, sqrt(x₀))) + (sqrt(x₁) ^ 1.2724)) - ...
#                                   -1.4241) - square(x₁)) / (x₀ / 0.36477))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.530e+04
# Head worker occupation: 1.5%
# Progress: 1133 / 1500 total iterations (75.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.261e-04  1.231e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.3625))
# 11          5.704e-04  9.311e-02  y = ((x₀ - ((x₂ * x₁) * 0.70819)) / (x₀ / 0.38018))
# 12          4.933e-04  1.453e-01  y = ((x₀ - (x₂ * (sqrt(x₁) ^ 1.4494))) / (x₀ / 0.38955))
# 13          4.878e-04  1.123e-02  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 15          4.718e-04  1.665e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 17          4.621e-04  1.046e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + (x₁ + 0.64326)) - square...
#                                   (x₁)) / (x₀ / 0.36477))
# 18          4.586e-04  7.482e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁)) + 1.4539) - s...
#                                   quare(x₁)) / (x₀ / 0.36477))
# 20          4.586e-04  4.232e-05  y = (((((x₀ - physics(x₂, sqrt(x₀))) + (sqrt(x₁) ^ 1.2724)) - ...
#                                   -1.4241) - square(x₁)) / (x₀ / 0.36477))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.200e+04
# Head worker occupation: 1.5%
# Progress: 1174 / 1500 total iterations (78.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.261e-04  1.231e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.3625))
# 11          5.278e-04  1.707e-01  y = ((x₀ - ((x₂ - x₁) * x₁)) / (x₀ / 0.37524))
# 12          4.883e-04  7.790e-02  y = ((x₀ - ((x₂ * 1.2711) * sqrt(x₁))) / (x₀ / 0.38955))
# 13          4.878e-04  9.901e-04  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 15          4.718e-04  1.665e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 17          4.621e-04  1.046e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + (x₁ + 0.64326)) - square...
#                                   (x₁)) / (x₀ / 0.36477))
# 18          4.586e-04  7.482e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁)) + 1.4539) - s...
#                                   quare(x₁)) / (x₀ / 0.36477))
# 20          4.586e-04  4.232e-05  y = (((((x₀ - physics(x₂, sqrt(x₀))) + (sqrt(x₁) ^ 1.2724)) - ...
#                                   -1.4241) - square(x₁)) / (x₀ / 0.36477))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.270e+04
# Head worker occupation: 1.5%
# Progress: 1224 / 1500 total iterations (81.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.186e-04  1.352e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.36591))
# 11          5.278e-04  1.587e-01  y = ((x₀ - ((x₂ - x₁) * x₁)) / (x₀ / 0.37524))
# 12          4.883e-04  7.790e-02  y = ((x₀ - ((x₂ * 1.2711) * sqrt(x₁))) / (x₀ / 0.38955))
# 13          4.878e-04  9.901e-04  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 15          4.718e-04  1.665e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 17          4.621e-04  1.046e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + (x₁ + 0.64326)) - square...
#                                   (x₁)) / (x₀ / 0.36477))
# 18          4.586e-04  7.482e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁)) + 1.4539) - s...
#                                   quare(x₁)) / (x₀ / 0.36477))
# 20          4.586e-04  4.232e-05  y = (((((x₀ - physics(x₂, sqrt(x₀))) + (sqrt(x₁) ^ 1.2724)) - ...
#                                   -1.4241) - square(x₁)) / (x₀ / 0.36477))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.140e+04
# Head worker occupation: 1.5%
# Progress: 1270 / 1500 total iterations (84.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.186e-04  1.352e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.36591))
# 11          5.278e-04  1.587e-01  y = ((x₀ - ((x₂ - x₁) * x₁)) / (x₀ / 0.37524))
# 12          4.883e-04  7.790e-02  y = ((x₀ - ((x₂ * 1.2711) * sqrt(x₁))) / (x₀ / 0.38955))
# 13          4.878e-04  9.901e-04  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 15          4.718e-04  1.665e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 17          4.621e-04  1.046e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + (x₁ + 0.64326)) - square...
#                                   (x₁)) / (x₀ / 0.36477))
# 18          4.586e-04  7.482e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁)) + 1.4539) - s...
#                                   quare(x₁)) / (x₀ / 0.36477))
# 20          4.586e-04  4.232e-05  y = (((((x₀ - physics(x₂, sqrt(x₀))) + (sqrt(x₁) ^ 1.2724)) - ...
#                                   -1.4241) - square(x₁)) / (x₀ / 0.36477))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.070e+04
# Head worker occupation: 1.5%
# Progress: 1318 / 1500 total iterations (87.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.186e-04  1.352e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.36591))
# 11          5.278e-04  1.587e-01  y = ((x₀ - ((x₂ - x₁) * x₁)) / (x₀ / 0.37524))
# 12          4.883e-04  7.790e-02  y = ((x₀ - ((x₂ * 1.2711) * sqrt(x₁))) / (x₀ / 0.38955))
# 13          4.878e-04  9.901e-04  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 14          4.843e-04  7.114e-03  y = ((x₀ - (x₂ * sqrt(x₁ + (-0.8606 + x₁)))) / (x₀ / 0.38955))
# 15          4.718e-04  2.618e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + x₁) - square(x₁)) / (x₀ ...
#                                   / 0.36477))
# 17          4.621e-04  1.046e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + (x₁ + 0.64326)) - square...
#                                   (x₁)) / (x₀ / 0.36477))
# 18          4.586e-04  7.482e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁)) + 1.4539) - s...
#                                   quare(x₁)) / (x₀ / 0.36477))
# 20          4.586e-04  4.232e-05  y = (((((x₀ - physics(x₂, sqrt(x₀))) + (sqrt(x₁) ^ 1.2724)) - ...
#                                   -1.4241) - square(x₁)) / (x₀ / 0.36477))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.290e+04
# Head worker occupation: 1.5%
# Progress: 1372 / 1500 total iterations (91.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.186e-04  1.352e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.36591))
# 11          5.278e-04  1.587e-01  y = ((x₀ - ((x₂ - x₁) * x₁)) / (x₀ / 0.37524))
# 12          4.883e-04  7.790e-02  y = ((x₀ - ((x₂ * 1.2711) * sqrt(x₁))) / (x₀ / 0.38955))
# 13          4.878e-04  9.901e-04  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 14          4.662e-04  4.531e-02  y = ((x₀ - (x₂ * sqrt(x₁ + x₁))) / ((x₀ / 0.38955) - x₂))
# 16          4.658e-04  3.999e-04  y = ((x₀ - ((x₂ * sqrt(x₁ + x₁)) - -0.37891)) / ((x₀ / 0.38955...
#                                   ) - x₂))
# 17          4.621e-04  8.109e-03  y = ((((x₀ - physics(x₂, sqrt(x₀))) + (x₁ + 0.64326)) - square...
#                                   (x₁)) / (x₀ / 0.36477))
# 18          4.586e-04  7.482e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁)) + 1.4539) - s...
#                                   quare(x₁)) / (x₀ / 0.36477))
# 20          4.585e-04  7.821e-05  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁ + 0.0682)) + 1....
#                                   4539) - square(x₁)) / (x₀ / 0.36477))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.270e+04
# Head worker occupation: 1.5%
# Progress: 1417 / 1500 total iterations (94.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.186e-04  1.352e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.36591))
# 11          5.278e-04  1.587e-01  y = ((x₀ - ((x₂ - x₁) * x₁)) / (x₀ / 0.37524))
# 12          4.883e-04  7.790e-02  y = ((x₀ - ((x₂ * 1.2711) * sqrt(x₁))) / (x₀ / 0.38955))
# 13          4.878e-04  9.901e-04  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 14          4.662e-04  4.531e-02  y = ((x₀ - (x₂ * sqrt(x₁ + x₁))) / ((x₀ / 0.38955) - x₂))
# 16          4.658e-04  3.999e-04  y = ((x₀ - ((x₂ * sqrt(x₁ + x₁)) - -0.37891)) / ((x₀ / 0.38955...
#                                   ) - x₂))
# 17          4.621e-04  8.109e-03  y = ((((x₀ - physics(x₂, sqrt(x₀))) + (x₁ + 0.64326)) - square...
#                                   (x₁)) / (x₀ / 0.36477))
# 18          4.586e-04  7.482e-03  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁)) + 1.4539) - s...
#                                   quare(x₁)) / (x₀ / 0.36477))
# 20          4.585e-04  7.821e-05  y = (((((x₀ - physics(x₂, sqrt(x₀))) + sqrt(x₁ + 0.0682)) + 1....
#                                   4539) - square(x₁)) / (x₀ / 0.36477))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.300e+04
# Head worker occupation: 1.5%
# Progress: 1473 / 1500 total iterations (98.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.653e-03  1.359e-01  y = (inv(x₂) - -0.17195)
# 5           1.434e-03  1.418e-01  y = ((x₂ + x₁) ^ -0.51313)
# 6           1.430e-03  3.288e-03  y = sqrt(physics(0.96834, x₂ + x₁))
# 7           1.221e-03  1.575e-01  y = ((x₀ - x₂) / (x₀ / 0.33507))
# 8           8.802e-04  3.276e-01  y = cube(x₀ / ((x₀ + x₂) / 0.7454))
# 9           7.082e-04  2.175e-01  y = (x₀ / ((x₀ + (x₂ * x₁)) / 0.3833))
# 10          6.186e-04  1.352e-01  y = ((x₀ - (x₂ * sqrt(x₁))) / (x₀ / 0.36591))
# 11          5.278e-04  1.587e-01  y = ((x₀ - ((x₂ - x₁) * x₁)) / (x₀ / 0.37524))
# 12          4.883e-04  7.790e-02  y = ((x₀ - ((x₂ * 1.2711) * sqrt(x₁))) / (x₀ / 0.38955))
# 13          4.878e-04  9.901e-04  y = ((x₀ - (x₂ * sqrt(x₁ / sqrt(0.39173)))) / (x₀ / 0.38955))
# 14          4.662e-04  4.531e-02  y = ((x₀ - (x₂ * sqrt(x₁ + x₁))) / ((x₀ / 0.38955) - x₂))
# 16          4.651e-04  1.182e-03  y = ((x₀ - (x₂ * sqrt(x₁ + x₁))) / (((x₀ / 0.38955) - -0.60649...
#                                   ) - x₂))
# 17          4.568e-04  1.810e-02  y = ((((x₀ - physics(x₂, sqrt(x₀))) + 0.52909) - square(x₁)) /...
#                                    ((x₀ / 0.36477) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          0.2909311
# 	1         0.048946                                 (x2 ^ -0.57741714)
# 	2         0.135933                            (inv(x2) - -0.17195228)
# 	3         0.141841                           ((x2 + x1) ^ -0.5131328)
# 	4         0.003288                  sqrt(physics(0.9683394, x2 + x1))
# 	5         0.157469                    ((x0 - x2) / (x0 / 0.33506727))
# 	6         0.327591                 cube(x0 / ((x0 + x2) / 0.7454021))
# 	7         0.219836              (x0 / ((x0 + (x2 * x1)) / 0.3816281))
# 	8         0.132861       ((x0 - (x2 * sqrt(x1))) / (x0 / 0.36591077))
# 	9   >>>>  0.158678      ((x0 - ((x2 - x1) * x1)) / (x0 / 0.37524402))
# 	10        0.077899  ((x0 - ((x2 * 1.271072) * sqrt(x1))) / (x0 / 0...
# 	11        0.000990  ((x0 - (x2 * sqrt(x1 / sqrt(0.39172533)))) / (...
# 	12        0.045312  ((x0 - (x2 * sqrt(x1 + x1))) / ((x0 / 0.389554...
# 	13        0.001182  ((x0 - (x2 * sqrt(x1 + x1))) / (((x0 / 0.38955...
# 	14        0.018098  ((((x0 - physics(x2, sqrt(x0))) + 0.529094) - ...
# 	15        0.001349  ((((x0 - physics(x2, sqrt(x0 - x1))) + x1) - s...
#
# 	        loss  complexity
# 	0   0.002088           1
# 	1   0.001894           3
# 	2   0.001653           4
# 	3   0.001434           5
# 	4   0.001430           6
# 	5   0.001221           7
# 	6   0.000880           8
# 	7   0.000707           9
# 	8   0.000619          10
# 	9   0.000528          11
# 	10  0.000488          12
# 	11  0.000488          13
# 	12  0.000466          14
# 	13  0.000465          16
# 	14  0.000457          17
# 	15  0.000455          20
# ]

# %%
model.sympy()
# Out:
# 0.37524402*(x0 - x1*(-x1 + x2))/x0

# %%
n_bm2_pred = model.predict(X)
ypredict_simpler = model.predict(X, 2)

print("Default selection MSE:", np.power(n_bm2_pred - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 0.1596117656019573
# Manual selection MSE for index 2: 0.155651053727596

# %%
x_line = [0, 0.5]
y_line = [0, 0.5]

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_bm2, y=n_bm2_pred, marker='o', c='none', edgecolor='b', label='Interior Girder')
ax1.plot(x_line, y_line, c = "k")
ax1.set_title('Accuracy')
ax1.legend()
plt.xlim((0,0.5))
plt.ylim((0,0.5))
ax1.set_xlabel('Target $n_{bm2}$')
ax1.set_ylabel('Predicted $n_{bm2}$')
ax1.grid()

# %%
model.latex()
# Out:
# '\\frac{0.375 \\left(x_{0} - x_{1} \\left(- x_{1} + x_{2}\\right)\\right)}{x_{0}}'

# %% [markdown]
# The following expression best suits the data for $n_{bm2}$
#
# $\frac{0.375 \left(L - w_{oh} \left(- w_{oh} + S\right)\right)}{L}$

# %%
X = np.stack((L, w_oh, S), axis=-1)
y = n_bm1

# %%
# Learn equations
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# model = PySRRegressor(
#     niterations=30,
#     binary_operators=['+', '-', '*', '/', '^'],
#     unary_operators=["square", "cube", "sqrt"],
#     **default_pysr_params
# )

model1 = PySRRegressor(
    niterations=50,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    **default_pysr_params
)

model1.fit(X, y)

print(model1)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 3.980e+03
# Head worker occupation: 0.2%
# Progress: 9 / 1500 total iterations (0.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.216e-02  1.594e+01  y = 0.56201
# 2           1.915e-02  1.462e-01  y = sqrt(0.56201)
# 5           1.182e-02  1.609e-01  y = (0.43862 ^ (0.43862 / 0.86458))
# 8           1.179e-02  6.846e-04  y = ((0.9967 + -0.32363) / square(sqrt(square(1.0089))))
# 9           1.165e-02  1.258e-02  y = (((sqrt(x₁) ^ inv(x₀)) + -0.32363) / 1.0089)
# 10          6.842e-03  5.319e-01  y = sqrt(sqrt(inv(inv(sqrt(x₂))) + -0.19604) + -1.1998)
# 16          5.679e-03  3.105e-02  y = sqrt(x₁ / sqrt(sqrt(square((x₂ * 1.2612) / physics(x₂, x₀)...
#                                   ) * square(x₁))))
# 18          5.371e-03  2.788e-02  y = sqrt(x₁ / sqrt(sqrt(square((x₂ * 1.2612) / physics(x₂, x₀)...
#                                   ) * square(x₁)) + 1.1501))
# 20          4.889e-03  4.704e-02  y = sqrt(x₁ / sqrt(sqrt(square((x₂ * 1.3683) / physics(x₂, x₀ ...
#                                   - (0.90887 - x₂))) * square(x₁))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.320e+04
# Head worker occupation: 0.4%
# Progress: 65 / 1500 total iterations (4.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 5           1.003e-02  5.385e-02  y = physics(0.76532, 0.97984 ^ x₂)
# 7           5.270e-03  3.217e-01  y = sqrt(0.44509 ^ (sqrt(x₀) / x₂))
# 9           5.257e-03  1.228e-03  y = sqrt(sqrt(physics(-0.41031, square(sqrt(x₀) / x₂))))
# 11          5.164e-03  8.943e-03  y = sqrt(sqrt(physics(-0.46554, square((sqrt(x₀) + 0.8388) / x...
#                                   ₂))))
# 12          4.671e-03  1.004e-01  y = sqrt(sqrt(sqrt(x₁) / sqrt(square(x₂ / physics(x₂, x₀)))))
# 14          4.044e-03  7.208e-02  y = sqrt(sqrt(physics(0.55365 / -1.4548, physics(sqrt(x₀ / 0.5...
#                                   4851) / x₂, x₁))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.400e+04
# Head worker occupation: 0.7%
# Progress: 96 / 1500 total iterations (6.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 4           1.101e-02  3.394e-02  y = sqrt(x₀ ^ -0.20874)
# 5           1.003e-02  9.367e-02  y = physics(0.76532, 0.97984 ^ x₂)
# 7           5.270e-03  3.217e-01  y = sqrt(0.44509 ^ (sqrt(x₀) / x₂))
# 8           5.257e-03  2.455e-03  y = sqrt(sqrt(physics(-0.41031, x₀ / square(x₂))))
# 11          5.164e-03  5.962e-03  y = sqrt(sqrt(physics(-0.46554, square((sqrt(x₀) + 0.8388) / x...
#                                   ₂))))
# 12          4.671e-03  1.004e-01  y = sqrt(sqrt(sqrt(x₁) / sqrt(square(x₂ / physics(x₂, x₀)))))
# 14          4.044e-03  7.208e-02  y = sqrt(sqrt(physics(0.55365 / -1.4548, physics(sqrt(x₀ / 0.5...
#                                   4851) / x₂, x₁))))
# 16          3.932e-03  1.393e-02  y = sqrt(sqrt(physics(0.55365 / -1.4548, physics(sqrt((x₀ / 0....
#                                   54851) + x₁) / x₂, x₁))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.560e+04
# Head worker occupation: 0.7%
# Progress: 138 / 1500 total iterations (9.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 4           1.101e-02  3.394e-02  y = sqrt(x₀ ^ -0.20874)
# 5           1.003e-02  9.367e-02  y = physics(0.76532, 0.97984 ^ x₂)
# 7           5.258e-03  3.228e-01  y = sqrt(0.44048 ^ (sqrt(x₀) / x₂))
# 8           5.257e-03  2.043e-04  y = sqrt(sqrt(physics(-0.41031, x₀ / square(x₂))))
# 10          3.817e-03  1.600e-01  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 19          3.811e-03  1.706e-04  y = sqrt(sqrt(physics((0.55365 * -0.85286) / -1.4548, physics(...
#                                   sqrt((x₀ / sqrt(0.54851)) + x₂) / x₂, x₁))))
# 20          3.705e-03  2.834e-02  y = sqrt(physics(0.55365, sqrt(physics(sqrt((x₀ - (x₁ / x₂)) /...
#                                    0.62486) / x₂, square(sqrt(x₁)) + 0.59546))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.770e+04
# Head worker occupation: 0.7%
# Progress: 177 / 1500 total iterations (11.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 4           1.101e-02  3.394e-02  y = sqrt(x₀ ^ -0.20874)
# 5           1.003e-02  9.367e-02  y = physics(0.76532, 0.97984 ^ x₂)
# 7           5.258e-03  3.228e-01  y = sqrt(0.44048 ^ (sqrt(x₀) / x₂))
# 8           5.161e-03  1.855e-02  y = sqrt(sqrt(physics(0.42245, x₀ / square(x₂))))
# 9           5.111e-03  9.893e-03  y = sqrt(0.4025 / (sqrt(x₀) / (x₂ + 0.45376)))
# 10          3.817e-03  2.918e-01  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 13          3.802e-03  1.280e-03  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / (x₂ + x₁), ...
#                                   sqrt(x₁)))))
# 14          3.787e-03  4.154e-03  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁ - (-...
#                                   0.12101 / x₁)))))
# 16          3.707e-03  1.068e-02  y = sqrt(physics(0.55365, sqrt(physics(sqrt(x₀ / 0.62486) / x₂...
#                                   , square(sqrt(x₁)) + 0.59546))))
# 20          3.705e-03  1.313e-04  y = sqrt(physics(0.55365, sqrt(physics(sqrt((x₀ - (x₁ / x₂)) /...
#                                    0.62486) / x₂, square(sqrt(x₁)) + 0.59546))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.850e+04
# Head worker occupation: 0.8%
# Progress: 212 / 1500 total iterations (14.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 4           1.101e-02  3.394e-02  y = sqrt(x₀ ^ -0.20874)
# 5           1.003e-02  9.367e-02  y = physics(0.76532, 0.97984 ^ x₂)
# 7           5.258e-03  3.228e-01  y = sqrt(0.44048 ^ (sqrt(x₀) / x₂))
# 8           5.161e-03  1.855e-02  y = sqrt(sqrt(physics(0.42245, x₀ / square(x₂))))
# 9           5.111e-03  9.893e-03  y = sqrt(0.4025 / (sqrt(x₀) / (x₂ + 0.45376)))
# 10          3.817e-03  2.918e-01  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 12          3.817e-03  3.088e-05  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀ + -0.13946) / ...
#                                   x₂, x₁))))
# 13          3.730e-03  2.294e-02  y = sqrt(physics(-0.51285, sqrt(physics(sqrt(x₀) / (x₂ + x₁), ...
#                                   sqrt(x₁)))))
# 15          3.617e-03  1.545e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.060e+04
# Head worker occupation: 0.8%
# Progress: 276 / 1500 total iterations (18.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 4           1.101e-02  3.394e-02  y = sqrt(x₀ ^ -0.20874)
# 5           1.003e-02  9.367e-02  y = physics(0.76532, 0.97984 ^ x₂)
# 6           6.769e-03  3.931e-01  y = (sqrt(0.34167 * x₂) * 0.38351)
# 7           5.161e-03  2.712e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           5.030e-03  1.293e-02  y = sqrt(0.41481 / (sqrt(x₀ - x₁) / x₂))
# 10          3.817e-03  2.759e-01  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 12          3.817e-03  3.088e-05  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀ + -0.13946) / ...
#                                   x₂, x₁))))
# 13          3.730e-03  2.294e-02  y = sqrt(physics(-0.51285, sqrt(physics(sqrt(x₀) / (x₂ + x₁), ...
#                                   sqrt(x₁)))))
# 15          3.617e-03  1.545e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.170e+04
# Head worker occupation: 0.8%
# Progress: 320 / 1500 total iterations (21.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 4           1.101e-02  3.394e-02  y = sqrt(x₀ ^ -0.20874)
# 5           7.111e-03  4.374e-01  y = (0.76069 - (0.76069 ^ x₂))
# 6           6.769e-03  4.934e-02  y = (sqrt(0.34167 * x₂) * 0.38351)
# 7           5.161e-03  2.712e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           5.030e-03  1.293e-02  y = sqrt(0.41481 / (sqrt(x₀ - x₁) / x₂))
# 10          3.817e-03  2.759e-01  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 12          3.788e-03  3.837e-03  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁) ^ 0...
#                                   .96348)))
# 13          3.704e-03  2.233e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   sqrt(0.82124)))
# 15          3.617e-03  1.195e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.130e+04
# Head worker occupation: 0.8%
# Progress: 361 / 1500 total iterations (24.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           9.080e-03  1.463e-01  y = (0.76069 - inv(x₂))
# 5           7.111e-03  2.443e-01  y = (0.76069 - (0.76069 ^ x₂))
# 6           6.769e-03  4.934e-02  y = (sqrt(0.34167 * x₂) * 0.38351)
# 7           5.161e-03  2.712e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           5.030e-03  1.293e-02  y = sqrt(0.41481 / (sqrt(x₀ - x₁) / x₂))
# 10          3.817e-03  2.759e-01  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 12          3.788e-03  3.837e-03  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁) ^ 0...
#                                   .96348)))
# 13          3.704e-03  2.233e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   sqrt(0.82124)))
# 15          3.617e-03  1.195e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.323e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.380e+04
# Head worker occupation: 0.8%
# Progress: 411 / 1500 total iterations (27.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 6           6.768e-03  4.855e-05  y = sqrt(0.050254 * (x₂ + 0.050254))
# 7           5.161e-03  2.711e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           5.030e-03  1.293e-02  y = sqrt(0.41481 / (sqrt(x₀ - x₁) / x₂))
# 10          3.817e-03  2.759e-01  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 12          3.788e-03  3.837e-03  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁) ^ 0...
#                                   .96348)))
# 13          3.704e-03  2.233e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   sqrt(0.82124)))
# 15          3.617e-03  1.195e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.323e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁)) ^ 1.6416)))
# 20          3.615e-03  0.000e+00  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ - cube(-...
#                                   0.52155)) - (x₂ - -0.64579)) / x₂, x₁)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.140e+04
# Head worker occupation: 0.8%
# Progress: 442 / 1500 total iterations (29.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 6           6.768e-03  4.855e-05  y = sqrt(0.050254 * (x₂ + 0.050254))
# 7           5.161e-03  2.711e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           4.187e-03  1.047e-01  y = sqrt(physics(-0.58624, sqrt(x₀) / (x₁ + x₂)))
# 10          3.817e-03  9.240e-02  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 12          3.788e-03  3.837e-03  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁) ^ 0...
#                                   .96348)))
# 13          3.704e-03  2.233e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   sqrt(0.82124)))
# 15          3.617e-03  1.195e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.323e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁)) ^ 1.6416)))
# 19          3.615e-03  0.000e+00  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - inv(inv...
#                                   (x₂ + 0.52664))) / x₂, x₁)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.920e+04
# Head worker occupation: 0.8%
# Progress: 481 / 1500 total iterations (32.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 6           6.768e-03  4.855e-05  y = sqrt(0.050254 * (x₂ + 0.050254))
# 7           5.161e-03  2.711e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 12          3.788e-03  2.558e-03  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁) ^ 0...
#                                   .96348)))
# 13          3.704e-03  2.233e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   sqrt(0.82124)))
# 14          3.697e-03  2.087e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) + -0.77796) ...
#                                   / x₂, x₁)) ^ 0.82124))
# 15          3.617e-03  2.181e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.323e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁)) ^ 1.6416)))
# 19          3.615e-03  0.000e+00  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - inv(inv...
#                                   (x₂ + 0.52664))) / x₂, x₁)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.110e+04
# Head worker occupation: 0.8%
# Progress: 531 / 1500 total iterations (35.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 6           6.768e-03  4.855e-05  y = sqrt(0.050254 * (x₂ + 0.050254))
# 7           5.161e-03  2.711e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 12          3.788e-03  2.558e-03  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁) ^ 0...
#                                   .96348)))
# 13          3.704e-03  2.233e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   sqrt(0.82124)))
# 14          3.697e-03  2.087e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) + -0.77796) ...
#                                   / x₂, x₁)) ^ 0.82124))
# 15          3.617e-03  2.181e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.323e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁)) ^ 1.6416)))
# 19          3.592e-03  3.213e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ ^ 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.990e+04
# Head worker occupation: 0.9%
# Progress: 569 / 1500 total iterations (37.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 7           5.161e-03  1.340e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 12          3.704e-03  1.005e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.90661))
# 14          3.674e-03  3.978e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.90661))
# 15          3.617e-03  1.580e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.323e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁)) ^ 1.6416)))
# 18          3.614e-03  2.567e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.592e-03  6.169e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ ^ 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.110e+04
# Head worker occupation: 0.9%
# Progress: 618 / 1500 total iterations (41.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 7           5.161e-03  1.340e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 11          3.815e-03  3.082e-04  y = sqrt(physics(-0.51923, sqrt((x₀ / x₁) + 0.088344) / x₂))
# 12          3.704e-03  2.952e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.90661))
# 13          3.698e-03  1.506e-03  y = sqrt(physics(physics(0.76746, -1.0986), physics(sqrt(x₀) /...
#                                    x₂, x₁) ^ 0.45402))
# 14          3.674e-03  6.450e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.90661))
# 15          3.617e-03  1.580e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.592e-03  6.169e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ ^ 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.320e+04
# Head worker occupation: 0.9%
# Progress: 669 / 1500 total iterations (44.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 6           5.848e-03  1.432e-01  y = cube(x₀ ^ (-0.2862 / x₂))
# 7           5.161e-03  1.249e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 11          3.815e-03  3.082e-04  y = sqrt(physics(-0.51923, sqrt((x₀ / x₁) + 0.088344) / x₂))
# 12          3.704e-03  2.952e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.90661))
# 13          3.698e-03  1.506e-03  y = sqrt(physics(physics(0.76746, -1.0986), physics(sqrt(x₀) /...
#                                    x₂, x₁) ^ 0.45402))
# 14          3.674e-03  6.450e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.90661))
# 15          3.617e-03  1.580e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.592e-03  6.169e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ ^ 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.200e+04
# Head worker occupation: 0.9%
# Progress: 708 / 1500 total iterations (47.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 6           5.848e-03  1.432e-01  y = cube(x₀ ^ (-0.2862 / x₂))
# 7           5.161e-03  1.249e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 11          3.809e-03  1.096e-03  y = sqrt(physics(-0.51923, sqrt(x₀ / (x₁ + 0.056866)) / x₂))
# 12          3.704e-03  2.795e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.90661))
# 13          3.698e-03  1.506e-03  y = sqrt(physics(physics(0.76746, -1.0986), physics(sqrt(x₀) /...
#                                    x₂, x₁) ^ 0.45402))
# 14          3.674e-03  6.450e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.90661))
# 15          3.617e-03  1.580e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.589e-03  7.008e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.220e+04
# Head worker occupation: 0.9%
# Progress: 757 / 1500 total iterations (50.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 2           1.179e-02  0.000e+00  y = sqrt(0.44072)
# 3           1.051e-02  1.147e-01  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 6           5.848e-03  1.432e-01  y = cube(x₀ ^ (-0.2862 / x₂))
# 7           5.161e-03  1.249e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 11          3.809e-03  1.096e-03  y = sqrt(physics(-0.51923, sqrt(x₀ / (x₁ + 0.056866)) / x₂))
# 12          3.694e-03  3.059e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.674e-03  2.654e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.90661))
# 15          3.617e-03  1.580e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.589e-03  7.008e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.200e+04
# Head worker occupation: 0.9%
# Progress: 799 / 1500 total iterations (53.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 6           5.848e-03  1.432e-01  y = cube(x₀ ^ (-0.2862 / x₂))
# 7           5.161e-03  1.249e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.809e-03  2.192e-03  y = sqrt(physics(-0.51923, sqrt(x₀ / (x₁ + 0.056866)) / x₂))
# 12          3.694e-03  3.059e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.674e-03  2.654e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.90661))
# 15          3.617e-03  1.580e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.589e-03  7.008e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.030e+04
# Head worker occupation: 0.9%
# Progress: 837 / 1500 total iterations (55.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 6           5.848e-03  1.432e-01  y = cube(x₀ ^ (-0.2862 / x₂))
# 7           5.161e-03  1.249e-01  y = sqrt(0.42268 / (sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.809e-03  2.192e-03  y = sqrt(physics(-0.51923, sqrt(x₀ / (x₁ + 0.056866)) / x₂))
# 12          3.694e-03  3.059e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.674e-03  2.654e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.90661))
# 15          3.617e-03  1.580e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.589e-03  7.008e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.210e+04
# Head worker occupation: 0.9%
# Progress: 887 / 1500 total iterations (59.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 6           5.848e-03  1.432e-01  y = cube(x₀ ^ (-0.2862 / x₂))
# 7           5.161e-03  1.249e-01  y = sqrt(physics(-0.65006, sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.809e-03  2.192e-03  y = sqrt(physics(-0.51923, sqrt(x₀ / (x₁ + 0.056866)) / x₂))
# 12          3.694e-03  3.059e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.674e-03  2.654e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.90661))
# 15          3.617e-03  1.580e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.589e-03  7.008e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.080e+04
# Head worker occupation: 0.9%
# Progress: 927 / 1500 total iterations (61.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096317)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 6           5.848e-03  1.432e-01  y = cube(x₀ ^ (-0.2862 / x₂))
# 7           5.161e-03  1.249e-01  y = sqrt(physics(-0.65006, sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.809e-03  2.192e-03  y = sqrt(physics(-0.51923, sqrt(x₀ / (x₁ + 0.056866)) / x₂))
# 12          3.694e-03  3.059e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.665e-03  3.865e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.589e-03  7.008e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.010e+04
# Head worker occupation: 0.9%
# Progress: 975 / 1500 total iterations (65.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096306)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 6           5.689e-03  1.708e-01  y = cube(x₀ ^ (-0.27339 / x₂))
# 7           5.161e-03  9.731e-02  y = sqrt(physics(-0.65006, sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.809e-03  2.192e-03  y = sqrt(physics(-0.51923, sqrt(x₀ / (x₁ + 0.056866)) / x₂))
# 12          3.694e-03  3.059e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.665e-03  3.865e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.589e-03  7.008e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.150e+04
# Head worker occupation: 0.9%
# Progress: 1020 / 1500 total iterations (68.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096306)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           6.748e-03  3.054e-03  y = (0.96453 + (-2.527 / x₂))
# 6           5.689e-03  1.708e-01  y = cube(x₀ ^ (-0.27339 / x₂))
# 7           5.161e-03  9.731e-02  y = sqrt(physics(-0.65006, sqrt(x₀) / x₂))
# 9           3.817e-03  1.509e-01  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.809e-03  2.192e-03  y = sqrt(physics(-0.51923, sqrt(x₀ / (x₁ + 0.056866)) / x₂))
# 12          3.694e-03  3.059e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.665e-03  3.865e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.614e-03  2.566e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, inv(x₀) + x₁)) ^ 1.6416)))
# 19          3.589e-03  7.008e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.2601))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.980e+04
# Head worker occupation: 1.0%
# Progress: 1056 / 1500 total iterations (70.400%)
# ====================================================================================================
# Hall of Fame:
# ...
# 7           4.324e-03  2.743e-01  y = ((x₀ / x₁) ^ (-1.0295 / x₂))
# 9           3.817e-03  6.237e-02  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.745e-03  1.893e-02  y = sqrt(physics(-0.49446, sqrt(x₀ / x₁) / (x₂ - -0.87029)))
# 12          3.694e-03  1.385e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.665e-03  3.865e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.611e-03  1.132e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((inv(-0.0797...
#                                   66) + x₁) + x₀) / x₂, x₁) ^ 1.6416))))
# 19          3.589e-03  6.161e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.25496))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.690e+04
# Head worker occupation: 0.9%
# Progress: 1323 / 1500 total iterations (88.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096306)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 7           4.324e-03  1.372e-01  y = ((x₀ / x₁) ^ (-1.0295 / x₂))
# 9           3.817e-03  6.237e-02  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.745e-03  1.893e-02  y = sqrt(physics(-0.49446, sqrt(x₀ / x₁) / (x₂ - -0.87029)))
# 12          3.694e-03  1.385e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.665e-03  3.865e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.611e-03  1.132e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((inv(-0.0797...
#                                   66) + x₁) + x₀) / x₂, x₁) ^ 1.6416))))
# 19          3.589e-03  6.161e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.25496))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.530e+04
# Head worker occupation: 1.0%
# Progress: 1355 / 1500 total iterations (90.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096306)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 7           4.317e-03  1.380e-01  y = ((x₀ / x₁) ^ (-1.0396 / x₂))
# 9           3.817e-03  6.154e-02  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.745e-03  1.893e-02  y = sqrt(physics(-0.49446, sqrt(x₀ / x₁) / (x₂ - -0.87029)))
# 12          3.694e-03  1.385e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.665e-03  3.865e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.611e-03  1.132e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((inv(-0.0797...
#                                   66) + x₁) + x₀) / x₂, x₁) ^ 1.6416))))
# 19          3.589e-03  6.161e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.25496))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.540e+04
# Head worker occupation: 1.0%
# Progress: 1391 / 1500 total iterations (92.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096306)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 7           4.317e-03  1.380e-01  y = ((x₀ / x₁) ^ (-1.0396 / x₂))
# 9           3.817e-03  6.154e-02  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.745e-03  1.893e-02  y = sqrt(physics(-0.49446, sqrt(x₀ / x₁) / (x₂ - -0.87029)))
# 12          3.694e-03  1.385e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.665e-03  3.865e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.611e-03  1.132e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((inv(-0.0797...
#                                   66) + x₁) + x₀) / x₂, x₁) ^ 1.6416))))
# 19          3.589e-03  6.161e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.25496))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.630e+04
# Head worker occupation: 1.0%
# Progress: 1429 / 1500 total iterations (95.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096306)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 7           4.317e-03  1.380e-01  y = ((x₀ / x₁) ^ (-1.0396 / x₂))
# 9           3.817e-03  6.154e-02  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.743e-03  1.963e-02  y = sqrt(physics(-0.49446, sqrt(x₀ / x₁) / (x₂ - -0.89751)))
# 12          3.694e-03  1.315e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.665e-03  3.865e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.611e-03  1.132e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((inv(-0.0797...
#                                   66) + x₁) + x₀) / x₂, x₁) ^ 1.6416))))
# 19          3.589e-03  6.161e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.25496))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.530e+04
# Head worker occupation: 1.0%
# Progress: 1454 / 1500 total iterations (96.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096306)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 7           4.317e-03  1.380e-01  y = ((x₀ / x₁) ^ (-1.0396 / x₂))
# 9           3.817e-03  6.154e-02  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.743e-03  1.963e-02  y = sqrt(physics(-0.49446, sqrt(x₀ / x₁) / (x₂ - -0.89751)))
# 12          3.694e-03  1.315e-02  y = sqrt(physics(-0.52883, sqrt(physics(sqrt(x₀) / x₂, x₁)) ^ ...
#                                   0.92091))
# 14          3.665e-03  3.865e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.611e-03  1.132e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((inv(-0.0797...
#                                   66) + x₁) + x₀) / x₂, x₁) ^ 1.6416))))
# 19          3.589e-03  6.161e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.25496))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.560e+04
# Head worker occupation: 1.0%
# Progress: 1494 / 1500 total iterations (99.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096306)
# 4           6.769e-03  4.400e-01  y = sqrt(0.050254 * x₂)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 7           4.317e-03  1.380e-01  y = ((x₀ / x₁) ^ (-1.0396 / x₂))
# 9           3.817e-03  6.154e-02  y = sqrt(physics(-0.51923, sqrt(x₀ / x₁) / x₂))
# 10          3.817e-03  0.000e+00  y = sqrt(physics(-0.51923, sqrt(physics(sqrt(x₀) / x₂, x₁))))
# 11          3.680e-03  3.654e-02  y = (sqrt(physics(-0.46012, sqrt(x₀ / x₁) / x₂)) - -0.077156)
# 14          3.665e-03  1.324e-03  y = sqrt(physics(-0.52883, sqrt(physics((sqrt(x₀) - 0.19657) /...
#                                    x₂, x₁)) ^ 0.88324))
# 15          3.617e-03  1.338e-02  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - x₂) / x...
#                                   ₂, x₁)) ^ 1.6416)))
# 17          3.615e-03  2.324e-04  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((x₀ + -0.528...
#                                   83) - x₂) / x₂, x₁) ^ 1.6416))))
# 18          3.611e-03  1.132e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt((inv(-0.0797...
#                                   66) + x₁) + x₀) / x₂, x₁) ^ 1.6416))))
# 19          3.589e-03  6.161e-03  y = sqrt(physics(-0.52883, sqrt(sqrt(physics(sqrt(x₀ - square(...
#                                   inv(0.25496))) / x₂, x₁ * 0.90152)) ^ 1.6416)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                          0.6638675
# 	1         5.732884e-02                                 (x0 ^ -0.09630615)
# 	2         4.399630e-01                             sqrt(0.050253835 * x2)
# 	3         1.738434e-01                            (x0 ^ (-0.820299 / x2))
# 	4   >>>>  1.379837e-01                    ((x0 / x1) ^ (-1.0396062 / x2))
# 	5         6.153670e-02      sqrt(physics(-0.5192339, sqrt(x0 / x1) / x2))
# 	6         5.239646e-08  sqrt(physics(-0.5192314, sqrt(physics(sqrt(x0)...
# 	7         3.654293e-02  (sqrt(physics(-0.46011603, sqrt(x0 / x1) / x2)...
# 	8         1.324273e-03  sqrt(physics(-0.5288344, sqrt(physics((sqrt(x0...
# 	9         1.338065e-02  sqrt(physics(-0.5288344, sqrt(sqrt(physics(sqr...
# 	10        2.324159e-04  sqrt(physics(-0.5288344, sqrt(sqrt(physics(sqr...
# 	11        1.131871e-03  sqrt(physics(-0.5288344, sqrt(sqrt(physics(sqr...
# 	12        6.161672e-03  sqrt(physics(-0.5288344, sqrt(sqrt(physics(sqr...
#
# 	        loss  complexity
# 	0   0.011787           1
# 	1   0.010510           3
# 	2   0.006769           4
# 	3   0.005689           5
# 	4   0.004317           7
# 	5   0.003817           9
# 	6   0.003817          10
# 	7   0.003680          11
# 	8   0.003665          14
# 	9   0.003617          15
# 	10  0.003615          17
# 	11  0.003611          18
# 	12  0.003589          19
# ]

# %%
model1.sympy()
# Out:
# (x0/x1)**(-1.0396062/x2)

# %%
n_bm1_pred = model1.predict(X)
ypredict_simpler = model1.predict(X, 2)

print("Default selection MSE:", np.power(n_bm1_pred - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 0.0043169609843600465
# Manual selection MSE for index 2: 0.00676906220853474

# %%
x_line = [0, 0.5]
y_line = [0, 0.5]

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_bm2, y=n_bm2_pred, marker='o', c='none', edgecolor='r', label='Exterior Girder')
ax1.plot(x_line, y_line, c = "k")
ax1.set_title('Accuracy')
ax1.legend()
plt.xlim((0,0.5))
plt.ylim((0,0.5))
ax1.set_xlabel('Target $n_{bm1}$')
ax1.set_ylabel('Predicted $n_{bm1}$')
ax1.grid()

# %%
model1.latex()
# Out:
# '\\left(\\frac{x_{0}}{x_{1}}\\right)^{- \\frac{1.04}{x_{2}}}'

# %% [markdown]
# The following expression best suits the data for $n_{bm1}$
#
# $\left(\frac{L}{w_{oh}}\right)^{- \frac{1.04}{S}}$
