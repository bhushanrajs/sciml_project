# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanrajs/sciml_project/blob/main/project_PySR_bm2-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Symbolic Regression

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi
# Out:
# Installing Julia 1.8.5 on the current Colab Runtime...
# 2023-12-04 04:16:55 URL:https://storage.googleapis.com/julialang2/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz [130873886/130873886] -> "/tmp/julia.tar.gz" [1]
# Installing PyCall.jl...
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed VersionParsing ── v1.3.0
#    Installed Conda ─────────── v1.10.0
#    Installed Parsers ───────── v2.8.0
#    Installed MacroTools ────── v0.5.11
#    Installed Preferences ───── v1.4.1
#    Installed PrecompileTools ─ v1.2.0
#    Installed JSON ──────────── v0.21.4
#    Installed PyCall ────────── v1.96.2
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [438e738f] + PyCall v1.96.2
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [8f4d0f93] + Conda v1.10.0
#   [682c06a0] + JSON v0.21.4
#   [1914dd2f] + MacroTools v0.5.11
#   [69de0a69] + Parsers v2.8.0
#   [aea7be01] + PrecompileTools v1.2.0
#   [21216c6a] + Preferences v1.4.1
#   [438e738f] + PyCall v1.96.2
#   [81def892] + VersionParsing v1.3.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b27032c2] + LibCURL v0.6.3
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [fa267f1f] + TOML v1.0.0
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.0+0
#   [14a3606d] + MozillaCACerts_jll v2022.2.1
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [83775a58] + Zlib_jll v1.2.12+3
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
# Success

# %% [markdown]
# Install PySR and PyTorch-Lightning:

# %%
# %pip install -Uq pysr pytorch_lightning --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 13.3 MB/s eta 0:00:00

# %%
from julia import Julia

julia = Julia(compiled_modules=False, threads="auto")
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()

# %%
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 22.04.3 LTS
#   uname: Linux 5.15.120+ #1 SMP Wed Aug 30 11:19:59 UTC 2023 x86_64 x86_64
#   CPU: Intel(R) Xeon(R) CPU @ 2.20GHz:
#               speed         user         nice          sys         idle          irq
#        #1  2199 MHz        840 s          0 s        178 s       2449 s          0 s
#        #2  2199 MHz       1051 s          0 s        186 s       2236 s          0 s
#   Memory: 12.6783447265625 GB (11547.390625 MB free)
#   Uptime: 356.42 sec
#   Load Avg:  1.67  0.77  0.33
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, broadwell)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/lib64-nvidia
#   JULIA_PROJECT = @pysr-0.16.3
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.10.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#     Updating registry at `~/.julia/registries/General.toml`
#      Cloning git-repo `https://github.com/MilesCranmer/SymbolicRegression.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed IrrationalConstants ────────────── v0.2.2
#    Installed ScientificTypesBase ────────────── v3.0.0
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed Tricks ─────────────────────────── v0.1.8
#    Installed DynamicExpressions ─────────────── v0.13.1
#    Installed Adapt ──────────────────────────── v3.7.1
#    Installed DiffRules ──────────────────────── v1.15.1
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed LayoutPointers ─────────────────── v0.1.15
#    Installed StatisticalTraits ──────────────── v3.2.0
#    Installed OffsetArrays ───────────────────── v1.12.10
#    Installed MLJModelInterface ──────────────── v1.9.3
#    Installed VectorizationBase ──────────────── v0.21.65
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed PDMats ─────────────────────────── v0.11.30
#    Installed CPUSummary ─────────────────────── v0.2.4
#    Installed DataAPI ────────────────────────── v1.15.0
#    Installed SpecialFunctions ───────────────── v2.3.1
#    Installed Setfield ───────────────────────── v1.1.1
#    Installed LoopVectorization ──────────────── v0.12.166
#    Installed JLLWrappers ────────────────────── v1.5.0
#    Installed NaNMath ────────────────────────── v1.0.2
#    Installed StaticArraysCore ───────────────── v1.4.2
#    Installed StaticArrays ───────────────────── v1.7.0
#    Installed ConstructionBase ───────────────── v1.5.4
#    Installed HostCPUFeatures ────────────────── v0.1.16
#    Installed Optim ──────────────────────────── v1.7.6
#    Installed OrderedCollections ─────────────── v1.6.3
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed NLSolversBase ──────────────────── v7.8.3
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed ArrayInterface ─────────────────── v7.5.1
#    Installed ForwardDiff ────────────────────── v0.10.36
#    Installed ChainRulesCore ─────────────────── v1.18.0
#    Installed FillArrays ─────────────────────── v1.8.0
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed CommonSubexpressions ───────────── v0.3.0
#    Installed LogExpFunctions ────────────────── v0.3.26
#    Installed Requires ───────────────────────── v1.3.0
#    Installed LineSearches ───────────────────── v7.2.0
#    Installed DataStructures ─────────────────── v0.18.15
#    Installed ProgressBars ───────────────────── v1.5.1
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed PackageExtensionCompat ─────────── v1.0.2
#    Installed Static ─────────────────────────── v0.8.8
#    Installed ClusterManagers ────────────────── v0.4.5
#    Installed StatsAPI ───────────────────────── v1.7.0
#    Installed SLEEFPirates ───────────────────── v0.6.42
#    Installed OpenSpecFun_jll ────────────────── v0.5.5+0
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed Compat ─────────────────────────── v4.10.1
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed InverseFunctions ───────────────── v0.1.12
#    Installed DynamicQuantities ──────────────── v0.6.3
#    Installed Missings ───────────────────────── v1.1.0
#    Installed StaticArrayInterface ───────────── v1.4.1
#    Installed StatsBase ──────────────────────── v0.34.2
#    Installed LossFunctions ──────────────────── v0.11.1
#    Installed SortingAlgorithms ──────────────── v1.2.0
#    Installed ChangesOfVariables ─────────────── v0.1.8
#    Installed DocStringExtensions ────────────── v0.9.3
#    Installed FiniteDiff ─────────────────────── v2.21.1
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [34f1f09b] + ClusterManagers v0.4.5
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [79e6a3ab] + Adapt v3.7.1
# ⌅ [4fba245c] + ArrayInterface v7.5.1
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [2a0fbf3d] + CPUSummary v0.2.4
#   [d360d2e6] + ChainRulesCore v1.18.0
#   [9e997f8a] + ChangesOfVariables v0.1.8
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [34f1f09b] + ClusterManagers v0.4.5
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.10.1
#   [187b0558] + ConstructionBase v1.5.4
#   [adafc99b] + CpuId v0.3.1
#   [9a962f9c] + DataAPI v1.15.0
#   [864edb3b] + DataStructures v0.18.15
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [ffbed154] + DocStringExtensions v0.9.3
#   [a40a106e] + DynamicExpressions v0.13.1
# ⌅ [06fc5a27] + DynamicQuantities v0.6.3
#   [1a297f60] + FillArrays v1.8.0
#   [6a86dc24] + FiniteDiff v2.21.1
#   [f6369f11] + ForwardDiff v0.10.36
#   [3e5b6fbb] + HostCPUFeatures v0.1.16
#   [615f187c] + IfElse v0.1.1
#   [3587e190] + InverseFunctions v0.1.12
#   [92d709cd] + IrrationalConstants v0.2.2
#   [692b3bcd] + JLLWrappers v1.5.0
#   [10f19ff3] + LayoutPointers v0.1.15
#   [d3d80556] + LineSearches v7.2.0
#   [2ab3a3ac] + LogExpFunctions v0.3.26
#   [bdcacae8] + LoopVectorization v0.12.166
#   [30fc2ffe] + LossFunctions v0.11.1
#   [e80e1ace] + MLJModelInterface v1.9.3
#   [d125e4d3] + ManualMemory v0.1.8
#   [e1d29d7a] + Missings v1.1.0
#   [d41bc354] + NLSolversBase v7.8.3
#   [77ba4419] + NaNMath v1.0.2
#   [6fe1bfb0] + OffsetArrays v1.12.10
# ⌅ [429524aa] + Optim v1.7.6
#   [bac558e1] + OrderedCollections v1.6.3
#   [90014a1f] + PDMats v0.11.30
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [d96e819e] + Parameters v0.12.3
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [49802e3a] + ProgressBars v1.5.1
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.3.0
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.42
#   [30f210dd] + ScientificTypesBase v3.0.0
#   [efcf1570] + Setfield v1.1.1
#   [a2af1166] + SortingAlgorithms v1.2.0
#   [276daf66] + SpecialFunctions v2.3.1
#   [aedffcd0] + Static v0.8.8
#   [0d7ed370] + StaticArrayInterface v1.4.1
#   [90137ffa] + StaticArrays v1.7.0
#   [1e83bf80] + StaticArraysCore v1.4.2
#   [64bff920] + StatisticalTraits v3.2.0
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.2
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#   [8290d209] + ThreadingUtilities v0.5.2
#   [410a4b4d] + Tricks v0.1.8
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.65
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [56ddb016] + Logging
#   [44cfe95a] + Pkg v1.8.0
#   [3fa0cd96] + REPL
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [a4e569a6] + Tar v1.10.1
#   [8dfed614] + Test
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [3f19e933] + p7zip_jll v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:118: UserWarning: It is recommended to restart Python after installing PySR's dependencies, so that the Julia environment is properly initialized.
#   warnings.warn(

# %%
import sympy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bhushanrajs/sciml_project/main/analysis_data.csv')

tx_girders = {'Tx28' : {'D' : 28.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 6.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx34' : {'D' : 34.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 12.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx40' : {'D' : 40.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 18.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx46' : {'D' : 46.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 22.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx54' : {'D' : 54.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 30.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx62' : {'D' : 62.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 37.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx70' : {'D' : 70.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 45.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx84' : {'D' : 84.0, 'b1' : 58.0, 'b2' : 8.0, 'b3' : 38.0, 'b4' : 3.0, 'b5' : 3.0, 'd1' : 4.0, 'd2' : 3.5, 'd3' : 3.0, 'd4' : 55.75, 'd5' : 3.0, 'd6' : 6.0, 'd7' : 8.75}
              }

# bridge geometry data
L = df['L']/12 # span length in ft.
S = df['S']/12 # girder spacing in ft.
w_oh = df['w_oh']/12 # overhang width in ft.
ts = df['ts_U']/12 # thickness of overhang in ft.
girder = df['Girder Type']
D = []
for _, girder_type in girder.items():
  D.append(tx_girders[girder_type]['D'])
df['D'] = D

# intensity of railing dead load in kip/ft
b_rail = df['b_rail_left'] # width of railing
q_rail = (df['q_rail_left'] * b_rail * 12)/1000

# max bending moment in exterior girder G1 & interior girder G2 in kip-ft
bm1 = df['G1 - max_bm']/(1000*12)
bm2 = df['G2 - max_bm']/(1000*12)
bm3 = df['G3 - max_bm']/(1000*12)
bm4 = df['G4 - max_bm']/(1000*12)

# reaction in girders G1 & G2 in kip. (only A1 taken due to symmetry)
r1 = df['G1-A1-Y']/1000
r2 = df['G2-A1-Y']/1000
r3 = df['G3-A1-Y']/1000
r4 = df['G4-A1-Y']/1000

# line analysis with full railing load assumed to be applied on a girder
bm_line = q_rail * (L - 2*9/12)**2 / 8
r_line = q_rail * L / 2


# normalizing bending moments with respect to line analysis
n_bm1 = bm1 / bm_line
n_bm2 = bm2 / bm_line
n_bm3 = bm3 / bm_line
n_bm4 = bm4 / bm_line

# normalizing vertical reactions with respect to line analysis
n_r1 = r1 / r_line
n_r2 = r2 / r_line
n_r3 = r3 / r_line
n_r4 = r4 / r_line

# add the distribution factors to the dataframe
df['n_bm1'] = n_bm1
df['n_bm2'] = n_bm2
df['n_bm3'] = n_bm3
df['n_bm4'] = n_bm4
df['n_r1'] = n_r1
df['n_r2'] = n_r2
df['n_r3'] = n_r3
df['n_r4'] = n_r4

# %%
# sample data from leve rule
# n_r1 = (w_oh + S) / S

# %%
X = np.stack((L, w_oh, S), axis=-1)
y = n_bm2

# %%
# Learn equations
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# model = PySRRegressor(
#     niterations=30,
#     binary_operators=['+', '-', '*', '/', '^'],
#     unary_operators=["square", "cube", "sqrt"],
#     **default_pysr_params
# )

model = PySRRegressor(
    niterations=50,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    **default_pysr_params
)

model.fit(X, y)

print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# WARNING: using StaticArrays.setindex in module FiniteDiff conflicts with an existing identifier.
# Started!
#
# Expressions evaluated per second: 7.120e+03
# Head worker occupation: 3.3%
# Progress: 13 / 1500 total iterations (0.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.269e-03  1.594e+01  y = 0.20619
# 2           5.514e-03  5.194e-01  y = square(-0.59115)
# 3           4.583e-03  1.849e-01  y = inv(sqrt(x₂))
# 4           2.096e-03  7.826e-01  y = (square(0.59217) ^ 1.187)
# 5           1.637e-03  2.467e-01  y = inv(sqrt(x₂) + 0.49389)
# 8           1.628e-03  1.864e-03  y = inv(sqrt(x₂) + sqrt(sqrt(inv(x₂))))
# 9           1.449e-03  1.168e-01  y = inv(sqrt(x₂) + sqrt(inv(x₂) * x₁))
# 10          1.404e-03  3.176e-02  y = square(inv(square(1.3286)) - (physics(0.54453, x₀) * x₂))
# 14          1.168e-03  4.583e-02  y = square(0.59217 + (physics(-0.45884, x₀ * ((0.04672 ^ 0.482...
#                                   46) / x₂)) / -1.7503))
# 15          8.867e-04  2.759e-01  y = square(0.59217 + (physics(-0.45884, square(x₀ * ((0.04672 ...
#                                   ^ 0.48246) / x₂))) / -1.7503))
# 17          7.518e-04  8.247e-02  y = square(0.59217 + (physics(-0.45884, square(x₀ * ((0.04672 ...
#                                   ^ 0.48246) / x₂))) / (-1.7503 * 0.84552)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.770e+04
# Head worker occupation: 2.1%
# Progress: 72 / 1500 total iterations (4.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = inv(sqrt(x₂ + x₁))
# 7           1.405e-03  3.975e-02  y = inv(sqrt(x₂ + (x₁ / 0.74191)))
# 9           1.394e-03  3.739e-03  y = (sqrt(inv((x₁ + x₁) + x₂)) * 1.0786)
# 11          9.191e-04  2.084e-01  y = square(inv(square(1.3286)) - physics(x₂, physics(x₀, squar...
#                                   e(1.3286))))
# 14          8.173e-04  3.913e-02  y = square(inv(square(1.3286)) - (physics(x₂, physics(x₀, x₁ /...
#                                    x₂)) * x₂))
# 15          6.008e-04  3.078e-01  y = ((inv(cube(inv(sqrt((x₀ / x₁) / x₂))) - -1.6402) ^ 1.622) ...
#                                   - 0.0799)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+04
# Head worker occupation: 1.6%
# Progress: 125 / 1500 total iterations (8.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = inv(sqrt(x₂ + x₁))
# 7           1.405e-03  3.975e-02  y = inv(sqrt(x₂ + (x₁ / 0.74191)))
# 8           1.258e-03  1.100e-01  y = sqrt(square(inv(physics(x₂, x₀) + 2.333)))
# 10          8.173e-04  2.158e-01  y = square(inv(square(1.3286)) - physics(x₂, physics(x₀, x₁)))
# 12          6.556e-04  1.102e-01  y = square(inv(square(1.3286)) - physics(x₂ / -1.2041, physics...
#                                   (x₀, x₁)))
# 13          6.363e-04  2.981e-02  y = square(inv(square(1.3286)) - physics(x₂, physics(x₀, inv(1...
#                                   .3286 / x₁))))
# 15          6.008e-04  2.875e-02  y = ((inv(cube(inv(sqrt((x₀ / x₁) / x₂))) - -1.6402) ^ 1.622) ...
#                                   - 0.0799)
# 16          4.359e-04  3.207e-01  y = square((inv(square(1.3286)) ^ 0.93539) - (physics(x₂, phys...
#                                   ics(x₀, x₁ / x₂)) * x₂))
# 18          4.282e-04  8.903e-03  y = square(((inv(square(1.3286)) ^ 0.93539) - (physics(x₂, phy...
#                                   sics(x₀, x₁ / x₂)) * x₂)) + -0.0022269)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.370e+04
# Head worker occupation: 1.4%
# Progress: 201 / 1500 total iterations (13.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = inv(sqrt(x₂ + x₁))
# 7           1.404e-03  4.005e-02  y = inv(sqrt((x₁ * 1.3129) + x₂))
# 8           1.258e-03  1.094e-01  y = sqrt(square(inv(physics(x₂, x₀) + 2.333)))
# 10          8.173e-04  2.158e-01  y = square(inv(square(1.3286)) - physics(x₂, physics(x₀, x₁)))
# 11          8.005e-04  2.072e-02  y = square(inv(square(1.3286)) - physics(x₂, physics(x₀, sqrt(...
#                                   x₁))))
# 12          6.393e-04  2.248e-01  y = square(inv(square(1.3286)) - (physics(x₂, physics(x₀, x₁))...
#                                    / 1.2549))
# 13          6.363e-04  4.726e-03  y = square(inv(square(1.3286)) - physics(x₂, physics(x₀, inv(1...
#                                   .3286 / x₁))))
# 14          5.828e-04  8.789e-02  y = square(inv(square(1.3286)) - physics(x₁, physics((x₀ - x₂)...
#                                    - x₂, x₂)))
# 16          4.359e-04  1.451e-01  y = square((inv(square(1.3286)) ^ 0.93539) - (physics(x₂, phys...
#                                   ics(x₀, x₁ / x₂)) * x₂))
# 18          4.194e-04  1.935e-02  y = square((inv(square(1.3286)) ^ 0.93539) - ((physics(x₂, phy...
#                                   sics(x₀, x₁ / x₂)) * x₂) / 0.94752))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.630e+04
# Head worker occupation: 1.7%
# Progress: 250 / 1500 total iterations (16.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = inv(sqrt(x₂ + x₁))
# 6           1.480e-03  2.727e-02  y = (0.099852 / sqrt(sqrt(inv(x₀))))
# 7           1.404e-03  5.283e-02  y = inv(sqrt((x₁ * 1.3129) + x₂))
# 8           1.258e-03  1.094e-01  y = sqrt(square(inv(physics(x₂, x₀) + 2.333)))
# 10          8.173e-04  2.158e-01  y = square(inv(square(1.3286)) - physics(x₂, physics(x₀, x₁)))
# 11          8.005e-04  2.072e-02  y = square(inv(square(1.3286)) - physics(x₂, physics(x₀, sqrt(...
#                                   x₁))))
# 12          4.298e-04  6.219e-01  y = square((inv(square(1.3286)) ^ 0.93952) - physics(x₂, physi...
#                                   cs(x₀, x₁)))
# 14          4.182e-04  1.369e-02  y = square((inv(square(1.3286)) ^ 0.93952) - physics(x₂, physi...
#                                   cs(x₀, x₁) - x₀))
# 16          4.181e-04  1.621e-04  y = square((inv(square(1.3286)) ^ 0.93952) - physics(x₂, (phys...
#                                   ics(x₀, x₁) - x₀) - x₁))
# 17          4.171e-04  2.242e-03  y = square(inv(square(1.3047)) - physics(x₁, physics(x₀ - sqrt...
#                                   (x₁), physics(x₂, square(sqrt(x₁))))))
# 20          4.168e-04  2.613e-04  y = square((inv(square(1.3286)) ^ 0.93539) - (physics(x₂, phys...
#                                   ics(x₀ + (x₁ / -1.5296), x₁ / x₂)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.800e+04
# Head worker occupation: 1.5%
# Progress: 317 / 1500 total iterations (21.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = inv(sqrt(x₂ + x₁))
# 6           1.480e-03  2.727e-02  y = (0.099852 / sqrt(sqrt(inv(x₀))))
# 7           1.404e-03  5.283e-02  y = inv(sqrt((x₁ * 1.3129) + x₂))
# 8           1.258e-03  1.094e-01  y = sqrt(square(inv(physics(x₂, x₀) + 2.333)))
# 9           1.140e-03  9.914e-02  y = sqrt(square(inv(sqrt(physics(x₂, x₀)) + 2.333)))
# 10          4.712e-04  8.830e-01  y = square(inv(square(1.3142)) - physics(x₂, physics(x₀, x₁)))
# 12          4.298e-04  4.602e-02  y = square((inv(square(1.3286)) ^ 0.93952) - physics(x₂, physi...
#                                   cs(x₀, x₁)))
# 14          4.178e-04  1.418e-02  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀, x₁) ...
#                                   - x₀)) * -1.0407)
# 16          4.178e-04  4.247e-05  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    - x₀) - 1.3843)) * -1.0407)
# 17          4.171e-04  1.497e-03  y = square(inv(square(1.3047)) - physics(x₁, physics(x₀ - sqrt...
#                                   (x₁), physics(x₂, square(sqrt(x₁))))))
# 18          4.171e-04  2.635e-05  y = square((inv(square(1.3286)) ^ 0.93539) - (physics(x₂, phys...
#                                   ics(x₀ + -1.8525, x₁ / x₂)) * x₂))
# 20          4.168e-04  3.788e-04  y = square((inv(square(1.3286)) ^ 0.93539) - (physics(x₂, phys...
#                                   ics(x₀ + (x₁ / -1.5296), x₁ / x₂)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.010e+04
# Head worker occupation: 1.4%
# Progress: 378 / 1500 total iterations (25.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = inv(sqrt(x₂ + x₁))
# 6           1.258e-03  1.896e-01  y = inv(physics(x₂, x₀) + 2.333)
# 7           1.140e-03  9.914e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           1.052e-03  8.000e-02  y = inv((physics(x₂, x₀) ^ 0.72232) + 2.333)
# 9           1.035e-03  1.657e-02  y = inv(sqrt(physics(x₂, x₀ - x₂)) + 2.333)
# 10          4.612e-04  8.079e-01  y = square(inv(square(1.3133)) - physics(x₂, physics(x₀, x₁)))
# 12          4.298e-04  3.530e-02  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀, x₁))...
#                                   ) * -1.0407)
# 14          4.178e-04  1.416e-02  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀, x₁) ...
#                                   - x₀)) * -1.0407)
# 15          4.177e-04  1.470e-04  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀ - squ...
#                                   are(1.3286), x₁))) * -1.0407)
# 16          4.177e-04  7.034e-05  y = square(inv(square(1.3047)) - physics(x₁, physics(x₀ - 1.61...
#                                   05, physics(x₂, square(sqrt(x₁))))))
# 17          4.171e-04  1.364e-03  y = square(inv(square(1.3047)) - physics(x₁, physics(x₀ - sqrt...
#                                   (x₁), physics(x₂, square(sqrt(x₁))))))
# 18          4.171e-04  2.635e-05  y = square((inv(square(1.3286)) ^ 0.93539) - (physics(x₂, phys...
#                                   ics(x₀ + -1.8525, x₁ / x₂)) * x₂))
# 20          4.168e-04  3.788e-04  y = square((inv(square(1.3286)) ^ 0.93539) - (physics(x₂, phys...
#                                   ics(x₀ + (x₁ / -1.5296), x₁ / x₂)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.690e+04
# Head worker occupation: 1.6%
# Progress: 425 / 1500 total iterations (28.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = inv(sqrt(x₂ + x₁))
# 6           1.258e-03  1.896e-01  y = inv(physics(x₂, x₀) + 2.333)
# 7           1.140e-03  9.914e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           1.052e-03  8.000e-02  y = inv((physics(x₂, x₀) ^ 0.72232) + 2.333)
# 9           1.035e-03  1.657e-02  y = inv(sqrt(physics(x₂, x₀ - x₂)) + 2.333)
# 10          4.612e-04  8.079e-01  y = square(inv(square(1.3133)) - physics(x₂, physics(x₀, x₁)))
# 12          4.250e-04  4.087e-02  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀, x₁))...
#                                   ) * 1.0389)
# 14          4.170e-04  9.505e-03  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀ + -1....
#                                   2985, x₁))) * 1.0389)
# 18          4.170e-04  6.169e-06  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    - x₁) - (x₀ - 1.3286))) * 1.0389)
# 20          4.168e-04  2.513e-04  y = square((inv(square(1.3286)) ^ 0.93539) - (physics(x₂, phys...
#                                   ics(x₀ + (x₁ / -1.5296), x₁ / x₂)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.870e+04
# Head worker occupation: 1.5%
# Progress: 500 / 1500 total iterations (33.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.914e-03  4.364e-02  y = (x₂ ^ -0.58479)
# 5           1.521e-03  1.149e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.258e-03  1.896e-01  y = inv(physics(x₂, x₀) + 2.333)
# 7           1.140e-03  9.914e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           1.051e-03  8.100e-02  y = inv((physics(x₂, x₀) ^ 0.71077) + 2.333)
# 9           4.876e-04  7.679e-01  y = square(inv(1.6886) - physics(x₂, physics(x₀, x₁)))
# 10          4.612e-04  5.562e-02  y = square(inv(square(1.3133)) - physics(x₂, physics(x₀, x₁)))
# 11          4.318e-04  6.603e-02  y = square(inv(1.6886) - physics(x₂, physics(x₁ - x₀, x₁)))
# 12          4.250e-04  1.572e-02  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀, x₁))...
#                                   ) * 1.0389)
# 14          4.169e-04  9.632e-03  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀, x₁) ...
#                                   - x₀)) * 1.0389)
# 16          4.169e-04  5.090e-05  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    + 1.5036) - x₀)) * 1.0389)
# 18          4.169e-04  6.199e-06  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    + (1.5036 / 0.85731)) - x₀)) * 1.0389)
# 19          4.168e-04  1.568e-04  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    - x₁) - (x₀ - square(x₁)))) * 1.0389)
# 20          4.168e-04  7.630e-05  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    - square(2.4806)) - (x₀ - square(x₁)))) * 1.0389)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.940e+04
# Head worker occupation: 1.5%
# Progress: 561 / 1500 total iterations (37.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.914e-03  4.364e-02  y = (x₂ ^ -0.58479)
# 4           1.894e-03  1.061e-02  y = (x₂ ^ cube(-0.83274))
# 5           1.521e-03  2.192e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.258e-03  1.896e-01  y = inv(physics(x₂, x₀) + 2.333)
# 7           1.140e-03  9.914e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           5.603e-04  7.100e-01  y = square(0.57437 - physics(x₂, physics(x₀, x₁)))
# 9           4.282e-04  2.688e-01  y = square(inv(1.7081) - physics(x₂, physics(x₀, x₁)))
# 11          4.204e-04  9.209e-03  y = square(inv(1.7081) - physics(x₂, physics(x₀, x₁) - x₀))
# 13          4.204e-04  2.772e-06  y = square(inv(1.7081) - physics(x₂, (physics(x₀, x₁) - x₀) - ...
#                                   -1.2008))
# 14          4.169e-04  8.336e-03  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀, x₁) ...
#                                   - x₀)) * 1.0389)
# 16          4.169e-04  6.688e-05  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    + 2.1986) - x₀)) * 1.0389)
# 18          4.168e-04  3.722e-05  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    - x₀) - (x₁ * -2.2476))) * 1.0389)
# 19          4.168e-04  6.271e-05  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    - x₁) - (x₀ - square(x₁)))) * 1.0389)
# 20          4.168e-04  7.630e-05  y = square((inv(square(1.3286)) - physics(x₂, (physics(x₀, x₁)...
#                                    - square(2.4806)) - (x₀ - square(x₁)))) * 1.0389)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.700e+04
# Head worker occupation: 1.6%
# Progress: 611 / 1500 total iterations (40.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.914e-03  4.364e-02  y = (x₂ ^ -0.58479)
# 4           1.894e-03  1.061e-02  y = (x₂ ^ cube(-0.83274))
# 5           1.521e-03  2.192e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.258e-03  1.896e-01  y = inv(physics(x₂, x₀) + 2.333)
# 7           1.140e-03  9.914e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           5.603e-04  7.100e-01  y = square(0.57437 - physics(x₂, physics(x₀, x₁)))
# 9           4.282e-04  2.688e-01  y = square(inv(1.7081) - physics(x₂, physics(x₀, x₁)))
# 10          4.281e-04  2.908e-04  y = square(square(inv(1.3074)) - physics(x₂, physics(x₀, x₁)))
# 11          4.192e-04  2.090e-02  y = square(inv(1.6998) - physics(x₂, physics(x₀ - x₁, x₁)))
# 12          4.181e-04  2.628e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(x₁), x₁...
#                                   )))
# 13          4.174e-04  1.903e-03  y = square(inv(1.6998) - physics(x₂, physics((x₀ - x₁) - -0.57...
#                                   92, x₁)))
# 14          4.169e-04  1.040e-03  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀, x₁) ...
#                                   - x₀)) * 1.0389)
# 15          4.168e-04  2.726e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 1.7546, x₁) ...
#                                   - physics(x₁, 0.4385)))
# 20          4.167e-04  6.160e-05  y = square((inv(square(1.3286)) - physics(x₂, physics(x₀, x₁) ...
#                                   - inv((cube(0.15693) * 2.0175) * x₁))) * 1.0389)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.930e+04
# Head worker occupation: 1.5%
# Progress: 680 / 1500 total iterations (45.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.914e-03  4.364e-02  y = (x₂ ^ -0.58479)
# 4           1.894e-03  1.061e-02  y = (x₂ ^ cube(-0.83274))
# 5           1.521e-03  2.192e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.258e-03  1.896e-01  y = inv(physics(x₂, x₀) + 2.333)
# 7           1.140e-03  9.914e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           5.603e-04  7.100e-01  y = square(0.57437 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  2.690e-01  y = square(inv(1.7086) - physics(x₂, physics(x₀, x₁)))
# 10          4.281e-04  5.418e-05  y = square(square(inv(1.3074)) - physics(x₂, physics(x₀, x₁)))
# 11          4.169e-04  2.652e-02  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.1144, x₁))...
#                                   )
# 13          4.168e-04  6.995e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(cube(1....
#                                   6998)), x₁)))
# 14          4.166e-04  4.638e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(x₁ + x₁...
#                                   ), x₁)))
# 15          4.166e-04  1.909e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(1.6998...
#                                   ) * sqrt(x₁)), x₁)))
# 17          4.166e-04  1.371e-06  y = square(inv(1.6998) - physics(x₂, (physics(x₀ - 1.3253, x₁)...
#                                    - (0.4385 * x₀)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.730e+04
# Head worker occupation: 1.5%
# Progress: 732 / 1500 total iterations (48.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.914e-03  4.364e-02  y = (x₂ ^ -0.58479)
# 4           1.733e-03  9.952e-02  y = sqrt(0.71438 / x₂)
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.258e-03  1.896e-01  y = inv(physics(x₂, x₀) + 2.333)
# 7           1.140e-03  9.914e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           5.603e-04  7.100e-01  y = square(0.57437 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  2.690e-01  y = square(inv(1.7086) - physics(x₂, physics(x₀, x₁)))
# 10          4.281e-04  5.418e-05  y = square(square(inv(1.3074)) - physics(x₂, physics(x₀, x₁)))
# 11          4.169e-04  2.654e-02  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.1237, x₁))...
#                                   )
# 13          4.168e-04  5.836e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(cube(1....
#                                   6998)), x₁)))
# 14          4.166e-04  4.638e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(x₁ + x₁...
#                                   ), x₁)))
# 15          4.166e-04  1.909e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(1.6998...
#                                   ) * sqrt(x₁)), x₁)))
# 17          4.166e-04  1.636e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(physics...
#                                   (1.2099, inv(x₁ * 1.2099))), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.580e+04
# Head worker occupation: 1.5%
# Progress: 785 / 1500 total iterations (52.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.733e-03  8.891e-02  y = sqrt(0.71438 / x₂)
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.140e-03  8.306e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           4.588e-04  9.097e-01  y = square(0.59024 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  6.927e-02  y = square(inv(1.7086) - physics(x₂, physics(x₀, x₁)))
# 10          4.281e-04  5.418e-05  y = square(square(inv(1.3074)) - physics(x₂, physics(x₀, x₁)))
# 11          4.168e-04  2.666e-02  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 14          4.166e-04  1.618e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(x₁ + 1....
#                                   6998), x₁)))
# 15          4.166e-04  1.692e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(1.6998...
#                                   ) * sqrt(x₁)), x₁)))
# 16          4.166e-04  1.621e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁ + x...
#                                   ₁) + -0.13887), x₁)))
# 17          4.166e-04  1.639e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(physics...
#                                   (1.2099, inv(x₁ * 1.2099))), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.720e+04
# Head worker occupation: 1.4%
# Progress: 843 / 1500 total iterations (56.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.733e-03  8.891e-02  y = sqrt(0.71438 / x₂)
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.140e-03  8.306e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           4.588e-04  9.097e-01  y = square(0.59024 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  6.934e-02  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.181e-04  2.367e-02  y = square(0.59024 - physics(x₂ + 0.55056, physics(x₀, x₁)))
# 11          4.168e-04  2.969e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.168e-04  4.217e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁) ...
#                                   - x₁))
# 14          4.166e-04  5.257e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(x₁ + 2....
#                                   1614), x₁)))
# 15          4.166e-04  4.447e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(1.6998...
#                                   ) * sqrt(x₁)), x₁)))
# 16          4.166e-04  1.621e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁ + x...
#                                   ₁) + -0.13887), x₁)))
# 17          4.166e-04  1.639e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(physics...
#                                   (1.2099, inv(x₁ * 1.2099))), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.580e+04
# Head worker occupation: 1.5%
# Progress: 893 / 1500 total iterations (59.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.733e-03  8.891e-02  y = sqrt(0.71438 / x₂)
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.140e-03  8.306e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.333)
# 8           4.588e-04  9.097e-01  y = square(0.59024 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  6.934e-02  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.181e-04  2.367e-02  y = square(0.59024 - physics(x₂ + 0.55056, physics(x₀, x₁)))
# 11          4.168e-04  2.969e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.167e-04  1.093e-04  y = square(inv(1.6998) - physics(x₂, (physics(x₀, x₁) * 0.9705...
#                                   9) - x₀))
# 14          4.166e-04  3.916e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(x₁ + 2....
#                                   1614), x₁)))
# 15          4.166e-04  4.447e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(1.6998...
#                                   ) * sqrt(x₁)), x₁)))
# 16          4.166e-04  1.621e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁ + x...
#                                   ₁) + -0.13887), x₁)))
# 17          4.162e-04  8.451e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+04
# Head worker occupation: 1.5%
# Progress: 956 / 1500 total iterations (63.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.733e-03  8.891e-02  y = sqrt(0.71438 / x₂)
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.588e-04  9.024e-01  y = square(0.59024 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  6.934e-02  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.181e-04  2.367e-02  y = square(0.59024 - physics(x₂ + 0.55056, physics(x₀, x₁)))
# 11          4.168e-04  2.969e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.167e-04  1.093e-04  y = square(inv(1.6998) - physics(x₂, (physics(x₀, x₁) * 0.9705...
#                                   9) - x₀))
# 14          4.166e-04  3.916e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(x₁ + 2....
#                                   1614), x₁)))
# 15          4.166e-04  4.447e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(1.6998...
#                                   ) * sqrt(x₁)), x₁)))
# 16          4.166e-04  1.621e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁ + x...
#                                   ₁) + -0.13887), x₁)))
# 17          4.162e-04  8.451e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 19          4.162e-04  5.886e-05  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁ - 0.041236, x₂), 1.8341), x₁)))
# 20          4.161e-04  6.247e-05  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   square(physics(physics(x₁ - 0.041236, x₂), 1.8341)), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.880e+04
# Head worker occupation: 1.4%
# Progress: 1023 / 1500 total iterations (68.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.733e-03  8.891e-02  y = sqrt(0.71438 / x₂)
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.588e-04  9.024e-01  y = square(0.59024 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  6.934e-02  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.181e-04  2.367e-02  y = square(0.59024 - physics(x₂ + 0.55056, physics(x₀, x₁)))
# 11          4.168e-04  2.969e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.167e-04  1.093e-04  y = square(inv(1.6998) - physics(x₂, (physics(x₀, x₁) * 0.9705...
#                                   9) - x₀))
# 14          4.166e-04  3.916e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - sqrt(x₁ + 2....
#                                   1614), x₁)))
# 15          4.166e-04  4.447e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(1.6998...
#                                   ) * sqrt(x₁)), x₁)))
# 16          4.166e-04  1.621e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁ + x...
#                                   ₁) + -0.13887), x₁)))
# 17          4.162e-04  8.451e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 19          4.161e-04  1.486e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), sqrt(cube(1.8341))), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.720e+04
# Head worker occupation: 1.5%
# Progress: 1070 / 1500 total iterations (71.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.733e-03  8.891e-02  y = sqrt(0.71438 / x₂)
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.281e-04  9.718e-01  y = square(0.58511 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  3.576e-07  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.181e-04  2.367e-02  y = square(0.59024 - physics(x₂ + 0.55056, physics(x₀, x₁)))
# 11          4.168e-04  2.969e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.167e-04  1.093e-04  y = square(inv(1.6998) - physics(x₂, (physics(x₀, x₁) * 0.9705...
#                                   9) - x₀))
# 14          4.166e-04  4.603e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁)))
# 17          4.162e-04  2.791e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 19          4.161e-04  1.486e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), sqrt(cube(1.8341))), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.720e+04
# Head worker occupation: 1.4%
# Progress: 1130 / 1500 total iterations (75.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.733e-03  8.891e-02  y = sqrt(0.71438 / x₂)
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.281e-04  9.718e-01  y = square(0.58511 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  3.576e-07  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.181e-04  2.367e-02  y = square(0.59024 - physics(x₂ + 0.55056, physics(x₀, x₁)))
# 11          4.168e-04  2.969e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.167e-04  1.093e-04  y = square(inv(1.6998) - physics(x₂, (physics(x₀, x₁) * 0.9705...
#                                   9) - x₀))
# 14          4.166e-04  4.603e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁)))
# 17          4.162e-04  2.791e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 19          4.161e-04  1.778e-04  y = square(inv(1.6998) - physics(x₂, physics(((x₀ + -1.9397) +...
#                                    0.10181) - physics(physics(x₁, x₂), 1.8341), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.770e+04
# Head worker occupation: 1.4%
# Progress: 1192 / 1500 total iterations (79.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.699e-03  1.086e-01  y = (0.033786 * sqrt(x₀))
# 5           1.521e-03  1.107e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.281e-04  9.718e-01  y = square(0.58511 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  3.576e-07  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.181e-04  2.367e-02  y = square(0.59024 - physics(x₂ + 0.55056, physics(x₀, x₁)))
# 11          4.168e-04  2.969e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.167e-04  1.093e-04  y = square(inv(1.6998) - physics(x₂, (physics(x₀, x₁) * 0.9705...
#                                   9) - x₀))
# 14          4.166e-04  4.603e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁)))
# 16          4.166e-04  4.590e-06  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁) - 1.6998))
# 17          4.162e-04  8.280e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 19          4.161e-04  1.778e-04  y = square(inv(1.6998) - physics(x₂, physics(((x₀ + -1.9397) +...
#                                    0.10181) - physics(physics(x₁, x₂), 1.8341), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.490e+04
# Head worker occupation: 1.4%
# Progress: 1231 / 1500 total iterations (82.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.699e-03  1.086e-01  y = (0.033786 * sqrt(x₀))
# 5           1.521e-03  1.107e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.281e-04  9.718e-01  y = square(0.58512 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  0.000e+00  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.181e-04  2.367e-02  y = square(0.59024 - physics(x₂ + 0.55056, physics(x₀, x₁)))
# 11          4.168e-04  2.969e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.166e-04  3.047e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 0.80164, x₁)...
#                                    - x₀))
# 14          4.166e-04  6.944e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁)))
# 16          4.166e-04  4.590e-06  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁) - 1.6998))
# 17          4.162e-04  8.280e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 19          4.161e-04  1.778e-04  y = square(inv(1.6998) - physics(x₂, physics(((x₀ + -1.9397) +...
#                                    0.10181) - physics(physics(x₁, x₂), 1.8341), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.650e+04
# Head worker occupation: 1.4%
# Progress: 1295 / 1500 total iterations (86.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.699e-03  1.086e-01  y = (0.033786 * sqrt(x₀))
# 5           1.521e-03  1.107e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.281e-04  9.718e-01  y = square(0.58512 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  0.000e+00  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.181e-04  2.367e-02  y = square(0.59024 - physics(x₂ + 0.55056, physics(x₀, x₁)))
# 11          4.168e-04  2.969e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.166e-04  3.047e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 0.80164, x₁)...
#                                    - x₀))
# 14          4.166e-04  6.944e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁)))
# 16          4.166e-04  4.590e-06  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁) - 1.6998))
# 17          4.162e-04  8.280e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 19          4.161e-04  1.778e-04  y = square(inv(1.6998) - physics(x₂, physics(((x₀ + -1.9397) +...
#                                    0.10181) - physics(physics(x₁, x₂), 1.8341), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.700e+04
# Head worker occupation: 1.4%
# Progress: 1348 / 1500 total iterations (89.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.699e-03  1.086e-01  y = (0.033786 * sqrt(x₀))
# 5           1.521e-03  1.107e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.281e-04  9.718e-01  y = square(0.58512 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  0.000e+00  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.180e-04  2.385e-02  y = square(0.59024 - physics(x₂ + 0.52593, physics(x₀, x₁)))
# 11          4.168e-04  2.785e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.166e-04  3.047e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 0.80164, x₁)...
#                                    - x₀))
# 14          4.166e-04  6.944e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁)))
# 15          4.166e-04  1.848e-06  y = square((inv(1.6998) - physics(x₂, physics(x₀ - 0.80164, x₁...
#                                   ) - x₀)) * -0.99971)
# 16          4.166e-04  7.212e-06  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁) - 1.6998))
# 17          4.162e-04  8.280e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 19          4.161e-04  1.778e-04  y = square(inv(1.6998) - physics(x₂, physics(((x₀ + -1.9397) +...
#                                    0.10181) - physics(physics(x₁, x₂), 1.8341), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.470e+04
# Head worker occupation: 1.4%
# Progress: 1393 / 1500 total iterations (92.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.699e-03  1.086e-01  y = (0.033786 * sqrt(x₀))
# 5           1.521e-03  1.107e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.281e-04  9.718e-01  y = square(0.58512 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  0.000e+00  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.180e-04  2.385e-02  y = square(0.59024 - physics(x₂ + 0.52593, physics(x₀, x₁)))
# 11          4.168e-04  2.785e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.166e-04  3.047e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 0.80164, x₁)...
#                                    - x₀))
# 14          4.166e-04  6.944e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁)))
# 15          4.166e-04  1.848e-06  y = square((inv(1.6998) - physics(x₂, physics(x₀ - 0.80164, x₁...
#                                   ) - x₀)) * -0.99971)
# 16          4.166e-04  7.212e-06  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁) - 1.6998))
# 17          4.162e-04  8.280e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 19          4.161e-04  1.778e-04  y = square(inv(1.6998) - physics(x₂, physics(((x₀ + -1.9397) +...
#                                    0.10181) - physics(physics(x₁, x₂), 1.8341), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.640e+04
# Head worker occupation: 1.4%
# Progress: 1453 / 1500 total iterations (96.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 3           1.894e-03  4.895e-02  y = (x₂ ^ -0.57742)
# 4           1.699e-03  1.086e-01  y = (0.033786 * sqrt(x₀))
# 5           1.521e-03  1.107e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.238e-03  2.056e-01  y = inv(physics(x₂, x₀) + 2.4323)
# 7           1.131e-03  9.031e-02  y = inv(sqrt(physics(x₂, x₀)) + 2.4323)
# 8           4.281e-04  9.718e-01  y = square(0.58512 - physics(x₂, physics(x₀, x₁)))
# 9           4.281e-04  0.000e+00  y = square(inv(1.709) - physics(x₂, physics(x₀, x₁)))
# 10          4.180e-04  2.385e-02  y = square(0.59024 - physics(x₂ + 0.52593, physics(x₀, x₁)))
# 11          4.168e-04  2.785e-03  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 2.2177, x₁))...
#                                   )
# 13          4.166e-04  3.047e-04  y = square(inv(1.6998) - physics(x₂, physics(x₀ - 0.80164, x₁)...
#                                    - x₀))
# 14          4.166e-04  6.944e-05  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁)))
# 15          4.166e-04  1.848e-06  y = square((inv(1.6998) - physics(x₂, physics(x₀ - 0.80164, x₁...
#                                   ) - x₀)) * -0.99971)
# 16          4.166e-04  7.272e-06  y = square(inv(1.6998) - physics(x₂, physics(x₀ - (sqrt(x₁) + ...
#                                   0.53796), x₁) - 0.53796))
# 17          4.162e-04  8.280e-04  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), 1.8341), x₁)))
# 18          4.162e-04  7.010e-05  y = square(inv(1.6998) - physics(x₂, physics((x₀ + -1.9397) - ...
#                                   physics(physics(x₁, x₂), square(1.8341)), x₁)))
# 19          4.161e-04  2.854e-04  y = square(inv(1.6998) - physics(x₂, physics(((x₀ + -1.9397) +...
#                                    0.10181) - physics(physics(x₁, x₂), 1.8341), x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                         0.29093102
# 	1         4.894591e-02                                  (x2 ^ -0.5774195)
# 	2         1.085666e-01                           (0.033786315 * sqrt(x0))
# 	3         1.106670e-01                                 inv(sqrt(x2 + x1))
# 	4         2.056330e-01                   inv(physics(x2, x0) + 2.4322977)
# 	5         9.031301e-02             inv(sqrt(physics(x2, x0)) + 2.4322977)
# 	6   >>>>  9.717879e-01  square(0.58511585 - physics(x2, physics(x0, x1)))
# 	7         1.401568e-07  square(inv(1.7090476) - physics(x2, physics(x0...
# 	8         2.385443e-02  square(0.5902353 - physics(x2 + 0.52593446, ph...
# 	9         2.785618e-03  square(inv(1.6997766) - physics(x2, physics(x0...
# 	10        3.047076e-04  square(inv(1.6997766) - physics(x2, physics(x0...
# 	11        6.959222e-05  square(inv(1.6997766) - physics(x2, physics(x0...
# 	12        1.944523e-06  square((inv(1.6997766) - physics(x2, physics(x...
# 	13        7.418029e-06  square(inv(1.6997766) - physics(x2, physics(x0...
# 	14        8.280682e-04  square(inv(1.6997766) - physics(x2, physics((x...
# 	15        2.431364e-03  square((inv(1.6997766) - physics(inv(x2 / x1),...
#
# 	        loss  complexity
# 	0   0.002088           1
# 	1   0.001894           3
# 	2   0.001699           4
# 	3   0.001521           5
# 	4   0.001238           6
# 	5   0.001131           7
# 	6   0.000428           8
# 	7   0.000428           9
# 	8   0.000418          10
# 	9   0.000417          11
# 	10  0.000417          13
# 	11  0.000417          14
# 	12  0.000417          15
# 	13  0.000417          16
# 	14  0.000416          17
# 	15  0.000415          18
# ]

# %%
model.sympy(6)
# Out:
# (0.58511585 - x1*x2**2/x0**2)**2

# %%
n_bm2_pred = model.predict(X)
ypredict_simpler = model.predict(X, 2)

print("Default selection MSE:", np.power(n_bm2_pred - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 0.00042809191404695365
# Manual selection MSE for index 2: 0.0016989042523126322

# %%
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_bm2, y=n_bm2_pred, marker='o', c='none', edgecolor='b', label='Exterior Girder')

ax1.set_title('Accuracy')
plt.xlim((0,0.5))
plt.ylim((0,0.5))
ax1.legend()

ax1.set_xlabel('Target $n_{r1}$')
ax1.set_ylabel('Predicted $n_{r1}$')
ax1.grid()

# %%
model.latex()
# Out:
# '\\left(0.585 - \\frac{x_{1} x_{2}^{2}}{x_{0}^{2}}\\right)^{2}'

# %% [markdown]
# $\left(0.585 - \frac{w_{oh} S^{2}}{L^{2}}\right)^{2}$

# %%
X = np.stack((L, w_oh, S), axis=-1)
y = n_bm1

# %%
# Learn equations
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# model = PySRRegressor(
#     niterations=30,
#     binary_operators=['+', '-', '*', '/', '^'],
#     unary_operators=["square", "cube", "sqrt"],
#     **default_pysr_params
# )

model1 = PySRRegressor(
    niterations=50,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    **default_pysr_params
)

model1.fit(X, y)

print(model1)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# WARNING: using StaticArrays.setindex in module FiniteDiff conflicts with an existing identifier.
# Started!
#
# Expressions evaluated per second: 6.120e+03
# Head worker occupation: 5.3%
# Progress: 10 / 1500 total iterations (0.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 7           1.101e-02  1.135e-02  y = (sqrt(sqrt(0.36042) / x₀) + 0.58642)
# 8           1.091e-02  9.361e-03  y = (sqrt((0.36042 / x₀) / 0.75589) + 0.58642)
# 10          6.842e-03  2.332e-01  y = sqrt(sqrt(inv(inv(sqrt(x₂))) + -0.19604) + -1.1998)
# 18          6.063e-03  1.511e-02  y = sqrt(inv((square(x₂) * sqrt((1.978 / x₁) / cube(cube(sqrt(...
#                                   x₂) + -1.5791)))) ^ 0.29737))
# 20          5.690e-03  3.172e-02  y = sqrt(inv(physics(square(x₂) * sqrt(physics(-0.14775, x₁) /...
#                                    cube(square(sqrt(x₂) + -1.5791))), 0.51531) ^ 0.29737))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.490e+04
# Head worker occupation: 2.5%
# Progress: 59 / 1500 total iterations (3.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 5           9.254e-03  6.048e-02  y = ((x₂ / x₀) + 0.58642)
# 7           8.080e-03  6.784e-02  y = (((x₂ + -1.0209) / x₀) + 0.58642)
# 8           6.411e-03  2.314e-01  y = sqrt(sqrt(physics(0.44509, sqrt(x₀) / x₂)))
# 9           5.471e-03  1.586e-01  y = sqrt(sqrt(physics(0.44509, square(sqrt(x₀) / x₂))))
# 10          5.176e-03  5.530e-02  y = sqrt(sqrt(physics(-0.41771, physics(sqrt(x₀), x₂) / x₂)))
# 15          5.143e-03  1.303e-03  y = sqrt(sqrt(physics(0.42782, square(sqrt((x₀ + x₂) + -0.2746...
#                                   ) / (x₂ - -0.28705)))))
# 16          4.590e-03  1.136e-01  y = sqrt(x₁ / sqrt(sqrt(square((x₂ * -1.4848) / physics(x₂, x₀...
#                                   )) * square(x₁))))
# 18          4.562e-03  3.094e-03  y = sqrt(x₁ / sqrt(sqrt((square((x₂ * -1.4848) / physics(x₂, x...
#                                   ₀)) * square(x₁)) * 1.0616)))
# 20          4.375e-03  2.094e-02  y = square(inv(0.55894) - (physics(square((x₀ / x₂) / x₂), x₁)...
#                                    ^ physics(0.27511, inv(square(square(sqrt(0.5683)))))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.880e+04
# Head worker occupation: 1.9%
# Progress: 115 / 1500 total iterations (7.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 3           1.063e-02  5.174e-02  y = (x₀ ^ -0.09251)
# 5           6.666e-03  2.332e-01  y = ((x₂ / x₀) + 0.53967)
# 7           6.312e-03  2.734e-02  y = (((x₂ / x₀) + 0.58642) ^ 1.2659)
# 9           5.179e-03  9.893e-02  y = sqrt(sqrt(physics(0.42782, square(sqrt(x₀) / x₂))))
# 10          5.176e-03  4.267e-04  y = sqrt(sqrt(physics(-0.41771, physics(sqrt(x₀), x₂) / x₂)))
# 11          5.164e-03  2.344e-03  y = sqrt(sqrt(physics(0.42782, square(sqrt(x₀ + 1.0278) / x₂))...
#                                   ))
# 13          5.099e-03  6.322e-03  y = sqrt(sqrt(physics(0.35615, square((sqrt(x₀) / (x₂ - -1.302...
#                                   5)) + -0.022763))))
# 14          4.751e-03  7.070e-02  y = sqrt(sqrt(physics(-0.34954, square((sqrt(x₀) / x₂) / cube(...
#                                   1.0372 ^ x₁)))))
# 15          4.067e-03  1.555e-01  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + 2.3833) / x₂)...
#                                    * 1.5495)) * x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.890e+04
# Head worker occupation: 1.6%
# Progress: 160 / 1500 total iterations (10.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 3           1.063e-02  5.174e-02  y = (x₀ ^ -0.09251)
# 5           6.666e-03  2.332e-01  y = ((x₂ / x₀) + 0.53967)
# 7           6.312e-03  2.734e-02  y = (((x₂ / x₀) + 0.58642) ^ 1.2659)
# 9           5.174e-03  9.933e-02  y = sqrt(sqrt(physics(-0.41803, square(sqrt(x₀) / x₂))))
# 11          5.141e-03  3.236e-03  y = sqrt(sqrt(physics(0.42782, square(sqrt(x₀ - x₁) / x₂))))
# 12          5.057e-03  1.656e-02  y = sqrt(sqrt(physics(0.42782, square(sqrt(x₀ - square(x₁)) / ...
#                                   x₂))))
# 13          4.282e-03  1.662e-01  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * 1.5495...
#                                   )) * x₁))
# 14          4.157e-03  2.981e-02  y = sqrt(sqrt(physics(-0.34954, square((sqrt(x₀) / x₂) / (squa...
#                                   re(1.0372) ^ x₁)))))
# 15          3.793e-03  9.145e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + x₂) / x₂) * 1...
#                                   .5495)) * x₁))
# 16          3.750e-03  1.149e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + square(x₁)) /...
#                                    x₂) * -1.5589)) * x₁))
# 19          3.743e-03  6.423e-04  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + inv(2.3833)) ...
#                                   / x₂) * 1.5495)) * (cube(x₁) ^ 0.27861)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+04
# Head worker occupation: 1.6%
# Progress: 203 / 1500 total iterations (13.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 3           1.063e-02  5.174e-02  y = (x₀ ^ -0.09251)
# 5           6.666e-03  2.332e-01  y = ((x₂ / x₀) + 0.53967)
# 7           5.995e-03  5.310e-02  y = (((x₂ + x₁) / x₀) + 0.48626)
# 8           5.198e-03  1.426e-01  y = (sqrt(sqrt(physics(x₂, x₀))) / square(1.2347))
# 9           5.174e-03  4.561e-03  y = sqrt(sqrt(physics(-0.41803, square(sqrt(x₀) / x₂))))
# 11          5.123e-03  5.027e-03  y = sqrt(sqrt(physics(0.42782, square(sqrt(x₀) / x₂) ^ 0.96422...
#                                   )))
# 12          4.807e-03  6.354e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) + inv(x₁)) / x...
#                                   ₂))))
# 13          4.104e-03  1.583e-01  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * -1.570...
#                                   5)) * x₁))
# 15          3.793e-03  3.932e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + x₂) / x₂) * 1...
#                                   .5495)) * x₁))
# 16          3.750e-03  1.149e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + square(x₁)) /...
#                                    x₂) * -1.5589)) * x₁))
# 19          3.743e-03  6.423e-04  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + inv(2.3833)) ...
#                                   / x₂) * 1.5495)) * (cube(x₁) ^ 0.27861)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.380e+04
# Head worker occupation: 1.5%
# Progress: 262 / 1500 total iterations (17.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66388
# 3           1.063e-02  5.174e-02  y = (x₀ ^ -0.09251)
# 4           8.202e-03  2.591e-01  y = sqrt(x₂ * 0.056112)
# 5           6.648e-03  2.101e-01  y = ((x₂ / x₀) + 0.53545)
# 7           5.584e-03  8.721e-02  y = (((x₂ / x₀) * 1.707) + 0.44452)
# 8           5.198e-03  7.157e-02  y = (sqrt(sqrt(physics(x₂, x₀))) / square(1.2347))
# 9           5.174e-03  4.561e-03  y = sqrt(sqrt(physics(-0.41803, square(sqrt(x₀) / x₂))))
# 10          5.165e-03  1.738e-03  y = (sqrt(sqrt(physics(x₂, x₀ + 1.7224))) / square(1.2347))
# 11          4.003e-03  2.550e-01  y = sqrt(physics(0.71482, (sqrt(x₀ / x₁) / 0.50637) / x₂))
# 13          3.821e-03  2.319e-02  y = sqrt(sqrt(physics(-0.41515, square((sqrt(x₀) / x₂) * 1.549...
#                                   5)) * x₁))
# 15          3.793e-03  3.687e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + x₂) / x₂) * 1...
#                                   .5495)) * x₁))
# 16          3.732e-03  1.630e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * 1.5495...
#                                   )) * (cube(x₁) ^ 0.27861)))
# 18          3.712e-03  2.707e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ - 1.5495) / x₂)...
#                                    * 1.5495)) * (cube(x₁) ^ 0.27861)))
# 20          3.712e-03  2.012e-05  y = sqrt(sqrt(physics(0.44509, square((sqrt((x₀ + 0.44509) - 2...
#                                   .0655) / x₂) * 1.5495)) * (cube(x₁) ^ 0.27861)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.200e+04
# Head worker occupation: 1.5%
# Progress: 309 / 1500 total iterations (20.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           8.202e-03  2.536e-01  y = sqrt(x₂ * 0.056112)
# 5           6.648e-03  2.101e-01  y = ((x₂ / x₀) + 0.53545)
# 7           5.270e-03  1.161e-01  y = sqrt(0.44509 ^ (sqrt(x₀) / x₂))
# 8           5.198e-03  1.372e-02  y = (sqrt(sqrt(physics(x₂, x₀))) / square(1.2347))
# 9           5.174e-03  4.561e-03  y = sqrt(sqrt(physics(-0.41803, square(sqrt(x₀) / x₂))))
# 10          5.165e-03  1.738e-03  y = (sqrt(sqrt(physics(x₂, x₀ + 1.7224))) / square(1.2347))
# 11          4.003e-03  2.550e-01  y = sqrt(physics(0.71482, (sqrt(x₀ / x₁) / 0.50637) / x₂))
# 13          3.821e-03  2.319e-02  y = sqrt(sqrt(physics(-0.41515, square((sqrt(x₀) / x₂) * 1.549...
#                                   5)) * x₁))
# 15          3.793e-03  3.687e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + x₂) / x₂) * 1...
#                                   .5495)) * x₁))
# 16          3.732e-03  1.630e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * 1.5495...
#                                   )) * (cube(x₁) ^ 0.27861)))
# 17          3.723e-03  2.337e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ - x₁) / x₂) * -...
#                                   1.5589)) * (x₁ ^ 0.82087)))
# 18          3.678e-03  1.229e-02  y = sqrt(sqrt(physics(0.44509, square(((sqrt(x₀) / x₂) * 1.549...
#                                   5) ^ 0.96949)) * (cube(x₁) ^ 0.27861)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.190e+04
# Head worker occupation: 1.4%
# Progress: 348 / 1500 total iterations (23.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           8.202e-03  2.536e-01  y = sqrt(x₂ * 0.056112)
# 5           6.648e-03  2.101e-01  y = ((x₂ / x₀) + 0.53545)
# 7           5.270e-03  1.161e-01  y = sqrt(0.44509 ^ (sqrt(x₀) / x₂))
# 8           5.198e-03  1.372e-02  y = (sqrt(sqrt(physics(x₂, x₀))) / square(1.2347))
# 9           5.161e-03  7.081e-03  y = physics(sqrt(sqrt(sqrt(physics(x₂, x₀)))), square(1.2403))
# 10          4.663e-03  1.015e-01  y = (sqrt(x₁ / (x₀ ^ 1.2057)) ^ physics(-1.2552, x₂))
# 11          4.003e-03  1.527e-01  y = sqrt(physics(0.71482, (sqrt(x₀ / x₁) / 0.50637) / x₂))
# 12          3.843e-03  4.072e-02  y = sqrt(sqrt(physics(0.71482, physics((sqrt(x₀) / 0.37144) / ...
#                                   x₂, x₁))))
# 13          3.821e-03  5.649e-03  y = sqrt(sqrt(physics(-0.41515, square((sqrt(x₀) / x₂) * 1.549...
#                                   5)) * x₁))
# 15          3.793e-03  3.687e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + x₂) / x₂) * 1...
#                                   .5495)) * x₁))
# 16          3.732e-03  1.630e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * 1.5495...
#                                   )) * (cube(x₁) ^ 0.27861)))
# 17          3.723e-03  2.337e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ - x₁) / x₂) * -...
#                                   1.5589)) * (x₁ ^ 0.82087)))
# 18          3.678e-03  1.229e-02  y = sqrt(sqrt(physics(0.44509, square(((sqrt(x₀) / x₂) * 1.549...
#                                   5) ^ 0.96949)) * (cube(x₁) ^ 0.27861)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.350e+04
# Head worker occupation: 1.3%
# Progress: 400 / 1500 total iterations (26.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           8.202e-03  2.536e-01  y = sqrt(x₂ * 0.056112)
# 5           6.648e-03  2.101e-01  y = ((x₂ / x₀) + 0.53545)
# 7           5.165e-03  1.262e-01  y = sqrt(0.42484 / (sqrt(x₀) / x₂))
# 9           5.106e-03  5.682e-03  y = (sqrt(sqrt(x₁) / x₀) ^ physics(-1.323, x₂))
# 10          4.471e-03  1.328e-01  y = (sqrt((x₁ - 0.79901) / x₀) ^ physics(-1.323, x₂))
# 11          3.839e-03  1.524e-01  y = sqrt(physics(0.52364, sqrt(x₀) / x₂) * (x₁ ^ 0.49811))
# 13          3.821e-03  2.330e-03  y = sqrt(sqrt(physics(-0.41515, square((sqrt(x₀) / x₂) * 1.549...
#                                   5)) * x₁))
# 15          3.793e-03  3.687e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ + x₂) / x₂) * 1...
#                                   .5495)) * x₁))
# 16          3.732e-03  1.630e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * 1.5495...
#                                   )) * (cube(x₁) ^ 0.27861)))
# 17          3.723e-03  2.337e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ - x₁) / x₂) * -...
#                                   1.5589)) * (x₁ ^ 0.82087)))
# 18          3.678e-03  1.229e-02  y = sqrt(sqrt(physics(0.44509, square(((sqrt(x₀) / x₂) * 1.549...
#                                   5) ^ 0.96949)) * (cube(x₁) ^ 0.27861)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+04
# Head worker occupation: 1.3%
# Progress: 432 / 1500 total iterations (28.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           8.202e-03  2.536e-01  y = sqrt(x₂ * 0.056112)
# 5           6.648e-03  2.101e-01  y = ((x₂ / x₀) + 0.53545)
# 7           5.165e-03  1.262e-01  y = sqrt(0.42484 / (sqrt(x₀) / x₂))
# 9           4.966e-03  1.964e-02  y = (sqrt(sqrt(x₁) / x₀) ^ physics(1.3429, x₂))
# 10          4.471e-03  1.049e-01  y = (sqrt((x₁ - 0.79901) / x₀) ^ physics(-1.323, x₂))
# 11          3.839e-03  1.524e-01  y = sqrt(physics(0.52364, sqrt(x₀) / x₂) * (x₁ ^ 0.49811))
# 13          3.821e-03  2.330e-03  y = sqrt(sqrt(physics(-0.41515, square((sqrt(x₀) / x₂) * 1.549...
#                                   5)) * x₁))
# 14          3.815e-03  1.740e-03  y = sqrt(sqrt(physics(0.71482, physics((sqrt(x₀ - 1.6055) / 0....
#                                   37144) / x₂, x₁))))
# 15          3.783e-03  8.308e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * -1.558...
#                                   9)) * (x₁ ^ 0.82087)))
# 16          3.732e-03  1.362e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * 1.5495...
#                                   )) * (cube(x₁) ^ 0.27861)))
# 17          3.723e-03  2.337e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ - x₁) / x₂) * -...
#                                   1.5589)) * (x₁ ^ 0.82087)))
# 18          3.678e-03  1.229e-02  y = sqrt(sqrt(physics(0.44509, square(((sqrt(x₀) / x₂) * 1.549...
#                                   5) ^ 0.96949)) * (cube(x₁) ^ 0.27861)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.920e+04
# Head worker occupation: 1.3%
# Progress: 469 / 1500 total iterations (31.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           8.202e-03  2.536e-01  y = sqrt(x₂ * 0.056112)
# 5           6.648e-03  2.101e-01  y = ((x₂ / x₀) + 0.53545)
# 7           5.161e-03  1.265e-01  y = sqrt(0.42223 / (sqrt(x₀) / x₂))
# 8           4.866e-03  5.903e-02  y = (sqrt(x₁ / x₀) ^ physics(-1.38, x₂))
# 9           4.317e-03  1.196e-01  y = sqrt((x₁ / x₀) ^ (cube(1.2763) / x₂))
# 11          3.839e-03  5.864e-02  y = sqrt(physics(0.52364, sqrt(x₀) / x₂) * (x₁ ^ 0.49811))
# 13          3.821e-03  2.330e-03  y = sqrt(sqrt(physics(-0.41515, square((sqrt(x₀) / x₂) * 1.549...
#                                   5)) * x₁))
# 14          3.815e-03  1.740e-03  y = sqrt(sqrt(physics(0.71482, physics((sqrt(x₀ - 1.6055) / 0....
#                                   37144) / x₂, x₁))))
# 15          3.783e-03  8.308e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * -1.558...
#                                   9)) * (x₁ ^ 0.82087)))
# 16          3.732e-03  1.362e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * 1.5495...
#                                   )) * (cube(x₁) ^ 0.27861)))
# 17          3.723e-03  2.337e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀ - x₁) / x₂) * -...
#                                   1.5589)) * (x₁ ^ 0.82087)))
# 18          3.678e-03  1.229e-02  y = sqrt(sqrt(physics(0.44509, square(((sqrt(x₀) / x₂) * 1.549...
#                                   5) ^ 0.96949)) * (cube(x₁) ^ 0.27861)))
# 20          3.663e-03  1.998e-03  y = sqrt(sqrt(physics(0.44509, square((((sqrt(x₀) / x₂) * 1.54...
#                                   95) ^ 0.96949) ^ 0.96949)) * (cube(x₁) ^ 0.27861)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.990e+04
# Head worker occupation: 1.2%
# Progress: 507 / 1500 total iterations (33.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 7           5.161e-03  1.265e-01  y = sqrt(0.42223 / (sqrt(x₀) / x₂))
# 8           4.866e-03  5.903e-02  y = (sqrt(x₁ / x₀) ^ physics(-1.38, x₂))
# 9           4.317e-03  1.196e-01  y = sqrt((x₁ / x₀) ^ (cube(1.2763) / x₂))
# 10          3.767e-03  1.364e-01  y = (physics(sqrt(x₁ / x₀), 0.29881) ^ physics(1.2742, x₂))
# 12          3.745e-03  2.861e-03  y = (physics(sqrt(x₁ / (x₀ - 1.326)), 0.29881) ^ physics(1.274...
#                                   2, x₂))
# 14          3.737e-03  1.026e-03  y = (physics(sqrt(x₁ / (x₀ - 0.96457)) * -1.1079, 0.29881) ^ p...
#                                   hysics(1.326, x₂))
# 15          3.737e-03  3.362e-05  y = (physics(sqrt(x₁ / (x₀ - sqrt(square(cube(1.326))))), 0.29...
#                                   881) ^ physics(1.2742, x₂))
# 16          3.732e-03  1.423e-03  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / x₂) * 1.5495...
#                                   )) * (cube(x₁) ^ 0.27861)))
# 17          3.679e-03  1.424e-02  y = sqrt(sqrt(physics(0.44509, square((sqrt(x₀) / (x₂ + sqrt(x...
#                                   ₁))) * -1.5589)) * sqrt(x₁)))
# 18          3.652e-03  7.331e-03  y = (physics(sqrt(x₁ / (x₀ - ((0.96075 * x₂) - cube(square(-0....
#                                   080484))))), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.680e+04
# Head worker occupation: 1.2%
# Progress: 524 / 1500 total iterations (34.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 7           5.161e-03  1.265e-01  y = sqrt(0.42223 / (sqrt(x₀) / x₂))
# 8           4.866e-03  5.903e-02  y = (sqrt(x₁ / x₀) ^ physics(-1.38, x₂))
# 9           4.317e-03  1.196e-01  y = sqrt((x₁ / x₀) ^ (cube(1.2763) / x₂))
# 10          3.767e-03  1.364e-01  y = (physics(sqrt(x₁ / x₀), 0.29881) ^ physics(1.2742, x₂))
# 12          3.638e-03  1.735e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.29881) ^ physics(1.326, x...
#                                   ₂))
# 14          3.597e-03  5.626e-03  y = (physics(sqrt(x₁ / (x₀ - (1.326 + x₂))), 0.29881) ^ physic...
#                                   s(1.326, x₂))
# 15          3.573e-03  6.847e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.520e+04
# Head worker occupation: 1.1%
# Progress: 556 / 1500 total iterations (37.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.259e-03  2.343e-01  y = (0.66277 ^ (sqrt(x₀) / x₂))
# 7           4.402e-03  1.779e-01  y = ((x₁ / x₀) ^ (1.0048 / x₂))
# 8           4.326e-03  1.746e-02  y = ((x₁ / x₀) ^ (inv(0.97246) / x₂))
# 9           4.217e-03  2.547e-02  y = sqrt(sqrt((x₂ ^ sqrt(sqrt(x₁))) / x₀))
# 10          3.767e-03  1.130e-01  y = (physics(sqrt(x₁ / x₀), 0.29881) ^ physics(1.2742, x₂))
# 12          3.638e-03  1.735e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.29881) ^ physics(1.326, x...
#                                   ₂))
# 14          3.588e-03  6.973e-03  y = (physics(sqrt(x₁ / ((x₀ - x₂) - x₁)), 0.29881) ^ physics(1...
#                                   .326, x₂))
# 15          3.573e-03  4.153e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 18          3.573e-03  2.609e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075) + x₂)) - x₂))...
#                                   , 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.520e+04
# Head worker occupation: 1.1%
# Progress: 585 / 1500 total iterations (39.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.259e-03  2.343e-01  y = (0.66277 ^ (sqrt(x₀) / x₂))
# 7           4.380e-03  1.829e-01  y = ((x₁ / x₀) ^ physics(1.0048, x₂))
# 8           4.326e-03  1.244e-02  y = ((x₁ / x₀) ^ (inv(0.97246) / x₂))
# 9           4.217e-03  2.547e-02  y = sqrt(sqrt((x₂ ^ sqrt(sqrt(x₁))) / x₀))
# 10          3.767e-03  1.130e-01  y = (physics(sqrt(x₁ / x₀), 0.29881) ^ physics(1.2742, x₂))
# 12          3.638e-03  1.735e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.29881) ^ physics(1.326, x...
#                                   ₂))
# 14          3.588e-03  6.973e-03  y = (physics(sqrt(x₁ / ((x₀ - x₂) - x₁)), 0.29881) ^ physics(1...
#                                   .326, x₂))
# 15          3.573e-03  4.153e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 18          3.573e-03  2.609e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075) + x₂)) - x₂))...
#                                   , 0.29881) ^ physics(1.326, x₂))
# 20          3.572e-03  2.277e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075 / x₁) + x₂)) -...
#                                    x₂)), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.360e+04
# Head worker occupation: 1.1%
# Progress: 607 / 1500 total iterations (40.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.259e-03  2.343e-01  y = (0.66277 ^ (sqrt(x₀) / x₂))
# 7           4.380e-03  1.829e-01  y = ((x₁ / x₀) ^ physics(1.0048, x₂))
# 8           4.326e-03  1.244e-02  y = ((x₁ / x₀) ^ (inv(0.97246) / x₂))
# 9           3.988e-03  8.140e-02  y = ((x₁ / (x₀ / 2.082)) ^ (1.3487 / x₂))
# 10          3.763e-03  5.803e-02  y = (physics(sqrt(x₁ / x₀), 0.28956) ^ physics(1.2742, x₂))
# 12          3.638e-03  1.685e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.29881) ^ physics(1.326, x...
#                                   ₂))
# 14          3.588e-03  6.973e-03  y = (physics(sqrt(x₁ / ((x₀ - x₂) - x₁)), 0.29881) ^ physics(1...
#                                   .326, x₂))
# 15          3.573e-03  4.153e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 18          3.573e-03  2.609e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075) + x₂)) - x₂))...
#                                   , 0.29881) ^ physics(1.326, x₂))
# 20          3.572e-03  2.277e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075 / x₁) + x₂)) -...
#                                    x₂)), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.240e+04
# Head worker occupation: 1.0%
# Progress: 635 / 1500 total iterations (42.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.259e-03  2.343e-01  y = (0.66277 ^ (sqrt(x₀) / x₂))
# 7           4.380e-03  1.829e-01  y = ((x₁ / x₀) ^ physics(1.0048, x₂))
# 8           4.326e-03  1.244e-02  y = ((x₁ / x₀) ^ (inv(0.97246) / x₂))
# 9           3.866e-03  1.125e-01  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.763e-03  2.698e-02  y = (physics(sqrt(x₁ / x₀), 0.28956) ^ physics(1.2742, x₂))
# 12          3.602e-03  2.180e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.588e-03  2.031e-03  y = (physics(sqrt(x₁ / ((x₀ - x₂) - x₁)), 0.29881) ^ physics(1...
#                                   .326, x₂))
# 15          3.573e-03  4.153e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 17          3.573e-03  3.889e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(0.96075 + x₂)) - x₂)), 0.29...
#                                   881) ^ physics(1.326, x₂))
# 18          3.573e-03  3.397e-06  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(1.2673) + x₂)) - x₂)),...
#                                    0.29881) ^ physics(1.326, x₂))
# 20          3.572e-03  2.128e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075 / x₁) + x₂)) -...
#                                    x₂)), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.260e+04
# Head worker occupation: 1.0%
# Progress: 658 / 1500 total iterations (43.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.259e-03  2.343e-01  y = (0.66277 ^ (sqrt(x₀) / x₂))
# 7           4.380e-03  1.829e-01  y = ((x₁ / x₀) ^ physics(1.0048, x₂))
# 8           4.324e-03  1.283e-02  y = (sqrt(x₁ / x₀) ^ physics(1.4349, x₂))
# 9           3.866e-03  1.121e-01  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.763e-03  2.698e-02  y = (physics(sqrt(x₁ / x₀), 0.28956) ^ physics(1.2742, x₂))
# 12          3.602e-03  2.180e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.588e-03  2.031e-03  y = (physics(sqrt(x₁ / ((x₀ - x₂) - x₁)), 0.29881) ^ physics(1...
#                                   .326, x₂))
# 15          3.573e-03  4.153e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 17          3.573e-03  4.104e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(1.2673 + x₂)) - x₂)), 0.298...
#                                   81) ^ physics(1.326, x₂))
# 20          3.572e-03  1.393e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075 / x₁) + x₂)) -...
#                                    x₂)), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.170e+04
# Head worker occupation: 1.0%
# Progress: 680 / 1500 total iterations (45.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.259e-03  2.343e-01  y = (0.66277 ^ (sqrt(x₀) / x₂))
# 7           4.332e-03  1.938e-01  y = ((x₁ / x₀) ^ physics(1.0269, x₂))
# 8           4.324e-03  1.882e-03  y = (sqrt(x₁ / x₀) ^ physics(1.4349, x₂))
# 9           3.866e-03  1.121e-01  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.763e-03  2.698e-02  y = (physics(sqrt(x₁ / x₀), 0.28956) ^ physics(1.2742, x₂))
# 12          3.602e-03  2.180e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.588e-03  2.031e-03  y = (physics(sqrt(x₁ / ((x₀ - x₂) - x₁)), 0.29881) ^ physics(1...
#                                   .326, x₂))
# 15          3.573e-03  4.153e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 17          3.573e-03  4.104e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(1.2673 + x₂)) - x₂)), 0.298...
#                                   81) ^ physics(1.326, x₂))
# 20          3.572e-03  1.393e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075 / x₁) + x₂)) -...
#                                    x₂)), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.130e+04
# Head worker occupation: 1.0%
# Progress: 702 / 1500 total iterations (46.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.259e-03  2.343e-01  y = (0.66277 ^ (sqrt(x₀) / x₂))
# 7           4.332e-03  1.938e-01  y = ((x₁ / x₀) ^ physics(1.0269, x₂))
# 8           4.324e-03  1.882e-03  y = (sqrt(x₁ / x₀) ^ physics(1.4349, x₂))
# 9           3.866e-03  1.121e-01  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.763e-03  2.698e-02  y = (physics(sqrt(x₁ / x₀), 0.28956) ^ physics(1.2742, x₂))
# 12          3.602e-03  2.180e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.588e-03  2.031e-03  y = (physics(sqrt(x₁ / ((x₀ - x₂) - x₁)), 0.29881) ^ physics(1...
#                                   .326, x₂))
# 15          3.573e-03  4.153e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 17          3.573e-03  4.104e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(1.2673 + x₂)) - x₂)), 0.298...
#                                   81) ^ physics(1.326, x₂))
# 20          3.572e-03  1.393e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075 / x₁) + x₂)) -...
#                                    x₂)), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.050e+04
# Head worker occupation: 0.9%
# Progress: 720 / 1500 total iterations (48.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.259e-03  2.343e-01  y = (0.66277 ^ (sqrt(x₀) / x₂))
# 7           4.328e-03  1.948e-01  y = ((x₁ / x₀) ^ (1.0269 / x₂))
# 8           4.320e-03  1.893e-03  y = ((x₁ / x₀) ^ (sqrt(1.0947) / x₂))
# 9           3.866e-03  1.111e-01  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.763e-03  2.698e-02  y = (physics(sqrt(x₁ / x₀), 0.28956) ^ physics(1.2742, x₂))
# 12          3.602e-03  2.180e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.577e-03  3.521e-03  y = (physics(sqrt(x₁ / (x₀ - (2.7 + x₂))), 0.29881) ^ physics(...
#                                   1.326, x₂))
# 15          3.573e-03  1.174e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 17          3.573e-03  4.104e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(1.2673 + x₂)) - x₂)), 0.298...
#                                   81) ^ physics(1.326, x₂))
# 20          3.572e-03  1.393e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(sqrt(0.96075 / x₁) + x₂)) -...
#                                    x₂)), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.970e+03
# Head worker occupation: 0.9%
# Progress: 741 / 1500 total iterations (49.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.259e-03  2.343e-01  y = (0.66277 ^ (sqrt(x₀) / x₂))
# 7           4.328e-03  1.948e-01  y = ((x₁ / x₀) ^ (1.0269 / x₂))
# 8           4.320e-03  1.893e-03  y = ((x₁ / x₀) ^ (sqrt(1.0947) / x₂))
# 9           3.866e-03  1.111e-01  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.763e-03  2.698e-02  y = (physics(sqrt(x₁ / x₀), 0.28956) ^ physics(1.2742, x₂))
# 12          3.602e-03  2.180e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.577e-03  3.521e-03  y = (physics(sqrt(x₁ / (x₀ - (2.7 + x₂))), 0.29881) ^ physics(...
#                                   1.326, x₂))
# 15          3.573e-03  1.174e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 17          3.573e-03  4.104e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(1.2673 + x₂)) - x₂)), 0.298...
#                                   81) ^ physics(1.326, x₂))
# 19          3.571e-03  2.779e-04  y = (physics(sqrt(x₁ / (x₀ - (sqrt(square(inv(sqrt(sqrt(0.3059...
#                                   5))))) * x₂))), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.070e+04
# Head worker occupation: 0.9%
# Progress: 768 / 1500 total iterations (51.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.258e-03  2.345e-01  y = (0.66371 ^ (sqrt(x₀) / x₂))
# 7           4.317e-03  1.972e-01  y = ((x₁ / x₀) ^ (1.0389 / x₂))
# 8           4.317e-03  8.702e-06  y = ((x₁ / x₀) ^ (inv(0.9619) / x₂))
# 9           3.866e-03  1.104e-01  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.763e-03  2.698e-02  y = (physics(sqrt(x₁ / x₀), 0.28956) ^ physics(1.2742, x₂))
# 12          3.602e-03  2.180e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.577e-03  3.521e-03  y = (physics(sqrt(x₁ / (x₀ - (2.7 + x₂))), 0.29881) ^ physics(...
#                                   1.326, x₂))
# 15          3.573e-03  1.174e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 17          3.573e-03  4.104e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(1.2673 + x₂)) - x₂)), 0.298...
#                                   81) ^ physics(1.326, x₂))
# 19          3.571e-03  2.779e-04  y = (physics(sqrt(x₁ / (x₀ - (sqrt(square(inv(sqrt(sqrt(0.3059...
#                                   5))))) * x₂))), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.940e+03
# Head worker occupation: 0.9%
# Progress: 785 / 1500 total iterations (52.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.452e-02  y = (x₀ ^ -0.099047)
# 4           6.895e-03  4.272e-01  y = sqrt(x₂ * 0.04858)
# 5           6.648e-03  3.647e-02  y = ((x₂ / x₀) + 0.53545)
# 6           5.258e-03  2.345e-01  y = (0.66371 ^ (sqrt(x₀) / x₂))
# 7           4.317e-03  1.972e-01  y = ((x₁ / x₀) ^ (1.0389 / x₂))
# 8           4.317e-03  8.702e-06  y = ((x₁ / x₀) ^ (inv(0.9619) / x₂))
# 9           3.866e-03  1.104e-01  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.763e-03  2.698e-02  y = (physics(sqrt(x₁ / x₀), 0.28956) ^ physics(1.2742, x₂))
# 12          3.602e-03  2.180e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.577e-03  3.521e-03  y = (physics(sqrt(x₁ / (x₀ - (2.7 + x₂))), 0.29881) ^ physics(...
#                                   1.326, x₂))
# 15          3.573e-03  1.174e-03  y = (physics(sqrt(x₁ / (x₀ - (sqrt(x₂) + x₂))), 0.29881) ^ phy...
#                                   sics(1.326, x₂))
# 17          3.573e-03  4.104e-05  y = (physics(sqrt(x₁ / ((x₀ - sqrt(1.2673 + x₂)) - x₂)), 0.298...
#                                   81) ^ physics(1.326, x₂))
# 19          3.571e-03  2.779e-04  y = (physics(sqrt(x₁ / (x₀ - (sqrt(square(inv(sqrt(sqrt(0.3059...
#                                   5))))) * x₂))), 0.29881) ^ physics(1.326, x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# ...
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.190e+04
# Head worker occupation: 0.7%
# Progress: 1358 / 1500 total iterations (90.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096322)
# 4           6.769e-03  4.400e-01  y = sqrt(x₂ * 0.050257)
# 5           6.648e-03  1.809e-02  y = ((x₂ / x₀) + 0.53536)
# 6           5.258e-03  2.345e-01  y = (0.66371 ^ (sqrt(x₀) / x₂))
# 7           4.317e-03  1.972e-01  y = ((x₁ / x₀) ^ (1.0397 / x₂))
# 9           3.866e-03  5.520e-02  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.749e-03  3.069e-02  y = (physics(sqrt(x₁ / x₀), 0.23966) ^ physics(1.326, x₂))
# 11          3.715e-03  8.990e-03  y = ((2.5183 / ((x₀ * 0.60042) / x₁)) ^ physics(-1.3471, x₂))
# 12          3.602e-03  3.089e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.571e-03  4.321e-03  y = (physics(sqrt(x₁ / (x₀ - (1.326 * x₂))), 0.29881) ^ physic...
#                                   s(1.326, x₂))
# 15          3.570e-03  4.279e-04  y = (physics(sqrt(x₁ / (x₀ - sqrt(x₂ ^ 2.2715))), 0.29881) ^ p...
#                                   hysics(1.326, x₂))
# 17          3.570e-03  8.255e-06  y = (physics(sqrt(x₁ / (x₀ - sqrt((x₂ ^ 2.2715) / 0.9953))), 0...
#                                   .29881) ^ physics(1.326, x₂))
# 19          3.550e-03  2.792e-03  y = (physics(sqrt(x₁ / (((x₀ - x₂) - x₂) * 0.76187)), sqrt(0.2...
#                                   7974)) ^ physics(-1.4086, x₂ - -1.8212))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.240e+04
# Head worker occupation: 0.7%
# Progress: 1385 / 1500 total iterations (92.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096322)
# 4           6.769e-03  4.400e-01  y = sqrt(x₂ * 0.050257)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 6           4.427e-03  2.507e-01  y = ((x₁ / x₀) ^ inv(x₂))
# 7           4.317e-03  2.525e-02  y = ((x₁ / x₀) ^ (1.0397 / x₂))
# 9           3.866e-03  5.520e-02  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.749e-03  3.069e-02  y = (physics(sqrt(x₁ / x₀), 0.23966) ^ physics(1.326, x₂))
# 11          3.715e-03  8.990e-03  y = ((2.5183 / ((x₀ * 0.60042) / x₁)) ^ physics(-1.3471, x₂))
# 12          3.602e-03  3.089e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.571e-03  4.321e-03  y = (physics(sqrt(x₁ / (x₀ - (1.326 * x₂))), 0.29881) ^ physic...
#                                   s(1.326, x₂))
# 15          3.570e-03  4.279e-04  y = (physics(sqrt(x₁ / (x₀ - sqrt(x₂ ^ 2.2715))), 0.29881) ^ p...
#                                   hysics(1.326, x₂))
# 17          3.570e-03  8.255e-06  y = (physics(sqrt(x₁ / (x₀ - sqrt((x₂ ^ 2.2715) / 0.9953))), 0...
#                                   .29881) ^ physics(1.326, x₂))
# 19          3.550e-03  2.792e-03  y = (physics(sqrt(x₁ / (((x₀ - x₂) - x₂) * 0.76187)), sqrt(0.2...
#                                   7974)) ^ physics(-1.4086, x₂ - -1.8212))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.130e+04
# Head worker occupation: 0.7%
# Progress: 1402 / 1500 total iterations (93.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096322)
# 4           6.769e-03  4.400e-01  y = sqrt(x₂ * 0.050257)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 6           4.427e-03  2.507e-01  y = ((x₁ / x₀) ^ inv(x₂))
# 7           4.317e-03  2.525e-02  y = ((x₁ / x₀) ^ (1.0397 / x₂))
# 9           3.866e-03  5.520e-02  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.749e-03  3.069e-02  y = (physics(sqrt(x₁ / x₀), 0.23966) ^ physics(1.326, x₂))
# 11          3.715e-03  8.990e-03  y = ((2.5183 / ((x₀ * 0.60042) / x₁)) ^ physics(-1.3471, x₂))
# 12          3.602e-03  3.089e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.571e-03  4.321e-03  y = (physics(sqrt(x₁ / (x₀ - (1.326 * x₂))), 0.29881) ^ physic...
#                                   s(1.326, x₂))
# 15          3.570e-03  4.279e-04  y = (physics(sqrt(x₁ / (x₀ - sqrt(x₂ ^ 2.2715))), 0.29881) ^ p...
#                                   hysics(1.326, x₂))
# 17          3.570e-03  8.255e-06  y = (physics(sqrt(x₁ / (x₀ - sqrt((x₂ ^ 2.2715) / 0.9953))), 0...
#                                   .29881) ^ physics(1.326, x₂))
# 19          3.550e-03  2.792e-03  y = (physics(sqrt(x₁ / (((x₀ - x₂) - x₂) * 0.76187)), sqrt(0.2...
#                                   7974)) ^ physics(-1.4086, x₂ - -1.8212))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.060e+04
# Head worker occupation: 0.7%
# Progress: 1424 / 1500 total iterations (94.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096322)
# 4           6.769e-03  4.400e-01  y = sqrt(x₂ * 0.050257)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 6           4.427e-03  2.507e-01  y = ((x₁ / x₀) ^ inv(x₂))
# 7           4.317e-03  2.525e-02  y = ((x₁ / x₀) ^ (1.0397 / x₂))
# 9           3.866e-03  5.520e-02  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.749e-03  3.069e-02  y = (physics(sqrt(x₁ / x₀), 0.23966) ^ physics(1.326, x₂))
# 11          3.715e-03  8.990e-03  y = ((2.5183 / ((x₀ * 0.60042) / x₁)) ^ physics(-1.3471, x₂))
# 12          3.602e-03  3.089e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.571e-03  4.321e-03  y = (physics(sqrt(x₁ / (x₀ - (1.326 * x₂))), 0.29881) ^ physic...
#                                   s(1.326, x₂))
# 15          3.570e-03  4.279e-04  y = (physics(sqrt(x₁ / (x₀ - sqrt(x₂ ^ 2.2715))), 0.29881) ^ p...
#                                   hysics(1.326, x₂))
# 17          3.570e-03  8.255e-06  y = (physics(sqrt(x₁ / (x₀ - sqrt((x₂ ^ 2.2715) / 0.9953))), 0...
#                                   .29881) ^ physics(1.326, x₂))
# 19          3.550e-03  2.792e-03  y = (physics(sqrt(x₁ / (((x₀ - x₂) - x₂) * 0.76187)), sqrt(0.2...
#                                   7974)) ^ physics(-1.4086, x₂ - -1.8212))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.980e+03
# Head worker occupation: 0.7%
# Progress: 1444 / 1500 total iterations (96.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096322)
# 4           6.769e-03  4.400e-01  y = sqrt(x₂ * 0.050257)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 6           4.427e-03  2.507e-01  y = ((x₁ / x₀) ^ inv(x₂))
# 7           4.317e-03  2.525e-02  y = ((x₁ / x₀) ^ (1.0397 / x₂))
# 8           4.311e-03  1.460e-03  y = ((x₁ / x₀) ^ inv(x₂ + -0.40707))
# 9           3.866e-03  1.089e-01  y = (physics(x₁, x₀) ^ ((1.1578 ^ x₁) / x₂))
# 10          3.749e-03  3.069e-02  y = (physics(sqrt(x₁ / x₀), 0.23966) ^ physics(1.326, x₂))
# 11          3.715e-03  8.990e-03  y = ((2.5183 / ((x₀ * 0.60042) / x₁)) ^ physics(-1.3471, x₂))
# 12          3.602e-03  3.089e-02  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.571e-03  4.321e-03  y = (physics(sqrt(x₁ / (x₀ - (1.326 * x₂))), 0.29881) ^ physic...
#                                   s(1.326, x₂))
# 15          3.570e-03  4.279e-04  y = (physics(sqrt(x₁ / (x₀ - sqrt(x₂ ^ 2.2715))), 0.29881) ^ p...
#                                   hysics(1.326, x₂))
# 17          3.570e-03  8.255e-06  y = (physics(sqrt(x₁ / (x₀ - sqrt((x₂ ^ 2.2715) / 0.9953))), 0...
#                                   .29881) ^ physics(1.326, x₂))
# 19          3.550e-03  2.792e-03  y = (physics(sqrt(x₁ / (((x₀ - x₂) - x₂) * 0.76187)), sqrt(0.2...
#                                   7974)) ^ physics(-1.4086, x₂ - -1.8212))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.070e+03
# Head worker occupation: 0.7%
# Progress: 1463 / 1500 total iterations (97.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096322)
# 4           6.769e-03  4.400e-01  y = sqrt(x₂ * 0.050257)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 6           4.427e-03  2.507e-01  y = ((x₁ / x₀) ^ inv(x₂))
# 7           4.317e-03  2.525e-02  y = ((x₁ / x₀) ^ (1.0397 / x₂))
# 8           4.311e-03  1.460e-03  y = ((x₁ / x₀) ^ inv(x₂ + -0.40707))
# 9           3.712e-03  1.496e-01  y = (physics(x₁ / x₀, 0.043825) ^ (0.96471 / x₂))
# 12          3.602e-03  9.959e-03  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.571e-03  4.321e-03  y = (physics(sqrt(x₁ / (x₀ - (1.326 * x₂))), 0.29881) ^ physic...
#                                   s(1.326, x₂))
# 15          3.570e-03  4.279e-04  y = (physics(sqrt(x₁ / (x₀ - sqrt(x₂ ^ 2.2715))), 0.29881) ^ p...
#                                   hysics(1.326, x₂))
# 17          3.570e-03  8.255e-06  y = (physics(sqrt(x₁ / (x₀ - sqrt((x₂ ^ 2.2715) / 0.9953))), 0...
#                                   .29881) ^ physics(1.326, x₂))
# 19          3.550e-03  2.792e-03  y = (physics(sqrt(x₁ / (((x₀ - x₂) - x₂) * 0.76187)), sqrt(0.2...
#                                   7974)) ^ physics(-1.4086, x₂ - -1.8212))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.600e+03
# Head worker occupation: 0.7%
# Progress: 1489 / 1500 total iterations (99.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.051e-02  5.733e-02  y = (x₀ ^ -0.096322)
# 4           6.769e-03  4.400e-01  y = sqrt(x₂ * 0.050257)
# 5           5.689e-03  1.738e-01  y = (x₀ ^ (-0.8203 / x₂))
# 6           4.427e-03  2.507e-01  y = ((x₁ / x₀) ^ inv(x₂))
# 7           4.317e-03  2.525e-02  y = ((x₁ / x₀) ^ (1.0397 / x₂))
# 8           4.311e-03  1.460e-03  y = ((x₁ / x₀) ^ inv(x₂ + -0.40707))
# 9           3.712e-03  1.496e-01  y = (physics(x₁ / x₀, 0.043825) ^ (0.96471 / x₂))
# 12          3.602e-03  9.959e-03  y = (physics(sqrt(x₁ / (x₀ - x₂)), 0.27974) ^ physics(1.326, x...
#                                   ₂))
# 14          3.571e-03  4.321e-03  y = (physics(sqrt(x₁ / (x₀ - (1.326 * x₂))), 0.29881) ^ physic...
#                                   s(1.326, x₂))
# 15          3.570e-03  4.279e-04  y = (physics(sqrt(x₁ / (x₀ - sqrt(x₂ ^ 2.2715))), 0.29881) ^ p...
#                                   hysics(1.326, x₂))
# 17          3.570e-03  8.255e-06  y = (physics(sqrt(x₁ / (x₀ - sqrt((x₂ ^ 2.2715) / 0.9953))), 0...
#                                   .29881) ^ physics(1.326, x₂))
# 19          3.550e-03  2.792e-03  y = (physics(sqrt(x₁ / (((x₀ - x₂) - x₂) * 0.76187)), sqrt(0.2...
#                                   7974)) ^ physics(-1.4086, x₂ - -1.8212))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          0.6638675
# 	1         0.057329                                 (x0 ^ -0.09632203)
# 	2         0.439963                             sqrt(x2 * 0.050257377)
# 	3         0.173844                            (x0 ^ (-0.820296 / x2))
# 	4   >>>>  0.250714                              ((x1 / x0) ^ inv(x2))
# 	5         0.025254                     ((x1 / x0) ^ (1.0396508 / x2))
# 	6         0.001460                ((x1 / x0) ^ inv(x2 + -0.40706986))
# 	7         0.149632  (physics(x1 / x0, 0.043825097) ^ (0.9647119 / ...
# 	8         0.000014  (physics(x1 / (x0 + -0.92363465), 0.043825097)...
# 	9         0.029850  (physics(sqrt(x1 / (x0 - x2)), 0.2797371) ^ ph...
# 	10        0.004321  (physics(sqrt(x1 / (x0 - (1.3259915 * x2))), 0...
# 	11        0.000428  (physics(sqrt(x1 / (x0 - sqrt(x2 ^ 2.2714994))...
# 	12        0.000008  (physics(sqrt(x1 / (x0 - sqrt((x2 ^ 2.2714994)...
# 	13        0.000014  (physics(sqrt(x1 / (x0 - sqrt((x2 ^ 2.2714994)...
# 	14        0.005571  (physics(sqrt(x1 / (((x0 - x2) - x2) * 0.76186...
#
# 	        loss  complexity
# 	0   0.011787           1
# 	1   0.010510           3
# 	2   0.006769           4
# 	3   0.005689           5
# 	4   0.004427           6
# 	5   0.004317           7
# 	6   0.004311           8
# 	7   0.003712           9
# 	8   0.003711          11
# 	9   0.003602          12
# 	10  0.003571          14
# 	11  0.003570          15
# 	12  0.003570          17
# 	13  0.003570          18
# 	14  0.003550          19
# ]

# %%
model1.sympy()
# Out:
# (x1/x0)**(1/x2)

# %%
n_bm1_pred = model1.predict(X)
ypredict_simpler = model1.predict(X, 2)

print("Default selection MSE:", np.power(n_bm1_pred - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 0.004427369339102962
# Manual selection MSE for index 2: 0.006769063258700248

# %%
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_bm1, y=n_bm1_pred, marker='o', c='none', edgecolor='b', label='Exterior Girder')

ax1.set_title('Accuracy')
plt.xlim((0,1))
plt.ylim((0,1))
ax1.legend()

ax1.set_xlabel('Target $n_{r1}$')
ax1.set_ylabel('Predicted $n_{r1}$')
ax1.grid()
