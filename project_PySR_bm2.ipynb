# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanrajs/sciml_project/blob/main/project_PySR_bm2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Symbolic Regression

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi

# %% [markdown]
# Install PySR and PyTorch-Lightning:

# %%
# %pip install -Uq pysr pytorch_lightning --quiet

# %%
from julia import Julia

julia = Julia(compiled_modules=False, threads="auto")
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()

# %%
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 22.04.3 LTS
#   uname: Linux 5.15.120+ #1 SMP Wed Aug 30 11:19:59 UTC 2023 x86_64 x86_64
#   CPU: Intel(R) Xeon(R) CPU @ 2.00GHz:
#               speed         user         nice          sys         idle          irq
#        #1  2000 MHz       6349 s          0 s        956 s      29716 s          0 s
#        #2  2000 MHz       5978 s          0 s        962 s      30081 s          0 s
#   Memory: 12.6783447265625 GB (10721.078125 MB free)
#   Uptime: 3720.82 sec
#   Load Avg:  0.91  0.45  0.33
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, skylake-avx512)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/lib64-nvidia
#   JULIA_PROJECT = @pysr-0.16.3
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.10.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:118: UserWarning: It is recommended to restart Python after installing PySR's dependencies, so that the Julia environment is properly initialized.
#   warnings.warn(

# %%
import sympy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bhushanrajs/sciml_project/main/analysis_data.csv')

tx_girders = {'Tx28' : {'D' : 28.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 6.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx34' : {'D' : 34.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 12.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx40' : {'D' : 40.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 18.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx46' : {'D' : 46.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 22.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx54' : {'D' : 54.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 30.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx62' : {'D' : 62.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 37.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx70' : {'D' : 70.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 45.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx84' : {'D' : 84.0, 'b1' : 58.0, 'b2' : 8.0, 'b3' : 38.0, 'b4' : 3.0, 'b5' : 3.0, 'd1' : 4.0, 'd2' : 3.5, 'd3' : 3.0, 'd4' : 55.75, 'd5' : 3.0, 'd6' : 6.0, 'd7' : 8.75}
              }

# bridge geometry data
L = df['L']/12 # span length in ft.
S = df['S']/12 # girder spacing in ft.
w_oh = df['w_oh']/12 # overhang width in ft.
ts = df['ts_U']/12 # thickness of overhang in ft.
girder = df['Girder Type']
D = []
for _, girder_type in girder.items():
  D.append(tx_girders[girder_type]['D'])
df['D'] = D

# intensity of railing dead load in kip/ft
b_rail = df['b_rail_left'] # width of railing
q_rail = (df['q_rail_left'] * b_rail * 12)/1000

# max bending moment in exterior girder G1 & interior girder G2 in kip-ft
bm1 = df['G1 - max_bm']/(1000*12)
bm2 = df['G2 - max_bm']/(1000*12)
bm3 = df['G3 - max_bm']/(1000*12)
bm4 = df['G4 - max_bm']/(1000*12)

# reaction in girders G1 & G2 in kip. (only A1 taken due to symmetry)
r1 = df['G1-A1-Y']/1000
r2 = df['G2-A1-Y']/1000
r3 = df['G3-A1-Y']/1000
r4 = df['G4-A1-Y']/1000

# line analysis with full railing load assumed to be applied on a girder
bm_line = q_rail * (L - 2*9/12)**2 / 8
r_line = q_rail * L / 2


# normalizing bending moments with respect to line analysis
n_bm1 = bm1 / bm_line
n_bm2 = bm2 / bm_line
n_bm3 = bm3 / bm_line
n_bm4 = bm4 / bm_line

# normalizing vertical reactions with respect to line analysis
n_r1 = r1 / r_line
n_r2 = r2 / r_line
n_r3 = r3 / r_line
n_r4 = r4 / r_line

# add the distribution factors to the dataframe
df['n_bm1'] = n_bm1
df['n_bm2'] = n_bm2
df['n_bm3'] = n_bm3
df['n_bm4'] = n_bm4
df['n_r1'] = n_r1
df['n_r2'] = n_r2
df['n_r3'] = n_r3
df['n_r4'] = n_r4

# %%
# sample data from leve rule
# n_r1 = (w_oh + S) / S

# %%
X = np.stack((L, w_oh, S), axis=-1)
y = n_bm2

# %%
# Learn equations
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# model = PySRRegressor(
#     niterations=30,
#     binary_operators=['+', '-', '*', '/', '^'],
#     unary_operators=["square", "cube", "sqrt"],
#     **default_pysr_params
# )

model = PySRRegressor(
    niterations=40,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
)

model.fit(X, y)

print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 1.530e+04
# Head worker occupation: 2.7%
# Progress: 32 / 600 total iterations (5.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 5           1.521e-03  7.928e-02  y = inv(sqrt(x₂ + x₁))
# 7           1.420e-03  3.434e-02  y = inv(sqrt(x₂ + (x₁ / 0.83634)))
# 8           1.404e-03  1.145e-02  y = inv(sqrt(x₂ + physics(sqrt(x₁), 0.75844)))
# 9           1.338e-03  4.791e-02  y = ((inv(-0.65027) / sqrt(physics(x₀, x₂))) + 0.34299)
# 10          1.272e-03  5.074e-02  y = ((inv(cube(-0.8891)) / sqrt(physics(x₀, x₂))) + 0.34299)
# 12          5.637e-04  4.069e-01  y = (((inv(-0.8891) / physics(x₀, x₂ / 0.097647)) * x₁) + 0.34...
#                                   299)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.340e+04
# Head worker occupation: 2.1%
# Progress: 59 / 600 total iterations (9.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.833e-03  4.355e-02  y = sqrt(0.76425 / x₂)
# 5           1.521e-03  1.865e-01  y = inv(sqrt(x₂ + x₁))
# 7           1.066e-03  1.776e-01  y = (((-0.45211 / x₀) * x₂) + 0.34299)
# 10          5.917e-04  1.963e-01  y = (((-0.8891 / physics(x₀, square(x₂))) * x₁) + 0.34299)
# 11          4.224e-04  3.371e-01  y = ((((-0.92605 - x₂) / physics(x₀, x₂)) * x₁) + 0.34299)
# 13          4.215e-04  1.044e-03  y = ((((-0.8891 - (x₂ * 1.0215)) / physics(x₀, x₂)) * x₁) + 0....
#                                   34299)
# 18          4.214e-04  3.397e-05  y = (((inv(-0.8891) / (physics(x₀, square(x₂) + inv(x₁ - x₀)) ...
#                                   + 0.50124)) * x₁) + 0.34299)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.300e+04
# Head worker occupation: 1.8%
# Progress: 87 / 600 total iterations (14.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.833e-03  4.355e-02  y = sqrt(0.76425 / x₂)
# 5           1.521e-03  1.865e-01  y = inv(sqrt(x₂ + x₁))
# 7           1.066e-03  1.776e-01  y = (((-0.45211 / x₀) * x₂) + 0.34299)
# 10          4.453e-04  2.910e-01  y = (((-1.0841 / physics(x₀, square(x₂))) * x₁) + 0.34645)
# 11          4.224e-04  5.293e-02  y = ((((-0.92605 - x₂) / physics(x₀, x₂)) * x₁) + 0.34299)
# 12          4.220e-04  9.118e-04  y = ((((inv(-1.0346) - x₂) / physics(x₀, x₂)) * x₁) + 0.34299)
# 13          4.178e-04  1.007e-02  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.830e+04
# Head worker occupation: 1.5%
# Progress: 158 / 600 total iterations (26.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.733e-03  6.227e-02  y = sqrt(physics(-0.84521, x₂))
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 7           1.036e-03  1.918e-01  y = (((-0.45211 / x₀) * x₂) + 0.34645)
# 10          4.223e-04  2.993e-01  y = (((-1.0981 / physics(x₀, square(x₂))) * x₁) + 0.34235)
# 11          4.215e-04  1.704e-03  y = ((((-1.0862 - x₂) / physics(x₀, x₂)) * x₁) + 0.34299)
# 13          4.178e-04  4.496e-03  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# 19          4.177e-04  3.763e-05  y = (((cube(-1.0841) / (physics(x₀ - (0.19712 * -0.55106), squ...
#                                   are(x₂) + 0.69949) + x₁)) * x₁) + 0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.940e+04
# Head worker occupation: 1.7%
# Progress: 203 / 600 total iterations (33.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.733e-03  6.227e-02  y = sqrt(physics(-0.8452, x₂))
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.392e-03  8.827e-02  y = (0.49107 - (1.6808 / sqrt(x₀)))
# 7           8.102e-04  5.415e-01  y = (((-0.75615 / x₀) * x₂) + 0.38987)
# 9           5.344e-04  2.081e-01  y = (((-11.636 / physics(x₀, x₂)) * x₁) + 0.34985)
# 10          4.223e-04  2.355e-01  y = (((-1.0981 / physics(x₀, square(x₂))) * x₁) + 0.34235)
# 11          4.215e-04  1.728e-03  y = ((((-1.0867 - x₂) / physics(x₀, x₂)) * x₁) + 0.34331)
# 13          4.178e-04  4.484e-03  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# 15          4.177e-04  5.579e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) - -0.2081) + x₁...
#                                   )) * x₁) + 0.34645)
# 19          4.177e-04  2.854e-05  y = (((cube(-1.0841) / (physics(x₀ - (0.19712 * -0.55106), squ...
#                                   are(x₂) + 0.69949) + x₁)) * x₁) + 0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.380e+04
# Head worker occupation: 1.8%
# Progress: 269 / 600 total iterations (44.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.733e-03  6.227e-02  y = sqrt(physics(-0.8452, x₂))
# 5           1.521e-03  1.303e-01  y = inv(sqrt(x₂ + x₁))
# 6           1.392e-03  8.827e-02  y = (0.49107 - (1.6808 / sqrt(x₀)))
# 7           8.082e-04  5.440e-01  y = (((-0.76551 / x₀) * x₂) + 0.39064)
# 9           5.344e-04  2.068e-01  y = (((-11.636 / physics(x₀, x₂)) * x₁) + 0.34985)
# 10          4.223e-04  2.355e-01  y = (((-1.0981 / physics(x₀, square(x₂))) * x₁) + 0.34235)
# 11          4.215e-04  1.862e-03  y = ((((-1.1441 - x₂) / physics(x₀, x₂)) * x₁) + 0.34345)
# 13          4.178e-04  4.417e-03  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# 15          4.177e-04  5.791e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) - -0.22491) + x...
#                                   ₁)) * x₁) + 0.34645)
# 17          4.172e-04  6.709e-04  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - 1.7943)...
#                                   ) + x₁)) * x₁) + 0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.790e+04
# Head worker occupation: 1.7%
# Progress: 333 / 600 total iterations (55.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.699e-03  6.882e-02  y = (0.033786 * sqrt(x₀))
# 5           1.367e-03  2.174e-01  y = ((-7.1512 / x₀) + 0.39409)
# 7           8.082e-04  2.627e-01  y = (((-0.76551 / x₀) * x₂) + 0.39064)
# 8           7.355e-04  9.429e-02  y = ((physics(x₂, -0.36502) / square(x₀)) + 0.342)
# 9           5.344e-04  3.194e-01  y = (((-11.636 / physics(x₀, x₂)) * x₁) + 0.34985)
# 10          4.223e-04  2.355e-01  y = (((-1.0981 / physics(x₀, square(x₂))) * x₁) + 0.34235)
# 11          4.215e-04  1.862e-03  y = ((((-1.1441 - x₂) / physics(x₀, x₂)) * x₁) + 0.34345)
# 12          4.178e-04  8.760e-03  y = (((-1.2772 / (physics(x₀, square(x₂)) + x₁)) * x₁) + 0.346...
#                                   45)
# 13          4.178e-04  7.326e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# 15          4.177e-04  6.357e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + 0.34345) + x₁...
#                                   )) * x₁) + 0.34645)
# 17          4.172e-04  6.652e-04  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - 1.7943)...
#                                   ) + x₁)) * x₁) + 0.34645)
# 18          4.172e-04  1.633e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - square(...
#                                   1.7943))) + x₁)) * x₁) + 0.34645)
# 19          4.169e-04  5.820e-04  y = (((cube(-1.0841) / (physics(x₀, (square(x₂) + (x₁ - 1.7943...
#                                   )) - 0.88028) + x₁)) * x₁) + 0.34645)
# 20          4.169e-04  3.082e-05  y = (((cube(-1.0841) / (physics(x₀, (square(x₂) + (x₁ - 1.7943...
#                                   )) - cube(0.88028)) + x₁)) * x₁) + 0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.550e+04
# Head worker occupation: 1.7%
# Progress: 369 / 600 total iterations (61.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.699e-03  6.882e-02  y = (0.033786 * sqrt(x₀))
# 5           1.367e-03  2.174e-01  y = ((-7.1507 / x₀) + 0.39409)
# 7           8.062e-04  2.640e-01  y = (((-0.77608 / x₀) * x₂) + 0.39066)
# 8           7.355e-04  9.178e-02  y = ((physics(x₂, -0.36502) / square(x₀)) + 0.342)
# 9           5.344e-04  3.194e-01  y = (((-11.636 / physics(x₀, x₂)) * x₁) + 0.34985)
# 10          4.223e-04  2.355e-01  y = (((-1.0981 / physics(x₀, square(x₂))) * x₁) + 0.34235)
# 11          4.215e-04  1.862e-03  y = ((((-1.1441 - x₂) / physics(x₀, x₂)) * x₁) + 0.34345)
# 12          4.178e-04  8.760e-03  y = (((-1.2772 / (physics(x₀, square(x₂)) + x₁)) * x₁) + 0.346...
#                                   45)
# 13          4.178e-04  7.326e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# 15          4.177e-04  6.357e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + 0.34345) + x₁...
#                                   )) * x₁) + 0.34645)
# 17          4.172e-04  6.652e-04  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - 1.7943)...
#                                   ) + x₁)) * x₁) + 0.34645)
# 18          4.172e-04  1.633e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - square(...
#                                   1.7943))) + x₁)) * x₁) + 0.34645)
# 19          4.169e-04  5.820e-04  y = (((cube(-1.0841) / (physics(x₀, (square(x₂) + (x₁ - 1.7943...
#                                   )) - 0.88028) + x₁)) * x₁) + 0.34645)
# 20          4.169e-04  3.082e-05  y = (((cube(-1.0841) / (physics(x₀, (square(x₂) + (x₁ - 1.7943...
#                                   )) - cube(0.88028)) + x₁)) * x₁) + 0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.650e+04
# Head worker occupation: 1.6%
# Progress: 438 / 600 total iterations (73.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.699e-03  6.882e-02  y = (0.033786 * sqrt(x₀))
# 5           1.367e-03  2.174e-01  y = ((-7.1507 / x₀) + 0.39409)
# 7           8.062e-04  2.640e-01  y = (((-0.77608 / x₀) * x₂) + 0.39066)
# 8           7.355e-04  9.178e-02  y = ((physics(x₂, -0.36502) / square(x₀)) + 0.342)
# 9           5.344e-04  3.194e-01  y = (((-11.636 / physics(x₀, x₂)) * x₁) + 0.34985)
# 10          4.223e-04  2.355e-01  y = (((-1.0981 / physics(x₀, square(x₂))) * x₁) + 0.34235)
# 11          4.215e-04  1.862e-03  y = ((((-1.1441 - x₂) / physics(x₀, x₂)) * x₁) + 0.34345)
# 12          4.178e-04  8.760e-03  y = (((-1.2772 / (physics(x₀, square(x₂)) + x₁)) * x₁) + 0.346...
#                                   45)
# 13          4.178e-04  7.326e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# 15          4.177e-04  6.357e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + 0.34345) + x₁...
#                                   )) * x₁) + 0.34645)
# 17          4.172e-04  6.652e-04  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - 1.7943)...
#                                   ) + x₁)) * x₁) + 0.34645)
# 18          4.172e-04  1.633e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - square(...
#                                   1.7943))) + x₁)) * x₁) + 0.34645)
# 19          4.169e-04  6.099e-04  y = (((cube(-1.0841) / (physics(x₀, (square(x₂) + -0.65743) + ...
#                                   (x₁ - 1.7943)) + x₁)) * x₁) + 0.34645)
# 20          4.169e-04  2.861e-06  y = (((cube(-1.0841) / (physics(x₀, (square(x₂) + (x₁ - 1.7943...
#                                   )) - cube(0.88028)) + x₁)) * x₁) + 0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.770e+04
# Head worker occupation: 1.5%
# Progress: 499 / 600 total iterations (83.167%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.699e-03  6.882e-02  y = (0.033786 * sqrt(x₀))
# 5           1.367e-03  2.174e-01  y = ((-7.1507 / x₀) + 0.39409)
# 7           8.062e-04  2.640e-01  y = (((-0.77608 / x₀) * x₂) + 0.39066)
# 8           7.355e-04  9.178e-02  y = ((physics(x₂, -0.36502) / square(x₀)) + 0.342)
# 9           5.324e-04  3.232e-01  y = (((-11.979 / physics(x₀, x₂)) * x₁) + 0.35067)
# 10          4.223e-04  2.317e-01  y = (((-1.0981 / physics(x₀, square(x₂))) * x₁) + 0.34235)
# 11          4.215e-04  1.862e-03  y = ((((-1.1441 - x₂) / physics(x₀, x₂)) * x₁) + 0.34345)
# 12          4.178e-04  8.760e-03  y = (((-1.2772 / (physics(x₀, square(x₂)) + x₁)) * x₁) + 0.346...
#                                   45)
# 13          4.178e-04  7.326e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# 15          4.177e-04  6.357e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + 0.34345) + x₁...
#                                   )) * x₁) + 0.34645)
# 16          4.177e-04  5.734e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + inv(x₂)) + x₁...
#                                   )) * x₁) + 0.34645)
# 17          4.172e-04  1.273e-03  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - 1.7943)...
#                                   ) + x₁)) * x₁) + 0.34645)
# 18          4.172e-04  1.633e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - square(...
#                                   1.7943))) + x₁)) * x₁) + 0.34645)
# 19          4.169e-04  7.241e-04  y = (((cube(-1.0841) / (physics(x₀ - -0.21007, square(x₂) + (x...
#                                   ₁ - 1.7943)) + x₁)) * x₁) + 0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.580e+04
# Head worker occupation: 1.6%
# Progress: 537 / 600 total iterations (89.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.699e-03  6.882e-02  y = (0.033786 * sqrt(x₀))
# 5           1.367e-03  2.174e-01  y = ((-7.1507 / x₀) + 0.39409)
# 7           8.062e-04  2.640e-01  y = (((-0.77608 / x₀) * x₂) + 0.39066)
# 8           7.355e-04  9.178e-02  y = ((physics(x₂, -0.36502) / square(x₀)) + 0.342)
# 9           5.324e-04  3.232e-01  y = (((-11.979 / physics(x₀, x₂)) * x₁) + 0.35067)
# 10          4.223e-04  2.317e-01  y = (((-1.0986 / physics(x₀, square(x₂))) * x₁) + 0.34236)
# 11          4.215e-04  1.861e-03  y = ((((-1.1441 - x₂) / physics(x₀, x₂)) * x₁) + 0.34345)
# 12          4.178e-04  8.760e-03  y = (((-1.2772 / (physics(x₀, square(x₂)) + x₁)) * x₁) + 0.346...
#                                   45)
# 13          4.178e-04  7.326e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# 15          4.177e-04  6.357e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + 0.34345) + x₁...
#                                   )) * x₁) + 0.34645)
# 16          4.177e-04  5.734e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + inv(x₂)) + x₁...
#                                   )) * x₁) + 0.34645)
# 17          4.172e-04  1.273e-03  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - 1.7943)...
#                                   ) + x₁)) * x₁) + 0.34645)
# 18          4.172e-04  1.633e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - square(...
#                                   1.7943))) + x₁)) * x₁) + 0.34645)
# 19          4.169e-04  7.241e-04  y = (((cube(-1.0841) / (physics(x₀ - -0.21007, square(x₂) + (x...
#                                   ₁ - 1.7943)) + x₁)) * x₁) + 0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.520e+04
# Head worker occupation: 1.6%
# Progress: 594 / 600 total iterations (99.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.088e-03  1.594e+01  y = 0.29093
# 4           1.699e-03  6.882e-02  y = (0.033786 * sqrt(x₀))
# 5           1.367e-03  2.174e-01  y = ((-7.1507 / x₀) + 0.39409)
# 7           8.062e-04  2.640e-01  y = (((-0.77608 / x₀) * x₂) + 0.39066)
# 8           7.355e-04  9.178e-02  y = ((physics(x₂, -0.36502) / square(x₀)) + 0.342)
# 9           5.324e-04  3.232e-01  y = (((-11.979 / physics(x₀, x₂)) * x₁) + 0.35067)
# 10          4.223e-04  2.317e-01  y = (((-1.0986 / physics(x₀, square(x₂))) * x₁) + 0.34236)
# 11          4.215e-04  1.861e-03  y = ((((-1.1441 - x₂) / physics(x₀, x₂)) * x₁) + 0.34345)
# 12          4.178e-04  8.760e-03  y = (((-1.2772 / (physics(x₀, square(x₂)) + x₁)) * x₁) + 0.346...
#                                   45)
# 13          4.178e-04  7.326e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂)) + x₁)) * x₁) +...
#                                    0.34645)
# 15          4.177e-04  6.357e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + 0.34345) + x₁...
#                                   )) * x₁) + 0.34645)
# 16          4.177e-04  5.734e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + inv(x₂)) + x₁...
#                                   )) * x₁) + 0.34645)
# 17          4.172e-04  1.273e-03  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - 1.7943)...
#                                   ) + x₁)) * x₁) + 0.34645)
# 18          4.172e-04  1.633e-05  y = (((cube(-1.0841) / (physics(x₀, square(x₂) + (x₁ - square(...
#                                   1.7943))) + x₁)) * x₁) + 0.34645)
# 19          4.169e-04  7.241e-04  y = (((cube(-1.0841) / (physics(x₀ - -0.21007, square(x₂) + (x...
#                                   ₁ - 1.7943)) + x₁)) * x₁) + 0.34645)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                         0.29093102
# 	1         0.068819                           (0.033786315 * sqrt(x0))
# 	2         0.217423                   ((-7.1507382 / x0) + 0.39408806)
# 	3         0.263994           (((-0.77607757 / x0) * x2) + 0.39066294)
# 	4         0.091781  ((physics(x2, -0.36501747) / square(x0)) + 0.3...
# 	5   >>>>  0.323240  (((-11.978534 / physics(x0, x2)) * x1) + 0.350...
# 	6         0.231684  (((-1.0985568 / physics(x0, square(x2))) * x1)...
# 	7         0.001861  ((((-1.1441168 - x2) / physics(x0, x2)) * x1) ...
# 	8         0.008760  (((-1.2772481 / (physics(x0, square(x2)) + x1)...
# 	9         0.000073  (((cube(-1.0840763) / (physics(x0, square(x2))...
# 	10        0.000064  (((cube(-1.0840763) / (physics(x0, square(x2) ...
# 	11        0.000058  (((cube(-1.0840763) / (physics(x0, square(x2) ...
# 	12        0.001273  (((cube(-1.0840763) / (physics(x0, square(x2) ...
# 	13        0.000016  (((cube(-1.0840763) / (physics(x0, square(x2) ...
# 	14        0.000724  (((cube(-1.0840763) / (physics(x0 - -0.2100719...
#
# 	        loss  complexity
# 	0   0.002088           1
# 	1   0.001699           4
# 	2   0.001367           5
# 	3   0.000806           7
# 	4   0.000735           8
# 	5   0.000532           9
# 	6   0.000422          10
# 	7   0.000421          11
# 	8   0.000418          12
# 	9   0.000418          13
# 	10  0.000418          15
# 	11  0.000418          16
# 	12  0.000417          17
# 	13  0.000417          18
# 	14  0.000417          19
# ]

# %%
model.sympy()
# Out:
# 0.35066944 - 11.978534*x1*x2/x0**2

# %%
n_bm2_pred = model.predict(X)
ypredict_simpler = model.predict(X, 2)

print("Default selection MSE:", np.power(n_bm2_pred - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 0.0005323529159587377
# Manual selection MSE for index 2: 0.0013669203450104874

# %%
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_bm2, y=n_bm2_pred, marker='o', c='none', edgecolor='b', label='Exterior Girder')

ax1.set_title('Accuracy')
ax1.legend()

ax1.set_xlabel('Target $n_{r1}$')
ax1.set_ylabel('Predicted $n_{r1}$')
ax1.grid()
