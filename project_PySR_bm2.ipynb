# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanrajs/sciml_project/blob/main/project_PySR_bm2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Symbolic Regression

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi
# Out:
# Installing Julia 1.8.5 on the current Colab Runtime...
# 2023-12-02 01:37:44 URL:https://julialang-s3.julialang.org/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz [130873886/130873886] -> "/tmp/julia.tar.gz" [1]
# Installing PyCall.jl...
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed VersionParsing ── v1.3.0
#    Installed PrecompileTools ─ v1.2.0
#    Installed Parsers ───────── v2.8.0
#    Installed MacroTools ────── v0.5.11
#    Installed PyCall ────────── v1.96.2
#    Installed Conda ─────────── v1.10.0
#    Installed JSON ──────────── v0.21.4
#    Installed Preferences ───── v1.4.1
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [438e738f] + PyCall v1.96.2
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [8f4d0f93] + Conda v1.10.0
#   [682c06a0] + JSON v0.21.4
#   [1914dd2f] + MacroTools v0.5.11
#   [69de0a69] + Parsers v2.8.0
#   [aea7be01] + PrecompileTools v1.2.0
#   [21216c6a] + Preferences v1.4.1
#   [438e738f] + PyCall v1.96.2
#   [81def892] + VersionParsing v1.3.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b27032c2] + LibCURL v0.6.3
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [fa267f1f] + TOML v1.0.0
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.0+0
#   [14a3606d] + MozillaCACerts_jll v2022.2.1
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [83775a58] + Zlib_jll v1.2.12+3
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
# Success

# %% [markdown]
# Install PySR and PyTorch-Lightning:

# %%
# %pip install -Uq pysr pytorch_lightning --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 31.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 68.8 MB/s eta 0:00:00

# %%
from julia import Julia

julia = Julia(compiled_modules=False, threads="auto")
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()

# %%
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 22.04.3 LTS
#   uname: Linux 5.15.120+ #1 SMP Wed Aug 30 11:19:59 UTC 2023 x86_64 x86_64
#   CPU: Intel(R) Xeon(R) CPU @ 2.00GHz:
#               speed         user         nice          sys         idle          irq
#        #1  2000 MHz        868 s          0 s        166 s       1745 s          0 s
#        #2  2000 MHz        795 s          0 s        171 s       1813 s          0 s
#   Memory: 12.6783447265625 GB (11603.03125 MB free)
#   Uptime: 286.83 sec
#   Load Avg:  2.24  0.91  0.36
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, skylake-avx512)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/lib64-nvidia
#   JULIA_PROJECT = @pysr-0.16.3
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.10.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#     Updating registry at `~/.julia/registries/General.toml`
#      Cloning git-repo `https://github.com/MilesCranmer/SymbolicRegression.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed IrrationalConstants ────────────── v0.2.2
#    Installed Tricks ─────────────────────────── v0.1.8
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed DynamicExpressions ─────────────── v0.13.1
#    Installed ScientificTypesBase ────────────── v3.0.0
#    Installed DiffRules ──────────────────────── v1.15.1
#    Installed Adapt ──────────────────────────── v3.7.1
#    Installed OffsetArrays ───────────────────── v1.12.10
#    Installed LayoutPointers ─────────────────── v0.1.15
#    Installed MLJModelInterface ──────────────── v1.9.3
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed StatisticalTraits ──────────────── v3.2.0
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed CPUSummary ─────────────────────── v0.2.4
#    Installed SpecialFunctions ───────────────── v2.3.1
#    Installed VectorizationBase ──────────────── v0.21.65
#    Installed Optim ──────────────────────────── v1.7.6
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed DataAPI ────────────────────────── v1.15.0
#    Installed PDMats ─────────────────────────── v0.11.30
#    Installed JLLWrappers ────────────────────── v1.5.0
#    Installed Setfield ───────────────────────── v1.1.1
#    Installed StaticArraysCore ───────────────── v1.4.2
#    Installed StaticArrays ───────────────────── v1.7.0
#    Installed LoopVectorization ──────────────── v0.12.166
#    Installed NaNMath ────────────────────────── v1.0.2
#    Installed OrderedCollections ─────────────── v1.6.3
#    Installed ConstructionBase ───────────────── v1.5.4
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed HostCPUFeatures ────────────────── v0.1.16
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed NLSolversBase ──────────────────── v7.8.3
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed ChainRulesCore ─────────────────── v1.18.0
#    Installed ArrayInterface ─────────────────── v7.5.1
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed CommonSubexpressions ───────────── v0.3.0
#    Installed FillArrays ─────────────────────── v1.8.0
#    Installed LogExpFunctions ────────────────── v0.3.26
#    Installed DataStructures ─────────────────── v0.18.15
#    Installed LineSearches ───────────────────── v7.2.0
#    Installed ForwardDiff ────────────────────── v0.10.36
#    Installed ProgressBars ───────────────────── v1.5.1
#    Installed Requires ───────────────────────── v1.3.0
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed StatsAPI ───────────────────────── v1.7.0
#    Installed Static ─────────────────────────── v0.8.8
#    Installed Compat ─────────────────────────── v4.10.1
#    Installed SLEEFPirates ───────────────────── v0.6.42
#    Installed PackageExtensionCompat ─────────── v1.0.2
#    Installed OpenSpecFun_jll ────────────────── v0.5.5+0
#    Installed ClusterManagers ────────────────── v0.4.5
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed StaticArrayInterface ───────────── v1.4.1
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed DynamicQuantities ──────────────── v0.6.3
#    Installed Missings ───────────────────────── v1.1.0
#    Installed InverseFunctions ───────────────── v0.1.12
#    Installed SortingAlgorithms ──────────────── v1.2.0
#    Installed StatsBase ──────────────────────── v0.34.2
#    Installed LossFunctions ──────────────────── v0.11.1
#    Installed ChangesOfVariables ─────────────── v0.1.8
#    Installed FiniteDiff ─────────────────────── v2.21.1
#    Installed DocStringExtensions ────────────── v0.9.3
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [34f1f09b] + ClusterManagers v0.4.5
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [79e6a3ab] + Adapt v3.7.1
# ⌅ [4fba245c] + ArrayInterface v7.5.1
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [2a0fbf3d] + CPUSummary v0.2.4
#   [d360d2e6] + ChainRulesCore v1.18.0
#   [9e997f8a] + ChangesOfVariables v0.1.8
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [34f1f09b] + ClusterManagers v0.4.5
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.10.1
#   [187b0558] + ConstructionBase v1.5.4
#   [adafc99b] + CpuId v0.3.1
#   [9a962f9c] + DataAPI v1.15.0
#   [864edb3b] + DataStructures v0.18.15
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [ffbed154] + DocStringExtensions v0.9.3
#   [a40a106e] + DynamicExpressions v0.13.1
# ⌅ [06fc5a27] + DynamicQuantities v0.6.3
#   [1a297f60] + FillArrays v1.8.0
#   [6a86dc24] + FiniteDiff v2.21.1
#   [f6369f11] + ForwardDiff v0.10.36
#   [3e5b6fbb] + HostCPUFeatures v0.1.16
#   [615f187c] + IfElse v0.1.1
#   [3587e190] + InverseFunctions v0.1.12
#   [92d709cd] + IrrationalConstants v0.2.2
#   [692b3bcd] + JLLWrappers v1.5.0
#   [10f19ff3] + LayoutPointers v0.1.15
#   [d3d80556] + LineSearches v7.2.0
#   [2ab3a3ac] + LogExpFunctions v0.3.26
#   [bdcacae8] + LoopVectorization v0.12.166
#   [30fc2ffe] + LossFunctions v0.11.1
#   [e80e1ace] + MLJModelInterface v1.9.3
#   [d125e4d3] + ManualMemory v0.1.8
#   [e1d29d7a] + Missings v1.1.0
#   [d41bc354] + NLSolversBase v7.8.3
#   [77ba4419] + NaNMath v1.0.2
#   [6fe1bfb0] + OffsetArrays v1.12.10
# ⌅ [429524aa] + Optim v1.7.6
#   [bac558e1] + OrderedCollections v1.6.3
#   [90014a1f] + PDMats v0.11.30
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [d96e819e] + Parameters v0.12.3
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [49802e3a] + ProgressBars v1.5.1
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.3.0
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.42
#   [30f210dd] + ScientificTypesBase v3.0.0
#   [efcf1570] + Setfield v1.1.1
#   [a2af1166] + SortingAlgorithms v1.2.0
#   [276daf66] + SpecialFunctions v2.3.1
#   [aedffcd0] + Static v0.8.8
#   [0d7ed370] + StaticArrayInterface v1.4.1
#   [90137ffa] + StaticArrays v1.7.0
#   [1e83bf80] + StaticArraysCore v1.4.2
#   [64bff920] + StatisticalTraits v3.2.0
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.2
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#   [8290d209] + ThreadingUtilities v0.5.2
#   [410a4b4d] + Tricks v0.1.8
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.65
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [56ddb016] + Logging
#   [44cfe95a] + Pkg v1.8.0
#   [3fa0cd96] + REPL
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [a4e569a6] + Tar v1.10.1
#   [8dfed614] + Test
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [3f19e933] + p7zip_jll v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:118: UserWarning: It is recommended to restart Python after installing PySR's dependencies, so that the Julia environment is properly initialized.
#   warnings.warn(

# %%
import sympy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bhushanrajs/sciml_project/main/analysis_data.csv')

tx_girders = {'Tx28' : {'D' : 28.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 6.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx34' : {'D' : 34.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 12.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx40' : {'D' : 40.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 18.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx46' : {'D' : 46.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 22.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx54' : {'D' : 54.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 30.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx62' : {'D' : 62.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 37.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx70' : {'D' : 70.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 45.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx84' : {'D' : 84.0, 'b1' : 58.0, 'b2' : 8.0, 'b3' : 38.0, 'b4' : 3.0, 'b5' : 3.0, 'd1' : 4.0, 'd2' : 3.5, 'd3' : 3.0, 'd4' : 55.75, 'd5' : 3.0, 'd6' : 6.0, 'd7' : 8.75}
              }

# bridge geometry data
L = df['L']/12 # span length in ft.
S = df['S']/12 # girder spacing in ft.
w_oh = df['w_oh']/12 # overhang width in ft.
ts = df['ts_U']/12 # thickness of overhang in ft.
girder = df['Girder Type']
D = []
for _, girder_type in girder.items():
  D.append(tx_girders[girder_type]['D'])
df['D'] = D

# intensity of railing dead load in kip/ft
b_rail = df['b_rail_left'] # width of railing
q_rail = (df['q_rail_left'] * b_rail * 12)/1000

# max bending moment in exterior girder G1 & interior girder G2 in kip-ft
bm1 = df['G1 - max_bm']/(1000*12)
bm2 = df['G2 - max_bm']/(1000*12)
bm3 = df['G3 - max_bm']/(1000*12)
bm4 = df['G4 - max_bm']/(1000*12)

# reaction in girders G1 & G2 in kip. (only A1 taken due to symmetry)
r1 = df['G1-A1-Y']/1000
r2 = df['G2-A1-Y']/1000
r3 = df['G3-A1-Y']/1000
r4 = df['G4-A1-Y']/1000

# line analysis with full railing load assumed to be applied on a girder
bm_line = q_rail * (L - 2*9/12)**2 / 8
r_line = q_rail * L / 2


# normalizing bending moments with respect to line analysis
n_bm1 = bm1 / bm_line
n_bm2 = bm2 / bm_line
n_bm3 = bm3 / bm_line
n_bm4 = bm4 / bm_line

# normalizing vertical reactions with respect to line analysis
n_r1 = r1 / r_line
n_r2 = r2 / r_line
n_r3 = r3 / r_line
n_r4 = r4 / r_line

# add the distribution factors to the dataframe
df['n_bm1'] = n_bm1
df['n_bm2'] = n_bm2
df['n_bm3'] = n_bm3
df['n_bm4'] = n_bm4
df['n_r1'] = n_r1
df['n_r2'] = n_r2
df['n_r3'] = n_r3
df['n_r4'] = n_r4

# %%
# sample data from leve rule
# n_r1 = (w_oh + S) / S

# %%
X = np.stack((L, w_oh, S), axis=-1)
y = n_bm1

# %%
# Learn equations
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# model = PySRRegressor(
#     niterations=30,
#     binary_operators=['+', '-', '*', '/', '^'],
#     unary_operators=["square", "cube", "sqrt"],
#     **default_pysr_params
# )

model = PySRRegressor(
    niterations=40,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
)

model.fit(X, y)

print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# WARNING: using StaticArrays.setindex in module FiniteDiff conflicts with an existing identifier.
# Started!
#
# Expressions evaluated per second: 2.800e+03
# Head worker occupation: 3.2%
# Progress: 6 / 600 total iterations (1.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.180e-02  1.594e+01  y = 0.66058
# 7           7.750e-03  7.003e-02  y = (inv(x₂ / -1.7265) + square(0.94423))
# 9           6.881e-03  5.948e-02  y = (inv((-0.8242 + x₂) / -1.7265) + square(0.94423))
# 12          6.872e-03  4.555e-04  y = (inv(((x₂ + inv(-1.7265)) / -1.7265) + 0.18391) + square(0...
#                                   .94423))
# 14          6.857e-03  1.100e-03  y = (inv(((x₂ + inv(-0.28248 * x₂)) - 0.28805) / -1.7265) + sq...
#                                   uare(0.94423))
# 16          6.159e-03  5.364e-02  y = (inv((x₂ + (inv(physics(x₁, sqrt(x₀)) * -1.7265) + -0.8242...
#                                   )) / -1.7265) + 0.94423)
# 18          5.642e-03  4.386e-02  y = (square(-0.80143) ^ physics(physics(square(sqrt((((x₀ - x₁...
#                                   ) - x₂) / 0.94176) / x₀)), 0.94176), 0.81457))
# 19          5.085e-03  1.039e-01  y = (((square(sqrt(cube(square(x₂ / sqrt(x₀)))) ^ inv(x₂)) + -...
#                                   0.35889) * 0.42536) - (-0.24704 * 1.5942))
# 20          4.969e-03  2.303e-02  y = (((square(sqrt(square(cube(square(x₂ / sqrt(x₀))))) ^ inv(...
#                                   x₂)) + -0.34829) * 0.22392) - (-0.31856 * 1.6086))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.400e+04
# Head worker occupation: 1.4%
# Progress: 63 / 600 total iterations (10.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 4           1.051e-02  3.822e-02  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 10          5.971e-03  2.447e-02  y = square(inv(x₂ / (-1.7265 / sqrt(x₁))) + 0.94522)
# 11          5.969e-03  3.528e-04  y = square(inv(x₂ / (-1.7265 / sqrt(x₁))) + sqrt(0.90271))
# 14          5.775e-03  1.103e-02  y = (((inv(x₂ / -1.7265) / 0.71226) - sqrt(0.028055 ^ x₁)) + s...
#                                   qrt(0.94423))
# 18          5.642e-03  5.828e-03  y = (square(-0.80143) ^ physics(physics(square(sqrt((((x₀ - x₁...
#                                   ) - x₂) / 0.94176) / x₀)), 0.94176), 0.81457))
# 19          5.085e-03  1.039e-01  y = (((square(sqrt(cube(square(x₂ / sqrt(x₀)))) ^ inv(x₂)) + -...
#                                   0.35889) * 0.42536) - (-0.24704 * 1.5942))
# 20          4.969e-03  2.303e-02  y = (((square(sqrt(square(cube(square(x₂ / sqrt(x₀))))) ^ inv(...
#                                   x₂)) + -0.34829) * 0.22392) - (-0.31856 * 1.6086))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.550e+04
# Head worker occupation: 1.1%
# Progress: 98 / 600 total iterations (16.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 4           1.051e-02  3.822e-02  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 9           6.576e-03  6.461e-03  y = (cube(inv(x₀ ^ 0.0028535)) + (-2.527 / x₂))
# 10          5.971e-03  9.652e-02  y = square(inv(x₂ / (-1.7265 / sqrt(x₁))) + 0.94522)
# 11          5.795e-03  3.003e-02  y = ((square(0.68194) ^ square(physics(0.68194, x₁))) + (-2.52...
#                                   7 / x₂))
# 12          5.684e-03  1.917e-02  y = (cube(0.68194 ^ cube(physics(sqrt(0.68194), x₁))) + (-2.52...
#                                   7 / x₂))
# 15          5.451e-03  1.399e-02  y = (inv(x₂ / physics(-1.9695, -1.3026)) + (cube(x₁) ^ square(...
#                                   inv(0.15538 * x₀))))
# 17          5.441e-03  9.431e-04  y = (inv(x₂ / (physics(-1.9695, -1.3026) + -0.024706)) + (cube...
#                                   (x₁) ^ square(inv(0.15538 * x₀))))
# 19          5.085e-03  3.379e-02  y = (((square(sqrt(cube(square(x₂ / sqrt(x₀)))) ^ inv(x₂)) + -...
#                                   0.35889) * 0.42536) - (-0.24704 * 1.5942))
# 20          4.969e-03  2.303e-02  y = (((square(sqrt(square(cube(square(x₂ / sqrt(x₀))))) ^ inv(...
#                                   x₂)) + -0.34829) * 0.22392) - (-0.31856 * 1.6086))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.400e+04
# Head worker occupation: 1.1%
# Progress: 117 / 600 total iterations (19.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 4           1.051e-02  3.822e-02  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 9           6.576e-03  6.461e-03  y = (cube(inv(x₀ ^ 0.0028535)) + (-2.527 / x₂))
# 10          5.971e-03  9.652e-02  y = square(inv(x₂ / (-1.7265 / sqrt(x₁))) + 0.94522)
# 11          5.714e-03  4.403e-02  y = ((cube(0.23421) ^ square(0.21215 / x₁)) + (-2.527 / x₂))
# 12          5.684e-03  5.168e-03  y = (cube(0.68194 ^ cube(physics(sqrt(0.68194), x₁))) + (-2.52...
#                                   7 / x₂))
# 15          5.274e-03  2.501e-02  y = ((x₀ ^ (sqrt(0.48093) ^ physics(sqrt(x₀ * 0.69925), x₁))) ...
#                                   + (-2.8093 / x₂))
# 19          5.085e-03  9.102e-03  y = (((square(sqrt(cube(square(x₂ / sqrt(x₀)))) ^ inv(x₂)) + -...
#                                   0.35889) * 0.42536) - (-0.24704 * 1.5942))
# 20          4.969e-03  2.303e-02  y = (((square(sqrt(square(cube(square(x₂ / sqrt(x₀))))) ^ inv(...
#                                   x₂)) + -0.34829) * 0.22392) - (-0.31856 * 1.6086))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.360e+04
# Head worker occupation: 1.0%
# Progress: 143 / 600 total iterations (23.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 4           1.051e-02  3.822e-02  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 8           6.586e-03  8.096e-03  y = ((cube(x₀) ^ -0.0027036) + (-2.527 / x₂))
# 9           6.576e-03  1.557e-03  y = (cube(inv(x₀ ^ 0.0028535)) + (-2.527 / x₂))
# 10          5.971e-03  9.652e-02  y = square(inv(x₂ / (-1.7265 / sqrt(x₁))) + 0.94522)
# 11          5.714e-03  4.403e-02  y = ((cube(0.23421) ^ square(0.21215 / x₁)) + (-2.527 / x₂))
# 12          5.684e-03  5.168e-03  y = (cube(0.68194 ^ cube(physics(sqrt(0.68194), x₁))) + (-2.52...
#                                   7 / x₂))
# 13          5.327e-03  6.502e-02  y = (inv(x₂ / (-1.9695 + -1.3026)) + (cube(square(x₁)) ^ inv(x...
#                                   ₀)))
# 15          4.993e-03  3.231e-02  y = (inv(x₂ / (-1.9695 + -1.3026)) + (physics(cube(x₁), sqrt(x...
#                                   ₀)) ^ inv(x₀)))
# 16          4.886e-03  2.178e-02  y = (inv(x₂ / (-1.9695 + -1.3026)) + (physics(cube(x₁), sqrt(s...
#                                   qrt(x₀))) ^ inv(x₀)))
# 17          4.862e-03  4.779e-03  y = (inv(x₂ / (-1.9695 + -1.3026)) + (physics(cube(x₁), sqrt(s...
#                                   qrt(square(x₂)))) ^ inv(x₀)))
# 18          4.749e-03  2.371e-02  y = (inv(x₂ / (-1.9695 + -1.3026)) + ((physics(cube(x₁), 1.187...
#                                   6 ^ x₂) - 0.67298) ^ inv(x₀)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.440e+04
# Head worker occupation: 0.9%
# Progress: 169 / 600 total iterations (28.167%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 4           1.051e-02  3.822e-02  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 8           6.257e-03  2.522e-02  y = sqrt(inv(sqrt(cube(x₀)) ^ inv(x₂)))
# 10          5.834e-03  3.499e-02  y = ((0.68194 ^ (0.68194 / cube(x₁))) + (-2.527 / x₂))
# 11          5.710e-03  2.144e-02  y = ((0.75455 ^ cube(sqrt(0.57847) ^ x₁)) + (-2.527 / x₂))
# 12          5.460e-03  4.485e-02  y = ((0.51907 ^ (physics(0.042475, inv(x₀)) / x₁)) + (-2.527 /...
#                                    x₂))
# 13          5.327e-03  2.465e-02  y = (inv(x₂ / (-1.9695 + -1.3026)) + (cube(square(x₁)) ^ inv(x...
#                                   ₀)))
# 14          5.002e-03  6.284e-02  y = (inv(x₂ / (-1.9695 + -1.3026)) + (physics(cube(x₁), x₂) ^ ...
#                                   inv(x₀)))
# 15          4.993e-03  1.779e-03  y = (inv(x₂ / (-1.9695 + -1.3026)) + (physics(cube(x₁), sqrt(x...
#                                   ₀)) ^ inv(x₀)))
# 16          4.108e-03  1.952e-01  y = sqrt(inv(physics(sqrt(cube(x₀) * square(0.32927)), x₂ * sq...
#                                   uare(x₁)) ^ inv(x₂)))
# 18          4.108e-03  4.143e-06  y = sqrt(inv(physics(sqrt((cube(x₀) + x₀) * square(0.32927)), ...
#                                   x₂ * square(x₁)) ^ inv(x₂)))
# 20          3.899e-03  2.613e-02  y = sqrt(inv(physics(sqrt((cube(x₀) + x₀) * square(-0.84978)),...
#                                    x₂ * square(x₁ * x₁)) ^ inv(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.140e+04
# Head worker occupation: 0.9%
# Progress: 190 / 600 total iterations (31.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 4           1.051e-02  3.822e-02  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 8           6.257e-03  2.522e-02  y = sqrt(inv(sqrt(cube(x₀)) ^ inv(x₂)))
# 10          5.717e-03  4.510e-02  y = ((sqrt(0.64349) ^ inv(square(x₁))) + (-2.527 / x₂))
# 11          5.710e-03  1.211e-03  y = ((0.75455 ^ cube(sqrt(0.57847) ^ x₁)) + (-2.527 / x₂))
# 12          5.255e-03  8.304e-02  y = sqrt(inv(sqrt(cube(x₀) / x₁) ^ (inv(x₂) * 1.2135)))
# 14          4.074e-03  1.273e-01  y = sqrt(inv(sqrt(cube(sqrt(cube(x₀) / square(square(x₁))))) ^...
#                                    inv(x₂)))
# 16          4.048e-03  3.191e-03  y = (((x₁ ^ (sqrt(0.52777) ^ sqrt(x₀ - x₂))) / square(1.0572))...
#                                    + (-2.527 / x₂))
# 17          3.807e-03  6.129e-02  y = sqrt(inv(physics(sqrt(cube(x₀) * sqrt(square(0.32927))), x...
#                                   ₂ * cube(x₁)) ^ inv(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.100e+04
# Head worker occupation: 0.8%
# Progress: 217 / 600 total iterations (36.167%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 4           1.051e-02  3.822e-02  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 8           5.722e-03  5.497e-02  y = sqrt(inv(x₀ ^ inv(x₂ * 0.59681)))
# 9           5.686e-03  6.428e-03  y = ((0.69245 ^ inv(cube(x₁))) + (-2.527 / x₂))
# 11          5.660e-03  2.234e-03  y = sqrt(inv(sqrt(cube(x₀)) ^ inv(x₂ - square(-0.81431))))
# 12          5.255e-03  7.431e-02  y = sqrt(inv(sqrt(cube(x₀) / x₁) ^ (inv(x₂) * 1.2135)))
# 13          3.876e-03  3.045e-01  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁))) ^ inv(x₂))
# 15          3.802e-03  9.624e-03  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁) - -0.57963)) ...
#                                   ^ inv(x₂))
# 18          3.793e-03  7.864e-04  y = inv(sqrt(((cube(x₀ - 1.3787) / x₂) - square(x₀)) / square(...
#                                   square(x₁))) ^ inv(x₂))
# 20          3.738e-03  7.210e-03  y = inv(sqrt((((cube(x₀) / x₂) + -0.066378) - physics(x₂, inv(...
#                                   x₀))) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.080e+04
# Head worker occupation: 0.8%
# Progress: 236 / 600 total iterations (39.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.426e-03  1.989e-04  y = inv(((x₀ - -0.70253) / x₁) ^ inv(x₂))
# 11          4.338e-03  1.001e-02  y = inv(((x₀ + -1.2809) / x₁) ^ inv(x₂ + -0.13064))
# 13          3.876e-03  5.634e-02  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁))) ^ inv(x₂))
# 15          3.802e-03  9.624e-03  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁) - -0.57963)) ...
#                                   ^ inv(x₂))
# 16          3.795e-03  1.895e-03  y = inv((sqrt((cube(x₀) / x₂) / square(x₁ + x₁)) - x₂) ^ inv(x...
#                                   ₂))
# 17          3.737e-03  1.519e-02  y = inv(sqrt(((cube(x₀) / x₂) - (x₀ / 0.01327)) / square(squar...
#                                   e(x₁))) ^ inv(x₂))
# 20          3.701e-03  3.236e-03  y = inv((sqrt(((cube(x₀) / square(x₁ + x₁)) / x₂) - x₀) - (x₁ ...
#                                   + x₁)) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.020e+04
# Head worker occupation: 0.8%
# Progress: 258 / 600 total iterations (43.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.298e-03  1.485e-02  y = inv((x₀ / (x₁ + -0.26354)) ^ inv(x₂))
# 11          4.238e-03  7.026e-03  y = inv(((x₀ / x₁) + -0.86539) ^ inv(x₂ - 0.31317))
# 13          3.876e-03  4.467e-02  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁))) ^ inv(x₂))
# 15          3.802e-03  9.624e-03  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁) - -0.57963)) ...
#                                   ^ inv(x₂))
# 16          3.794e-03  2.050e-03  y = inv(sqrt((cube(x₀) / x₂) / (square(square(x₁)) + cube(1.41...
#                                   58))) ^ inv(x₂))
# 17          3.737e-03  1.504e-02  y = inv(sqrt(((cube(x₀) / x₂) - (x₀ / 0.01327)) / square(squar...
#                                   e(x₁))) ^ inv(x₂))
# 19          3.705e-03  4.411e-03  y = inv(sqrt(((cube(x₀) / x₂) - ((x₀ + x₀) / 0.01327)) / squar...
#                                   e(square(x₁))) ^ inv(x₂))
# 20          3.701e-03  8.858e-04  y = inv((sqrt(((cube(x₀) / square(x₁ + x₁)) / x₂) - x₀) - (x₁ ...
#                                   + x₁)) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.080e+04
# Head worker occupation: 0.7%
# Progress: 287 / 600 total iterations (47.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.298e-03  1.485e-02  y = inv((x₀ / (x₁ + -0.26354)) ^ inv(x₂))
# 11          4.163e-03  1.588e-02  y = inv(((x₀ - x₂) / (x₁ + -0.30871)) ^ inv(x₂))
# 12          4.098e-03  1.578e-02  y = inv(physics(sqrt(x₀ - x₂), x₁) ^ inv(x₂ + -0.60232))
# 13          3.876e-03  5.586e-02  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁))) ^ inv(x₂))
# 15          3.760e-03  1.515e-02  y = inv(((((x₀ * 1.4831) / x₁) - (x₂ + 0.83689)) + -2.747) ^ i...
#                                   nv(x₂))
# 17          3.737e-03  3.015e-03  y = inv(sqrt(((cube(x₀) / x₂) - (x₀ / 0.01327)) / square(squar...
#                                   e(x₁))) ^ inv(x₂))
# 19          3.705e-03  4.411e-03  y = inv(sqrt(((cube(x₀) / x₂) - ((x₀ + x₀) / 0.01327)) / squar...
#                                   e(square(x₁))) ^ inv(x₂))
# 20          3.603e-03  2.783e-02  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.010e+04
# Head worker occupation: 0.7%
# Progress: 305 / 600 total iterations (50.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.298e-03  1.485e-02  y = inv((x₀ / (x₁ + -0.26354)) ^ inv(x₂))
# 11          4.163e-03  1.588e-02  y = inv(((x₀ - x₂) / (x₁ + -0.30871)) ^ inv(x₂))
# 12          4.098e-03  1.578e-02  y = inv(physics(sqrt(x₀ - x₂), x₁) ^ inv(x₂ + -0.60232))
# 13          3.876e-03  5.586e-02  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁))) ^ inv(x₂))
# 15          3.760e-03  1.515e-02  y = inv(((((x₀ * 1.4831) / x₁) - (x₂ + 0.83689)) + -2.747) ^ i...
#                                   nv(x₂))
# 17          3.737e-03  3.015e-03  y = inv(sqrt(((cube(x₀) / x₂) - (x₀ / 0.01327)) / square(squar...
#                                   e(x₁))) ^ inv(x₂))
# 18          3.722e-03  4.192e-03  y = inv(sqrt(physics((((cube(x₀) / x₁) / square(x₀)) - x₂) * 1...
#                                   .356, 0.76035)) ^ inv(x₂))
# 19          3.705e-03  4.631e-03  y = inv(sqrt(((cube(x₀) / x₂) - ((x₀ + x₀) / 0.01327)) / squar...
#                                   e(square(x₁))) ^ inv(x₂))
# 20          3.603e-03  2.783e-02  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.620e+03
# Head worker occupation: 0.7%
# Progress: 327 / 600 total iterations (54.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.298e-03  1.485e-02  y = inv((x₀ / (x₁ + -0.26354)) ^ inv(x₂))
# 11          4.163e-03  1.588e-02  y = inv(((x₀ - x₂) / (x₁ + -0.30871)) ^ inv(x₂))
# 12          4.098e-03  1.578e-02  y = inv(physics(sqrt(x₀ - x₂), x₁) ^ inv(x₂ + -0.60232))
# 13          3.876e-03  5.586e-02  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁))) ^ inv(x₂))
# 14          3.815e-03  1.587e-02  y = inv(sqrt(((cube(x₀) / cube(x₁)) * 0.37622) / x₂) ^ inv(x₂)...
#                                   )
# 15          3.760e-03  1.444e-02  y = inv(((((x₀ * 1.4831) / x₁) - (x₂ + 0.83689)) + -2.747) ^ i...
#                                   nv(x₂))
# 17          3.737e-03  3.015e-03  y = inv(sqrt(((cube(x₀) / x₂) - (x₀ / 0.01327)) / square(squar...
#                                   e(x₁))) ^ inv(x₂))
# 18          3.722e-03  4.192e-03  y = inv(sqrt(physics((((cube(x₀) / x₁) / square(x₀)) - x₂) * 1...
#                                   .356, 0.76035)) ^ inv(x₂))
# 19          3.679e-03  1.151e-02  y = (inv((physics((x₀ / x₁) - x₁, 1.3717) * 1.511) ^ inv((x₂ +...
#                                    0.77547) + 1.511)) * 1.2232)
# 20          3.603e-03  2.095e-02  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.080e+04
# Head worker occupation: 0.7%
# Progress: 355 / 600 total iterations (59.167%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.296e-03  1.507e-02  y = inv((x₀ / (x₁ - 0.34781)) ^ inv(x₂))
# 10          4.262e-03  7.851e-03  y = inv((x₀ / (square(x₁) * 0.34283)) ^ inv(x₂))
# 11          4.163e-03  2.347e-02  y = inv(((x₀ - x₂) / (x₁ + -0.30871)) ^ inv(x₂))
# 12          4.098e-03  1.578e-02  y = inv(physics(sqrt(x₀ - x₂), x₁) ^ inv(x₂ + -0.60232))
# 13          3.876e-03  5.586e-02  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁))) ^ inv(x₂))
# 14          3.815e-03  1.587e-02  y = inv(sqrt(((cube(x₀) / cube(x₁)) * 0.37622) / x₂) ^ inv(x₂)...
#                                   )
# 15          3.760e-03  1.444e-02  y = inv(((((x₀ * 1.4831) / x₁) - (x₂ + 0.83689)) + -2.747) ^ i...
#                                   nv(x₂))
# 17          3.737e-03  3.015e-03  y = inv(sqrt(((cube(x₀) / x₂) - (x₀ / 0.01327)) / square(squar...
#                                   e(x₁))) ^ inv(x₂))
# 18          3.722e-03  4.192e-03  y = inv(sqrt(physics((((cube(x₀) / x₁) / square(x₀)) - x₂) * 1...
#                                   .356, 0.76035)) ^ inv(x₂))
# 19          3.679e-03  1.151e-02  y = (inv((physics((x₀ / x₁) - x₁, 1.3717) * 1.511) ^ inv((x₂ +...
#                                    0.77547) + 1.511)) * 1.2232)
# 20          3.603e-03  2.095e-02  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.020e+04
# Head worker occupation: 0.7%
# Progress: 374 / 600 total iterations (62.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.294e-03  1.529e-02  y = inv((x₀ / (x₁ + -0.30871)) ^ inv(x₂))
# 10          4.262e-03  7.404e-03  y = inv((x₀ / (square(x₁) * 0.34283)) ^ inv(x₂))
# 11          4.163e-03  2.347e-02  y = inv(((x₀ - x₂) / (x₁ + -0.30871)) ^ inv(x₂))
# 12          4.098e-03  1.578e-02  y = inv(physics(sqrt(x₀ - x₂), x₁) ^ inv(x₂ + -0.60232))
# 13          3.876e-03  5.586e-02  y = inv(sqrt((cube(x₀) / x₂) / square(square(x₁))) ^ inv(x₂))
# 14          3.815e-03  1.587e-02  y = inv(sqrt(((cube(x₀) / cube(x₁)) * 0.37622) / x₂) ^ inv(x₂)...
#                                   )
# 15          3.760e-03  1.444e-02  y = inv(((((x₀ * 1.4831) / x₁) - (x₂ + 0.83689)) + -2.747) ^ i...
#                                   nv(x₂))
# 17          3.737e-03  3.015e-03  y = inv(sqrt(((cube(x₀) / x₂) - (x₀ / 0.01327)) / square(squar...
#                                   e(x₁))) ^ inv(x₂))
# 18          3.722e-03  4.192e-03  y = inv(sqrt(physics((((cube(x₀) / x₁) / square(x₀)) - x₂) * 1...
#                                   .356, 0.76035)) ^ inv(x₂))
# 19          3.679e-03  1.151e-02  y = (inv((physics((x₀ / x₁) - x₁, 1.3717) * 1.511) ^ inv((x₂ +...
#                                    0.77547) + 1.511)) * 1.2232)
# 20          3.603e-03  2.095e-02  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.020e+04
# Head worker occupation: 0.7%
# Progress: 400 / 600 total iterations (66.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.294e-03  1.529e-02  y = inv((x₀ / (x₁ + -0.30871)) ^ inv(x₂))
# 10          4.180e-03  2.690e-02  y = inv((x₀ - (x₁ / cube(0.43203))) ^ inv(x₂))
# 11          4.038e-03  3.464e-02  y = inv(((x₀ / x₁) - x₁) ^ inv(x₂ - 0.58886))
# 12          3.662e-03  9.781e-02  y = inv((((x₀ + x₀) / x₁) + cube(-2.7964)) ^ inv(x₂))
# 20          3.603e-03  2.020e-03  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.070e+04
# Head worker occupation: 0.7%
# Progress: 422 / 600 total iterations (70.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.294e-03  1.529e-02  y = inv((x₀ / (x₁ + -0.30871)) ^ inv(x₂))
# 10          4.180e-03  2.690e-02  y = inv((x₀ - (x₁ / cube(0.43203))) ^ inv(x₂))
# 11          4.038e-03  3.464e-02  y = inv(((x₀ / x₁) - x₁) ^ inv(x₂ - 0.58886))
# 12          3.662e-03  9.781e-02  y = inv((((x₀ + x₀) / x₁) + cube(-2.7964)) ^ inv(x₂))
# 20          3.603e-03  2.020e-03  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.080e+04
# Head worker occupation: 0.7%
# Progress: 446 / 600 total iterations (74.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.101e-03  3.824e-02  y = inv((x₀ + (x₁ * -12.086)) ^ inv(x₂))
# 11          4.038e-03  7.819e-03  y = inv(((x₀ / x₁) - x₁) ^ inv(x₂ - 0.58886))
# 12          3.662e-03  9.781e-02  y = inv((((x₀ + x₀) / x₁) + cube(-2.7964)) ^ inv(x₂))
# 20          3.603e-03  2.020e-03  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.150e+04
# Head worker occupation: 0.7%
# Progress: 475 / 600 total iterations (79.167%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.101e-03  3.824e-02  y = inv((x₀ + (x₁ * -12.086)) ^ inv(x₂))
# 11          4.038e-03  7.819e-03  y = inv(((x₀ / x₁) - x₁) ^ inv(x₂ - 0.58886))
# 12          3.662e-03  9.781e-02  y = inv((((x₀ + x₀) / x₁) + cube(-2.7964)) ^ inv(x₂))
# 20          3.603e-03  2.020e-03  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.150e+04
# Head worker occupation: 0.7%
# Progress: 494 / 600 total iterations (82.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.101e-03  3.824e-02  y = inv((x₀ + (x₁ * -12.086)) ^ inv(x₂))
# 11          3.851e-03  3.149e-02  y = inv(((x₀ / (x₁ - 0.73668)) - x₂) ^ inv(x₂))
# 12          3.662e-03  5.047e-02  y = inv((((x₀ + x₀) / x₁) + cube(-2.7964)) ^ inv(x₂))
# 14          3.659e-03  3.332e-04  y = inv((((x₀ + x₀) / (x₁ - -0.014767)) + cube(-2.7964)) ^ inv...
#                                   (x₂))
# 16          3.658e-03  9.788e-05  y = inv((((x₀ + x₀) / physics(x₁ - -0.014767, x₁)) + cube(-2.7...
#                                   964)) ^ inv(x₂))
# 20          3.603e-03  3.824e-03  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.110e+04
# Head worker occupation: 0.6%
# Progress: 516 / 600 total iterations (86.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.101e-03  3.824e-02  y = inv((x₀ + (x₁ * -12.086)) ^ inv(x₂))
# 11          3.851e-03  3.149e-02  y = inv(((x₀ / (x₁ - 0.73668)) - x₂) ^ inv(x₂))
# 12          3.662e-03  5.047e-02  y = inv((((x₀ + x₀) / x₁) + cube(-2.7964)) ^ inv(x₂))
# 14          3.659e-03  3.332e-04  y = inv((((x₀ + x₀) / (x₁ - -0.014767)) + cube(-2.7964)) ^ inv...
#                                   (x₂))
# 16          3.658e-03  9.788e-05  y = inv((((x₀ + x₀) / physics(x₁ - -0.014767, x₁)) + cube(-2.7...
#                                   964)) ^ inv(x₂))
# 20          3.603e-03  3.824e-03  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.100e+04
# Head worker occupation: 0.6%
# Progress: 539 / 600 total iterations (89.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.101e-03  3.824e-02  y = inv((x₀ + (x₁ * -12.086)) ^ inv(x₂))
# 11          3.851e-03  3.149e-02  y = inv(((x₀ / (x₁ - 0.73668)) - x₂) ^ inv(x₂))
# 12          3.662e-03  5.047e-02  y = inv((((x₀ + x₀) / x₁) + cube(-2.7964)) ^ inv(x₂))
# 14          3.659e-03  3.332e-04  y = inv((((x₀ + x₀) / (x₁ - -0.014767)) + cube(-2.7964)) ^ inv...
#                                   (x₂))
# 16          3.658e-03  9.788e-05  y = inv((((x₀ + x₀) / physics(x₁ - -0.014767, x₁)) + cube(-2.7...
#                                   964)) ^ inv(x₂))
# 20          3.603e-03  3.824e-03  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.040e+04
# Head worker occupation: 0.6%
# Progress: 554 / 600 total iterations (92.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.101e-03  3.824e-02  y = inv((x₀ + (x₁ * -12.086)) ^ inv(x₂))
# 11          3.851e-03  3.149e-02  y = inv(((x₀ / (x₁ - 0.73668)) - x₂) ^ inv(x₂))
# 12          3.662e-03  5.047e-02  y = inv((((x₀ + x₀) / x₁) + cube(-2.7964)) ^ inv(x₂))
# 14          3.659e-03  3.332e-04  y = inv((((x₀ + x₀) / (x₁ - -0.014767)) + cube(-2.7964)) ^ inv...
#                                   (x₂))
# 16          3.658e-03  9.788e-05  y = inv((((x₀ + x₀) / physics(x₁ - -0.014767, x₁)) + cube(-2.7...
#                                   964)) ^ inv(x₂))
# 20          3.603e-03  3.824e-03  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.790e+03
# Head worker occupation: 0.6%
# Progress: 577 / 600 total iterations (96.167%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.179e-02  1.594e+01  y = 0.66387
# 3           1.057e-02  5.470e-02  y = (x₀ ^ -0.098957)
# 4           1.051e-02  5.261e-03  y = square(x₀ ^ -0.048152)
# 5           6.748e-03  4.430e-01  y = (0.96454 + (-2.527 / x₂))
# 7           4.427e-03  2.108e-01  y = inv((x₀ / x₁) ^ inv(x₂))
# 9           4.101e-03  3.824e-02  y = inv((x₀ + (x₁ * -12.086)) ^ inv(x₂))
# 11          3.851e-03  3.149e-02  y = inv(((x₀ / (x₁ - 0.73668)) - x₂) ^ inv(x₂))
# 12          3.662e-03  5.047e-02  y = inv((((x₀ + x₀) / x₁) + cube(-2.7964)) ^ inv(x₂))
# 14          3.659e-03  3.332e-04  y = inv((((x₀ + x₀) / (x₁ - -0.014767)) + cube(-2.7964)) ^ inv...
#                                   (x₂))
# 16          3.658e-03  9.788e-05  y = inv((((x₀ + x₀) / physics(x₁ - -0.014767, x₁)) + cube(-2.7...
#                                   964)) ^ inv(x₂))
# 20          3.603e-03  3.824e-03  y = inv(sqrt((cube((x₀ - inv(-0.62587 - -0.66425)) * 1.5652) /...
#                                    x₂) / square(square(x₁))) ^ inv(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                         0.66386765
# 	1         5.732874e-02                                 (x0 ^ -0.09633101)
# 	2         1.902953e-07                          square(x0 ^ -0.048161805)
# 	3         4.430171e-01                   (0.96453655 + (-2.5270152 / x2))
# 	4   >>>>  2.107515e-01                           inv((x0 / x1) ^ inv(x2))
# 	5         3.823954e-02           inv((x0 + (x1 * -12.0856285)) ^ inv(x2))
# 	6         3.148711e-02     inv(((x0 / (x1 - 0.73668176)) - x2) ^ inv(x2))
# 	7         5.047171e-02  inv((((x0 + x0) / x1) + cube(-2.7964265)) ^ in...
# 	8         3.333190e-04  inv((((x0 + x0) / (x1 - -0.014766804)) + cube(...
# 	9         9.794384e-05  inv((((x0 + x0) / physics(x1 - -0.014766804, x...
# 	10        3.824385e-03  inv(sqrt((cube((x0 - inv(-0.62587273 - -0.6642...
#
# 	        loss  complexity
# 	0   0.011787           1
# 	1   0.010510           3
# 	2   0.010510           4
# 	3   0.006748           5
# 	4   0.004427           7
# 	5   0.004101           9
# 	6   0.003851          11
# 	7   0.003662          12
# 	8   0.003659          14
# 	9   0.003658          16
# 	10  0.003603          20
# ]

# %%
model.sympy()
# Out:
# (x0/x1)**(-1/x2)

# %%
n_bm1_pred = model.predict(X)
ypredict_simpler = model.predict(X, 2)

print("Default selection MSE:", np.power(n_bm1_pred - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 0.004427369339102961
# Manual selection MSE for index 2: 0.010509982700792883

# %%
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_bm1, y=n_bm1_pred, marker='o', c='none', edgecolor='b', label='Exterior Girder')

ax1.set_title('Accuracy')
ax1.legend()

ax1.set_xlabel('Target $n_{r1}$')
ax1.set_ylabel('Predicted $n_{r1}$')
ax1.grid()
