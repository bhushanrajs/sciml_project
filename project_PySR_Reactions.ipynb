# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanrajs/sciml_project/blob/main/project_PySR_Reactions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Symbolic Regression

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi
# Out:
# Installing Julia 1.8.5 on the current Colab Runtime...
# 2023-12-03 22:57:51 URL:https://storage.googleapis.com/julialang2/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz [130873886/130873886] -> "/tmp/julia.tar.gz" [1]
# Installing PyCall.jl...
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed MacroTools ────── v0.5.11
#    Installed Conda ─────────── v1.10.0
#    Installed VersionParsing ── v1.3.0
#    Installed Parsers ───────── v2.8.0
#    Installed Preferences ───── v1.4.1
#    Installed JSON ──────────── v0.21.4
#    Installed PyCall ────────── v1.96.2
#    Installed PrecompileTools ─ v1.2.0
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [438e738f] + PyCall v1.96.2
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [8f4d0f93] + Conda v1.10.0
#   [682c06a0] + JSON v0.21.4
#   [1914dd2f] + MacroTools v0.5.11
#   [69de0a69] + Parsers v2.8.0
#   [aea7be01] + PrecompileTools v1.2.0
#   [21216c6a] + Preferences v1.4.1
#   [438e738f] + PyCall v1.96.2
#   [81def892] + VersionParsing v1.3.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b27032c2] + LibCURL v0.6.3
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [fa267f1f] + TOML v1.0.0
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.0+0
#   [14a3606d] + MozillaCACerts_jll v2022.2.1
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [83775a58] + Zlib_jll v1.2.12+3
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
# Success

# %% [markdown]
# Install PySR and PyTorch-Lightning:

# %%
# %pip install -Uq pysr pytorch_lightning --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 13.7 MB/s eta 0:00:00

# %%
from julia import Julia

julia = Julia(compiled_modules=False, threads="auto")
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()

# %%
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 22.04.3 LTS
#   uname: Linux 5.15.120+ #1 SMP Wed Aug 30 11:19:59 UTC 2023 x86_64 x86_64
#   CPU: Intel(R) Xeon(R) CPU @ 2.20GHz:
#               speed         user         nice          sys         idle          irq
#        #1  2199 MHz       1050 s          0 s        188 s       2268 s          0 s
#        #2  2199 MHz       1136 s          0 s        180 s       2193 s          0 s
#   Memory: 12.6783447265625 GB (11548.51953125 MB free)
#   Uptime: 361.18 sec
#   Load Avg:  1.8  0.94  0.42
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, broadwell)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/lib64-nvidia
#   JULIA_PROJECT = @pysr-0.16.3
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.10.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#     Updating registry at `~/.julia/registries/General.toml`
#      Cloning git-repo `https://github.com/MilesCranmer/SymbolicRegression.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed IrrationalConstants ────────────── v0.2.2
#    Installed ScientificTypesBase ────────────── v3.0.0
#    Installed Tricks ─────────────────────────── v0.1.8
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed DiffRules ──────────────────────── v1.15.1
#    Installed Adapt ──────────────────────────── v3.7.1
#    Installed DynamicExpressions ─────────────── v0.13.1
#    Installed OffsetArrays ───────────────────── v1.12.10
#    Installed LayoutPointers ─────────────────── v0.1.15
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed MLJModelInterface ──────────────── v1.9.3
#    Installed StatisticalTraits ──────────────── v3.2.0
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed VectorizationBase ──────────────── v0.21.65
#    Installed CPUSummary ─────────────────────── v0.2.4
#    Installed SpecialFunctions ───────────────── v2.3.1
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed DataAPI ────────────────────────── v1.15.0
#    Installed PDMats ─────────────────────────── v0.11.30
#    Installed JLLWrappers ────────────────────── v1.5.0
#    Installed Setfield ───────────────────────── v1.1.1
#    Installed StaticArraysCore ───────────────── v1.4.2
#    Installed StaticArrays ───────────────────── v1.7.0
#    Installed LoopVectorization ──────────────── v0.12.166
#    Installed Optim ──────────────────────────── v1.7.6
#    Installed NaNMath ────────────────────────── v1.0.2
#    Installed HostCPUFeatures ────────────────── v0.1.16
#    Installed ConstructionBase ───────────────── v1.5.4
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed OrderedCollections ─────────────── v1.6.3
#    Installed NLSolversBase ──────────────────── v7.8.3
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed ChainRulesCore ─────────────────── v1.18.0
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed ArrayInterface ─────────────────── v7.5.1
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed FillArrays ─────────────────────── v1.8.0
#    Installed CommonSubexpressions ───────────── v0.3.0
#    Installed LineSearches ───────────────────── v7.2.0
#    Installed ForwardDiff ────────────────────── v0.10.36
#    Installed DataStructures ─────────────────── v0.18.15
#    Installed LogExpFunctions ────────────────── v0.3.26
#    Installed ProgressBars ───────────────────── v1.5.1
#    Installed Requires ───────────────────────── v1.3.0
#    Installed StatsAPI ───────────────────────── v1.7.0
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed Static ─────────────────────────── v0.8.8
#    Installed PackageExtensionCompat ─────────── v1.0.2
#    Installed Compat ─────────────────────────── v4.10.1
#    Installed SLEEFPirates ───────────────────── v0.6.42
#    Installed ClusterManagers ────────────────── v0.4.5
#    Installed OpenSpecFun_jll ────────────────── v0.5.5+0
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed InverseFunctions ───────────────── v0.1.12
#    Installed StaticArrayInterface ───────────── v1.4.1
#    Installed DynamicQuantities ──────────────── v0.6.3
#    Installed SortingAlgorithms ──────────────── v1.2.0
#    Installed Missings ───────────────────────── v1.1.0
#    Installed StatsBase ──────────────────────── v0.34.2
#    Installed LossFunctions ──────────────────── v0.11.1
#    Installed ChangesOfVariables ─────────────── v0.1.8
#    Installed DocStringExtensions ────────────── v0.9.3
#    Installed FiniteDiff ─────────────────────── v2.21.1
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [34f1f09b] + ClusterManagers v0.4.5
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [79e6a3ab] + Adapt v3.7.1
# ⌅ [4fba245c] + ArrayInterface v7.5.1
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [2a0fbf3d] + CPUSummary v0.2.4
#   [d360d2e6] + ChainRulesCore v1.18.0
#   [9e997f8a] + ChangesOfVariables v0.1.8
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [34f1f09b] + ClusterManagers v0.4.5
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.10.1
#   [187b0558] + ConstructionBase v1.5.4
#   [adafc99b] + CpuId v0.3.1
#   [9a962f9c] + DataAPI v1.15.0
#   [864edb3b] + DataStructures v0.18.15
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [ffbed154] + DocStringExtensions v0.9.3
#   [a40a106e] + DynamicExpressions v0.13.1
# ⌅ [06fc5a27] + DynamicQuantities v0.6.3
#   [1a297f60] + FillArrays v1.8.0
#   [6a86dc24] + FiniteDiff v2.21.1
#   [f6369f11] + ForwardDiff v0.10.36
#   [3e5b6fbb] + HostCPUFeatures v0.1.16
#   [615f187c] + IfElse v0.1.1
#   [3587e190] + InverseFunctions v0.1.12
#   [92d709cd] + IrrationalConstants v0.2.2
#   [692b3bcd] + JLLWrappers v1.5.0
#   [10f19ff3] + LayoutPointers v0.1.15
#   [d3d80556] + LineSearches v7.2.0
#   [2ab3a3ac] + LogExpFunctions v0.3.26
#   [bdcacae8] + LoopVectorization v0.12.166
#   [30fc2ffe] + LossFunctions v0.11.1
#   [e80e1ace] + MLJModelInterface v1.9.3
#   [d125e4d3] + ManualMemory v0.1.8
#   [e1d29d7a] + Missings v1.1.0
#   [d41bc354] + NLSolversBase v7.8.3
#   [77ba4419] + NaNMath v1.0.2
#   [6fe1bfb0] + OffsetArrays v1.12.10
# ⌅ [429524aa] + Optim v1.7.6
#   [bac558e1] + OrderedCollections v1.6.3
#   [90014a1f] + PDMats v0.11.30
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [d96e819e] + Parameters v0.12.3
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [49802e3a] + ProgressBars v1.5.1
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.3.0
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.42
#   [30f210dd] + ScientificTypesBase v3.0.0
#   [efcf1570] + Setfield v1.1.1
#   [a2af1166] + SortingAlgorithms v1.2.0
#   [276daf66] + SpecialFunctions v2.3.1
#   [aedffcd0] + Static v0.8.8
#   [0d7ed370] + StaticArrayInterface v1.4.1
#   [90137ffa] + StaticArrays v1.7.0
#   [1e83bf80] + StaticArraysCore v1.4.2
#   [64bff920] + StatisticalTraits v3.2.0
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.2
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#   [8290d209] + ThreadingUtilities v0.5.2
#   [410a4b4d] + Tricks v0.1.8
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.65
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [56ddb016] + Logging
#   [44cfe95a] + Pkg v1.8.0
#   [3fa0cd96] + REPL
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [a4e569a6] + Tar v1.10.1
#   [8dfed614] + Test
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [3f19e933] + p7zip_jll v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:118: UserWarning: It is recommended to restart Python after installing PySR's dependencies, so that the Julia environment is properly initialized.
#   warnings.warn(

# %%
import sympy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bhushanrajs/sciml_project/main/analysis_data.csv')

tx_girders = {'Tx28' : {'D' : 28.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 6.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx34' : {'D' : 34.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 12.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx40' : {'D' : 40.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 18.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx46' : {'D' : 46.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 22.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx54' : {'D' : 54.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 30.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx62' : {'D' : 62.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 37.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx70' : {'D' : 70.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 45.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx84' : {'D' : 84.0, 'b1' : 58.0, 'b2' : 8.0, 'b3' : 38.0, 'b4' : 3.0, 'b5' : 3.0, 'd1' : 4.0, 'd2' : 3.5, 'd3' : 3.0, 'd4' : 55.75, 'd5' : 3.0, 'd6' : 6.0, 'd7' : 8.75}
              }

# bridge geometry data
L = df['L']/12 # span length in ft.
S = df['S']/12 # girder spacing in ft.
w_oh = df['w_oh']/12 # overhang width in ft.
ts = df['ts_U']/12 # thickness of overhang in ft.
girder = df['Girder Type']
D = []
for _, girder_type in girder.items():
  D.append(tx_girders[girder_type]['D'])
df['D'] = D

# intensity of railing dead load in kip/ft
b_rail = df['b_rail_left'] # width of railing
q_rail = (df['q_rail_left'] * b_rail * 12)/1000

# max bending moment in exterior girder G1 & interior girder G2 in kip-ft
bm1 = df['G1 - max_bm']/(1000*12)
bm2 = df['G2 - max_bm']/(1000*12)
bm3 = df['G3 - max_bm']/(1000*12)
bm4 = df['G4 - max_bm']/(1000*12)

# reaction in girders G1 & G2 in kip. (only A1 taken due to symmetry)
r1 = df['G1-A1-Y']/1000
r2 = df['G2-A1-Y']/1000
r3 = df['G3-A1-Y']/1000
r4 = df['G4-A1-Y']/1000

# line analysis with full railing load assumed to be applied on a girder
bm_line = q_rail * (L - 2*9/12)**2 / 8
r_line = q_rail * L / 2


# normalizing bending moments with respect to line analysis
n_bm1 = bm1 / bm_line
n_bm2 = bm2 / bm_line
n_bm3 = bm3 / bm_line
n_bm4 = bm4 / bm_line

# normalizing vertical reactions with respect to line analysis
n_r1 = r1 / r_line
n_r2 = r2 / r_line
n_r3 = r3 / r_line
n_r4 = r4 / r_line

# add the distribution factors to the dataframe
df['n_bm1'] = n_bm1
df['n_bm2'] = n_bm2
df['n_bm3'] = n_bm3
df['n_bm4'] = n_bm4
df['n_r1'] = n_r1
df['n_r2'] = n_r2
df['n_r3'] = n_r3
df['n_r4'] = n_r4

# %%
# sample data from leve rule
# n_r1 = (w_oh + S) / S

# %%
X = np.stack((L, S, w_oh), axis=-1)
y = n_r1

# %%
# Learn equations
default_pysr_params = dict(
    populations=50,
    model_selection="best",
)

# model = PySRRegressor(
#     niterations=30,
#     binary_operators=['+', '-', '*', '/', '^'],
#     unary_operators=["square", "cube", "sqrt"],
#     **default_pysr_params
# )

model = PySRRegressor(
    niterations=50,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    **default_pysr_params
)

model.fit(X, y)

print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# WARNING: using StaticArrays.setindex in module FiniteDiff conflicts with an existing identifier.
# Started!
#
# Expressions evaluated per second: 7.530e+02
# Head worker occupation: NaN%
# Progress: 2 / 2500 total iterations (0.080%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.071e-01  1.594e+01  y = 0.53628
# 2           6.029e-03  3.536e+00  y = square(-0.99055)
# 4           6.019e-03  8.304e-04  y = (square(-0.99055) ^ 0.89134)
# 5           6.018e-03  1.165e-04  y = sqrt(sqrt(cube(square(-0.99055))))
# 6           5.971e-03  7.808e-03  y = (0.53628 ^ (inv(x₁) / x₁))
# 7           5.471e-03  8.760e-02  y = (0.53628 ^ (0.41827 / (x₁ * x₂)))
# 8           5.345e-03  2.324e-02  y = (square(cube(-0.99055)) ^ physics(inv(1.1058), x₂))
# 9           5.301e-03  8.309e-03  y = (square(cube(-0.99055)) ^ physics(sqrt(inv(1.1058)), x₂))
# 11          4.375e-03  9.596e-02  y = cube(0.53628 ^ ((0.41827 ^ x₂) / (x₁ + sqrt(0.62101))))
# 12          3.479e-03  2.290e-01  y = (0.53628 ^ (physics(0.41827 ^ x₂, inv(-1.2133 / -0.048011)...
#                                   ) / x₁))
# 14          3.448e-03  4.505e-03  y = (0.53628 ^ (physics(0.41827 ^ x₂, inv(0.96672 * (-1.2133 /...
#                                    -0.048011))) / x₁))
# 15          3.410e-03  1.124e-02  y = (0.53628 ^ (physics(0.41827 ^ x₂, inv(cube(0.96672) * (-1....
#                                   2133 / -0.048011))) / x₁))
# 16          2.807e-03  1.944e-01  y = ((square(-0.99055) ^ square(physics((inv(inv(x₀)) / square...
#                                   (x₂)) ^ 0.19797, x₂))) + 0.018914)
# 18          1.406e-03  3.455e-01  y = (cube((square(-0.99055) ^ physics((inv(inv(x₀)) / square(x...
#                                   ₂)) ^ 0.19797, x₂)) + 0.018914) ^ x₂)
# 20          1.400e-03  2.308e-03  y = (cube((square(-0.99055) ^ physics(((inv(inv(x₀)) + x₂) / s...
#                                   quare(x₂)) ^ 0.19797, x₂)) + 0.018914) ^ x₂)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.290e+03
# Head worker occupation: 2.3%
# Progress: 17 / 2500 total iterations (0.680%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.462e-03  1.594e+01  y = 1.0434
# 2           6.029e-03  4.507e-01  y = square(-0.99055)
# 4           6.019e-03  8.304e-04  y = (square(-0.99055) ^ 0.89134)
# 5           6.017e-03  3.374e-04  y = inv(1.0434 ^ cube(0.71854))
# 6           2.428e-03  9.076e-01  y = sqrt(sqrt(x₂) * square(0.79651))
# 8           2.427e-03  5.710e-05  y = sqrt(sqrt(sqrt(x₂ - 0.60584)) / 1.176)
# 10          2.312e-03  2.428e-02  y = sqrt(sqrt(sqrt(x₂ - sqrt(inv(x₂)))) / 1.176)
# 12          2.311e-03  2.803e-04  y = sqrt(sqrt(sqrt(x₂ - inv(sqrt(0.60584 + 1.176)))) / 1.176)
# 13          2.294e-03  7.344e-03  y = sqrt(sqrt(sqrt(x₂ - sqrt(sqrt(inv(x₂)) + -0.21995))) / 1.1...
#                                   76)
# 15          2.293e-03  3.606e-04  y = sqrt(sqrt(sqrt(x₂ - inv(sqrt((inv(x₂) + -0.40314) + x₂))))...
#                                    / 1.176)
# 16          2.270e-03  9.905e-03  y = sqrt(sqrt(sqrt(x₂ - inv(sqrt(sqrt(sqrt(x₂ ^ x₂) + 0.83966)...
#                                   )))) / 1.176)
# 17          1.443e-03  4.532e-01  y = square(sqrt(physics(physics(-0.41728, 1.1036) ^ ((1.8198 -...
#                                    (x₂ + 1.1751)) / x₀), 1.1036)) ^ 1.5402)
# 18          1.062e-03  3.062e-01  y = square(sqrt(physics(physics(-0.41728, 1.1036) ^ ((1.8198 -...
#                                    (x₂ + sqrt(0.73483))) / x₀), 1.1036)) ^ 1.5402)
# 19          1.018e-03  4.214e-02  y = square(sqrt(physics(physics(-0.41728, 1.1036) ^ ((1.8198 -...
#                                    (x₂ + sqrt(sqrt(0.73483)))) / x₀), 1.1036)) ^ 1.5402)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.470e+03
# Head worker occupation: 2.0%
# Progress: 38 / 2500 total iterations (1.520%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 5           2.465e-03  2.231e-01  y = (physics(1.561, x₂) ^ -0.1962)
# 6           2.394e-03  2.931e-02  y = sqrt(sqrt(inv(physics(1.6551, x₂))))
# 7           2.200e-03  8.453e-02  y = (physics(1.561, x₂ - 0.15187) ^ -0.1962)
# 9           2.191e-03  2.073e-03  y = (physics(1.561, x₂ - physics(0.52146, 1.5432)) ^ -0.1962)
# 11          2.090e-03  2.348e-02  y = (physics(1.561, x₂ - physics(1.561 - 0.17316, x₁)) ^ -0.19...
#                                   62)
# 13          1.287e-03  2.425e-01  y = sqrt(sqrt(sqrt(sqrt((inv(x₀) - cube(-1.1516)) / x₀)) * x₂)...
#                                   )
# 15          1.270e-03  6.409e-03  y = sqrt(sqrt(sqrt(sqrt(physics(inv(x₀) - cube(-0.89875), 0.34...
#                                   442) / x₀)) * x₂))
# 16          1.239e-03  2.501e-02  y = sqrt(sqrt(sqrt(sqrt(sqrt((inv(x₂) - cube(-0.89875)) / x₀))...
#                                    * x₂)) ^ x₂)
# 17          1.204e-03  2.901e-02  y = sqrt(sqrt(sqrt(sqrt(square((cube(inv(x₂)) ^ 0.97973) - cub...
#                                   e(-1.0474)) / x₀)) * x₂))
# 18          1.062e-03  1.250e-01  y = square(sqrt(physics(physics(-0.41728, 1.1036) ^ ((1.8198 -...
#                                    (x₂ + sqrt(0.73483))) / x₀), 1.1036)) ^ 1.5402)
# 19          1.018e-03  4.214e-02  y = square(sqrt(physics(physics(-0.41728, 1.1036) ^ ((1.8198 -...
#                                    (x₂ + sqrt(sqrt(0.73483)))) / x₀), 1.1036)) ^ 1.5402)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.530e+03
# Head worker occupation: 1.6%
# Progress: 75 / 2500 total iterations (3.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           6.017e-03  0.000e+00  y = (0.40597 * 2.4255)
# 5           2.365e-03  4.669e-01  y = sqrt(sqrt(x₂) * 0.60584)
# 6           2.273e-03  3.989e-02  y = sqrt(sqrt(x₂) / cube(1.176))
# 7           2.190e-03  3.708e-02  y = (physics(1.561, x₂ - 0.19023) ^ -0.1962)
# 8           1.990e-03  9.556e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀)))))
# 9           1.442e-03  3.219e-01  y = sqrt(sqrt(sqrt(sqrt(1.2643 / x₀)) * x₂))
# 10          1.279e-03  1.203e-01  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀)) - 0.3952)))
# 11          1.180e-03  8.068e-02  y = sqrt(sqrt(sqrt(sqrt(1.2643 / (x₀ - x₁))) * x₂))
# 13          1.169e-03  4.511e-03  y = (sqrt(sqrt(sqrt(sqrt(1.2643 / (x₀ - x₁))) * x₂)) - -0.0017...
#                                   387)
# 14          1.089e-03  7.123e-02  y = sqrt(sqrt(sqrt(physics(sqrt((inv(x₀) - -0.89875) / x₀), 0....
#                                   077263)) * x₂))
# 16          1.084e-03  2.420e-03  y = sqrt(sqrt(sqrt(physics(sqrt(physics(inv(x₀) - -0.89875, 0....
#                                   91358) / x₀), 0.077263)) * x₂))
# 18          9.464e-04  6.766e-02  y = sqrt(sqrt(sqrt(physics(sqrt(physics((inv(x₀) * -0.64345) -...
#                                    -0.89875, 0.91358) / x₀), 0.077263)) * x₂))
# 20          8.805e-04  3.611e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(square(physics(0.61914, (...
#                                   x₁ / (x₁ - 0.223)) ^ square(sqrt(x₁)))) * x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.040e+04
# Head worker occupation: 1.4%
# Progress: 110 / 2500 total iterations (4.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           6.017e-03  0.000e+00  y = (0.40597 * 2.4255)
# 5           2.345e-03  4.712e-01  y = (physics(-1.6744, x₂) ^ -0.1962)
# 6           2.273e-03  3.119e-02  y = sqrt(sqrt(x₂) / cube(1.176))
# 7           2.190e-03  3.708e-02  y = (physics(1.561, x₂ - 0.19023) ^ -0.1962)
# 8           1.990e-03  9.556e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀)))))
# 9           1.397e-03  3.540e-01  y = sqrt(sqrt(sqrt(sqrt(1.3072 / x₀)) * x₂))
# 10          1.279e-03  8.821e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀)) - 0.3952)))
# 11          1.180e-03  8.068e-02  y = sqrt(sqrt(sqrt(sqrt(1.2643 / (x₀ - x₁))) * x₂))
# 12          1.111e-03  6.049e-02  y = sqrt(sqrt(sqrt(inv(x₀ / (cube(1.0564) + x₁))) * x₂))
# 14          1.089e-03  9.878e-03  y = sqrt(sqrt(sqrt(physics(sqrt((inv(x₀) - -0.89875) / x₀), 0....
#                                   077263)) * x₂))
# 15          1.080e-03  7.675e-03  y = sqrt(sqrt(sqrt(inv(((x₀ * cube(sqrt(0.7731))) / x₁) + 1.29...
#                                   56)) * x₂))
# 16          1.019e-03  5.823e-02  y = square(sqrt(sqrt(sqrt(sqrt(inv((x₀ + square(x₂)) / (x₁ + x...
#                                   ₂))) * x₂))))
# 18          9.464e-04  3.713e-02  y = sqrt(sqrt(sqrt(physics(sqrt(physics((inv(x₀) * -0.64345) -...
#                                    -0.89875, 0.91358) / x₀), 0.077263)) * x₂))
# 20          8.805e-04  3.611e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(square(physics(0.61914, (...
#                                   x₁ / (x₁ - 0.223)) ^ square(sqrt(x₁)))) * x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.380e+04
# Head worker occupation: 1.4%
# Progress: 143 / 2500 total iterations (5.720%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 5           2.180e-03  2.538e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 8           1.990e-03  3.034e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀)))))
# 9           1.306e-03  4.214e-01  y = sqrt(sqrt(sqrt(sqrt(1.4562 / x₀)) * x₂))
# 10          1.177e-03  1.037e-01  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀) - 1.4201))))
# 11          1.011e-03  1.518e-01  y = sqrt(sqrt(sqrt(inv(x₀ / (x₁ - -1.9557))) * x₂))
# 13          9.613e-04  2.543e-02  y = sqrt(sqrt(sqrt(physics(sqrt(1.2643 / x₀), 0.10602)) * (x₂ ...
#                                   - 0.10602)))
# 14          9.563e-04  5.199e-03  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt((x₀ - (x₁ + x₁)) - x...
#                                   ₁)))))
# 15          8.715e-04  9.287e-02  y = sqrt(sqrt(sqrt(physics(sqrt(physics(-0.89875, 0.91358 ^ 0....
#                                   066111) / x₀), 0.077263)) * x₂))
# 16          8.713e-04  2.283e-04  y = sqrt(sqrt(sqrt(physics(sqrt(physics(-0.89875, x₂ ^ cube(0....
#                                   077263)) / x₀), 0.077263)) * x₂))
# 17          8.690e-04  2.590e-03  y = sqrt(sqrt(sqrt(physics(sqrt(physics(-0.89875, x₂ ^ sqrt(cu...
#                                   be(0.077263))) / x₀), 0.077263)) * x₂))
# 18          8.663e-04  3.158e-03  y = sqrt(sqrt(sqrt(physics(sqrt(physics(inv(x₀) - (-0.89875 * ...
#                                   0.93238), 0.91358) / x₀), 0.077263)) * x₂))
# 19          8.535e-04  1.493e-02  y = sqrt(sqrt(sqrt(physics(sqrt(physics(-0.89875, x₂ ^ cube(sq...
#                                   rt(0.077263))) / (x₀ + -2.5327)), 0.077263)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.580e+04
# Head worker occupation: 1.3%
# Progress: 187 / 2500 total iterations (7.480%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.975e-03  3.451e-03  y = (x₀ ^ -0.002919)
# 4           5.304e-03  1.192e-01  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 8           1.990e-03  3.034e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀)))))
# 9           1.306e-03  4.214e-01  y = sqrt(sqrt(sqrt(sqrt(1.4562 / x₀)) * x₂))
# 10          1.177e-03  1.037e-01  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀) - 1.4201))))
# 11          1.011e-03  1.518e-01  y = sqrt(sqrt(sqrt(inv(x₀ / (x₁ - -1.9557))) * x₂))
# 12          8.715e-04  1.489e-01  y = sqrt(sqrt(sqrt(physics(sqrt(square(-0.89875) / x₀), 0.0772...
#                                   63)) * x₂))
# 14          8.714e-04  7.395e-05  y = sqrt(sqrt(sqrt(inv(x₀ / (0.71608 + (inv(0.10341) + 0.10341...
#                                   )))) * x₂))
# 15          8.159e-04  6.581e-02  y = sqrt(sqrt(sqrt(physics(sqrt((1.2643 ^ -0.19896) / x₀), 0.1...
#                                   0602)) * (x₂ - -0.19896)))
# 19          7.843e-04  9.873e-03  y = sqrt(sqrt(sqrt(inv(x₀ / (sqrt(physics(physics(x₁, x₀), x₂)...
#                                   ) + (inv(0.10341) + 0.10341)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.820e+04
# Head worker occupation: 1.3%
# Progress: 227 / 2500 total iterations (9.080%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.975e-03  3.451e-03  y = (x₀ ^ -0.002919)
# 4           5.304e-03  1.192e-01  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 7           2.180e-03  5.960e-08  y = (((x₂ * 0.14465) * x₂) ^ 0.10857)
# 8           1.990e-03  9.101e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀)))))
# 9           1.306e-03  4.214e-01  y = sqrt(sqrt(sqrt(sqrt(1.4562 / x₀)) * x₂))
# 10          9.700e-04  2.973e-01  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.10341))) * x₂))
# 11          9.378e-04  3.383e-02  y = sqrt((sqrt(inv(x₀ / inv(0.10341))) * x₂) ^ 0.43251)
# 12          8.715e-04  7.330e-02  y = sqrt(sqrt(sqrt(physics(sqrt(square(-0.89875) / x₀), 0.0772...
#                                   63)) * x₂))
# 13          8.176e-04  6.381e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) - cube(-1.955)) / x₀)) * sqrt(x₂)...
#                                   )
# 15          8.072e-04  6.390e-03  y = sqrt(sqrt(sqrt(inv(x₀ / (inv(physics(x₂, x₁)) + inv(0.1034...
#                                   1)))) * x₂))
# 16          7.921e-04  1.888e-02  y = sqrt(sqrt(sqrt(inv((x₀ - (x₁ - x₂)) / (inv(0.10341) - 0.10...
#                                   341))) * x₂))
# 17          7.264e-04  8.661e-02  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁)) + -0.81608)...
#                                    + inv(0.10341)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.760e+04
# Head worker occupation: 1.3%
# Progress: 266 / 2500 total iterations (10.640%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.975e-03  3.451e-03  y = (x₀ ^ -0.002919)
# 4           5.304e-03  1.192e-01  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 7           2.180e-03  5.960e-08  y = (((x₂ * 0.14465) * x₂) ^ 0.10857)
# 8           1.990e-03  9.101e-02  y = sqrt(sqrt(sqrt(inv(sqrt(x₀))) * x₂))
# 9           1.294e-03  4.305e-01  y = sqrt(sqrt(sqrt(sqrt(1.5663 / x₀)) * x₂))
# 10          9.700e-04  2.882e-01  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.10341))) * x₂))
# 11          9.378e-04  3.383e-02  y = sqrt((sqrt(inv(x₀ / inv(0.10341))) * x₂) ^ 0.43251)
# 12          8.621e-04  8.413e-02  y = sqrt(sqrt(sqrt(inv((x₀ - x₁) / inv(0.10341))) * x₂))
# 13          8.176e-04  5.298e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) - cube(-1.955)) / x₀)) * sqrt(x₂)...
#                                   )
# 15          8.072e-04  6.390e-03  y = sqrt(sqrt(sqrt(inv(x₀ / (inv(physics(x₂, x₁)) + inv(0.1034...
#                                   1)))) * x₂))
# 16          7.921e-04  1.888e-02  y = sqrt(sqrt(sqrt(inv((x₀ - (x₁ - x₂)) / (inv(0.10341) - 0.10...
#                                   341))) * x₂))
# 17          7.264e-04  8.661e-02  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁)) + -0.81608)...
#                                    + inv(0.10341)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.950e+04
# Head worker occupation: 1.2%
# Progress: 313 / 2500 total iterations (12.520%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.975e-03  3.451e-03  y = (x₀ ^ -0.002919)
# 4           5.304e-03  1.192e-01  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 7           2.180e-03  5.960e-08  y = (((x₂ * 0.14465) * x₂) ^ 0.10857)
# 8           1.990e-03  9.101e-02  y = sqrt(sqrt(sqrt(inv(sqrt(x₀))) * x₂))
# 9           1.293e-03  4.311e-01  y = sqrt(sqrt(sqrt(sqrt(1.5523 / x₀)) * x₂))
# 10          9.695e-04  2.882e-01  y = sqrt(sqrt(sqrt(sqrt(inv(-26.865 + x₀))) * x₂))
# 11          9.378e-04  3.325e-02  y = sqrt((sqrt(inv(x₀ / inv(0.10341))) * x₂) ^ 0.43251)
# 12          8.321e-04  1.196e-01  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.10341))) * (x₂ - -0.11226)))
# 13          8.176e-04  1.753e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) - cube(-1.955)) / x₀)) * sqrt(x₂)...
#                                   )
# 14          7.959e-04  2.692e-02  y = sqrt(sqrt(sqrt(inv(((x₀ + x₂) - x₁) / inv(0.10341))) * x₂)...
#                                   )
# 16          7.921e-04  2.374e-03  y = sqrt(sqrt(sqrt(inv((x₀ - (x₁ - x₂)) / (inv(0.10341) - 0.10...
#                                   341))) * x₂))
# 17          7.264e-04  8.661e-02  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁)) + -0.81608)...
#                                    + inv(0.10341)))) * x₂))
# 19          7.232e-04  2.246e-03  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁ - 1.1259)) + ...
#                                   -0.81608) + inv(0.10341)))) * x₂))
# 20          7.095e-04  1.904e-02  y = sqrt(sqrt(sqrt(inv((x₀ - x₁) / ((inv(physics(square(x₂), x...
#                                   ₁)) + -0.81608) + inv(0.10341)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.950e+04
# Head worker occupation: 1.2%
# Progress: 349 / 2500 total iterations (13.960%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.975e-03  3.451e-03  y = (x₀ ^ -0.002919)
# 4           5.304e-03  1.192e-01  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 7           2.180e-03  5.960e-08  y = (((x₂ * 0.14465) * x₂) ^ 0.10857)
# 8           1.783e-03  2.009e-01  y = sqrt((square(square(x₂)) / x₀) ^ 0.10341)
# 9           1.293e-03  3.212e-01  y = sqrt(sqrt(sqrt(sqrt(1.5523 / x₀)) * x₂))
# 10          8.747e-04  3.911e-01  y = sqrt(sqrt(sqrt(physics(sqrt(inv(x₀)), 0.093969)) * x₂))
# 12          8.321e-04  2.498e-02  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.10341))) * (x₂ - -0.11226)))
# 13          8.176e-04  1.753e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) - cube(-1.955)) / x₀)) * sqrt(x₂)...
#                                   )
# 14          7.959e-04  2.692e-02  y = sqrt(sqrt(sqrt(inv(((x₀ + x₂) - x₁) / inv(0.10341))) * x₂)...
#                                   )
# 16          7.921e-04  2.374e-03  y = sqrt(sqrt(sqrt(inv((x₀ - (x₁ - x₂)) / (inv(0.10341) - 0.10...
#                                   341))) * x₂))
# 17          7.264e-04  8.661e-02  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁)) + -0.81608)...
#                                    + inv(0.10341)))) * x₂))
# 19          7.232e-04  2.246e-03  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁ - 1.1259)) + ...
#                                   -0.81608) + inv(0.10341)))) * x₂))
# 20          7.095e-04  1.904e-02  y = sqrt(sqrt(sqrt(inv((x₀ - x₁) / ((inv(physics(square(x₂), x...
#                                   ₁)) + -0.81608) + inv(0.10341)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.920e+04
# Head worker occupation: 1.2%
# Progress: 389 / 2500 total iterations (15.560%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.780e-03  2.009e-02  y = (0.9996 ^ x₀)
# 4           5.304e-03  8.594e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 7           1.990e-03  4.551e-02  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀)))))
# 8           1.783e-03  1.098e-01  y = sqrt((square(square(x₂)) / x₀) ^ 0.10341)
# 9           1.293e-03  3.212e-01  y = sqrt(sqrt(sqrt(sqrt(1.5523 / x₀)) * x₂))
# 10          8.714e-04  3.949e-01  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.095369))) * x₂))
# 12          8.285e-04  2.523e-02  y = sqrt(((square(square(x₂)) + (x₁ + x₁)) / x₀) ^ 0.18208)
# 13          8.176e-04  1.320e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) - cube(-1.955)) / x₀)) * sqrt(x₂)...
#                                   )
# 14          7.959e-04  2.692e-02  y = sqrt(sqrt(sqrt(inv(((x₀ + x₂) - x₁) / inv(0.10341))) * x₂)...
#                                   )
# 16          7.921e-04  2.374e-03  y = sqrt(sqrt(sqrt(inv((x₀ - (x₁ - x₂)) / (inv(0.10341) - 0.10...
#                                   341))) * x₂))
# 17          7.264e-04  8.661e-02  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁)) + -0.81608)...
#                                    + inv(0.10341)))) * x₂))
# 19          7.165e-04  6.895e-03  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁ - 1.1259)) + ...
#                                   -0.63853) + inv(0.10341)))) * x₂))
# 20          7.095e-04  9.739e-03  y = sqrt(sqrt(sqrt(inv((x₀ - x₁) / ((inv(physics(square(x₂), x...
#                                   ₁)) + -0.81608) + inv(0.10341)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.950e+04
# Head worker occupation: 1.1%
# Progress: 428 / 2500 total iterations (17.120%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.780e-03  2.009e-02  y = (0.9996 ^ x₀)
# 4           5.304e-03  8.594e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 7           1.990e-03  4.551e-02  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀)))))
# 8           1.783e-03  1.098e-01  y = sqrt((square(square(x₂)) / x₀) ^ 0.10341)
# 9           1.293e-03  3.212e-01  y = sqrt(sqrt(sqrt(sqrt(1.5523 / x₀)) * x₂))
# 10          8.714e-04  3.949e-01  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.095369))) * x₂))
# 12          8.285e-04  2.523e-02  y = sqrt(((square(square(x₂)) + (x₁ + x₁)) / x₀) ^ 0.18208)
# 13          8.176e-04  1.320e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) - cube(-1.955)) / x₀)) * sqrt(x₂)...
#                                   )
# 14          7.959e-04  2.692e-02  y = sqrt(sqrt(sqrt(inv(((x₀ + x₂) - x₁) / inv(0.10341))) * x₂)...
#                                   )
# 16          7.921e-04  2.374e-03  y = sqrt(sqrt(sqrt(inv((x₀ - (x₁ - x₂)) / (inv(0.10341) - 0.10...
#                                   341))) * x₂))
# 17          7.264e-04  8.661e-02  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁)) + -0.81608)...
#                                    + inv(0.10341)))) * x₂))
# 19          7.165e-04  6.895e-03  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁ - 1.1259)) + ...
#                                   -0.63853) + inv(0.10341)))) * x₂))
# 20          7.095e-04  9.739e-03  y = sqrt(sqrt(sqrt(inv((x₀ - x₁) / ((inv(physics(square(x₂), x...
#                                   ₁)) + -0.81608) + inv(0.10341)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.750e+04
# Head worker occupation: 1.2%
# Progress: 453 / 2500 total iterations (18.120%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.780e-03  2.009e-02  y = (0.9996 ^ x₀)
# 4           5.304e-03  8.594e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           2.035e-03  6.890e-02  y = (physics(x₂, sqrt(x₀)) ^ 0.12741)
# 7           1.990e-03  2.212e-02  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀)))))
# 8           1.143e-03  5.545e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 10          8.714e-04  1.357e-01  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.095369))) * x₂))
# 12          8.285e-04  2.523e-02  y = sqrt(((square(square(x₂)) + (x₁ + x₁)) / x₀) ^ 0.18208)
# 13          8.176e-04  1.320e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) - cube(-1.955)) / x₀)) * sqrt(x₂)...
#                                   )
# 14          7.959e-04  2.692e-02  y = sqrt(sqrt(sqrt(inv(((x₀ + x₂) - x₁) / inv(0.10341))) * x₂)...
#                                   )
# 16          7.921e-04  2.374e-03  y = sqrt(sqrt(sqrt(inv((x₀ - (x₁ - x₂)) / (inv(0.10341) - 0.10...
#                                   341))) * x₂))
# 17          7.264e-04  8.661e-02  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁)) + -0.81608)...
#                                    + inv(0.10341)))) * x₂))
# 19          7.165e-04  6.895e-03  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁ - 1.1259)) + ...
#                                   -0.63853) + inv(0.10341)))) * x₂))
# 20          7.095e-04  9.739e-03  y = sqrt(sqrt(sqrt(inv((x₀ - x₁) / ((inv(physics(square(x₂), x...
#                                   ₁)) + -0.81608) + inv(0.10341)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.660e+04
# Head worker occupation: 1.1%
# Progress: 492 / 2500 total iterations (19.680%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.780e-03  2.009e-02  y = (0.9996 ^ x₀)
# 4           5.304e-03  8.594e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           2.035e-03  6.890e-02  y = (physics(x₂, sqrt(x₀)) ^ 0.12741)
# 7           1.990e-03  2.212e-02  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀)))))
# 8           1.143e-03  5.545e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 10          8.714e-04  1.357e-01  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.095369))) * x₂))
# 12          8.285e-04  2.523e-02  y = sqrt(((square(square(x₂)) + (x₁ + x₁)) / x₀) ^ 0.18208)
# 13          8.176e-04  1.320e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) - cube(-1.955)) / x₀)) * sqrt(x₂)...
#                                   )
# 14          7.959e-04  2.692e-02  y = sqrt(sqrt(sqrt(inv(((x₀ + x₂) - x₁) / inv(0.10341))) * x₂)...
#                                   )
# 16          7.833e-04  7.990e-03  y = sqrt(sqrt(sqrt(inv((x₀ - (x₁ - cube(sqrt(x₂)))) / inv(0.10...
#                                   341))) * x₂))
# 17          7.264e-04  7.538e-02  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁)) + -0.81608)...
#                                    + inv(0.10341)))) * x₂))
# 19          7.165e-04  6.895e-03  y = sqrt(sqrt(sqrt(inv(x₀ / ((inv(physics(x₂, x₁ - 1.1259)) + ...
#                                   -0.63853) + inv(0.10341)))) * x₂))
# 20          7.095e-04  9.739e-03  y = sqrt(sqrt(sqrt(inv((x₀ - x₁) / ((inv(physics(square(x₂), x...
#                                   ₁)) + -0.81608) + inv(0.10341)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.650e+04
# Head worker occupation: 1.1%
# Progress: 524 / 2500 total iterations (20.960%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.780e-03  2.009e-02  y = (0.9996 ^ x₀)
# 4           5.304e-03  8.594e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           2.035e-03  6.890e-02  y = (physics(x₂, sqrt(x₀)) ^ 0.12741)
# 7           1.703e-03  1.781e-01  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.985e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 10          8.714e-04  1.357e-01  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.095369))) * x₂))
# 12          7.276e-04  9.018e-02  y = (inv(sqrt(x₀ / ((cube(x₂) + x₁) * 2.3925))) ^ 0.2816)
# 14          7.070e-04  1.431e-02  y = (inv(sqrt((x₀ - 1.3016) / ((cube(x₂) + x₁) * 2.3925))) ^ 0...
#                                   .2816)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.400e+04
# Head worker occupation: 1.1%
# Progress: 541 / 2500 total iterations (21.640%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.737e-03  2.383e-02  y = (0.99975 ^ x₀)
# 4           5.304e-03  7.847e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           2.035e-03  6.890e-02  y = (physics(x₂, sqrt(x₀)) ^ 0.12741)
# 7           1.703e-03  1.781e-01  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.985e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 9           8.735e-04  2.689e-01  y = sqrt(sqrt(sqrt(physics(cube(-1.4824), x₀)) * x₂))
# 10          8.714e-04  2.505e-03  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.095369))) * x₂))
# 12          7.276e-04  9.018e-02  y = (inv(sqrt(x₀ / ((cube(x₂) + x₁) * 2.3925))) ^ 0.2816)
# 14          7.070e-04  1.431e-02  y = (inv(sqrt((x₀ - 1.3016) / ((cube(x₂) + x₁) * 2.3925))) ^ 0...
#                                   .2816)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.390e+04
# Head worker occupation: 1.0%
# Progress: 575 / 2500 total iterations (23.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.737e-03  2.383e-02  y = (0.99975 ^ x₀)
# 4           5.304e-03  7.847e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           2.035e-03  6.890e-02  y = (physics(x₂, sqrt(x₀)) ^ 0.12741)
# 7           1.703e-03  1.781e-01  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.985e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 9           8.735e-04  2.689e-01  y = sqrt(sqrt(sqrt(physics(cube(-1.4824), x₀)) * x₂))
# 10          8.714e-04  2.505e-03  y = sqrt(sqrt(sqrt(inv(x₀ / inv(0.095369))) * x₂))
# 12          7.276e-04  9.018e-02  y = (inv(sqrt(x₀ / ((cube(x₂) + x₁) * 2.3925))) ^ 0.2816)
# 14          6.786e-04  3.484e-02  y = ((sqrt(inv(x₀ / ((cube(x₂) + x₁) * 2.3925))) ^ 0.2816) ^ 0...
#                                   .9334)
# 16          6.701e-04  6.302e-03  y = (sqrt(inv((x₀ - -1.4788) / (((cube(x₂) - -1.5692) + x₁) * ...
#                                   2.3925))) ^ 0.2816)
# 17          6.595e-04  1.592e-02  y = (sqrt(inv(x₀ / (((cube(x₂ - inv(x₀)) - -0.031366) + x₁) * ...
#                                   2.4983))) ^ 0.25924)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.420e+04
# Head worker occupation: 1.0%
# Progress: 599 / 2500 total iterations (23.960%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.737e-03  2.383e-02  y = (0.99975 ^ x₀)
# 4           5.304e-03  7.847e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.985e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 9           8.403e-04  3.078e-01  y = (physics(x₂, sqrt(x₀ + -25.994)) ^ inv(x₁))
# 12          7.276e-04  4.801e-02  y = (inv(sqrt(x₀ / ((cube(x₂) + x₁) * 2.3925))) ^ 0.2816)
# 14          6.786e-04  3.484e-02  y = ((sqrt(inv(x₀ / ((cube(x₂) + x₁) * 2.3925))) ^ 0.2816) ^ 0...
#                                   .9334)
# 16          6.701e-04  6.302e-03  y = (sqrt(inv((x₀ - -1.4788) / (((cube(x₂) - -1.5692) + x₁) * ...
#                                   2.3925))) ^ 0.2816)
# 17          6.595e-04  1.592e-02  y = (sqrt(inv(x₀ / (((cube(x₂ - inv(x₀)) - -0.031366) + x₁) * ...
#                                   2.4983))) ^ 0.25924)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.240e+04
# Head worker occupation: 1.0%
# Progress: 623 / 2500 total iterations (24.920%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.737e-03  2.383e-02  y = (0.99975 ^ x₀)
# 4           5.304e-03  7.847e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.985e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 9           8.403e-04  3.078e-01  y = (physics(x₂, sqrt(x₀ + -25.994)) ^ inv(x₁))
# 12          7.276e-04  4.801e-02  y = (inv(sqrt(x₀ / ((cube(x₂) + x₁) * 2.3925))) ^ 0.2816)
# 14          6.786e-04  3.484e-02  y = ((sqrt(inv(x₀ / ((cube(x₂) + x₁) * 2.3925))) ^ 0.2816) ^ 0...
#                                   .9334)
# 15          6.758e-04  4.057e-03  y = (sqrt(inv(x₀ / (((cube(x₂) + inv(0.77745)) + x₁) * 2.3925)...
#                                   )) ^ 0.2816)
# 16          6.701e-04  8.547e-03  y = (sqrt(inv((x₀ - -1.4788) / (((cube(x₂) - -1.5692) + x₁) * ...
#                                   2.3925))) ^ 0.2816)
# 17          6.595e-04  1.592e-02  y = (sqrt(inv(x₀ / (((cube(x₂ - inv(x₀)) - -0.031366) + x₁) * ...
#                                   2.4983))) ^ 0.25924)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.210e+04
# Head worker occupation: 1.0%
# Progress: 649 / 2500 total iterations (25.960%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.737e-03  2.383e-02  y = (0.99975 ^ x₀)
# 4           5.304e-03  7.847e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.985e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 9           8.403e-04  3.078e-01  y = (physics(x₂, sqrt(x₀ + -25.994)) ^ inv(x₁))
# 11          8.399e-04  2.398e-04  y = (physics(x₂, sqrt(x₀ + -25.994) / 0.91897) ^ inv(x₁))
# 12          6.579e-04  2.442e-01  y = (sqrt(inv(x₀ / ((cube(x₂) + x₁) * 2.4983))) ^ 0.25924)
# 15          6.572e-04  3.557e-04  y = (sqrt(inv(x₀ / ((cube(x₂ - cube(0.22218)) + x₁) * 2.4983))...
#                                   ) ^ 0.25924)
# 18          6.568e-04  1.834e-04  y = square(sqrt(sqrt(inv((x₀ + -0.11382) / (((cube(x₂) + x₁) *...
#                                    2.4983) - 0.34282))) ^ 0.25924))
# 20          6.568e-04  1.332e-05  y = square(sqrt(sqrt(inv((x₀ + -0.11382) / (((cube(x₂ + -0.007...
#                                   0066) + x₁) * 2.4983) - 0.34282))) ^ 0.25924))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.150e+04
# Head worker occupation: 1.0%
# Progress: 668 / 2500 total iterations (26.720%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.737e-03  2.383e-02  y = (0.99975 ^ x₀)
# 4           5.304e-03  7.847e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.985e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 9           8.403e-04  3.078e-01  y = (physics(x₂, sqrt(x₀ + -25.994)) ^ inv(x₁))
# 11          8.399e-04  2.398e-04  y = (physics(x₂, sqrt(x₀ + -25.994) / 0.91897) ^ inv(x₁))
# 12          6.579e-04  2.442e-01  y = (sqrt(inv(x₀ / ((cube(x₂) + x₁) * 2.4983))) ^ 0.25924)
# 15          6.572e-04  3.557e-04  y = (sqrt(inv(x₀ / ((cube(x₂ - cube(0.22218)) + x₁) * 2.4983))...
#                                   ) ^ 0.25924)
# 18          6.568e-04  1.834e-04  y = square(sqrt(sqrt(inv((x₀ + -0.11382) / (((cube(x₂) + x₁) *...
#                                    2.4983) - 0.34282))) ^ 0.25924))
# 20          6.568e-04  1.332e-05  y = square(sqrt(sqrt(inv((x₀ + -0.11382) / (((cube(x₂ + -0.007...
#                                   0066) + x₁) * 2.4983) - 0.34282))) ^ 0.25924))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.020e+04
# Head worker occupation: 0.9%
# Progress: 691 / 2500 total iterations (27.640%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.737e-03  2.383e-02  y = (0.99975 ^ x₀)
# 4           5.304e-03  7.847e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.985e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 9           8.403e-04  3.078e-01  y = (physics(x₂, sqrt(x₀ + -25.994)) ^ inv(x₁))
# 11          8.399e-04  2.398e-04  y = (physics(x₂, sqrt(x₀ + -25.994) / 0.91897) ^ inv(x₁))
# 12          6.579e-04  2.442e-01  y = (sqrt(inv(x₀ / ((cube(x₂) + x₁) * 2.4983))) ^ 0.25924)
# 14          6.576e-04  2.155e-04  y = (sqrt(inv(x₀ / (((cube(x₂) + x₁) - 0.024525) * 2.4983))) ^...
#                                    0.25924)
# 15          6.569e-04  1.129e-03  y = (sqrt(inv(x₀ / (((cube(x₂) + x₁) - sqrt(0.024525)) * 2.498...
#                                   3))) ^ 0.25924)
# 18          6.564e-04  2.324e-04  y = (sqrt(inv((x₀ - 1.0092) / (((cube(x₂) + (x₁ - 0.45481)) - ...
#                                   0.024525) * 2.4983))) ^ 0.25924)
# 20          6.545e-04  1.461e-03  y = (sqrt(inv(x₀ / (((cube(x₂) - inv(cube(sqrt(cube(x₂))) / x₂...
#                                   )) + x₁) * 2.4983))) ^ 0.25924)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.040e+04
# Head worker occupation: 0.9%
# Progress: 714 / 2500 total iterations (28.560%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.737e-03  2.383e-02  y = (0.99975 ^ x₀)
# 4           5.304e-03  7.847e-02  y = (0.95015 ^ inv(x₂))
# 5           2.180e-03  8.891e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.985e-01  y = (physics(x₂, sqrt(x₀) - 1.7314) ^ 0.12741)
# 9           8.403e-04  3.078e-01  y = (physics(x₂, sqrt(x₀ + -25.994)) ^ inv(x₁))
# ...
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.060e+04
# Head worker occupation: 0.7%
# Progress: 2376 / 2500 total iterations (95.040%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.721e-03  2.518e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.189e-02  y = (0.93048 ^ inv(x₂))
# 5           2.180e-03  8.730e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.989e-01  y = (physics(x₂, sqrt(x₀) - 1.7438) ^ 0.12741)
# 9           7.959e-04  3.617e-01  y = (sqrt(x₀ / cube(x₂ + 1.5003)) ^ -0.25432)
# 10          6.790e-04  1.589e-01  y = (inv(x₀ / cube(x₂ + 1.4726)) ^ inv(x₁))
# 11          6.682e-04  1.592e-02  y = (inv(x₀ / ((cube(x₂) + x₁) * 2.4983)) ^ 0.13502)
# 12          6.135e-04  8.553e-02  y = (inv((x₀ - x₁) / cube(x₂ + 1.3105)) ^ inv(x₁))
# 13          6.131e-04  5.931e-04  y = (inv((x₀ - x₁) / cube(x₂ + square(1.1464))) ^ inv(x₁))
# 14          6.066e-04  1.063e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁))
# 15          6.066e-04  3.940e-05  y = (inv((x₀ - (x₁ ^ cube(1.031))) / cube(x₂ + 1.2815)) ^ inv(...
#                                   x₁))
# 16          5.985e-04  1.342e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   0.2532))
# 17          5.984e-04  1.587e-04  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(x₁)))
# 18          5.963e-04  3.509e-03  y = (inv((x₀ - (x₁ ^ 1.1057)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(sqrt(x₁))))
# 19          5.951e-04  2.059e-03  y = (inv((x₀ - (x₁ ^ 1.1057)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(x₁ / 1.7854)))
# 20          5.910e-04  6.818e-03  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   square(inv(0.2532) / x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.030e+04
# Head worker occupation: 0.7%
# Progress: 2397 / 2500 total iterations (95.880%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.721e-03  2.518e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.189e-02  y = (0.93048 ^ inv(x₂))
# 5           2.180e-03  8.730e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.989e-01  y = (physics(x₂, sqrt(x₀) - 1.7438) ^ 0.12741)
# 9           7.959e-04  3.617e-01  y = (sqrt(x₀ / cube(x₂ + 1.5003)) ^ -0.25432)
# 10          6.790e-04  1.589e-01  y = (inv(x₀ / cube(x₂ + 1.4726)) ^ inv(x₁))
# 11          6.682e-04  1.592e-02  y = (inv(x₀ / ((cube(x₂) + x₁) * 2.4983)) ^ 0.13502)
# 12          6.135e-04  8.553e-02  y = (inv((x₀ - x₁) / cube(x₂ + 1.3105)) ^ inv(x₁))
# 13          6.131e-04  5.931e-04  y = (inv((x₀ - x₁) / cube(x₂ + square(1.1464))) ^ inv(x₁))
# 14          6.066e-04  1.063e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁))
# 15          6.066e-04  3.940e-05  y = (inv((x₀ - (x₁ ^ cube(1.031))) / cube(x₂ + 1.2815)) ^ inv(...
#                                   x₁))
# 16          5.984e-04  1.364e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   0.3073))
# 18          5.963e-04  1.725e-03  y = (inv((x₀ - (x₁ ^ 1.1057)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(sqrt(x₁))))
# 19          5.951e-04  2.059e-03  y = (inv((x₀ - (x₁ ^ 1.1057)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(x₁ / 1.7854)))
# 20          5.910e-04  6.818e-03  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   square(inv(0.2532) / x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.910e+03
# Head worker occupation: 0.7%
# Progress: 2419 / 2500 total iterations (96.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.721e-03  2.518e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.189e-02  y = (0.93048 ^ inv(x₂))
# 5           2.180e-03  8.730e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.989e-01  y = (physics(x₂, sqrt(x₀) - 1.7438) ^ 0.12741)
# 9           7.959e-04  3.617e-01  y = (sqrt(x₀ / cube(x₂ + 1.5003)) ^ -0.25432)
# 10          6.790e-04  1.589e-01  y = (inv(x₀ / cube(x₂ + 1.4726)) ^ inv(x₁))
# 11          6.682e-04  1.592e-02  y = (inv(x₀ / ((cube(x₂) + x₁) * 2.4983)) ^ 0.13502)
# 12          6.135e-04  8.553e-02  y = (inv((x₀ - x₁) / cube(x₂ + 1.3105)) ^ inv(x₁))
# 13          6.131e-04  5.931e-04  y = (inv((x₀ - x₁) / cube(x₂ + square(1.1464))) ^ inv(x₁))
# 14          6.066e-04  1.063e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁))
# 15          6.066e-04  3.940e-05  y = (inv((x₀ - (x₁ ^ cube(1.031))) / cube(x₂ + 1.2815)) ^ inv(...
#                                   x₁))
# 16          5.984e-04  1.364e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   0.3073))
# 18          5.962e-04  1.777e-03  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(sqrt(x₁))))
# 19          5.951e-04  1.956e-03  y = (inv((x₀ - (x₁ ^ 1.1057)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(x₁ / 1.7854)))
# 20          5.910e-04  6.818e-03  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   square(inv(0.2532) / x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.020e+04
# Head worker occupation: 0.7%
# Progress: 2444 / 2500 total iterations (97.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.721e-03  2.518e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.189e-02  y = (0.93048 ^ inv(x₂))
# 5           2.180e-03  8.730e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.989e-01  y = (physics(x₂, sqrt(x₀) - 1.7438) ^ 0.12741)
# 9           7.959e-04  3.617e-01  y = (sqrt(x₀ / cube(x₂ + 1.5003)) ^ -0.25432)
# 10          6.790e-04  1.589e-01  y = (inv(x₀ / cube(x₂ + 1.4726)) ^ inv(x₁))
# 11          6.682e-04  1.592e-02  y = (inv(x₀ / ((cube(x₂) + x₁) * 2.4983)) ^ 0.13502)
# 12          6.135e-04  8.553e-02  y = (inv((x₀ - x₁) / cube(x₂ + 1.3105)) ^ inv(x₁))
# 13          6.131e-04  5.931e-04  y = (inv((x₀ - x₁) / cube(x₂ + square(1.1464))) ^ inv(x₁))
# 14          6.066e-04  1.063e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁))
# 15          6.066e-04  3.940e-05  y = (inv((x₀ - (x₁ ^ cube(1.031))) / cube(x₂ + 1.2815)) ^ inv(...
#                                   x₁))
# 16          5.984e-04  1.364e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   0.3073))
# 18          5.962e-04  1.777e-03  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(sqrt(x₁))))
# 19          5.951e-04  1.956e-03  y = (inv((x₀ - (x₁ ^ 1.1057)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(x₁ / 1.7854)))
# 20          5.910e-04  6.818e-03  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   square(inv(0.2532) / x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.010e+04
# Head worker occupation: 0.7%
# Progress: 2464 / 2500 total iterations (98.560%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.721e-03  2.518e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.189e-02  y = (0.93048 ^ inv(x₂))
# 5           2.180e-03  8.730e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.989e-01  y = (physics(x₂, sqrt(x₀) - 1.7438) ^ 0.12741)
# 9           7.959e-04  3.617e-01  y = (sqrt(x₀ / cube(x₂ + 1.5003)) ^ -0.25432)
# 10          6.790e-04  1.589e-01  y = (inv(x₀ / cube(x₂ + 1.4726)) ^ inv(x₁))
# 11          6.682e-04  1.592e-02  y = (inv(x₀ / ((cube(x₂) + x₁) * 2.4983)) ^ 0.13502)
# 12          6.135e-04  8.553e-02  y = (inv((x₀ - x₁) / cube(x₂ + 1.3105)) ^ inv(x₁))
# 13          6.131e-04  5.931e-04  y = (inv((x₀ - x₁) / cube(x₂ + square(1.1464))) ^ inv(x₁))
# 14          6.066e-04  1.063e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁))
# 15          6.066e-04  3.940e-05  y = (inv((x₀ - (x₁ ^ cube(1.031))) / cube(x₂ + 1.2815)) ^ inv(...
#                                   x₁))
# 16          5.984e-04  1.364e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   0.3073))
# 18          5.962e-04  1.777e-03  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(sqrt(x₁))))
# 19          5.951e-04  1.956e-03  y = (inv((x₀ - (x₁ ^ 1.1057)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   inv(x₁ / 1.7854)))
# 20          5.910e-04  6.818e-03  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   square(inv(0.2532) / x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.030e+04
# Head worker occupation: 0.7%
# Progress: 2486 / 2500 total iterations (99.440%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.720e-03  2.529e-02  y = (0.99969 ^ x₀)
# 4           5.219e-03  9.166e-02  y = (0.93048 ^ inv(x₂))
# 5           2.180e-03  8.730e-01  y = (physics(-1.6215, x₂) ^ -0.21716)
# 6           1.782e-03  2.015e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10163)
# 7           1.703e-03  4.547e-02  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           1.143e-03  3.989e-01  y = (physics(x₂, sqrt(x₀) - 1.7438) ^ 0.12741)
# 9           7.959e-04  3.617e-01  y = (sqrt(x₀ / cube(x₂ + 1.5003)) ^ -0.25432)
# 10          6.790e-04  1.589e-01  y = (inv(x₀ / cube(x₂ + 1.4726)) ^ inv(x₁))
# 11          6.682e-04  1.592e-02  y = (inv(x₀ / ((cube(x₂) + x₁) * 2.4983)) ^ 0.13502)
# 12          6.135e-04  8.553e-02  y = (inv((x₀ - x₁) / cube(x₂ + 1.3105)) ^ inv(x₁))
# 13          6.131e-04  5.931e-04  y = (inv((x₀ - x₁) / cube(x₂ + square(1.1464))) ^ inv(x₁))
# 14          6.066e-04  1.063e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁))
# 15          6.066e-04  3.940e-05  y = (inv((x₀ - (x₁ ^ cube(1.031))) / cube(x₂ + 1.2815)) ^ inv(...
#                                   x₁))
# 16          5.984e-04  1.364e-02  y = (inv((x₀ - (x₁ ^ 1.1017)) / cube(x₂ + 1.2815)) ^ inv(x₁ + ...
#                                   0.3073))
# 18          5.909e-04  6.241e-03  y = ((inv((x₀ - (x₁ ^ 1.1057)) / cube(x₂ + 1.2815)) ^ inv(x₁ +...
#                                    1.2815)) ^ 1.1712)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          0.9846646
# 	1         0.025292                                   (0.9996921 ^ x0)
# 	2         0.091663                             (0.93047625 ^ inv(x2))
# 	3         0.873024            (physics(-1.6215453, x2) ^ -0.21715538)
# 	4         0.201549               (physics(x2, sqrt(x0)) ^ 0.10162924)
# 	5         0.045466                  (physics(x2, sqrt(x0)) ^ inv(x1))
# 	6         0.398908   (physics(x2, sqrt(x0) - 1.7438189) ^ 0.12740618)
# 	7   >>>>  0.361701    (sqrt(x0 / cube(x2 + 1.5003273)) ^ -0.25432232)
# 	8         0.158852         (inv(x0 / cube(x2 + 1.4725767)) ^ inv(x1))
# 	9         0.015921  (inv(x0 / ((cube(x2) + x1) * 2.4982538)) ^ 0.1...
# 	10        0.085526  (inv((x0 - x1) / cube(x2 + 1.3105192)) ^ inv(x1))
# 	11        0.000593  (inv((x0 - x1) / cube(x2 + square(1.146389))) ...
# 	12        0.010629  (inv((x0 - (x1 ^ 1.1017194)) / cube(x2 + 1.281...
# 	13        0.000040  (inv((x0 - (x1 ^ cube(1.030964))) / cube(x2 + ...
# 	14        0.013642  (inv((x0 - (x1 ^ 1.1017194)) / cube(x2 + 1.281...
# 	15        0.006241  ((inv((x0 - (x1 ^ 1.1057315)) / cube(x2 + 1.28...
#
# 	        loss  complexity
# 	0   0.006017           1
# 	1   0.005720           3
# 	2   0.005219           4
# 	3   0.002180           5
# 	4   0.001782           6
# 	5   0.001703           7
# 	6   0.001143           8
# 	7   0.000796           9
# 	8   0.000679          10
# 	9   0.000668          11
# 	10  0.000613          12
# 	11  0.000613          13
# 	12  0.000607          14
# 	13  0.000607          15
# 	14  0.000598          16
# 	15  0.000591          18
# ]

# %%
model.sympy(6)
# Out:
# (x2**2/(sqrt(x0) - 1.7438189))**0.12740618

# %%
n_r1_pred = model.predict(X)

print("Default selection MSE:", np.power(n_r1_pred - y, 2).mean())
# Out:
# Default selection MSE: 0.0007958504245134017

# %%
x_line = [0.5, 1.5]
y_line = [0.5, 1.5]

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_r1, y=n_r1_pred, marker='o', c='none', edgecolor='b', label='Exterior Girder')
ax1.plot(x_line, y_line, c = "k")
ax1.set_title('Accuracy')
ax1.legend()
plt.xlim((0.7,1.3))
plt.ylim((0.7,1.3))
ax1.set_xlabel('Target $n_{r1}$')
ax1.set_ylabel('Predicted $n_{r1}$')
ax1.grid()

# %%
model.latex()
# Out:
# '\\frac{1.17}{\\left(\\frac{x_{0}}{\\left(0.667 x_{2} + 1\\right)^{3}}\\right)^{0.127}}'

# %% [markdown]
# $0.757 + \frac{1}{\sqrt{\frac{x_{0}^{2}}{x_{1}^{2} x_{3}}}}$
#
# $0.757 + \frac{w_{oh} D^{0.5}}{L}$
#
#
# $ 0.881 + \frac{1.77 x_{1}^{2} x_{2}}{x_{0}^{2}} $
#
# $ 0.881 + \frac{1.77 S^{2} w_{oh}}{L^{2}} $

# %%
y2 = n_r2
model2 = PySRRegressor(
    niterations=50,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    **default_pysr_params
)

model2.fit(X, y2)

print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 1.970e+03
# Head worker occupation: 0.1%
# Progress: 4 / 2500 total iterations (0.160%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.333e-02  1.594e+01  y = 0.17873
# 2           1.115e-02  7.380e-01  y = inv(x₁)
# 3           3.172e-03  1.257e+00  y = physics(0.3492, x₂)
# 6           2.827e-03  3.835e-02  y = physics(0.22309, sqrt(x₂ + -1.3096))
# 7           2.446e-03  1.448e-01  y = inv(square(x₂ * (-1.5983 + -0.23868)))
# 9           2.407e-03  8.106e-03  y = physics(0.22309, (inv(sqrt(0.77429)) * x₂) + -1.3096)
# 11          2.059e-03  7.802e-02  y = inv(((x₂ ^ x₂) + 1.2765) + square(x₂ * -1.5983))
# 16          1.917e-03  1.429e-02  y = inv((1.2765 ^ square(((x₂ * x₂) + -2.0002) - 1.0792)) + sq...
#                                   uare(x₂ * -1.5983))
# 17          1.871e-03  2.414e-02  y = inv(((sqrt(1.2765) ^ square((x₂ * x₂) * 0.59728)) + x₂) + ...
#                                   square(x₂ * -1.5983))
# 18          1.817e-03  2.960e-02  y = inv(((1.2765 ^ square(((x₂ * x₂) + -2.0002) * 0.59728)) + ...
#                                   x₂) + square(x₂ * -1.5983))
# 19          1.816e-03  5.096e-04  y = inv(((x₂ ^ ((((x₂ - -0.12192) * x₂) + -2.0002) - x₂)) + 1....
#                                   2765) + square(x₂ * -1.5983))
# 20          1.801e-03  8.168e-03  y = inv(((1.2765 ^ square(((x₂ * x₂) + (-2.0002 + 0.87095)) - ...
#                                   x₂)) + 1.2765) + square(x₂ * -1.5983))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+03
# Head worker occupation: 0.2%
# Progress: 12 / 2500 total iterations (0.480%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.506e-03  1.594e+01  y = 0.036309
# 3           3.172e-03  1.755e-01  y = physics(0.3492, x₂)
# 5           2.195e-03  1.841e-01  y = cube(sqrt(0.59158) / x₂)
# 7           1.846e-03  8.654e-02  y = cube(sqrt(x₀ * 0.0073044) / x₂)
# 15          1.819e-03  1.844e-03  y = inv((x₂ * square(x₂ + sqrt(0.58308))) + cube(cube(physics(...
#                                   square(x₂), x₀))))
# 16          1.747e-03  4.064e-02  y = inv((x₂ * square(x₂ + sqrt(0.53813))) + cube(cube(cube(phy...
#                                   sics(square(x₂), x₀)))))
# 17          1.678e-03  4.009e-02  y = inv((1.8411 * (square(x₂ + 0.53813) + 0.33246)) + cube(cub...
#                                   e(cube(physics(square(x₂), x₀)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.160e+03
# Head worker occupation: 0.9%
# Progress: 44 / 2500 total iterations (1.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.506e-03  1.594e+01  y = 0.036309
# 2           4.487e-03  4.120e-03  y = square(-0.19661)
# 3           3.172e-03  3.469e-01  y = physics(0.3492, x₂)
# 4           2.216e-03  3.585e-01  y = (0.47802 / cube(x₂))
# 5           2.195e-03  9.567e-03  y = cube(sqrt(0.59158) / x₂)
# 6           2.143e-03  2.417e-02  y = sqrt(inv(cube(2.3562) ^ x₂))
# 7           1.846e-03  1.489e-01  y = cube(sqrt(x₀ * 0.0073044) / x₂)
# 13          1.844e-03  2.408e-04  y = (inv(x₂ + physics(cube(cube(x₂ + -1.153)), x₀)) * square(-...
#                                   0.39698))
# 15          1.064e-03  2.750e-01  y = (((sqrt(sqrt(physics(x₀, x₂)) / x₂) - x₂) - sqrt(0.14763))...
#                                    * square(0.1564))
# 18          9.953e-04  2.216e-02  y = ((sqrt(sqrt(physics(x₀, inv(inv(x₂ / 1.877) / x₂))) / x₂) ...
#                                   - x₂) * square(0.1564))
# 19          9.032e-04  9.714e-02  y = ((sqrt((sqrt(physics(x₀, inv((x₂ / x₂) / x₂))) / x₂) - x₂)...
#                                    - x₂) * square(0.1564))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.310e+04
# Head worker occupation: 1.0%
# Progress: 116 / 2500 total iterations (4.640%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 7           1.846e-03  4.401e-02  y = cube(sqrt(x₀ * 0.0073044) / x₂)
# 8           1.818e-03  1.521e-02  y = cube(((x₀ * 0.0073044) ^ 0.48146) / x₂)
# 9           1.778e-03  2.251e-02  y = cube(sqrt((x₀ * 0.0073044) ^ 0.87146) / x₂)
# 13          9.288e-04  1.623e-01  y = ((square(-0.1717) * (square(sqrt(sqrt(x₀))) - square(x₂)))...
#                                    / sqrt(x₂))
# 18          8.383e-04  2.049e-02  y = ((square(-0.1717 / sqrt(inv(sqrt(sqrt(x₂))))) * (square(sq...
#                                   rt(sqrt(x₀))) - square(x₂))) / x₂)
# 19          7.962e-04  5.153e-02  y = (((square(-0.1717 / inv(sqrt(sqrt(x₂)))) * (square(sqrt(sq...
#                                   rt(x₀))) - square(x₂))) / x₂) / 1.1984)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.540e+04
# Head worker occupation: 1.1%
# Progress: 153 / 2500 total iterations (6.120%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 7           1.846e-03  4.401e-02  y = cube(sqrt(x₀ * 0.0073044) / x₂)
# 8           1.818e-03  1.521e-02  y = cube(((x₀ * 0.0073044) ^ 0.48146) / x₂)
# 9           1.778e-03  2.251e-02  y = cube(sqrt((x₀ * 0.0073044) ^ 0.87146) / x₂)
# 12          1.000e-03  1.917e-01  y = ((square(-0.1717) * (square(sqrt(sqrt(x₀))) - square(x₂)))...
#                                    / x₂)
# 13          9.288e-04  7.417e-02  y = ((square(-0.1717) * (square(sqrt(sqrt(x₀))) - square(x₂)))...
#                                    / sqrt(x₂))
# 15          8.954e-04  1.826e-02  y = ((square(-0.1717) * (square(sqrt(sqrt(x₀))) - square(x₂)))...
#                                    / sqrt(sqrt(sqrt(x₀))))
# 18          8.383e-04  2.198e-02  y = ((square(-0.1717 / sqrt(inv(sqrt(sqrt(x₂))))) * (square(sq...
#                                   rt(sqrt(x₀))) - square(x₂))) / x₂)
# 19          7.962e-04  5.153e-02  y = (((square(-0.1717 / inv(sqrt(sqrt(x₂)))) * (square(sqrt(sq...
#                                   rt(x₀))) - square(x₂))) / x₂) / 1.1984)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.990e+04
# Head worker occupation: 1.1%
# Progress: 197 / 2500 total iterations (7.880%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 7           1.846e-03  4.401e-02  y = cube(sqrt(x₀ * 0.0073044) / x₂)
# 8           1.818e-03  1.521e-02  y = cube(((x₀ * 0.0073044) ^ 0.48146) / x₂)
# 9           1.778e-03  2.251e-02  y = cube(sqrt((x₀ * 0.0073044) ^ 0.87146) / x₂)
# 10          9.251e-04  6.532e-01  y = ((square(0.18293) * (sqrt(x₀) - square(x₂))) / x₂)
# 11          8.037e-04  1.407e-01  y = ((square(-0.1633) / sqrt(x₂)) * (sqrt(x₀) - square(x₂)))
# 15          7.936e-04  3.179e-03  y = ((square(-0.1633) / square(sqrt(sqrt(x₂)))) * (sqrt(x₀ + x...
#                                   ₂) - square(x₂)))
# 17          7.899e-04  2.313e-03  y = ((square(-0.1717) / (sqrt(x₂) - -0.48803)) * ((sqrt(x₀) - ...
#                                   square(x₂)) / sqrt(cube(0.88099))))
# 18          7.784e-04  1.460e-02  y = ((square(-0.1633) / square(sqrt(sqrt(x₂)))) * (sqrt(physic...
#                                   s(x₀, x₀) + square(x₂)) - square(x₂)))
# 19          7.367e-04  5.516e-02  y = ((square(-0.1717) * ((square(sqrt(sqrt(x₀))) + 0.70738) - ...
#                                   square(x₂))) / square(sqrt(sqrt(sqrt(sqrt(x₀))))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.140e+04
# Head worker occupation: 1.1%
# Progress: 232 / 2500 total iterations (9.280%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 7           1.846e-03  4.401e-02  y = cube(sqrt(x₀ * 0.0073044) / x₂)
# 8           1.818e-03  1.521e-02  y = cube(((x₀ * 0.0073044) ^ 0.48146) / x₂)
# 9           9.387e-04  6.612e-01  y = ((0.03178 * (sqrt(x₀) - square(x₂))) / x₂)
# 10          9.251e-04  1.453e-02  y = ((square(0.18293) * (sqrt(x₀) - square(x₂))) / x₂)
# 11          8.037e-04  1.407e-01  y = ((square(-0.1633) / sqrt(x₂)) * (sqrt(x₀) - square(x₂)))
# 12          6.023e-04  2.885e-01  y = (square(0.18709) * ((sqrt(x₀ / x₂) - cube(1.2312)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.930e+04
# Head worker occupation: 1.0%
# Progress: 259 / 2500 total iterations (10.360%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           1.846e-03  6.762e-02  y = cube(sqrt(x₀ * 0.0073044) / x₂)
# 8           1.100e-03  5.177e-01  y = (square(0.14824) * (sqrt(x₀) - square(x₂)))
# 9           9.387e-04  1.587e-01  y = ((0.03178 * (sqrt(x₀) - square(x₂))) / x₂)
# 10          9.251e-04  1.453e-02  y = ((square(0.18293) * (sqrt(x₀) - square(x₂))) / x₂)
# 11          8.017e-04  1.433e-01  y = ((square(0.16299) / sqrt(x₂)) * (sqrt(x₀) - square(x₂)))
# 12          6.023e-04  2.860e-01  y = (square(0.18709) * ((sqrt(x₀ / x₂) - cube(1.2312)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.870e+04
# Head worker occupation: 1.0%
# Progress: 306 / 2500 total iterations (12.240%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           1.555e-03  2.390e-01  y = ((square(-0.17084) * sqrt(x₀)) ^ x₂)
# 8           8.700e-04  5.810e-01  y = (square(0.13488) * (sqrt(x₀) - square(x₂)))
# 11          7.258e-04  6.040e-02  y = (square(0.18709) * ((sqrt(x₀ / x₂) - 1.5101) - x₂))
# 12          6.023e-04  1.866e-01  y = (square(0.18709) * ((sqrt(x₀ / x₂) - cube(1.2312)) - x₂))
# 14          6.009e-04  1.138e-03  y = (square(0.18709) * ((sqrt(x₀ / x₂) - (cube(1.2312) - 0.051...
#                                   538)) - x₂))
# 15          5.369e-04  1.126e-01  y = (square(0.18709) * ((sqrt(((x₀ - x₁) / x₂) - x₂) - 1.2312)...
#                                    - x₂))
# 19          5.345e-04  1.125e-03  y = (square(0.18709) * ((sqrt((((x₀ + 1.4787) - x₁) / x₂) - (x...
#                                   ₂ - -0.6781)) - 1.2312) - x₂))
# 20          5.266e-04  1.488e-02  y = (square(0.18709) * ((sqrt((x₀ / x₂) - (cube(1.7677) * 1.45...
#                                   78)) - 1.5101) - (x₂ * sqrt(cube(0.87542)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.880e+04
# Head worker occupation: 1.0%
# Progress: 349 / 2500 total iterations (13.960%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           1.555e-03  2.390e-01  y = ((square(-0.17084) * sqrt(x₀)) ^ x₂)
# 8           8.700e-04  5.810e-01  y = (square(0.13488) * (sqrt(x₀) - square(x₂)))
# 10          7.405e-04  8.060e-02  y = (cube(0.25324) * ((sqrt(x₀) - square(x₂)) + 0.65384))
# 11          6.211e-04  1.759e-01  y = (square(0.18709) * ((sqrt(x₀ / x₂) - 1.7006) - x₂))
# 12          6.023e-04  3.072e-02  y = (square(0.18709) * ((sqrt(x₀ / x₂) - cube(1.2312)) - x₂))
# 13          5.667e-04  6.088e-02  y = (square(0.18709) * ((sqrt((x₀ / x₂) - x₂) - 1.5101) - x₂))
# 14          5.648e-04  3.430e-03  y = (square(0.18709) * ((sqrt((x₀ / x₂) - cube(1.5101)) - 1.51...
#                                   01) - x₂))
# 15          5.369e-04  5.056e-02  y = (square(0.18709) * ((sqrt(((x₀ - x₁) / x₂) - x₂) - 1.2312)...
#                                    - x₂))
# 16          5.216e-04  2.897e-02  y = ((square(-0.1719) * ((sqrt(x₀ / x₂) - (1.443 - -0.49865)) ...
#                                   - x₂)) * sqrt(x₂))
# 18          5.051e-04  1.601e-02  y = (square(0.18709) * (((sqrt(x₀ / x₂) - cube(x₀ ^ (x₂ / x₀))...
#                                   ) - 0.23862) - x₂))
# 20          4.827e-04  2.272e-02  y = (square(0.18709) * ((sqrt(x₀ / (x₂ - -0.24899)) - cube(x₀ ...
#                                   ^ (x₂ / physics(x₀, x₀)))) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.930e+04
# Head worker occupation: 1.0%
# Progress: 396 / 2500 total iterations (15.840%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           1.555e-03  2.390e-01  y = ((square(-0.17084) * sqrt(x₀)) ^ x₂)
# 8           8.700e-04  5.810e-01  y = (square(0.13488) * (sqrt(x₀) - square(x₂)))
# 10          7.279e-04  8.918e-02  y = (cube(0.25324) * (sqrt(x₀) - (square(x₂) - 0.93958)))
# 11          6.211e-04  1.588e-01  y = (square(0.18709) * ((sqrt(x₀ / x₂) - 1.7006) - x₂))
# 12          6.023e-04  3.072e-02  y = (square(0.18709) * ((sqrt(x₀ / x₂) - cube(1.2312)) - x₂))
# 13          5.667e-04  6.088e-02  y = (square(0.18709) * ((sqrt((x₀ / x₂) - x₂) - 1.5101) - x₂))
# 14          5.648e-04  3.430e-03  y = (square(0.18709) * ((sqrt((x₀ / x₂) - cube(1.5101)) - 1.51...
#                                   01) - x₂))
# 15          5.369e-04  5.056e-02  y = (square(0.18709) * ((sqrt(((x₀ - x₁) / x₂) - x₂) - 1.2312)...
#                                    - x₂))
# 16          5.216e-04  2.897e-02  y = ((square(-0.1719) * ((sqrt(x₀ / x₂) - (1.443 - -0.49865)) ...
#                                   - x₂)) * sqrt(x₂))
# 18          5.051e-04  1.601e-02  y = (square(0.18709) * (((sqrt(x₀ / x₂) - cube(x₀ ^ (x₂ / x₀))...
#                                   ) - 0.23862) - x₂))
# 20          4.827e-04  2.272e-02  y = (square(0.18709) * ((sqrt(x₀ / (x₂ - -0.24899)) - cube(x₀ ...
#                                   ^ (x₂ / physics(x₀, x₀)))) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.220e+04
# Head worker occupation: 1.0%
# Progress: 451 / 2500 total iterations (18.040%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           1.420e-03  3.303e-01  y = ((sqrt(x₀) - square(x₂)) / x₀)
# 8           8.700e-04  4.897e-01  y = (square(0.13488) * (sqrt(x₀) - square(x₂)))
# 10          7.279e-04  8.918e-02  y = (cube(0.25324) * (sqrt(x₀) - (square(x₂) - 0.93958)))
# 11          6.211e-04  1.588e-01  y = (square(0.18709) * ((sqrt(x₀ / x₂) - 1.7006) - x₂))
# 12          6.023e-04  3.072e-02  y = (square(0.18709) * ((sqrt(x₀ / x₂) - cube(1.2312)) - x₂))
# 13          5.667e-04  6.088e-02  y = (square(0.18709) * ((sqrt((x₀ / x₂) - x₂) - 1.5101) - x₂))
# 14          5.648e-04  3.430e-03  y = (square(0.18709) * ((sqrt((x₀ / x₂) - cube(1.5101)) - 1.51...
#                                   01) - x₂))
# 15          5.369e-04  5.056e-02  y = (square(0.18709) * ((sqrt(((x₀ - x₁) / x₂) - x₂) - 1.2312)...
#                                    - x₂))
# 16          5.152e-04  4.128e-02  y = (square(-0.17164) * ((sqrt((x₀ - x₁) / sqrt(x₂)) - x₂) - p...
#                                   hysics(x₂, x₂)))
# 17          4.553e-04  1.235e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.553e-04  8.059e-05  y = (square(0.17014) * ((sqrt((x₀ / x₂) + -0.21874) - square(s...
#                                   quare(x₂ ^ physics(x₂, x₀)))) - x₂))
# 20          4.475e-04  1.716e-02  y = (square(-0.16825) * ((sqrt(x₀ / x₂) - physics(square((x₂ -...
#                                    -0.54338) ^ physics(x₂, x₀)), 1.1419)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.160e+04
# Head worker occupation: 1.1%
# Progress: 486 / 2500 total iterations (19.440%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           1.420e-03  3.303e-01  y = ((sqrt(x₀) - square(x₂)) / x₀)
# 8           8.700e-04  4.897e-01  y = (square(0.13488) * (sqrt(x₀) - square(x₂)))
# 10          7.140e-04  9.883e-02  y = (square(0.13488) * (sqrt(x₀ / 0.84799) - square(x₂)))
# 11          6.211e-04  1.395e-01  y = (square(0.18709) * ((sqrt(x₀ / x₂) - 1.7006) - x₂))
# 12          6.023e-04  3.072e-02  y = (square(0.18709) * ((sqrt(x₀ / x₂) - cube(1.2312)) - x₂))
# 13          5.667e-04  6.088e-02  y = (square(0.18709) * ((sqrt((x₀ / x₂) - x₂) - 1.5101) - x₂))
# 14          5.648e-04  3.430e-03  y = (square(0.18709) * ((sqrt((x₀ / x₂) - cube(1.5101)) - 1.51...
#                                   01) - x₂))
# 15          5.369e-04  5.056e-02  y = (square(0.18709) * ((sqrt(((x₀ - x₁) / x₂) - x₂) - 1.2312)...
#                                    - x₂))
# 16          5.152e-04  4.128e-02  y = (square(-0.17164) * ((sqrt((x₀ - x₁) / sqrt(x₂)) - x₂) - p...
#                                   hysics(x₂, x₂)))
# 17          4.553e-04  1.235e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.553e-04  8.059e-05  y = (square(0.17014) * ((sqrt((x₀ / x₂) + -0.21874) - square(s...
#                                   quare(x₂ ^ physics(x₂, x₀)))) - x₂))
# 20          4.475e-04  1.716e-02  y = (square(-0.16825) * ((sqrt(x₀ / x₂) - physics(square((x₂ -...
#                                    -0.54338) ^ physics(x₂, x₀)), 1.1419)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.200e+04
# Head worker occupation: 1.1%
# Progress: 540 / 2500 total iterations (21.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           1.420e-03  3.303e-01  y = ((sqrt(x₀) - square(x₂)) / x₀)
# 8           8.700e-04  4.897e-01  y = (square(0.13488) * (sqrt(x₀) - square(x₂)))
# 10          7.140e-04  9.883e-02  y = (square(0.13488) * (sqrt(x₀ / 0.84799) - square(x₂)))
# 11          6.211e-04  1.395e-01  y = (square(0.18709) * ((sqrt(x₀ / x₂) - 1.7006) - x₂))
# 12          6.023e-04  3.072e-02  y = (square(0.18709) * ((sqrt(x₀ / x₂) - cube(1.2312)) - x₂))
# 13          5.667e-04  6.088e-02  y = (square(0.18709) * ((sqrt((x₀ / x₂) - x₂) - 1.5101) - x₂))
# 14          5.648e-04  3.430e-03  y = (square(0.18709) * ((sqrt((x₀ / x₂) - cube(1.5101)) - 1.51...
#                                   01) - x₂))
# 15          5.369e-04  5.056e-02  y = (square(0.18709) * ((sqrt(((x₀ - x₁) / x₂) - x₂) - 1.2312)...
#                                    - x₂))
# 16          5.139e-04  4.383e-02  y = (square(0.18709) * (((sqrt(x₀ / sqrt(x₂)) - x₂) - sqrt(x₂)...
#                                   ) - sqrt(x₂)))
# 17          4.553e-04  1.210e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.517e-04  4.034e-03  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀ + -1.2565)))) - x₂))
# 20          4.475e-04  9.249e-03  y = (square(-0.16825) * ((sqrt(x₀ / x₂) - physics(square((x₂ -...
#                                    -0.54338) ^ physics(x₂, x₀)), 1.1419)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.350e+04
# Head worker occupation: 1.1%
# Progress: 594 / 2500 total iterations (23.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           8.700e-04  8.200e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 10          6.855e-04  7.948e-02  y = (cube(0.25324) * ((sqrt(x₀) / 0.9165) - square(x₂)))
# 11          6.211e-04  9.868e-02  y = (square(0.18709) * ((sqrt(x₀ / x₂) - 1.7006) - x₂))
# 12          6.023e-04  3.072e-02  y = (square(0.18709) * ((sqrt(x₀ / x₂) - cube(1.2312)) - x₂))
# 13          5.667e-04  6.088e-02  y = (square(0.18709) * ((sqrt((x₀ / x₂) - x₂) - 1.5101) - x₂))
# 14          5.648e-04  3.430e-03  y = (square(0.18709) * ((sqrt((x₀ / x₂) - cube(1.5101)) - 1.51...
#                                   01) - x₂))
# 15          5.142e-04  9.376e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂, x₀)...
#                                   )) - x₂))
# 16          5.139e-04  6.216e-04  y = (square(0.18709) * (((sqrt(x₀ / sqrt(x₂)) - x₂) - sqrt(x₂)...
#                                   ) - sqrt(x₂)))
# 17          4.553e-04  1.210e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.500e-04  5.932e-03  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀ + -2.1062)))) - x₂))
# 20          4.475e-04  5.453e-03  y = (square(-0.16825) * ((sqrt(x₀ / x₂) - physics(square((x₂ -...
#                                    -0.54338) ^ physics(x₂, x₀)), 1.1419)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.250e+04
# Head worker occupation: 1.1%
# Progress: 636 / 2500 total iterations (25.440%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           8.700e-04  8.200e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 9           7.260e-04  9.050e-02  y = (0.018192 * (sqrt(x₀) - square(x₂ + -0.19018)))
# 10          6.756e-04  7.194e-02  y = (cube(0.25324) * ((sqrt(x₀) / 0.89287) - square(x₂)))
# 11          5.595e-04  1.886e-01  y = (square(0.18709) * ((sqrt(x₀) / 1.3423) - (x₂ + x₂)))
# 13          5.575e-04  1.766e-03  y = (square(0.18709) * ((sqrt(x₀ + -0.13044) / 1.3423) - (x₂ +...
#                                    x₂)))
# 15          5.142e-04  4.042e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂, x₀)...
#                                   )) - x₂))
# 16          4.805e-04  6.786e-02  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) - (x₂ + x₂)) + ph...
#                                   ysics(0.18407, sqrt(x₂))))
# 17          4.553e-04  5.376e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.500e-04  5.932e-03  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀ + -2.1062)))) - x₂))
# 20          4.475e-04  5.453e-03  y = (square(-0.16825) * ((sqrt(x₀ / x₂) - physics(square((x₂ -...
#                                    -0.54338) ^ physics(x₂, x₀)), 1.1419)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.310e+04
# Head worker occupation: 1.1%
# Progress: 687 / 2500 total iterations (27.480%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.975e-03  2.041e-02  y = square((x₀ * 0.0064927) / x₂)
# 7           8.700e-04  8.200e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 9           7.260e-04  9.050e-02  y = (0.018192 * (sqrt(x₀) - square(x₂ + -0.19018)))
# 10          6.756e-04  7.194e-02  y = (cube(0.25324) * ((sqrt(x₀) / 0.89287) - square(x₂)))
# 11          4.815e-04  3.386e-01  y = (square(0.20017) * ((sqrt(x₀) / 1.4094) - (x₂ + x₂)))
# 15          4.804e-04  5.775e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) - (x₂ + x₂)) + ph...
#                                   ysics(0.20017, x₂)))
# 16          4.726e-04  1.645e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.500e-04  5.932e-03  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀ + -2.1062)))) - x₂))
# 20          4.474e-04  5.736e-03  y = (square(-0.16903) * ((sqrt(x₀ / x₂) - physics(square((x₂ -...
#                                    -0.54338) ^ physics(x₂, x₀)), 1.1419)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.330e+04
# Head worker occupation: 1.1%
# Progress: 733 / 2500 total iterations (29.320%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.929e-03  4.422e-02  y = physics(0.51324, 1.3838 ^ square(x₂))
# 7           8.700e-04  7.962e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 9           7.081e-04  1.030e-01  y = (0.018192 * (sqrt(x₀) - square(x₂ + -0.11854)))
# 10          6.756e-04  4.695e-02  y = (cube(0.25324) * ((sqrt(x₀) / 0.89287) - square(x₂)))
# 11          4.815e-04  3.386e-01  y = (square(0.20017) * ((sqrt(x₀) / 1.4094) - (x₂ + x₂)))
# 13          4.812e-04  3.884e-04  y = (square(0.20017) * ((sqrt(x₀ + 0.15995) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 14          4.806e-04  1.131e-03  y = (square(0.20017) * ((sqrt(x₀) / 1.4094) - ((x₂ - square(0....
#                                   15751)) + x₂)))
# 15          4.804e-04  4.014e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) - (x₂ + x₂)) + ph...
#                                   ysics(0.20017, x₂)))
# 16          4.726e-04  1.645e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.500e-04  5.932e-03  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀ + -2.1062)))) - x₂))
# 20          4.474e-04  5.736e-03  y = (square(-0.16903) * ((sqrt(x₀ / x₂) - physics(square((x₂ -...
#                                    -0.54338) ^ physics(x₂, x₀)), 1.1419)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.090e+04
# Head worker occupation: 1.1%
# Progress: 770 / 2500 total iterations (30.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.788e-03  1.203e-01  y = ((x₀ * 0.0064927) / cube(x₂))
# 7           8.700e-04  7.201e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 9           7.081e-04  1.030e-01  y = (0.018192 * (sqrt(x₀) - square(x₂ + -0.11854)))
# 10          6.756e-04  4.695e-02  y = (cube(0.25324) * ((sqrt(x₀) / 0.89287) - square(x₂)))
# 11          4.815e-04  3.386e-01  y = (square(0.20017) * ((sqrt(x₀) / 1.4094) - (x₂ + x₂)))
# 13          4.812e-04  3.884e-04  y = (square(0.20017) * ((sqrt(x₀ + 0.15995) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 14          4.806e-04  1.131e-03  y = (square(0.20017) * ((sqrt(x₀) / 1.4094) - ((x₂ - square(0....
#                                   15751)) + x₂)))
# 15          4.804e-04  4.014e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) - (x₂ + x₂)) + ph...
#                                   ysics(0.20017, x₂)))
# 16          4.726e-04  1.645e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.500e-04  5.932e-03  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀ + -2.1062)))) - x₂))
# 20          4.474e-04  5.736e-03  y = (square(-0.16903) * ((sqrt(x₀ / x₂) - physics(square((x₂ -...
#                                    -0.54338) ^ physics(x₂, x₀)), 1.1419)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.170e+04
# Head worker occupation: 1.1%
# Progress: 819 / 2500 total iterations (32.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.788e-03  1.203e-01  y = ((x₀ * 0.0064927) / cube(x₂))
# 7           8.700e-04  7.201e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 9           7.059e-04  1.045e-01  y = (0.018192 * (sqrt(x₀) - square(x₂ / -1.0779)))
# 10          6.756e-04  4.388e-02  y = (cube(0.25324) * ((sqrt(x₀) / 0.89287) - square(x₂)))
# 11          4.812e-04  3.393e-01  y = (square(-0.2007) * ((sqrt(x₀) / 1.4094) - (x₂ + x₂)))
# 13          4.809e-04  3.639e-04  y = (square(0.20017) * ((sqrt(x₀ + 0.52031) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 14          4.806e-04  5.093e-04  y = (square(0.20017) * ((sqrt(x₀) / 1.4094) - ((x₂ - square(0....
#                                   15751)) + x₂)))
# 15          4.804e-04  4.014e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) - (x₂ + x₂)) + ph...
#                                   ysics(0.20017, x₂)))
# 16          4.726e-04  1.645e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.303e-04  2.829e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - physics(cube(cube(x₂)...
#                                    ^ physics(-1.7681, x₀)), 1.3979)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.040e+04
# Head worker occupation: 1.1%
# Progress: 856 / 2500 total iterations (34.240%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.788e-03  1.203e-01  y = ((x₀ * 0.0064927) / cube(x₂))
# 7           8.700e-04  7.201e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 9           7.059e-04  1.045e-01  y = (0.018192 * (sqrt(x₀) - square(x₂ / -1.0779)))
# 10          6.756e-04  4.388e-02  y = (cube(0.25324) * ((sqrt(x₀) / 0.89287) - square(x₂)))
# 11          4.812e-04  3.393e-01  y = (square(-0.2007) * ((sqrt(x₀) / 1.4094) - (x₂ + x₂)))
# 13          4.809e-04  3.680e-04  y = (square(0.20017) * ((sqrt(x₀ + 0.47875) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 14          4.803e-04  1.148e-03  y = (square(0.20017) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 16          4.726e-04  8.101e-03  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.303e-04  2.829e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - physics(cube(cube(x₂)...
#                                    ^ physics(-1.7681, x₀)), 1.3979)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.940e+04
# Head worker occupation: 1.1%
# Progress: 896 / 2500 total iterations (35.840%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.788e-03  1.203e-01  y = ((x₀ * 0.0064927) / cube(x₂))
# 7           8.700e-04  7.201e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 9           6.771e-04  1.254e-01  y = (0.018192 * (sqrt(x₀) - square(x₂ / 1.047)))
# 10          6.756e-04  2.213e-03  y = (cube(0.25324) * ((sqrt(x₀) / 0.89287) - square(x₂)))
# 11          4.812e-04  3.393e-01  y = (square(-0.2007) * ((sqrt(x₀) / 1.4094) - (x₂ + x₂)))
# 13          4.809e-04  3.680e-04  y = (square(0.20017) * ((sqrt(x₀ + 0.47875) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 14          4.803e-04  1.148e-03  y = (square(0.20017) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 16          4.726e-04  8.101e-03  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.303e-04  2.829e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - physics(cube(cube(x₂)...
#                                    ^ physics(-1.7681, x₀)), 1.3979)) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.980e+04
# Head worker occupation: 1.1%
# Progress: 934 / 2500 total iterations (37.360%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.788e-03  1.203e-01  y = ((x₀ * 0.0064927) / cube(x₂))
# 7           8.700e-04  7.201e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 9           6.771e-04  1.254e-01  y = (0.018192 * (sqrt(x₀) - square(x₂ / 1.047)))
# 10          6.756e-04  2.213e-03  y = (cube(0.25324) * ((sqrt(x₀) / 0.89287) - square(x₂)))
# 11          4.812e-04  3.393e-01  y = (square(-0.2007) * ((sqrt(x₀) / 1.4094) - (x₂ + x₂)))
# 13          4.809e-04  3.680e-04  y = (square(0.20017) * ((sqrt(x₀ + 0.47875) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 14          4.803e-04  1.148e-03  y = (square(0.20017) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 15          4.803e-04  9.185e-05  y = (square(0.20017) * ((sqrt(x₀ + physics(1.4094, x₂)) / 1.40...
#                                   94) - (x₂ + x₂)))
# 16          4.726e-04  1.611e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 19          4.303e-04  2.829e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - physics(cube(cube(x₂)...
#                                    ^ physics(-1.7681, x₀)), 1.3979)) - x₂))
# 20          4.076e-04  5.410e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(physics(square...
#                                   (cube(x₂ ^ physics(-1.7681, x₀))), 1.3979))) - x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.870e+04
# Head worker occupation: 1.1%
# Progress: 969 / 2500 total iterations (38.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           2.016e-03  6.897e-03  y = (physics(-0.53014, x₂) - 0.072591)
# 6           1.788e-03  1.203e-01  y = ((x₀ * 0.0064927) / cube(x₂))
# 7           8.700e-04  7.201e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 9           6.748e-04  1.270e-01  y = (0.018192 * (sqrt(x₀) - square(x₂ / 1.0511)))
# 11          4.812e-04  1.691e-01  y = (square(-0.2007) * ((sqrt(x₀) / 1.4094) - (x₂ + x₂)))
# 13          4.809e-04  3.680e-04  y = (square(0.20017) * ((sqrt(x₀ + 0.47875) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 14          4.803e-04  1.148e-03  y = (square(0.20017) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ + ...
#                                   x₂)))
# 15          4.803e-04  9.185e-05  y = (square(0.20017) * ((sqrt(x₀ + physics(1.4094, x₂)) / 1.40...
#                                   94) - (x₂ + x₂)))
# 16          4.726e-04  1.611e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# ...
# 18          4.034e-04  1.212e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀))) - sqrt(x₂)))
# 20          4.026e-04  9.222e-04  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀ - 0.53155))) - sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.990e+04
# Head worker occupation: 1.1%
# Progress: 2276 / 2500 total iterations (91.040%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           1.737e-03  8.146e-02  y = ((0.39526 / x₂) + -0.12891)
# 6           1.674e-03  3.685e-02  y = ((cube(0.1447) * x₀) ^ x₂)
# 7           8.700e-04  6.544e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 8           6.747e-04  2.542e-01  y = (0.018276 * (sqrt(x₀) - physics(x₂, 1.1045)))
# 9           6.577e-04  2.548e-02  y = (0.018192 * (sqrt(x₀) - square(x₂ ^ 0.95002)))
# 11          4.808e-04  1.567e-01  y = (square(0.20025) * ((sqrt(x₀) / 1.4042) - (x₂ + x₂)))
# 13          4.806e-04  1.514e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) + 0.024522) - (x₂...
#                                    + x₂)))
# 14          4.803e-04  6.657e-04  y = (square(-0.20032) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ +...
#                                    x₂)))
# 15          4.784e-04  4.055e-03  y = (square(0.20017) * (((sqrt(x₀ - x₂) + 0.18349) / 1.4094) -...
#                                    (x₂ + x₂)))
# 16          4.726e-04  1.213e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 18          4.034e-04  1.212e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀))) - sqrt(x₂)))
# 20          4.026e-04  9.222e-04  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀ - 0.53155))) - sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.830e+04
# Head worker occupation: 1.1%
# Progress: 2310 / 2500 total iterations (92.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           1.737e-03  8.146e-02  y = ((0.39526 / x₂) + -0.12891)
# 6           1.674e-03  3.685e-02  y = ((cube(0.1447) * x₀) ^ x₂)
# 7           8.700e-04  6.544e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 8           6.747e-04  2.542e-01  y = (0.018276 * (sqrt(x₀) - physics(x₂, 1.1045)))
# 9           6.577e-04  2.548e-02  y = (0.018192 * (sqrt(x₀) - square(x₂ ^ 0.95002)))
# 11          4.808e-04  1.567e-01  y = (square(0.20025) * ((sqrt(x₀) / 1.4042) - (x₂ + x₂)))
# 13          4.806e-04  1.514e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) + 0.024522) - (x₂...
#                                    + x₂)))
# 14          4.803e-04  6.657e-04  y = (square(-0.20032) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ +...
#                                    x₂)))
# 15          4.784e-04  4.055e-03  y = (square(0.20017) * (((sqrt(x₀ - x₂) + 0.18349) / 1.4094) -...
#                                    (x₂ + x₂)))
# 16          4.726e-04  1.213e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 18          4.034e-04  1.212e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀))) - sqrt(x₂)))
# 20          4.026e-04  9.222e-04  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀ - 0.53155))) - sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.900e+04
# Head worker occupation: 1.1%
# Progress: 2360 / 2500 total iterations (94.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           1.737e-03  8.146e-02  y = ((0.39526 / x₂) + -0.12891)
# 6           1.674e-03  3.685e-02  y = ((cube(0.1447) * x₀) ^ x₂)
# 7           8.700e-04  6.544e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 8           6.747e-04  2.542e-01  y = (0.018276 * (sqrt(x₀) - physics(x₂, 1.1045)))
# 9           6.577e-04  2.548e-02  y = (0.018192 * (sqrt(x₀) - square(x₂ ^ 0.95002)))
# 11          4.808e-04  1.567e-01  y = (square(0.20025) * ((sqrt(x₀) / 1.4042) - (x₂ + x₂)))
# 13          4.806e-04  1.514e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) + 0.024522) - (x₂...
#                                    + x₂)))
# 14          4.803e-04  6.657e-04  y = (square(-0.20032) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ +...
#                                    x₂)))
# 15          4.784e-04  4.055e-03  y = (square(0.20017) * (((sqrt(x₀ - x₂) + 0.18349) / 1.4094) -...
#                                    (x₂ + x₂)))
# 16          4.726e-04  1.213e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 18          4.034e-04  1.212e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀))) - sqrt(x₂)))
# 20          4.026e-04  9.222e-04  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀ - 0.53155))) - sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+04
# Head worker occupation: 1.1%
# Progress: 2405 / 2500 total iterations (96.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           1.737e-03  8.146e-02  y = ((0.39526 / x₂) + -0.12891)
# 6           1.674e-03  3.685e-02  y = ((cube(0.1447) * x₀) ^ x₂)
# 7           8.700e-04  6.544e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 8           6.747e-04  2.542e-01  y = (0.018276 * (sqrt(x₀) - physics(x₂, 1.1045)))
# 9           6.577e-04  2.548e-02  y = (0.018192 * (sqrt(x₀) - square(x₂ ^ 0.95002)))
# 11          4.808e-04  1.567e-01  y = (square(0.20025) * ((sqrt(x₀) / 1.4042) - (x₂ + x₂)))
# 13          4.806e-04  1.514e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) + 0.024522) - (x₂...
#                                    + x₂)))
# 14          4.803e-04  6.657e-04  y = (square(-0.20032) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ +...
#                                    x₂)))
# 15          4.784e-04  4.055e-03  y = (square(0.20017) * (((sqrt(x₀ - x₂) + 0.18349) / 1.4094) -...
#                                    (x₂ + x₂)))
# 16          4.726e-04  1.213e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 18          4.034e-04  1.212e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀))) - sqrt(x₂)))
# 20          4.026e-04  9.222e-04  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀ - 0.53155))) - sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.960e+04
# Head worker occupation: 1.1%
# Progress: 2442 / 2500 total iterations (97.680%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           1.737e-03  8.146e-02  y = ((0.39526 / x₂) + -0.12891)
# 6           1.674e-03  3.685e-02  y = ((cube(0.1447) * x₀) ^ x₂)
# 7           8.700e-04  6.544e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 8           6.747e-04  2.542e-01  y = (0.018276 * (sqrt(x₀) - physics(x₂, 1.1045)))
# 9           6.577e-04  2.548e-02  y = (0.018192 * (sqrt(x₀) - square(x₂ ^ 0.95002)))
# 11          4.808e-04  1.567e-01  y = (square(0.20025) * ((sqrt(x₀) / 1.4042) - (x₂ + x₂)))
# 13          4.806e-04  1.514e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) + 0.024522) - (x₂...
#                                    + x₂)))
# 14          4.803e-04  6.657e-04  y = (square(-0.20032) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ +...
#                                    x₂)))
# 15          4.784e-04  4.055e-03  y = (square(0.20017) * (((sqrt(x₀ - x₂) + 0.18349) / 1.4094) -...
#                                    (x₂ + x₂)))
# 16          4.726e-04  1.213e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 18          4.034e-04  1.212e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀))) - sqrt(x₂)))
# 20          4.026e-04  9.222e-04  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀ - 0.53155))) - sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.010e+04
# Head worker occupation: 1.1%
# Progress: 2488 / 2500 total iterations (99.520%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041416
# 3           2.044e-03  3.923e-01  y = (0.25458 ^ x₂)
# 5           1.737e-03  8.146e-02  y = ((0.39526 / x₂) + -0.12891)
# 6           1.674e-03  3.685e-02  y = ((cube(0.1447) * x₀) ^ x₂)
# 7           8.700e-04  6.544e-01  y = (0.018192 * (sqrt(x₀) - square(x₂)))
# 8           6.747e-04  2.542e-01  y = (0.018276 * (sqrt(x₀) - physics(x₂, 1.1045)))
# 9           6.577e-04  2.548e-02  y = (0.018192 * (sqrt(x₀) - square(x₂ ^ 0.95002)))
# 11          4.808e-04  1.567e-01  y = (square(0.20025) * ((sqrt(x₀) / 1.4042) - (x₂ + x₂)))
# 13          4.806e-04  1.514e-04  y = (square(0.20017) * (((sqrt(x₀) / 1.4094) + 0.024522) - (x₂...
#                                    + x₂)))
# 14          4.803e-04  6.657e-04  y = (square(-0.20032) * ((sqrt(x₀ + inv(x₂)) / 1.4094) - (x₂ +...
#                                    x₂)))
# 15          4.784e-04  4.055e-03  y = (square(0.20017) * (((sqrt(x₀ - x₂) + 0.18349) / 1.4094) -...
#                                    (x₂ + x₂)))
# 16          4.726e-04  1.213e-02  y = (square(0.18709) * ((sqrt(x₀ + (x₂ * inv(-0.19164))) / 1.2...
#                                   369) - (x₂ + x₂)))
# 17          4.553e-04  3.723e-02  y = (square(0.17014) * ((sqrt(x₀ / x₂) - square(square(x₂ ^ ph...
#                                   ysics(x₂, x₀)))) - x₂))
# 18          4.034e-04  1.212e-01  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀))) - sqrt(x₂)))
# 20          4.026e-04  9.222e-04  y = (square(0.17014) * ((sqrt(x₀ / x₂) - (x₀ ^ physics(x₂ - -1...
#                                   .1659, x₀ - 0.53155))) - sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          0.9846646
# 	1         0.025292                                   (0.9996921 ^ x0)
# 	2         0.091663                             (0.93047625 ^ inv(x2))
# 	3         0.873024            (physics(-1.6215453, x2) ^ -0.21715538)
# 	4         0.201549               (physics(x2, sqrt(x0)) ^ 0.10162924)
# 	5         0.045466                  (physics(x2, sqrt(x0)) ^ inv(x1))
# 	6         0.398908   (physics(x2, sqrt(x0) - 1.7438189) ^ 0.12740618)
# 	7   >>>>  0.361701    (sqrt(x0 / cube(x2 + 1.5003273)) ^ -0.25432232)
# 	8         0.158852         (inv(x0 / cube(x2 + 1.4725767)) ^ inv(x1))
# 	9         0.015921  (inv(x0 / ((cube(x2) + x1) * 2.4982538)) ^ 0.1...
# 	10        0.085526  (inv((x0 - x1) / cube(x2 + 1.3105192)) ^ inv(x1))
# 	11        0.000593  (inv((x0 - x1) / cube(x2 + square(1.146389))) ...
# 	12        0.010629  (inv((x0 - (x1 ^ 1.1017194)) / cube(x2 + 1.281...
# 	13        0.000040  (inv((x0 - (x1 ^ cube(1.030964))) / cube(x2 + ...
# 	14        0.013642  (inv((x0 - (x1 ^ 1.1017194)) / cube(x2 + 1.281...
# 	15        0.006241  ((inv((x0 - (x1 ^ 1.1057315)) / cube(x2 + 1.28...
#
# 	        loss  complexity
# 	0   0.006017           1
# 	1   0.005720           3
# 	2   0.005219           4
# 	3   0.002180           5
# 	4   0.001782           6
# 	5   0.001703           7
# 	6   0.001143           8
# 	7   0.000796           9
# 	8   0.000679          10
# 	9   0.000668          11
# 	10  0.000613          12
# 	11  0.000613          13
# 	12  0.000607          14
# 	13  0.000607          15
# 	14  0.000598          16
# 	15  0.000591          18
# ]

# %%
model2.sympy(2)
# Out:
# -0.12891248 + 0.3952553/x2

# %%
n_r2_pred = model2.predict(X)

print("Default selection MSE:", np.power(n_r2_pred - y2, 2).mean())
# Out:
# Default selection MSE: 0.00048076890762363696

# %%
x_line = [-0.25, 0.25]
y_line = [-0.25, 0.25]

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_r2, y=n_r2_pred, marker='o', c='none', edgecolor='b', label='Interior Girder')
ax1.plot(x_line, y_line, c = "k")
ax1.set_title('Accuracy')
ax1.legend()
plt.xlim((-0.25, 0.25))
plt.ylim((-0.25, 0.25))
ax1.set_xlabel('Target $n_{r2}$')
ax1.set_ylabel('Predicted $n_{r2}$')
ax1.grid()

# %%
model2.latex()
# Out:
# '0.0286 \\sqrt{x_{0}} - 0.0802 x_{2}'

# %% [markdown]
# $ \frac{x_{1}^{2}}{x_{0} - \frac{x_{3}}{x_{1}}} + 0.167 $
#
# $ \frac{w_{oh}^{2}}{L - \frac{D}{w_{oh}}} + 0.167 $
#
# $ 0.149 - \frac{1.09 x_{1}^{2}}{x_{0}} $
#
# $ 0.149 - \frac{1.09 w_{oh}^{2}}{L} $
#
# $ 0.14 - \frac{w_{oh}^{2}}{L} $
