# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanrajs/sciml_project/blob/main/project_PySR_Reactions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Symbolic Regression

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi
# Out:
# Installing Julia 1.8.5 on the current Colab Runtime...
# 2023-12-04 03:34:56 URL:https://storage.googleapis.com/julialang2/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz [130873886/130873886] -> "/tmp/julia.tar.gz" [1]
# Installing PyCall.jl...
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Conda ─────────── v1.10.0
#    Installed PyCall ────────── v1.96.2
#    Installed VersionParsing ── v1.3.0
#    Installed JSON ──────────── v0.21.4
#    Installed Parsers ───────── v2.8.0
#    Installed MacroTools ────── v0.5.11
#    Installed Preferences ───── v1.4.1
#    Installed PrecompileTools ─ v1.2.0
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [438e738f] + PyCall v1.96.2
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [8f4d0f93] + Conda v1.10.0
#   [682c06a0] + JSON v0.21.4
#   [1914dd2f] + MacroTools v0.5.11
#   [69de0a69] + Parsers v2.8.0
#   [aea7be01] + PrecompileTools v1.2.0
#   [21216c6a] + Preferences v1.4.1
#   [438e738f] + PyCall v1.96.2
#   [81def892] + VersionParsing v1.3.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b27032c2] + LibCURL v0.6.3
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [fa267f1f] + TOML v1.0.0
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.0+0
#   [14a3606d] + MozillaCACerts_jll v2022.2.1
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [83775a58] + Zlib_jll v1.2.12+3
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/1cb97fa63a3629c6d892af4f76fcc4ad8191837c/build.log`
# Success

# %% [markdown]
# Install PySR and PyTorch-Lightning:

# %%
# %pip install -Uq pysr pytorch_lightning --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 24.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 63.1 MB/s eta 0:00:00

# %%
from julia import Julia

julia = Julia(compiled_modules=False, threads="auto")
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()

# %%
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 22.04.3 LTS
#   uname: Linux 5.15.120+ #1 SMP Wed Aug 30 11:19:59 UTC 2023 x86_64 x86_64
#   CPU: Intel(R) Xeon(R) CPU @ 2.00GHz:
#               speed         user         nice          sys         idle          irq
#        #1  2000 MHz       1016 s          0 s        168 s       1130 s          0 s
#        #2  2000 MHz       1100 s          0 s        166 s       1054 s          0 s
#   Memory: 12.6783447265625 GB (11530.61328125 MB free)
#   Uptime: 240.41 sec
#   Load Avg:  2.83  1.17  0.46
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, skylake-avx512)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/lib64-nvidia
#   JULIA_PROJECT = @pysr-0.16.3
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 22.04.3 LTS
#   uname: Linux 5.15.120+ #1 SMP Wed Aug 30 11:19:59 UTC 2023 x86_64 x86_64
#   CPU: Intel(R) Xeon(R) CPU @ 2.00GHz:
#               speed         user         nice          sys         idle          irq
#        #1  2000 MHz       1345 s          0 s        192 s       1184 s          0 s
#        #2  2000 MHz       1432 s          0 s        192 s       1101 s          0 s
#   Memory: 12.6783447265625 GB (10983.30859375 MB free)
#   Uptime: 281.1 sec
#   Load Avg:  2.76  1.38  0.56
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, skylake-avx512)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/lib64-nvidia
#   JULIA_PROJECT = @pysr-0.16.3
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.10.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#
# signal (2): Interrupt
# in expression starting at /usr/local/lib/python3.10/dist-packages/julia/install.jl:73
# obviously_disjoint at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/subtype.c:356
# obviously_disjoint at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/subtype.c:347 [inlined]
# ijl_type_morespecific at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/subtype.c:3971
# ml_matches at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:3094
# ijl_matching_methods at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:1954
# _methods_by_ftype at ./reflection.jl:945 [inlined]
# _findall at ./compiler/methodtable.jl:106 [inlined]
# #findall#248 at ./compiler/methodtable.jl:75 [inlined]
# findall##kw at ./compiler/methodtable.jl:74 [inlined]
# #findall#250 at ./compiler/methodtable.jl:122
# findall##kw at ./compiler/methodtable.jl:113 [inlined]
# find_matching_methods at ./compiler/abstractinterpretation.jl:326
# abstract_call_gf_by_type at ./compiler/abstractinterpretation.jl:63
# abstract_call_known at ./compiler/abstractinterpretation.jl:1716
# abstract_call at ./compiler/abstractinterpretation.jl:1786
# abstract_call at ./compiler/abstractinterpretation.jl:1753
# abstract_eval_statement at ./compiler/abstractinterpretation.jl:1910
# typeinf_local at ./compiler/abstractinterpretation.jl:2386
# typeinf_nocycle at ./compiler/abstractinterpretation.jl:2482
# _typeinf at ./compiler/typeinfer.jl:230
# typeinf at ./compiler/typeinfer.jl:213
# typeinf_edge at ./compiler/typeinfer.jl:877
# abstract_call_method at ./compiler/abstractinterpretation.jl:647
# abstract_call_gf_by_type at ./compiler/abstractinterpretation.jl:139
# abstract_call_known at ./compiler/abstractinterpretation.jl:1716
# abstract_call at ./compiler/abstractinterpretation.jl:1786
# abstract_call at ./compiler/abstractinterpretation.jl:1753
# abstract_eval_statement at ./compiler/abstractinterpretation.jl:1910
# typeinf_local at ./compiler/abstractinterpretation.jl:2386
# typeinf_nocycle at ./compiler/abstractinterpretation.jl:2482
# _typeinf at ./compiler/typeinfer.jl:230
# typeinf at ./compiler/typeinfer.jl:213
# typeinf_edge at ./compiler/typeinfer.jl:877
# abstract_call_method at ./compiler/abstractinterpretation.jl:647
# abstract_call_gf_by_type at ./compiler/abstractinterpretation.jl:139
# abstract_call_known at ./compiler/abstractinterpretation.jl:1716
# abstract_call at ./compiler/abstractinterpretation.jl:1786
# abstract_call at ./compiler/abstractinterpretation.jl:1753
# abstract_eval_statement at ./compiler/abstractinterpretation.jl:1910
# typeinf_local at ./compiler/abstractinterpretation.jl:2386
# typeinf_nocycle at ./compiler/abstractinterpretation.jl:2482
# _typeinf at ./compiler/typeinfer.jl:230
# typeinf at ./compiler/typeinfer.jl:213
# typeinf_edge at ./compiler/typeinfer.jl:877
# abstract_call_method at ./compiler/abstractinterpretation.jl:647
# abstract_call_gf_by_type at ./compiler/abstractinterpretation.jl:139
# abstract_call_known at ./compiler/abstractinterpretation.jl:1716
# abstract_call at ./compiler/abstractinterpretation.jl:1786
# abstract_call at ./compiler/abstractinterpretation.jl:1753
# abstract_eval_statement at ./compiler/abstractinterpretation.jl:1910
# typeinf_local at ./compiler/abstractinterpretation.jl:2386
# typeinf_nocycle at ./compiler/abstractinterpretation.jl:2482
# _typeinf at ./compiler/typeinfer.jl:230
# typeinf at ./compiler/typeinfer.jl:213
# typeinf_edge at ./compiler/typeinfer.jl:877
# abstract_call_method at ./compiler/abstractinterpretation.jl:647
# abstract_call_gf_by_type at ./compiler/abstractinterpretation.jl:139
# abstract_call_known at ./compiler/abstractinterpretation.jl:1716
# abstract_call at ./compiler/abstractinterpretation.jl:1786
# abstract_call at ./compiler/abstractinterpretation.jl:1753
# abstract_eval_statement at ./compiler/abstractinterpretation.jl:1910
# typeinf_local at ./compiler/abstractinterpretation.jl:2386
# typeinf_nocycle at ./compiler/abstractinterpretation.jl:2482
# _typeinf at ./compiler/typeinfer.jl:230
# typeinf at ./compiler/typeinfer.jl:213
# typeinf_edge at ./compiler/typeinfer.jl:877
# abstract_call_method at ./compiler/abstractinterpretation.jl:647
# abstract_call_gf_by_type at ./compiler/abstractinterpretation.jl:139
# abstract_call_known at ./compiler/abstractinterpretation.jl:1716
# abstract_call at ./compiler/abstractinterpretation.jl:1786
# abstract_call at ./compiler/abstractinterpretation.jl:1753
# abstract_eval_statement at ./compiler/abstractinterpretation.jl:1910
# typeinf_local at ./compiler/abstractinterpretation.jl:2386
# typeinf_nocycle at ./compiler/abstractinterpretation.jl:2482
# _typeinf at ./compiler/typeinfer.jl:230
# typeinf at ./compiler/typeinfer.jl:213
# typeinf_edge at ./compiler/typeinfer.jl:877
# abstract_call_method at ./compiler/abstractinterpretation.jl:647
# abstract_call_gf_by_type at ./compiler/abstractinterpretation.jl:139
# abstract_call_known at ./compiler/abstractinterpretation.jl:1716
# abstract_call at ./compiler/abstractinterpretation.jl:1786
# abstract_call at ./compiler/abstractinterpretation.jl:1753
# abstract_eval_statement at ./compiler/abstractinterpretation.jl:1910
# typeinf_local at ./compiler/abstractinterpretation.jl:2386
# typeinf_nocycle at ./compiler/abstractinterpretation.jl:2482
# _typeinf at ./compiler/typeinfer.jl:230
# typeinf at ./compiler/typeinfer.jl:213
# typeinf_edge at ./compiler/typeinfer.jl:877
# abstract_call_method at ./compiler/abstractinterpretation.jl:647
# abstract_call_gf_by_type at ./compiler/abstractinterpretation.jl:139
# abstract_call_known at ./compiler/abstractinterpretation.jl:1716
# abstract_call at ./compiler/abstractinterpretation.jl:1786
# abstract_call at ./compiler/abstractinterpretation.jl:1753
# abstract_eval_statement at ./compiler/abstractinterpretation.jl:1910
# typeinf_local at ./compiler/abstractinterpretation.jl:2386
# typeinf_nocycle at ./compiler/abstractinterpretation.jl:2482
# _typeinf at ./compiler/typeinfer.jl:230
# typeinf at ./compiler/typeinfer.jl:213
# typeinf_edge at ./compiler/typeinfer.jl:877
# abstract_call_method at ./compiler/abstractinterpretation.jl:647
# abstract_call_gf_by_type at ./compiler/abstractinterpretation.jl:139
# abstract_call_known at ./compiler/abstractinterpretation.jl:1716
# abstract_call at ./compiler/abstractinterpretation.jl:1786
# abstract_call at ./compiler/abstractinterpretation.jl:1753
# abstract_eval_statement at ./compiler/abstractinterpretation.jl:1910
# typeinf_local at ./compiler/abstractinterpretation.jl:2386
# typeinf_nocycle at ./compiler/abstractinterpretation.jl:2482
# _typeinf at ./compiler/typeinfer.jl:230
# typeinf at ./compiler/typeinfer.jl:213
# typeinf_ext at ./compiler/typeinfer.jl:967
# typeinf_ext_toplevel at ./compiler/typeinfer.jl:1000
# typeinf_ext_toplevel at ./compiler/typeinfer.jl:996
# jfptr_typeinf_ext_toplevel_17539.clone_1 at /usr/local/lib/julia/sys.so (unknown line)
# _jl_invoke at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2377 [inlined]
# ijl_apply_generic at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2559
# jl_apply at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/julia.h:1843 [inlined]
# jl_type_infer at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:315
# jl_generate_fptr_impl at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/jitlayers.cpp:319
# jl_compile_method_internal at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2091 [inlined]
# jl_compile_method_internal at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2035
# _jl_invoke at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2369 [inlined]
# ijl_apply_generic at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2559
# jl_apply at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/julia.h:1843 [inlined]
# ijl_atexit_hook at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/init.c:219
# ijl_exit at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/jl_uv.c:640
# exit at ./initdefs.jl:28
# unknown function (ip: 0x7f4d70d26955)
# _jl_invoke at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2377 [inlined]
# ijl_apply_generic at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2559
# jl_apply at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/julia.h:1843 [inlined]
# do_call at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/interpreter.c:126
# eval_value at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/interpreter.c:215
# eval_stmt_value at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/interpreter.c:166 [inlined]
# eval_body at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/interpreter.c:612
# jl_interpret_toplevel_thunk at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/interpreter.c:750
# jl_toplevel_eval_flex at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/toplevel.c:906
# jl_toplevel_eval_flex at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/toplevel.c:850
# ijl_toplevel_eval_in at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/toplevel.c:965
# eval at ./boot.jl:368 [inlined]
# include_string at ./loading.jl:1428
# _jl_invoke at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2377 [inlined]
# ijl_apply_generic at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2559
# _include at ./loading.jl:1488
# include at ./Base.jl:419
# jfptr_include_38905.clone_1 at /usr/local/lib/julia/sys.so (unknown line)
# _jl_invoke at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2377 [inlined]
# ijl_apply_generic at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2559
# exec_options at ./client.jl:303
# _start at ./client.jl:522
# jfptr__start_38041.clone_1 at /usr/local/lib/julia/sys.so (unknown line)
# _jl_invoke at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2377 [inlined]
# ijl_apply_generic at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/gf.c:2559
# jl_apply at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/julia.h:1843 [inlined]
# true_main at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/jlapi.c:575
# jl_repl_entrypoint at /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/src/jlapi.c:719
# main at julia (unknown line)
# unknown function (ip: 0x7f4d86f0cd8f)
# __libc_start_main at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# unknown function (ip: 0x401098)
# unknown function (ip: (nil))
# Allocations: 4428213 (Pool: 4425219; Big: 2994); GC: 4
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.10.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#     Updating registry at `~/.julia/registries/General.toml`
#      Cloning git-repo `https://github.com/MilesCranmer/SymbolicRegression.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed IrrationalConstants ────────────── v0.2.2
#    Installed ScientificTypesBase ────────────── v3.0.0
#    Installed Tricks ─────────────────────────── v0.1.8
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed Adapt ──────────────────────────── v3.7.1
#    Installed DiffRules ──────────────────────── v1.15.1
#    Installed DynamicExpressions ─────────────── v0.13.1
#    Installed LayoutPointers ─────────────────── v0.1.15
#    Installed OffsetArrays ───────────────────── v1.12.10
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed MLJModelInterface ──────────────── v1.9.3
#    Installed StatisticalTraits ──────────────── v3.2.0
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed CPUSummary ─────────────────────── v0.2.4
#    Installed SpecialFunctions ───────────────── v2.3.1
#    Installed VectorizationBase ──────────────── v0.21.65
#    Installed Optim ──────────────────────────── v1.7.6
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed DataAPI ────────────────────────── v1.15.0
#    Installed PDMats ─────────────────────────── v0.11.30
#    Installed JLLWrappers ────────────────────── v1.5.0
#    Installed StaticArraysCore ───────────────── v1.4.2
#    Installed Setfield ───────────────────────── v1.1.1
#    Installed StaticArrays ───────────────────── v1.7.0
#    Installed NaNMath ────────────────────────── v1.0.2
#    Installed LoopVectorization ──────────────── v0.12.166
#    Installed HostCPUFeatures ────────────────── v0.1.16
#    Installed ConstructionBase ───────────────── v1.5.4
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed OrderedCollections ─────────────── v1.6.3
#    Installed NLSolversBase ──────────────────── v7.8.3
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed ArrayInterface ─────────────────── v7.5.1
#    Installed ChainRulesCore ─────────────────── v1.18.0
#    Installed ForwardDiff ────────────────────── v0.10.36
#    Installed FillArrays ─────────────────────── v1.8.0
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed LineSearches ───────────────────── v7.2.0
#    Installed CommonSubexpressions ───────────── v0.3.0
#    Installed ProgressBars ───────────────────── v1.5.1
#    Installed Requires ───────────────────────── v1.3.0
#    Installed LogExpFunctions ────────────────── v0.3.26
#    Installed DataStructures ─────────────────── v0.18.15
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed PackageExtensionCompat ─────────── v1.0.2
#    Installed Static ─────────────────────────── v0.8.8
#    Installed StatsAPI ───────────────────────── v1.7.0
#    Installed OpenSpecFun_jll ────────────────── v0.5.5+0
#    Installed SLEEFPirates ───────────────────── v0.6.42
#    Installed ClusterManagers ────────────────── v0.4.5
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed Compat ─────────────────────────── v4.10.1
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed InverseFunctions ───────────────── v0.1.12
#    Installed StaticArrayInterface ───────────── v1.4.1
#    Installed DynamicQuantities ──────────────── v0.6.3
#    Installed Missings ───────────────────────── v1.1.0
#    Installed SortingAlgorithms ──────────────── v1.2.0
#    Installed StatsBase ──────────────────────── v0.34.2
#    Installed LossFunctions ──────────────────── v0.11.1
#    Installed ChangesOfVariables ─────────────── v0.1.8
#    Installed FiniteDiff ─────────────────────── v2.21.1
#    Installed DocStringExtensions ────────────── v0.9.3
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [34f1f09b] + ClusterManagers v0.4.5
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [79e6a3ab] + Adapt v3.7.1
# ⌅ [4fba245c] + ArrayInterface v7.5.1
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [2a0fbf3d] + CPUSummary v0.2.4
#   [d360d2e6] + ChainRulesCore v1.18.0
#   [9e997f8a] + ChangesOfVariables v0.1.8
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [34f1f09b] + ClusterManagers v0.4.5
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.10.1
#   [187b0558] + ConstructionBase v1.5.4
#   [adafc99b] + CpuId v0.3.1
#   [9a962f9c] + DataAPI v1.15.0
#   [864edb3b] + DataStructures v0.18.15
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [ffbed154] + DocStringExtensions v0.9.3
#   [a40a106e] + DynamicExpressions v0.13.1
# ⌅ [06fc5a27] + DynamicQuantities v0.6.3
#   [1a297f60] + FillArrays v1.8.0
#   [6a86dc24] + FiniteDiff v2.21.1
#   [f6369f11] + ForwardDiff v0.10.36
#   [3e5b6fbb] + HostCPUFeatures v0.1.16
#   [615f187c] + IfElse v0.1.1
#   [3587e190] + InverseFunctions v0.1.12
#   [92d709cd] + IrrationalConstants v0.2.2
#   [692b3bcd] + JLLWrappers v1.5.0
#   [10f19ff3] + LayoutPointers v0.1.15
#   [d3d80556] + LineSearches v7.2.0
#   [2ab3a3ac] + LogExpFunctions v0.3.26
#   [bdcacae8] + LoopVectorization v0.12.166
#   [30fc2ffe] + LossFunctions v0.11.1
#   [e80e1ace] + MLJModelInterface v1.9.3
#   [d125e4d3] + ManualMemory v0.1.8
#   [e1d29d7a] + Missings v1.1.0
#   [d41bc354] + NLSolversBase v7.8.3
#   [77ba4419] + NaNMath v1.0.2
#   [6fe1bfb0] + OffsetArrays v1.12.10
# ⌅ [429524aa] + Optim v1.7.6
#   [bac558e1] + OrderedCollections v1.6.3
#   [90014a1f] + PDMats v0.11.30
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [d96e819e] + Parameters v0.12.3
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [49802e3a] + ProgressBars v1.5.1
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.3.0
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.42
#   [30f210dd] + ScientificTypesBase v3.0.0
#   [efcf1570] + Setfield v1.1.1
#   [a2af1166] + SortingAlgorithms v1.2.0
#   [276daf66] + SpecialFunctions v2.3.1
#   [aedffcd0] + Static v0.8.8
#   [0d7ed370] + StaticArrayInterface v1.4.1
#   [90137ffa] + StaticArrays v1.7.0
#   [1e83bf80] + StaticArraysCore v1.4.2
#   [64bff920] + StatisticalTraits v3.2.0
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.2
#   [8254be44] + SymbolicRegression v0.22.4 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.22.4`
#   [8290d209] + ThreadingUtilities v0.5.2
#   [410a4b4d] + Tricks v0.1.8
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.65
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [56ddb016] + Logging
#   [44cfe95a] + Pkg v1.8.0
#   [3fa0cd96] + REPL
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [a4e569a6] + Tar v1.10.1
#   [8dfed614] + Test
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [3f19e933] + p7zip_jll v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:118: UserWarning: It is recommended to restart Python after installing PySR's dependencies, so that the Julia environment is properly initialized.
#   warnings.warn(

# %%
import sympy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bhushanrajs/sciml_project/main/analysis_data.csv')

tx_girders = {'Tx28' : {'D' : 28.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 6.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx34' : {'D' : 34.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 12.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx40' : {'D' : 40.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 18.75, 'd5' : 3.0, 'd6' : 4.0, 'd7' : 6.75},
              'Tx46' : {'D' : 46.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 22.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx54' : {'D' : 54.0, 'b1' : 36.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.0, 'd3' : 2.0, 'd4' : 30.0, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx62' : {'D' : 62.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 37.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx70' : {'D' : 70.0, 'b1' : 42.0, 'b2' : 7.0, 'b3' : 32.0, 'b4' : 2.0, 'b5' : 3.0, 'd1' : 3.5, 'd2' : 2.5, 'd3' : 2.0, 'd4' : 45.5, 'd5' : 3.0, 'd6' : 4.75, 'd7' : 8.75},
              'Tx84' : {'D' : 84.0, 'b1' : 58.0, 'b2' : 8.0, 'b3' : 38.0, 'b4' : 3.0, 'b5' : 3.0, 'd1' : 4.0, 'd2' : 3.5, 'd3' : 3.0, 'd4' : 55.75, 'd5' : 3.0, 'd6' : 6.0, 'd7' : 8.75}
              }

# bridge geometry data
L = df['L']/12 # span length in ft.
S = df['S']/12 # girder spacing in ft.
w_oh = df['w_oh']/12 # overhang width in ft.
ts = df['ts_U']/12 # thickness of overhang in ft.
girder = df['Girder Type']
D = []
for _, girder_type in girder.items():
  D.append(tx_girders[girder_type]['D'])
df['D'] = D

# intensity of railing dead load in kip/ft
b_rail = df['b_rail_left'] # width of railing
q_rail = (df['q_rail_left'] * b_rail * 12)/1000

# max bending moment in exterior girder G1 & interior girder G2 in kip-ft
bm1 = df['G1 - max_bm']/(1000*12)
bm2 = df['G2 - max_bm']/(1000*12)
bm3 = df['G3 - max_bm']/(1000*12)
bm4 = df['G4 - max_bm']/(1000*12)

# reaction in girders G1 & G2 in kip. (only A1 taken due to symmetry)
r1 = df['G1-A1-Y']/1000
r2 = df['G2-A1-Y']/1000
r3 = df['G3-A1-Y']/1000
r4 = df['G4-A1-Y']/1000

# line analysis with full railing load assumed to be applied on a girder
bm_line = q_rail * (L - 2*9/12)**2 / 8
r_line = q_rail * L / 2


# normalizing bending moments with respect to line analysis
n_bm1 = bm1 / bm_line
n_bm2 = bm2 / bm_line
n_bm3 = bm3 / bm_line
n_bm4 = bm4 / bm_line

# normalizing vertical reactions with respect to line analysis
n_r1 = r1 / r_line
n_r2 = r2 / r_line
n_r3 = r3 / r_line
n_r4 = r4 / r_line

# add the distribution factors to the dataframe
df['n_bm1'] = n_bm1
df['n_bm2'] = n_bm2
df['n_bm3'] = n_bm3
df['n_bm4'] = n_bm4
df['n_r1'] = n_r1
df['n_r2'] = n_r2
df['n_r3'] = n_r3
df['n_r4'] = n_r4

# %%
# sample data from leve rule
# n_r1 = (w_oh + S) / S

# %%
X = np.stack((L, S, w_oh), axis=-1)
y = n_r1

# %%
# Learn equations
default_pysr_params = dict(
    populations=50,
    model_selection="best",
)

# model = PySRRegressor(
#     niterations=30,
#     binary_operators=['+', '-', '*', '/', '^'],
#     unary_operators=["square", "cube", "sqrt"],
#     **default_pysr_params
# )

model = PySRRegressor(
    niterations=40,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    **default_pysr_params
)

model.fit(X, y)

print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# WARNING: using StaticArrays.setindex in module FiniteDiff conflicts with an existing identifier.
# Started!
#
# Expressions evaluated per second: 3.700e+02
# Head worker occupation: 13.5%
# Progress: 5 / 2000 total iterations (0.250%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.596e-01  1.594e+01  y = 1.3766
# 2           6.970e-02  8.286e-01  y = sqrt(0.53628)
# 3           6.252e-03  2.411e+00  y = (x₀ / x₀)
# 5           6.033e-03  1.784e-02  y = sqrt(1.3766 ^ cube(-0.49618))
# 6           5.432e-03  1.050e-01  y = (1.3766 ^ (cube(-0.49618) / x₂))
# 7           5.226e-03  3.858e-02  y = square(1.3766 ^ (cube(-0.49618) / x₂))
# 8           5.052e-03  3.389e-02  y = (1.3766 ^ (-0.49618 / physics(square(x₂), 0.97457)))
# 9           3.699e-03  3.116e-01  y = cube(1.3766 ^ (-0.49618 / physics(square(x₂), 1.3766)))
# 11          3.658e-03  5.538e-03  y = inv(x₂ ^ ((0.65418 ^ (x₂ * square(x₂))) ^ 0.65418))
# 12          3.421e-03  6.705e-02  y = inv(sqrt(square(x₂) ^ (0.65418 ^ ((x₂ ^ x₂) + x₂))))
# 15          3.410e-03  1.127e-03  y = (0.53628 ^ (physics(0.41827 ^ x₂, inv(cube(0.96672) * (-1....
#                                   2133 / -0.048011))) / x₁))
# 16          3.394e-03  4.718e-03  y = sqrt(inv(x₂ ^ ((0.65418 ^ ((sqrt(x₂) ^ x₂) * square(x₂))) ...
#                                   ^ square(0.65418))))
# 17          2.836e-03  1.796e-01  y = square(cube(cube(((x₀ - (0.79069 ^ square(x₂))) + physics(...
#                                   0.79069, x₁ ^ 0.40763)) / x₀)))
# 20          2.448e-03  4.904e-02  y = square(cube(cube(((x₀ - (sqrt(sqrt(0.40763)) ^ square(x₂))...
#                                   ) + physics(0.69369, x₀ ^ square(0.38578))) / x₀)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.730e+03
# Head worker occupation: 0.6%
# Progress: 34 / 2000 total iterations (1.700%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 5           2.465e-03  2.231e-01  y = (physics(1.561, x₂) ^ -0.1962)
# 6           2.394e-03  2.931e-02  y = sqrt(sqrt(inv(physics(1.6551, x₂))))
# 7           2.200e-03  8.453e-02  y = (physics(1.561, x₂ - 0.15187) ^ -0.1962)
# 9           2.191e-03  2.073e-03  y = (physics(1.561, x₂ - physics(0.52146, 1.5432)) ^ -0.1962)
# 11          2.090e-03  2.348e-02  y = (physics(1.561, x₂ - physics(1.561 - 0.17316, x₁)) ^ -0.19...
#                                   62)
# 13          1.253e-03  2.557e-01  y = sqrt(sqrt(sqrt(sqrt((square(sqrt(x₁)) / x₀) ^ 1.7252)) * x...
#                                   ₂))
# 15          1.188e-03  2.678e-02  y = sqrt(sqrt(sqrt(sqrt((square(sqrt(x₁)) / x₀) ^ (1.7252 * 1....
#                                   0886))) * x₂))
# 17          1.120e-03  2.929e-02  y = sqrt(sqrt(sqrt(sqrt(((square(sqrt(x₁)) / x₀) ^ 0.95879) ^ ...
#                                   (1.7252 * 1.0886))) * x₂))
# 18          1.110e-03  9.734e-03  y = sqrt(sqrt(sqrt(sqrt((square(sqrt(x₁ + sqrt(1.7252))) / x₀)...
#                                    ^ (1.7252 * 1.0886))) * x₂))
# 19          1.089e-03  1.910e-02  y = sqrt(sqrt(sqrt(sqrt((square(sqrt(x₁ + inv(sqrt(x₁)))) / x₀...
#                                   ) ^ (1.7252 * 1.0886))) * x₂))
# 20          1.047e-03  3.843e-02  y = sqrt(sqrt(sqrt(sqrt(physics(square(sqrt(x₁ + square(sqrt(x...
#                                   ₁)))) / x₀, sqrt(x₁) * 1.0886))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.760e+03
# Head worker occupation: 0.6%
# Progress: 57 / 2000 total iterations (2.850%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 5           2.465e-03  2.231e-01  y = (physics(1.561, x₂) ^ -0.1962)
# 6           2.394e-03  2.931e-02  y = sqrt(sqrt(inv(physics(1.6551, x₂))))
# 7           2.200e-03  8.453e-02  y = (physics(1.561, x₂ - 0.15187) ^ -0.1962)
# 9           2.191e-03  2.073e-03  y = (physics(1.561, x₂ - physics(0.52146, 1.5432)) ^ -0.1962)
# 11          2.090e-03  2.348e-02  y = (physics(1.561, x₂ - physics(1.561 - 0.17316, x₁)) ^ -0.19...
#                                   62)
# 12          1.294e-03  4.795e-01  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(0.61914 * (x₀ * 1.06...
#                                   18))))))
# 13          1.253e-03  3.189e-02  y = sqrt(sqrt(sqrt(sqrt((square(sqrt(x₁)) / x₀) ^ 1.7252)) * x...
#                                   ₂))
# 14          1.195e-03  4.771e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(0.61914 * (x₀ / 0.53...
#                                   672))) - 0.3952)))
# 15          1.188e-03  5.850e-03  y = sqrt(sqrt(sqrt(sqrt((square(sqrt(x₁)) / x₀) ^ (1.7252 * 1....
#                                   0886))) * x₂))
# 16          1.103e-03  7.406e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀ + x₀)) - sqrt(sqr...
#                                   t(square(inv(1.2534)))))))
# 17          1.073e-03  2.784e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀ + x₀)) - sqrt(sqr...
#                                   t(square(inv(sqrt(x₂))))))))
# 20          8.805e-04  6.589e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(square(physics(0.61914, (...
#                                   x₁ / (x₁ - 0.223)) ^ square(sqrt(x₁)))) * x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.580e+03
# Head worker occupation: 0.8%
# Progress: 86 / 2000 total iterations (4.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 5           2.410e-03  2.288e-01  y = (physics(-1.6857, x₂) ^ -0.1962)
# 6           2.222e-03  8.110e-02  y = sqrt(sqrt(sqrt(x₂) - 0.61313))
# 7           2.200e-03  1.007e-02  y = (physics(1.561, x₂ - 0.15187) ^ -0.1962)
# 8           1.698e-03  2.588e-01  y = sqrt(sqrt(sqrt(x₁ / x₀) * x₂))
# 11          1.239e-03  1.052e-01  y = sqrt(sqrt(sqrt((x₁ / x₀) ^ inv(1.0537)) * x₂))
# 12          1.120e-03  1.006e-01  y = sqrt(sqrt(sqrt((x₁ / x₀) ^ inv(square(1.0537))) * x₂))
# 14          1.119e-03  3.488e-04  y = sqrt(sqrt(sqrt((x₁ / (x₀ + 0.27868)) ^ inv(square(1.0537))...
#                                   ) * x₂))
# 15          1.083e-03  3.256e-02  y = sqrt(sqrt((sqrt((x₁ / x₀) ^ inv(sqrt(square(1.0537)))) * x...
#                                   ₂) + 0.045145))
# 17          1.073e-03  4.870e-03  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀ + x₀)) - sqrt(sqr...
#                                   t(square(inv(sqrt(x₂))))))))
# 20          8.805e-04  6.589e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(square(physics(0.61914, (...
#                                   x₁ / (x₁ - 0.223)) ^ square(sqrt(x₁)))) * x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.140e+04
# Head worker occupation: 0.7%
# Progress: 117 / 2000 total iterations (5.850%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 4           5.226e-03  4.699e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 7           2.200e-03  4.356e-03  y = (physics(1.561, x₂ - 0.15187) ^ -0.1962)
# 8           1.698e-03  2.588e-01  y = sqrt(sqrt(sqrt(x₁ / x₀) * x₂))
# 10          1.144e-03  1.973e-01  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀) + -1.9623))))
# 12          1.120e-03  1.079e-02  y = sqrt(sqrt(sqrt((x₁ / x₀) ^ inv(square(1.0537))) * x₂))
# 14          1.119e-03  3.488e-04  y = sqrt(sqrt(sqrt((x₁ / (x₀ + 0.27868)) ^ inv(square(1.0537))...
#                                   ) * x₂))
# 15          1.083e-03  3.256e-02  y = sqrt(sqrt((sqrt((x₁ / x₀) ^ inv(sqrt(square(1.0537)))) * x...
#                                   ₂) + 0.045145))
# 16          1.062e-03  1.989e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀ + x₀)) - sqrt(sqr...
#                                   t(inv(sqrt(x₂)))))))
# 20          8.805e-04  4.688e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(square(physics(0.61914, (...
#                                   x₁ / (x₁ - 0.223)) ^ square(sqrt(x₁)))) * x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.540e+04
# Head worker occupation: 0.7%
# Progress: 162 / 2000 total iterations (8.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 4           5.226e-03  4.699e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 7           2.193e-03  5.924e-03  y = ((physics(-1.6857, x₂) + -0.06046) ^ -0.1962)
# 8           1.698e-03  2.556e-01  y = sqrt(sqrt(sqrt(x₁ / x₀) * x₂))
# 9           1.331e-03  2.440e-01  y = (sqrt(sqrt(x₁ / x₀) * x₂) ^ 0.3826)
# 10          1.144e-03  1.506e-01  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(sqrt(x₀) + -1.9623))))
# 11          1.133e-03  1.036e-02  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(sqrt(square(x₀))) - 1.7846...
#                                   ))))
# 12          1.039e-03  8.678e-02  y = sqrt(sqrt(sqrt((x₁ - (1.39 / -0.89557)) / x₀) * x₂))
# 13          9.950e-04  4.284e-02  y = (sqrt(sqrt(sqrt((x₁ + sqrt(x₂)) / x₀) * x₂)) ^ 0.95858)
# 14          9.232e-04  7.484e-02  y = (sqrt(sqrt(sqrt((x₁ + sqrt(x₂)) / x₀) * x₂)) ^ cube(0.9585...
#                                   8))
# 19          9.174e-04  1.272e-03  y = (sqrt(cube(sqrt(sqrt(sqrt(sqrt(((x₁ + -0.65962) + x₂) / x₀...
#                                   ) * x₂))))) ^ (0.95858 - -0.058118))
# 20          8.805e-04  4.107e-02  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(square(physics(0.61914, (...
#                                   x₁ / (x₁ - 0.223)) ^ square(sqrt(x₁)))) * x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.530e+04
# Head worker occupation: 0.7%
# Progress: 192 / 2000 total iterations (9.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 4           5.226e-03  4.699e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 7           2.193e-03  5.924e-03  y = ((physics(-1.6857, x₂) + -0.06046) ^ -0.1962)
# 8           1.698e-03  2.556e-01  y = sqrt(sqrt(sqrt(x₁ / x₀) * x₂))
# 9           1.331e-03  2.440e-01  y = (sqrt(sqrt(x₁ / x₀) * x₂) ^ 0.3826)
# 10          1.023e-03  2.629e-01  y = sqrt(sqrt(sqrt((x₁ + 1.698) / x₀) * x₂))
# 12          1.012e-03  5.560e-03  y = sqrt(sqrt(sqrt(((x₁ - -0.31721) + 1.698) / x₀) * x₂))
# 13          9.903e-04  2.129e-02  y = sqrt(cube(sqrt(sqrt(sqrt(sqrt((x₁ + x₂) / x₀) * x₂)))))
# 14          9.232e-04  7.014e-02  y = (sqrt(sqrt(sqrt((x₁ + sqrt(x₂)) / x₀) * x₂)) ^ cube(0.9585...
#                                   8))
# 16          9.077e-04  8.461e-03  y = (sqrt(sqrt(((x₁ - cube(-1.5386)) / x₀) * (0.681 ^ 0.40635)...
#                                   ) * x₂) ^ 0.40635)
# 20          8.805e-04  7.626e-03  y = sqrt(sqrt(physics(sqrt(x₂), sqrt(square(physics(0.61914, (...
#                                   x₁ / (x₁ - 0.223)) ^ square(sqrt(x₁)))) * x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.700e+04
# Head worker occupation: 0.7%
# Progress: 233 / 2000 total iterations (11.650%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 4           5.226e-03  4.699e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 7           1.990e-03  5.437e-02  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀)))))
# 8           1.698e-03  1.587e-01  y = sqrt(sqrt(sqrt(x₁ / x₀) * x₂))
# 9           1.133e-03  4.044e-01  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀) + -1.8264))))
# 10          1.023e-03  1.025e-01  y = sqrt(sqrt(sqrt((x₁ + 1.698) / x₀) * x₂))
# 12          1.011e-03  5.647e-03  y = sqrt(sqrt(sqrt((x₁ + sqrt(inv(0.26007))) / x₀) * x₂))
# 13          9.508e-04  6.179e-02  y = (sqrt(sqrt((x₁ - -1.1142) / (x₀ - x₂)) * x₂) ^ 0.40635)
# 14          9.232e-04  2.947e-02  y = (sqrt(sqrt(sqrt((x₁ + sqrt(x₂)) / x₀) * x₂)) ^ cube(0.9585...
#                                   8))
# 15          9.224e-04  8.568e-04  y = (sqrt(sqrt(sqrt(((x₁ + 0.047011) - -1.8283) / x₀) * x₂)) ^...
#                                    cube(0.95858))
# 16          9.077e-04  1.607e-02  y = (sqrt(sqrt(((x₁ - cube(-1.5386)) / x₀) * (0.681 ^ 0.40635)...
#                                   ) * x₂) ^ 0.40635)
# 17          8.377e-04  8.028e-02  y = sqrt(sqrt(sqrt(square(sqrt(cube(sqrt((((sqrt(x₀) + x₂) / x...
#                                   ₀) / 0.40868) * x₂)))))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.830e+04
# Head worker occupation: 0.7%
# Progress: 271 / 2000 total iterations (13.550%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 4           5.226e-03  4.699e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 7           1.990e-03  5.437e-02  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀)))))
# 8           1.698e-03  1.587e-01  y = sqrt(sqrt(sqrt(x₁ / x₀) * x₂))
# 9           1.133e-03  4.044e-01  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀) + -1.8264))))
# 10          1.012e-03  1.137e-01  y = sqrt(sqrt(sqrt((x₁ + 1.9451) / x₀) * x₂))
# 12          9.617e-04  2.525e-02  y = ((sqrt((x₁ + x₂) / x₀) * x₂) ^ square(cube(0.76255)))
# 13          9.384e-04  2.454e-02  y = sqrt(sqrt(sqrt(sqrt((x₁ - -1.8488) / x₀) * x₂) ^ 1.8619))
# 14          9.232e-04  1.633e-02  y = (sqrt(sqrt(sqrt((x₁ + sqrt(x₂)) / x₀) * x₂)) ^ cube(0.9585...
#                                   8))
# 15          8.506e-04  8.197e-02  y = sqrt(sqrt(sqrt((((x₁ - -10.068) + inv(x₂)) - x₁) / x₀) * x...
#                                   ₂))
# 17          8.377e-04  7.614e-03  y = sqrt(sqrt(sqrt(square(sqrt(cube(sqrt((((sqrt(x₀) + x₂) / x...
#                                   ₀) / 0.40868) * x₂)))))))
# 19          8.375e-04  1.458e-04  y = sqrt(sqrt(sqrt(square(sqrt(cube(sqrt((((sqrt(x₀ - -0.07084...
#                                   1) + x₂) / x₀) / 0.40868) * x₂)))))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.670e+04
# Head worker occupation: 0.8%
# Progress: 299 / 2000 total iterations (14.950%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 4           5.226e-03  4.699e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 7           1.990e-03  5.437e-02  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀)))))
# 8           1.698e-03  1.587e-01  y = sqrt(sqrt(sqrt(x₁ / x₀) * x₂))
# 9           1.133e-03  4.044e-01  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀) + -1.8264))))
# 10          1.012e-03  1.137e-01  y = sqrt(sqrt(sqrt((x₁ + 1.9451) / x₀) * x₂))
# 11          9.538e-04  5.872e-02  y = sqrt((sqrt((x₁ + x₂) / x₀) * x₂) ^ 0.40635)
# 13          9.181e-04  1.908e-02  y = sqrt((sqrt((x₁ + x₂) / (x₂ + x₀)) * x₂) ^ 0.40635)
# 15          8.506e-04  3.822e-02  y = sqrt(sqrt(sqrt((((x₁ - -10.068) + inv(x₂)) - x₁) / x₀) * x...
#                                   ₂))
# 17          8.377e-04  7.614e-03  y = sqrt(sqrt(sqrt(square(sqrt(cube(sqrt((((sqrt(x₀) + x₂) / x...
#                                   ₀) / 0.40868) * x₂)))))))
# 19          8.375e-04  1.458e-04  y = sqrt(sqrt(sqrt(square(sqrt(cube(sqrt((((sqrt(x₀ - -0.07084...
#                                   1) + x₂) / x₀) / 0.40868) * x₂)))))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.680e+04
# Head worker occupation: 0.8%
# Progress: 331 / 2000 total iterations (16.550%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 7           1.990e-03  5.437e-02  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀)))))
# 8           1.381e-03  3.653e-01  y = ((sqrt(x₁ / x₀) * x₂) ^ 0.21467)
# 9           1.133e-03  1.978e-01  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀) + -1.8264))))
# 10          1.012e-03  1.137e-01  y = sqrt(sqrt(sqrt((x₁ + 1.9451) / x₀) * x₂))
# 11          9.538e-04  5.872e-02  y = sqrt((sqrt((x₁ + x₂) / x₀) * x₂) ^ 0.40635)
# 12          8.964e-04  6.212e-02  y = sqrt(sqrt(sqrt(((x₁ - -10.068) - x₁) / x₀) * x₂))
# 15          8.506e-04  1.750e-02  y = sqrt(sqrt(sqrt((((x₁ - -10.068) + inv(x₂)) - x₁) / x₀) * x...
#                                   ₂))
# 17          8.377e-04  7.614e-03  y = sqrt(sqrt(sqrt(square(sqrt(cube(sqrt((((sqrt(x₀) + x₂) / x...
#                                   ₀) / 0.40868) * x₂)))))))
# 18          8.239e-04  1.662e-02  y = sqrt(sqrt(sqrt((((x₁ - -10.068) + square(inv(-0.58751 * x₂...
#                                   ))) - x₁) / x₀) * x₂))
# 20          8.222e-04  1.058e-03  y = sqrt(sqrt(sqrt((((x₁ - -10.068) + cube(inv((0.062739 - -0....
#                                   58751) * x₂))) - x₁) / x₀) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.530e+04
# Head worker occupation: 0.8%
# Progress: 357 / 2000 total iterations (17.850%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 6           2.203e-03  7.222e-03  y = square(physics(-1.6342, x₂) ^ -0.10123)
# 7           1.990e-03  1.015e-01  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀)))))
# 8           1.381e-03  3.653e-01  y = ((sqrt(x₁ / x₀) * x₂) ^ 0.21467)
# 9           1.127e-03  2.036e-01  y = sqrt(sqrt(sqrt(inv(0.10867) / x₀) * x₂))
# 10          1.012e-03  1.079e-01  y = sqrt(sqrt(sqrt((x₁ + 1.9451) / x₀) * x₂))
# 11          8.863e-04  1.322e-01  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ / 1.1043)) * x₂))
# 13          8.744e-04  6.746e-03  y = sqrt(sqrt(sqrt((inv(0.10867) + 0.15978) / (x₀ / 1.1043)) *...
#                                    x₂))
# 14          8.611e-04  1.528e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ / 1.1043) - square(1.63...
#                                   43))) * x₂))
# 15          8.506e-04  1.237e-02  y = sqrt(sqrt(sqrt((((x₁ - -10.068) + inv(x₂)) - x₁) / x₀) * x...
#                                   ₂))
# 16          7.929e-04  7.019e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ - physics(cube(1.6343), ...
#                                   x₂))) * physics(x₂, x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.470e+04
# Head worker occupation: 0.8%
# Progress: 393 / 2000 total iterations (19.650%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 6           2.203e-03  7.222e-03  y = square(physics(-1.6342, x₂) ^ -0.10123)
# 7           1.853e-03  1.728e-01  y = sqrt(physics(x₂, sqrt(x₀)) ^ 0.23048)
# 8           1.381e-03  2.940e-01  y = ((sqrt(x₁ / x₀) * x₂) ^ 0.21467)
# 9           9.695e-04  3.539e-01  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀ - 26.867)))))
# 11          8.776e-04  4.980e-02  y = sqrt(sqrt(sqrt((inv(0.10867) - -1.4971) / x₀) * x₂))
# 13          8.744e-04  1.813e-03  y = sqrt(sqrt(sqrt((inv(0.10867) + 0.15978) / (x₀ / 1.1043)) *...
#                                    x₂))
# 14          7.614e-04  1.384e-01  y = sqrt(sqrt(sqrt((sqrt(x₁) + inv(0.15978)) / x₀) * (x₂ - -0....
#                                   16131)))
# 19          7.496e-04  3.111e-03  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ / 1.1043) - physics(cub...
#                                   e(1.6343 / x₂), inv(x₁)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.650e+04
# Head worker occupation: 0.8%
# Progress: 441 / 2000 total iterations (22.050%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.219e-03  8.566e-01  y = (physics(-1.6342, x₂) ^ -0.1962)
# 6           2.203e-03  7.222e-03  y = square(physics(-1.6342, x₂) ^ -0.10123)
# 7           1.818e-03  1.918e-01  y = sqrt(physics(x₂, sqrt(x₀)) ^ 0.18404)
# 8           1.381e-03  2.751e-01  y = ((sqrt(x₁ / x₀) * x₂) ^ 0.21467)
# 9           9.695e-04  3.539e-01  y = sqrt(sqrt(sqrt(physics(x₂, sqrt(x₀ - 26.867)))))
# 11          8.076e-04  9.135e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ - x₁)) * x₂))
# 14          7.614e-04  1.964e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) + inv(0.15978)) / x₀) * (x₂ - -0....
#                                   16131)))
# 18          7.593e-04  6.684e-04  y = sqrt(sqrt(sqrt(((sqrt(x₁ - x₂) + inv(0.15978)) + 0.50465) ...
#                                   / x₀) * (x₂ - -0.16131)))
# 19          7.496e-04  1.288e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ / 1.1043) - physics(cub...
#                                   e(1.6343 / x₂), inv(x₁)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.710e+04
# Head worker occupation: 0.8%
# Progress: 473 / 2000 total iterations (23.650%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 7           1.818e-03  9.528e-02  y = sqrt(physics(x₂, sqrt(x₀)) ^ 0.18404)
# 8           1.381e-03  2.751e-01  y = ((sqrt(x₁ / x₀) * x₂) ^ 0.21467)
# 9           8.836e-04  4.466e-01  y = sqrt(sqrt(sqrt(inv(0.098121) / x₀) * x₂))
# 11          8.076e-04  4.499e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ - x₁)) * x₂))
# 13          8.070e-04  3.433e-04  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ - x₁) + 0.11273)) * x₂)...
#                                   )
# 14          7.614e-04  5.824e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) + inv(0.15978)) / x₀) * (x₂ - -0....
#                                   16131)))
# 18          7.593e-04  6.684e-04  y = sqrt(sqrt(sqrt(((sqrt(x₁ - x₂) + inv(0.15978)) + 0.50465) ...
#                                   / x₀) * (x₂ - -0.16131)))
# 19          7.436e-04  2.100e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ / 1.1043) - (cube(1.634...
#                                   3 / x₂) / inv(x₁)))) * x₂))
# 20          7.436e-04  0.000e+00  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ / 1.1043) - physics(sqr...
#                                   t(cube(1.6343 / x₂)), inv(x₁)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.820e+04
# Head worker occupation: 0.8%
# Progress: 517 / 2000 total iterations (25.850%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.818e-03  7.485e-02  y = sqrt(physics(x₂, sqrt(x₀)) ^ 0.18404)
# 8           1.381e-03  2.751e-01  y = ((sqrt(x₁ / x₀) * x₂) ^ 0.21467)
# 9           8.836e-04  4.466e-01  y = sqrt(sqrt(sqrt(inv(0.098121) / x₀) * x₂))
# 11          8.076e-04  4.499e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ - x₁)) * x₂))
# 13          8.061e-04  9.205e-04  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ - x₁) + 0.46306)) * x₂)...
#                                   )
# 14          7.614e-04  5.709e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) + inv(0.15978)) / x₀) * (x₂ - -0....
#                                   16131)))
# 18          7.593e-04  6.684e-04  y = sqrt(sqrt(sqrt(((sqrt(x₁ - x₂) + inv(0.15978)) + 0.50465) ...
#                                   / x₀) * (x₂ - -0.16131)))
# 19          7.436e-04  2.100e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ / 1.1043) - (cube(1.634...
#                                   3 / x₂) / inv(x₁)))) * x₂))
# 20          7.436e-04  0.000e+00  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ / 1.1043) - physics(sqr...
#                                   t(cube(1.6343 / x₂)), inv(x₁)))) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+04
# Head worker occupation: 0.8%
# Progress: 559 / 2000 total iterations (27.950%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.818e-03  7.485e-02  y = sqrt(physics(x₂, sqrt(x₀)) ^ 0.18404)
# 8           1.006e-03  5.918e-01  y = sqrt(sqrt(sqrt(physics(x₂ / 0.32379, x₀))))
# 9           8.784e-04  1.359e-01  y = sqrt(sqrt(sqrt(inv(0.097445) / x₀) * x₂))
# 11          8.060e-04  4.303e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂))
# 14          7.614e-04  1.897e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) + inv(0.15978)) / x₀) * (x₂ - -0....
#                                   16131)))
# 16          7.490e-04  8.218e-03  y = sqrt(sqrt(sqrt((sqrt(x₁ - 1.856) + inv(0.15978)) / x₀) * (...
#                                   x₂ - -0.22258)))
# 18          6.941e-04  3.805e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ - cube(sqrt(inv(x₂ / x₁...
#                                   )))) + -0.6107)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.820e+04
# Head worker occupation: 0.8%
# Progress: 589 / 2000 total iterations (29.450%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.818e-03  7.485e-02  y = sqrt(physics(x₂, sqrt(x₀)) ^ 0.18404)
# 8           1.006e-03  5.918e-01  y = sqrt(sqrt(sqrt(physics(x₂ / 0.32379, x₀))))
# 9           8.714e-04  1.439e-01  y = sqrt(sqrt(sqrt(inv(0.095379) / x₀) * x₂))
# 10          8.394e-04  3.740e-02  y = sqrt(sqrt(sqrt(physics(x₂ / 0.32379, x₀ - x₁))))
# 11          8.060e-04  4.061e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂))
# 14          7.614e-04  1.897e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) + inv(0.15978)) / x₀) * (x₂ - -0....
#                                   16131)))
# 16          7.392e-04  1.478e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ - (sqrt(x₁) ^ physics(-1...
#                                   .8847, x₂)))) * x₂))
# 18          6.941e-04  3.149e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ - cube(sqrt(inv(x₂ / x₁...
#                                   )))) + -0.6107)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.720e+04
# Head worker occupation: 0.8%
# Progress: 625 / 2000 total iterations (31.250%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.789e-03  9.103e-02  y = (sqrt(physics(x₂, sqrt(x₀))) ^ 0.19467)
# 8           1.006e-03  5.756e-01  y = sqrt(sqrt(sqrt(physics(x₂ / 0.32379, x₀))))
# 9           8.714e-04  1.439e-01  y = sqrt(sqrt(sqrt(inv(0.095379) / x₀) * x₂))
# 10          8.394e-04  3.740e-02  y = sqrt(sqrt(sqrt(physics(x₂ / 0.32379, x₀ - x₁))))
# 11          8.060e-04  4.061e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂))
# 13          7.821e-04  1.506e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂) ^ 0.8687)
# 14          7.614e-04  2.680e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) + inv(0.15978)) / x₀) * (x₂ - -0....
#                                   16131)))
# 16          7.392e-04  1.478e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ - (sqrt(x₁) ^ physics(-1...
#                                   .8847, x₂)))) * x₂))
# 18          6.941e-04  3.149e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ - cube(sqrt(inv(x₂ / x₁...
#                                   )))) + -0.6107)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.690e+04
# Head worker occupation: 0.8%
# Progress: 659 / 2000 total iterations (32.950%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.789e-03  9.103e-02  y = (sqrt(physics(x₂, sqrt(x₀))) ^ 0.19467)
# 8           8.827e-04  7.065e-01  y = sqrt(sqrt(sqrt(physics(x₂ / 0.31308, x₀))))
# 9           8.714e-04  1.299e-02  y = sqrt(sqrt(sqrt(inv(0.095379) / x₀) * x₂))
# 10          8.394e-04  3.740e-02  y = sqrt(sqrt(sqrt(physics(x₂ / 0.32379, x₀ - x₁))))
# 11          8.060e-04  4.061e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂))
# 13          7.821e-04  1.506e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂) ^ 0.8687)
# 14          7.614e-04  2.680e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) + inv(0.15978)) / x₀) * (x₂ - -0....
#                                   16131)))
# 16          7.392e-04  1.478e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ - (sqrt(x₁) ^ physics(-1...
#                                   .8847, x₂)))) * x₂))
# 18          6.941e-04  3.149e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ - cube(sqrt(inv(x₂ / x₁...
#                                   )))) + -0.6107)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.540e+04
# Head worker occupation: 0.9%
# Progress: 689 / 2000 total iterations (34.450%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.703e-03  1.406e-01  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           8.714e-04  6.700e-01  y = sqrt(sqrt(sqrt(physics(x₂ / -0.30885, x₀))))
# 9           8.714e-04  4.768e-07  y = sqrt(sqrt(sqrt(inv(0.095379) / x₀) * x₂))
# 10          8.322e-04  4.595e-02  y = sqrt(sqrt(sqrt(physics((x₂ / 0.32379) + 0.46311, x₀))))
# 11          8.060e-04  3.207e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂))
# 13          7.821e-04  1.506e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂) ^ 0.8687)
# 14          7.614e-04  2.680e-02  y = sqrt(sqrt(sqrt((sqrt(x₁) + inv(0.15978)) / x₀) * (x₂ - -0....
#                                   16131)))
# 16          7.392e-04  1.478e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ - (sqrt(x₁) ^ physics(-1...
#                                   .8847, x₂)))) * x₂))
# 18          6.941e-04  3.149e-02  y = sqrt(sqrt(sqrt(inv(0.10867) / ((x₀ - cube(sqrt(inv(x₂ / x₁...
#                                   )))) + -0.6107)) * x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.560e+04
# Head worker occupation: 0.8%
# Progress: 727 / 2000 total iterations (36.350%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.703e-03  1.406e-01  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           8.714e-04  6.700e-01  y = sqrt(sqrt(sqrt(physics(x₂ / -0.30885, x₀))))
# 9           8.504e-04  2.430e-02  y = (sqrt(sqrt(physics(x₂ / 0.30801, x₀))) ^ 0.46951)
# 10          8.322e-04  2.165e-02  y = sqrt(sqrt(sqrt(physics((x₂ / 0.32379) + 0.46311, x₀))))
# 11          8.060e-04  3.207e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂))
# 12          7.917e-04  1.784e-02  y = sqrt(sqrt(sqrt(physics(x₂ / 0.32379, (x₀ - x₁) + x₂))))
# 13          7.821e-04  1.228e-02  y = sqrt(sqrt(sqrt(inv(0.10947) / (x₀ - x₁)) * x₂) ^ 0.8687)
# 14          7.433e-04  5.077e-02  y = (physics(x₂ / 0.32379, (x₀ - sqrt(x₁)) + inv(1.2)) ^ inv(x...
#                                   ₁))
# 16          7.392e-04  2.792e-03  y = sqrt(sqrt(sqrt(inv(0.10867) / (x₀ - (sqrt(x₁) ^ physics(-1...
#                                   .8847, x₂)))) * x₂))
# 18          6.734e-04  4.659e-02  y = (sqrt(sqrt(cube(sqrt(inv(0.10947) / ((x₀ - x₁) - 0.8687)) ...
#                                   * x₂))) ^ (0.8687 ^ x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.600e+04
# Head worker occupation: 0.9%
# Progress: 762 / 2000 total iterations (38.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.703e-03  1.406e-01  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           8.165e-04  7.350e-01  y = (physics(x₂ / 0.32379, x₀) ^ inv(x₁))
# 10          7.838e-04  2.044e-02  y = (physics(x₂ / 0.32379, x₀ + -0.91215) ^ inv(x₁))
# 12          7.733e-04  6.689e-03  y = (physics(x₂ / 0.32379, x₀) ^ inv(x₁ - (-0.7346 / x₂)))
# 13          6.669e-04  1.481e-01  y = (physics(x₂ / 0.32379, (x₀ - x₁) + inv(1.2)) ^ inv(x₁))
# 15          6.645e-04  1.782e-03  y = (physics(x₂ / 0.32379, (x₀ - x₁) + inv(1.2 ^ -0.26736)) ^ ...
#                                   inv(x₁))
# 16          6.524e-04  1.836e-02  y = (physics(x₂ / (0.32379 * 1.0356), (x₀ - x₁) + inv(cube(-1....
#                                   0989))) ^ inv(x₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.430e+04
# Head worker occupation: 0.8%
# Progress: 784 / 2000 total iterations (39.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.703e-03  1.406e-01  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           8.165e-04  7.350e-01  y = (physics(x₂ / 0.32379, x₀) ^ inv(x₁))
# 10          6.799e-04  9.153e-02  y = (physics(x₂ / 0.32379, x₀ - x₁) ^ inv(x₁))
# 12          6.511e-04  2.161e-02  y = (physics(x₂ / 0.32379, (x₀ - x₁) + x₂) ^ inv(x₁))
# 14          6.511e-04  3.412e-05  y = (physics(x₂ / 0.32379, (x₀ + x₂) - (x₁ + 0.70807)) ^ inv(x...
#                                   ₁))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.430e+04
# Head worker occupation: 0.8%
# Progress: 810 / 2000 total iterations (40.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.703e-03  1.406e-01  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# 8           8.165e-04  7.350e-01  y = (physics(x₂ / 0.32379, x₀) ^ inv(x₁))
# 10          6.799e-04  9.153e-02  y = (physics(x₂ / 0.32379, x₀ - x₁) ^ inv(x₁))
# 12          6.511e-04  2.161e-02  y = (physics(x₂ / 0.32379, (x₀ - x₁) + x₂) ^ inv(x₁))
# 14          6.511e-04  3.412e-05  y = (physics(x₂ / 0.32379, (x₀ + x₂) - (x₁ + 0.70807)) ^ inv(x...
#                                   ₁))
# 15          6.391e-04  1.863e-02  y = (physics(x₂ / (0.32379 * 1.0371), x₀ - x₁) ^ inv(x₁ + squa...
#                                   re(-0.67322)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.320e+04
# Head worker occupation: 0.8%
# Progress: 834 / 2000 total iterations (41.700%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.226e-03  9.092e-02  y = (0.92501 ^ inv(x₂))
# 5           2.200e-03  8.650e-01  y = (physics(-1.6342, x₂) ^ -0.22568)
# 6           1.960e-03  1.157e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.1232)
# 7           1.703e-03  1.406e-01  y = (physics(x₂, sqrt(x₀)) ^ inv(x₁))
# ...
# 12          6.270e-04  1.912e-02  y = (physics((x₂ / -0.36055) - 0.60441, x₀ - x₁) ^ inv(x₁))
# 14          6.150e-04  9.631e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ - -0.7529...
#                                   2))
# 15          6.130e-04  3.253e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ + inv(x₂)...
#                                   ))
# 16          6.037e-04  1.526e-02  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - 2.2625) - -0.10003) ^...
#                                    (inv(x₁) + 0.010277))
# 17          5.995e-04  6.934e-03  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - sqrt(x₁)) - -0.10003)...
#                                    ^ (inv(x₁) + 0.010277))
# 18          5.995e-04  9.686e-05  y = (physics(x₂ / -0.36055, (x₀ - (x₁ + square(x₂))) - 1.6339)...
#                                    ^ inv(x₁ + sqrt(x₂)))
# 19          5.968e-04  4.501e-03  y = (physics(x₂ / -0.36055, (x₀ - (sqrt(x₁) + square(x₂))) - x...
#                                   ₁) ^ inv(x₁ + sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.880e+03
# Head worker occupation: 0.7%
# Progress: 1870 / 2000 total iterations (93.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.219e-02  y = (0.93049 ^ inv(x₂))
# 5           2.194e-03  8.667e-01  y = (physics(-1.6342, x₂) ^ -0.2085)
# 6           1.782e-03  2.079e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10165)
# 7           8.494e-04  7.410e-01  y = (physics(x₂ / -0.30944, x₀) ^ 0.11727)
# 8           7.233e-04  1.607e-01  y = (physics(x₂ / -0.311, x₀) ^ inv(x₁))
# 10          6.514e-04  5.234e-02  y = (physics(x₂ / 0.33104, x₀ - x₁) ^ inv(x₁))
# 12          6.270e-04  1.912e-02  y = (physics((x₂ / -0.36055) - 0.60441, x₀ - x₁) ^ inv(x₁))
# 14          6.150e-04  9.631e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ - -0.7529...
#                                   2))
# 15          6.130e-04  3.253e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ + inv(x₂)...
#                                   ))
# 16          6.037e-04  1.526e-02  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - 2.2625) - -0.10003) ^...
#                                    (inv(x₁) + 0.010277))
# 17          5.995e-04  6.934e-03  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - sqrt(x₁)) - -0.10003)...
#                                    ^ (inv(x₁) + 0.010277))
# 18          5.995e-04  9.686e-05  y = (physics(x₂ / -0.36055, (x₀ - (x₁ + square(x₂))) - 1.6339)...
#                                    ^ inv(x₁ + sqrt(x₂)))
# 19          5.968e-04  4.501e-03  y = (physics(x₂ / -0.36055, (x₀ - (sqrt(x₁) + square(x₂))) - x...
#                                   ₁) ^ inv(x₁ + sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.060e+04
# Head worker occupation: 0.7%
# Progress: 1899 / 2000 total iterations (94.950%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.219e-02  y = (0.93049 ^ inv(x₂))
# 5           2.194e-03  8.667e-01  y = (physics(-1.6342, x₂) ^ -0.2085)
# 6           1.782e-03  2.079e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10165)
# 7           8.494e-04  7.410e-01  y = (physics(x₂ / -0.30944, x₀) ^ 0.11727)
# 8           7.233e-04  1.607e-01  y = (physics(x₂ / -0.311, x₀) ^ inv(x₁))
# 10          6.514e-04  5.234e-02  y = (physics(x₂ / 0.33104, x₀ - x₁) ^ inv(x₁))
# 12          6.270e-04  1.912e-02  y = (physics((x₂ / -0.36055) - 0.60441, x₀ - x₁) ^ inv(x₁))
# 14          6.150e-04  9.631e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ - -0.7529...
#                                   2))
# 15          6.130e-04  3.253e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ + inv(x₂)...
#                                   ))
# 16          6.037e-04  1.526e-02  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - 2.2625) - -0.10003) ^...
#                                    (inv(x₁) + 0.010277))
# 17          5.995e-04  6.934e-03  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - sqrt(x₁)) - -0.10003)...
#                                    ^ (inv(x₁) + 0.010277))
# 18          5.995e-04  9.686e-05  y = (physics(x₂ / -0.36055, (x₀ - (x₁ + square(x₂))) - 1.6339)...
#                                    ^ inv(x₁ + sqrt(x₂)))
# 19          5.968e-04  4.501e-03  y = (physics(x₂ / -0.36055, (x₀ - (sqrt(x₁) + square(x₂))) - x...
#                                   ₁) ^ inv(x₁ + sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.010e+04
# Head worker occupation: 0.7%
# Progress: 1919 / 2000 total iterations (95.950%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.219e-02  y = (0.93049 ^ inv(x₂))
# 5           2.194e-03  8.667e-01  y = (physics(-1.6342, x₂) ^ -0.2085)
# 6           1.782e-03  2.079e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10165)
# 7           8.494e-04  7.410e-01  y = (physics(x₂ / -0.30944, x₀) ^ 0.11727)
# 8           7.233e-04  1.607e-01  y = (physics(x₂ / -0.311, x₀) ^ inv(x₁))
# 10          6.514e-04  5.234e-02  y = (physics(x₂ / 0.33104, x₀ - x₁) ^ inv(x₁))
# 12          6.270e-04  1.912e-02  y = (physics((x₂ / -0.36055) - 0.60441, x₀ - x₁) ^ inv(x₁))
# 14          6.150e-04  9.631e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ - -0.7529...
#                                   2))
# 15          6.130e-04  3.253e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ + inv(x₂)...
#                                   ))
# 16          6.037e-04  1.526e-02  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - 2.2625) - -0.10003) ^...
#                                    (inv(x₁) + 0.010277))
# 17          5.995e-04  6.934e-03  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - sqrt(x₁)) - -0.10003)...
#                                    ^ (inv(x₁) + 0.010277))
# 18          5.995e-04  9.686e-05  y = (physics(x₂ / -0.36055, (x₀ - (x₁ + square(x₂))) - 1.6339)...
#                                    ^ inv(x₁ + sqrt(x₂)))
# 19          5.968e-04  4.501e-03  y = (physics(x₂ / -0.36055, (x₀ - (sqrt(x₁) + square(x₂))) - x...
#                                   ₁) ^ inv(x₁ + sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.050e+04
# Head worker occupation: 0.7%
# Progress: 1947 / 2000 total iterations (97.350%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.219e-02  y = (0.93049 ^ inv(x₂))
# 5           2.194e-03  8.667e-01  y = (physics(-1.6342, x₂) ^ -0.2085)
# 6           1.782e-03  2.079e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10164)
# 7           8.494e-04  7.410e-01  y = (physics(x₂ / -0.30944, x₀) ^ 0.11727)
# 8           7.233e-04  1.607e-01  y = (physics(x₂ / -0.311, x₀) ^ inv(x₁))
# 10          6.514e-04  5.234e-02  y = (physics(x₂ / 0.33104, x₀ - x₁) ^ inv(x₁))
# 12          6.270e-04  1.912e-02  y = (physics((x₂ / -0.36055) - 0.60441, x₀ - x₁) ^ inv(x₁))
# 14          6.150e-04  9.631e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ - -0.7529...
#                                   2))
# 15          6.130e-04  3.253e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ + inv(x₂)...
#                                   ))
# 16          6.037e-04  1.526e-02  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - 2.2625) - -0.10003) ^...
#                                    (inv(x₁) + 0.010277))
# 17          5.995e-04  6.934e-03  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - sqrt(x₁)) - -0.10003)...
#                                    ^ (inv(x₁) + 0.010277))
# 18          5.995e-04  9.686e-05  y = (physics(x₂ / -0.36055, (x₀ - (x₁ + square(x₂))) - 1.6339)...
#                                    ^ inv(x₁ + sqrt(x₂)))
# 19          5.968e-04  4.501e-03  y = (physics(x₂ / -0.36055, (x₀ - (sqrt(x₁) + square(x₂))) - x...
#                                   ₁) ^ inv(x₁ + sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.120e+04
# Head worker occupation: 0.7%
# Progress: 1970 / 2000 total iterations (98.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.219e-02  y = (0.93049 ^ inv(x₂))
# 5           2.194e-03  8.667e-01  y = (physics(-1.6342, x₂) ^ -0.2085)
# 6           1.782e-03  2.079e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10164)
# 7           8.494e-04  7.410e-01  y = (physics(x₂ / -0.30944, x₀) ^ 0.11727)
# 8           7.233e-04  1.607e-01  y = (physics(x₂ / -0.311, x₀) ^ inv(x₁))
# 10          6.514e-04  5.234e-02  y = (physics(x₂ / 0.33104, x₀ - x₁) ^ inv(x₁))
# 12          6.270e-04  1.912e-02  y = (physics((x₂ / -0.36055) - 0.60441, x₀ - x₁) ^ inv(x₁))
# 14          6.150e-04  9.631e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ - -0.7529...
#                                   2))
# 15          6.130e-04  3.253e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ + inv(x₂)...
#                                   ))
# 16          6.037e-04  1.526e-02  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - 2.2625) - -0.10003) ^...
#                                    (inv(x₁) + 0.010277))
# 17          5.995e-04  6.934e-03  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - sqrt(x₁)) - -0.10003)...
#                                    ^ (inv(x₁) + 0.010277))
# 18          5.995e-04  9.686e-05  y = (physics(x₂ / -0.36055, (x₀ - (x₁ + square(x₂))) - 1.6339)...
#                                    ^ inv(x₁ + sqrt(x₂)))
# 19          5.968e-04  4.501e-03  y = (physics(x₂ / -0.36055, (x₀ - (sqrt(x₁) + square(x₂))) - x...
#                                   ₁) ^ inv(x₁ + sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.070e+04
# Head worker occupation: 0.7%
# Progress: 1990 / 2000 total iterations (99.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.017e-03  1.594e+01  y = 0.98466
# 3           5.723e-03  2.503e-02  y = (0.99968 ^ x₀)
# 4           5.219e-03  9.219e-02  y = (0.93049 ^ inv(x₂))
# 5           2.194e-03  8.667e-01  y = (physics(-1.6342, x₂) ^ -0.2085)
# 6           1.782e-03  2.079e-01  y = (physics(x₂, sqrt(x₀)) ^ 0.10164)
# 7           8.494e-04  7.410e-01  y = (physics(x₂ / -0.30944, x₀) ^ 0.11727)
# 8           7.233e-04  1.607e-01  y = (physics(x₂ / -0.311, x₀) ^ inv(x₁))
# 10          6.514e-04  5.234e-02  y = (physics(x₂ / 0.33104, x₀ - x₁) ^ inv(x₁))
# 12          6.270e-04  1.912e-02  y = (physics((x₂ / -0.36055) - 0.60441, x₀ - x₁) ^ inv(x₁))
# 14          6.150e-04  9.631e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ - -0.7529...
#                                   2))
# 15          6.130e-04  3.253e-03  y = (physics(x₂ / -0.36055, x₀ - (x₁ + x₁)) ^ inv(x₁ + inv(x₂)...
#                                   ))
# 16          6.037e-04  1.526e-02  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - 2.2625) - -0.10003) ^...
#                                    (inv(x₁) + 0.010277))
# 17          5.995e-04  6.934e-03  y = ((physics(x₂ / -0.36055, (x₀ - x₁) - sqrt(x₁)) - -0.10003)...
#                                    ^ (inv(x₁) + 0.010277))
# 18          5.995e-04  9.686e-05  y = (physics(x₂ / -0.36055, (x₀ - (x₁ + square(x₂))) - 1.6339)...
#                                    ^ inv(x₁ + sqrt(x₂)))
# 19          5.968e-04  4.501e-03  y = (physics(x₂ / -0.36055, (x₀ - (x₁ + square(x₂))) - sqrt(x₁...
#                                   )) ^ inv(x₁ + sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          0.9846646
# 	1         0.025030                                  (0.99967515 ^ x0)
# 	2         0.092188                              (0.9304864 ^ inv(x2))
# 	3         0.866715             (physics(-1.634159, x2) ^ -0.20850202)
# 	4         0.207859              (physics(x2, sqrt(x0)) ^ 0.101635255)
# 	5   >>>>  0.740984      (physics(x2 / -0.30944166, x0) ^ 0.117272355)
# 	6         0.160719           (physics(x2 / -0.3109984, x0) ^ inv(x1))
# 	7         0.052336      (physics(x2 / 0.33104002, x0 - x1) ^ inv(x1))
# 	8         0.019117  (physics((x2 / -0.36054888) - 0.6044107, x0 - ...
# 	9         0.009631  (physics(x2 / -0.36054888, x0 - (x1 + x1)) ^ i...
# 	10        0.003253  (physics(x2 / -0.36054888, x0 - (x1 + x1)) ^ i...
# 	11        0.015256  ((physics(x2 / -0.36054888, (x0 - x1) - 2.2625...
# 	12        0.006935  ((physics(x2 / -0.36054888, (x0 - x1) - sqrt(x...
# 	13        0.000097  (physics(x2 / -0.36054888, (x0 - (x1 + square(...
# 	14        0.004501  (physics(x2 / -0.36054888, (x0 - (x1 + square(...
#
# 	        loss  complexity
# 	0   0.006017           1
# 	1   0.005723           3
# 	2   0.005219           4
# 	3   0.002194           5
# 	4   0.001782           6
# 	5   0.000849           7
# 	6   0.000723           8
# 	7   0.000651          10
# 	8   0.000627          12
# 	9   0.000615          14
# 	10  0.000613          15
# 	11  0.000604          16
# 	12  0.000600          17
# 	13  0.000599          18
# 	14  0.000597          19
# ]

# %%
model.sympy()
# Out:
# 1.31668549659907*(x2**2/x0)**0.117272355

# %%
n_r1_pred = model.predict(X)
# n_r1_pred = 0.757 + w_oh * D**0.5/L
print("Default selection MSE:", np.power(n_r1_pred - y, 2).mean())
# Out:
# Default selection MSE: 0.0008493762544633727

# %%
x_line = [0.5, 1.5]
y_line = [0.5, 1.5]

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_r1, y=n_r1_pred, marker='o', c='none', edgecolor='r', label='Exterior Girder')
ax1.plot(x_line, y_line, c = "k")
ax1.set_title('Accuracy')
ax1.legend()
plt.xlim((0.7,1.3))
plt.ylim((0.7,1.3))
ax1.set_xlabel('Target $n_{r1}$')
ax1.set_ylabel('Predicted $n_{r1}$')
ax1.grid()

# %%
model.latex()
# Out:
# '1.32 \\left(\\frac{x_{2}^{2}}{x_{0}}\\right)^{0.117}'

# %% [markdown]
# $0.757 + \frac{1}{\sqrt{\frac{x_{0}^{2}}{x_{1}^{2} x_{3}}}}$
#
# $0.757 + \frac{w_{oh} D^{0.5}}{L}$
#
#
# $ 0.881 + \frac{1.77 x_{1}^{2} x_{2}}{x_{0}^{2}} $
#
# $ 0.881 + \frac{1.77 S^{2} w_{oh}}{L^{2}} $
#
# $ 1.32 \left(\frac{x_{2}^{2}}{x_{0}}\right)^{0.117} $
#
# $ 1.32 \left(\frac{w_{oh}^{2}}{L}\right)^{0.117} $

# %%
y2 = n_r2
model2 = PySRRegressor(
    niterations=40,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    **default_pysr_params
)

model2.fit(X, y2)

print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:109: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 3.300e+03
# Head worker occupation: 0.1%
# Progress: 7 / 2000 total iterations (0.350%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.506e-03  1.594e+01  y = 0.036309
# 3           3.172e-03  1.755e-01  y = physics(0.3492, x₂)
# 5           2.195e-03  1.841e-01  y = cube(sqrt(0.59158) / x₂)
# 10          2.076e-03  1.113e-02  y = ((square(-0.18677 / sqrt(x₂)) * sqrt(x₀)) / x₂)
# 11          2.059e-03  8.267e-03  y = inv(((x₂ ^ x₂) + 1.2765) + square(x₂ * -1.5983))
# 12          2.037e-03  1.079e-02  y = ((square(-0.18677 / sqrt(cube(sqrt(x₂)))) * sqrt(x₀)) / x₂...
#                                   )
# 14          1.903e-03  3.401e-02  y = ((square(-0.18677 / sqrt(x₂)) * (square(sqrt(sqrt(x₀))) - ...
#                                   x₂)) / x₂)
# 16          1.800e-03  2.775e-02  y = ((square(-0.18677 / sqrt(cube(sqrt(x₂ / 1.2927)))) * (sqrt...
#                                   (x₀) - x₂)) / x₂)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.200e+03
# Head worker occupation: 0.4%
# Progress: 20 / 2000 total iterations (1.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.506e-03  1.594e+01  y = 0.036309
# 3           3.172e-03  1.755e-01  y = physics(0.3492, x₂)
# 4           2.216e-03  3.585e-01  y = (0.47802 / cube(x₂))
# 5           2.195e-03  9.567e-03  y = cube(sqrt(0.59158) / x₂)
# 9           2.166e-03  3.300e-03  y = inv(((x₂ + x₂) * square(x₂)) + 1.0957)
# 10          2.054e-03  5.320e-02  y = (inv(x₂ + physics(cube(x₂), x₀)) * square(-0.39698))
# 12          1.955e-03  2.473e-02  y = sqrt(physics(square(0.097763), cube(cube(sqrt(x₂ * 0.54383...
#                                   )))) * x₀)
# 13          1.844e-03  5.867e-02  y = (inv(x₂ + physics(cube(cube(x₂ + -1.153)), x₀)) * square(-...
#                                   0.39698))
# 15          1.810e-03  9.289e-03  y = (inv(sqrt(square(x₂ + physics(square(cube(x₂ + -1.153)), x...
#                                   ₀)))) * square(-0.39698))
# 16          1.674e-03  7.787e-02  y = physics(cube(0.87605 / (0.99768 ^ (x₀ - (x₂ ^ x₂)))) * -0....
#                                   39678, cube(sqrt(x₂)))
# 20          1.518e-03  2.452e-02  y = physics(cube(sqrt(square(0.87605)) / (0.99768 ^ (x₀ - (cub...
#                                   e(sqrt(x₂)) ^ x₂)))) * -0.39678, square(sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.250e+04
# Head worker occupation: 0.5%
# Progress: 83 / 2000 total iterations (4.150%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041428
# 3           2.860e-03  2.244e-01  y = (0.18037 ^ x₂)
# 4           2.044e-03  3.358e-01  y = cube(0.63378 ^ x₂)
# 9           1.903e-03  1.430e-02  y = (square(-0.18677 / x₂) * (sqrt(x₀) - x₂))
# 10          1.721e-03  1.004e-01  y = (inv(1.29 + physics(cube(x₂), x₀)) * square(-0.39698))
# 12          1.682e-03  1.159e-02  y = (inv((1.29 + physics(cube(x₂), x₀)) + -0.33764) * square(-...
#                                   0.39698))
# 14          1.652e-03  8.965e-03  y = (inv((1.29 + physics(cube(x₂) + 0.3485, x₀)) + -0.33764) *...
#                                    square(-0.39698))
# 15          1.607e-03  2.732e-02  y = physics(cube(0.87605 / (0.99768 ^ (x₀ - (x₂ ^ x₂)))) * 0.4...
#                                   8498, square(x₂))
# 20          1.518e-03  1.149e-02  y = physics(cube(sqrt(square(0.87605)) / (0.99768 ^ (x₀ - (cub...
#                                   e(sqrt(x₂)) ^ x₂)))) * -0.39678, square(sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.350e+04
# Head worker occupation: 0.6%
# Progress: 117 / 2000 total iterations (5.850%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.053e-03  3.900e-01  y = (0.26145 ^ x₂)
# 4           2.044e-03  4.477e-03  y = cube(0.63378 ^ x₂)
# 6           2.028e-03  3.893e-03  y = (square(0.49627) / (x₂ ^ x₂))
# 8           1.914e-03  2.895e-02  y = inv((sqrt(x₂) ^ square(x₂)) + x₁)
# 9           1.903e-03  5.812e-03  y = (square(-0.18677 / x₂) * (sqrt(x₀) - x₂))
# 10          1.721e-03  1.004e-01  y = (inv(1.29 + physics(cube(x₂), x₀)) * square(-0.39698))
# 12          1.682e-03  1.159e-02  y = (inv((1.29 + physics(cube(x₂), x₀)) + -0.33764) * square(-...
#                                   0.39698))
# 14          1.652e-03  8.965e-03  y = (inv((1.29 + physics(cube(x₂) + 0.3485, x₀)) + -0.33764) *...
#                                    square(-0.39698))
# 15          1.607e-03  2.732e-02  y = physics(cube(0.87605 / (0.99768 ^ (x₀ - (x₂ ^ x₂)))) * 0.4...
#                                   8498, square(x₂))
# 20          1.518e-03  1.149e-02  y = physics(cube(sqrt(square(0.87605)) / (0.99768 ^ (x₀ - (cub...
#                                   e(sqrt(x₂)) ^ x₂)))) * -0.39678, square(sqrt(x₂)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.500e+04
# Head worker occupation: 0.7%
# Progress: 149 / 2000 total iterations (7.450%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.048e-03  3.914e-01  y = (0.25029 ^ x₂)
# 4           2.044e-03  1.727e-03  y = cube(0.63378 ^ x₂)
# 5           2.037e-03  3.643e-03  y = physics(0.48498, x₂ ^ x₂)
# 6           2.028e-03  4.143e-03  y = (square(0.49627) / (x₂ ^ x₂))
# 7           2.025e-03  1.812e-03  y = ((0.16523 ^ x₂) * (x₂ - -0.31128))
# 8           1.914e-03  5.609e-02  y = inv((sqrt(x₂) ^ square(x₂)) + x₁)
# 9           1.903e-03  5.812e-03  y = (square(-0.18677 / x₂) * (sqrt(x₀) - x₂))
# 10          1.644e-03  1.463e-01  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 12          1.595e-03  1.502e-02  y = (inv(1.29 + physics(physics(cube(x₂), x₀), x₂)) * square(-...
#                                   0.39698))
# 13          1.579e-03  1.015e-02  y = (inv(physics(cube(x₂), x₀ - cube(x₂)) - -1.0377) * square(...
#                                   -0.39698))
# 16          1.325e-03  5.862e-02  y = (((sqrt(inv(square(1.29 + physics(cube(x₂), x₀)))) - 0.088...
#                                   375) * square(-0.39698)) * x₂)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.880e+04
# Head worker occupation: 0.6%
# Progress: 189 / 2000 total iterations (9.450%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.048e-03  3.914e-01  y = (0.25029 ^ x₂)
# 4           2.044e-03  1.727e-03  y = cube(0.63378 ^ x₂)
# 5           2.037e-03  3.643e-03  y = physics(0.48498, x₂ ^ x₂)
# 6           2.028e-03  4.143e-03  y = (square(0.49627) / (x₂ ^ x₂))
# 7           2.025e-03  1.812e-03  y = ((0.16523 ^ x₂) * (x₂ - -0.31128))
# 8           1.914e-03  5.609e-02  y = inv((sqrt(x₂) ^ square(x₂)) + x₁)
# 9           1.903e-03  5.812e-03  y = (square(-0.18677 / x₂) * (sqrt(x₀) - x₂))
# 10          1.644e-03  1.463e-01  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 12          1.595e-03  1.502e-02  y = (inv(1.29 + physics(physics(cube(x₂), x₀), x₂)) * square(-...
#                                   0.39698))
# 13          1.579e-03  1.015e-02  y = (inv(physics(cube(x₂), x₀ - cube(x₂)) - -1.0377) * square(...
#                                   -0.39698))
# 14          1.346e-03  1.598e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / x₂) - inv(inv(cube(x₂))))...
#                                   )
# 16          1.177e-03  6.689e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) + 0.881...
#                                   25) / 2.5939))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.740e+04
# Head worker occupation: 0.7%
# Progress: 228 / 2000 total iterations (11.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.048e-03  3.914e-01  y = (0.25029 ^ x₂)
# 4           2.044e-03  1.727e-03  y = cube(0.63378 ^ x₂)
# 5           2.037e-03  3.643e-03  y = physics(0.48498, x₂ ^ x₂)
# 6           2.028e-03  4.143e-03  y = (square(0.49627) / (x₂ ^ x₂))
# 7           2.004e-03  1.194e-02  y = ((inv(x₂) - sqrt(0.088375)) * 0.42786)
# 8           1.794e-03  1.106e-01  y = inv(x₁ + square(physics(cube(x₂), x₀)))
# 9           1.684e-03  6.351e-02  y = (inv(physics(cube(x₂), x₀) + 1.5772) * 0.22119)
# 10          1.644e-03  2.394e-02  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 11          1.644e-03  3.236e-04  y = (inv(physics(cube(x₂), x₀) - inv(-0.90341)) * square(-0.39...
#                                   698))
# 12          1.346e-03  1.997e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / x₂) - cube(x₂)))
# 14          1.232e-03  4.431e-02  y = inv(x₁ + (physics(cube(x₂), (x₀ / x₂) - cube(x₂)) / 2.5939...
#                                   ))
# 16          1.177e-03  2.258e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) + 0.881...
#                                   25) / 2.5939))
# 18          1.161e-03  7.000e-03  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) + (0.88...
#                                   125 * 1.42)) / 2.5939))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.730e+04
# Head worker occupation: 0.7%
# Progress: 269 / 2000 total iterations (13.450%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.048e-03  3.914e-01  y = (0.25029 ^ x₂)
# 4           2.044e-03  1.727e-03  y = cube(0.63378 ^ x₂)
# 5           2.028e-03  7.786e-03  y = physics(0.49623, x₂ ^ x₂)
# 6           2.028e-03  0.000e+00  y = (square(0.49627) / (x₂ ^ x₂))
# 7           2.002e-03  1.295e-02  y = physics(-0.51288, (x₂ ^ x₂) - -0.32666)
# 8           1.794e-03  1.096e-01  y = inv(x₁ + square(physics(cube(x₂), x₀)))
# 9           1.684e-03  6.351e-02  y = (inv(physics(cube(x₂), x₀) + 1.5772) * 0.22119)
# 10          1.644e-03  2.394e-02  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 11          1.644e-03  3.236e-04  y = (inv(physics(cube(x₂), x₀) - inv(-0.90341)) * square(-0.39...
#                                   698))
# 12          1.346e-03  1.997e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / x₂) - cube(x₂)))
# 14          1.232e-03  4.431e-02  y = inv(x₁ + (physics(cube(x₂), (x₀ / x₂) - cube(x₂)) / 2.5939...
#                                   ))
# 16          1.177e-03  2.258e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) + 0.881...
#                                   25) / 2.5939))
# 17          1.166e-03  9.889e-03  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) + inv(0...
#                                   .88125)) / 2.5939))
# 18          1.161e-03  4.110e-03  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) + (0.88...
#                                   125 * 1.42)) / 2.5939))
# 19          1.158e-03  2.985e-03  y = (inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) + inv(...
#                                   0.88125)) / 2.5939)) * 0.99082)
# 20          1.157e-03  3.133e-04  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - inv(cube(inv(x₂))...
#                                   )) + x₂) / sqrt(inv(0.35626))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.890e+04
# Head worker occupation: 0.7%
# Progress: 313 / 2000 total iterations (15.650%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.046e-03  3.919e-01  y = (0.25166 ^ x₂)
# 4           2.044e-03  8.077e-04  y = cube(0.63378 ^ x₂)
# 5           2.028e-03  7.786e-03  y = physics(0.49623, x₂ ^ x₂)
# 6           2.028e-03  0.000e+00  y = (square(0.49627) / (x₂ ^ x₂))
# 7           1.942e-03  4.351e-02  y = ((inv(x₂) - sqrt(0.088375)) * 0.28918)
# 8           1.794e-03  7.904e-02  y = inv(x₁ + square(physics(cube(x₂), x₀)))
# 9           1.684e-03  6.351e-02  y = (inv(physics(cube(x₂), x₀) + 1.5772) * 0.22119)
# 10          1.644e-03  2.394e-02  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 11          1.644e-03  3.236e-04  y = (inv(physics(cube(x₂), x₀) - inv(-0.90341)) * square(-0.39...
#                                   698))
# 12          1.346e-03  1.997e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / x₂) - cube(x₂)))
# 14          1.232e-03  4.431e-02  y = inv(x₁ + (physics(cube(x₂), (x₀ / x₂) - cube(x₂)) / 2.5939...
#                                   ))
# 16          1.155e-03  3.231e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) + 1.42)...
#                                    / 2.5939))
# 18          1.123e-03  1.381e-02  y = inv(x₁ + (((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) + 0.88...
#                                   125) / 2.5939) - -0.9363))
# 19          1.045e-03  7.187e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂ - 0.05760...
#                                   9)) + square(x₂)) / 2.5939))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.880e+04
# Head worker occupation: 0.8%
# Progress: 351 / 2000 total iterations (17.550%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25483 ^ x₂)
# 4           2.044e-03  4.351e-06  y = cube(0.63378 ^ x₂)
# 5           2.028e-03  7.786e-03  y = physics(0.49624, x₂ ^ x₂)
# 7           1.942e-03  2.175e-02  y = ((inv(x₂) - sqrt(0.088375)) * 0.28918)
# 8           1.794e-03  7.904e-02  y = inv(x₁ + square(physics(cube(x₂), x₀)))
# 9           1.684e-03  6.351e-02  y = (inv(physics(cube(x₂), x₀) + 1.5772) * 0.22119)
# 10          1.644e-03  2.394e-02  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 11          1.644e-03  3.236e-04  y = (inv(physics(cube(x₂), x₀) - inv(-0.90341)) * square(-0.39...
#                                   698))
# 12          1.346e-03  1.997e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / x₂) - cube(x₂)))
# 14          1.232e-03  4.431e-02  y = inv(x₁ + (physics(cube(x₂), (x₀ / x₂) - cube(x₂)) / 2.5939...
#                                   ))
# 16          1.130e-03  4.325e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / x₂) - cube(x₂)) / 2.593...
#                                   9) - -0.9363))
# 17          1.112e-03  1.545e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / sqrt(x₁)) - cube(x₂)) +...
#                                    0.88125) / 2.5939))
# 18          9.454e-04  1.627e-01  y = inv(x₁ + ((physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)) + s...
#                                   qrt(cube(x₂))) / 2.5939))
# 20          9.345e-04  5.826e-03  y = inv(x₁ + ((physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)) + (...
#                                   sqrt(cube(x₂)) + x₂)) / 2.5939))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.870e+04
# Head worker occupation: 0.8%
# Progress: 391 / 2000 total iterations (19.550%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25483 ^ x₂)
# 4           2.044e-03  4.351e-06  y = cube(0.63378 ^ x₂)
# 5           2.028e-03  7.786e-03  y = physics(0.49624, x₂ ^ x₂)
# 6           1.934e-03  4.737e-02  y = ((inv(x₂) - 0.28918) * 0.28918)
# 8           1.794e-03  3.759e-02  y = inv(x₁ + square(physics(cube(x₂), x₀)))
# 9           1.684e-03  6.351e-02  y = (inv(physics(cube(x₂), x₀) + 1.5772) * 0.22119)
# 10          1.644e-03  2.394e-02  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 11          1.644e-03  3.236e-04  y = (inv(physics(cube(x₂), x₀) - inv(-0.90341)) * square(-0.39...
#                                   698))
# 12          1.346e-03  1.997e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / x₂) - cube(x₂)))
# 14          8.947e-04  2.042e-01  y = inv(x₁ + (physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)) / x₂...
#                                   ))
# 16          8.611e-04  1.915e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)) + x...
#                                   ₂) / x₂))
# 18          8.527e-04  4.920e-03  y = inv(x₁ + ((physics(cube(x₂) - -0.6736, (x₀ / 2.5939) - cub...
#                                   e(x₂)) + x₂) / x₂))
# 20          8.494e-04  1.929e-03  y = inv((x₁ + ((physics(cube(x₂) - -0.6736, (x₀ / 2.5939) - cu...
#                                   be(x₂)) + x₂) / x₂)) - 0.73648)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.920e+04
# Head worker occupation: 0.8%
# Progress: 430 / 2000 total iterations (21.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25483 ^ x₂)
# 4           2.044e-03  4.351e-06  y = cube(0.63378 ^ x₂)
# 5           2.028e-03  7.786e-03  y = physics(0.49624, x₂ ^ x₂)
# 6           1.847e-03  9.383e-02  y = ((inv(x₂) - 0.28918) * 0.35678)
# 8           1.794e-03  1.436e-02  y = inv(x₁ + square(physics(cube(x₂), x₀)))
# 9           1.680e-03  6.563e-02  y = (inv(physics(cube(x₂), x₀) + 1.6133) * 0.22119)
# 10          1.644e-03  2.182e-02  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 11          1.644e-03  3.236e-04  y = (inv(physics(cube(x₂), x₀) - inv(-0.90341)) * square(-0.39...
#                                   698))
# 12          1.312e-03  2.253e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)))
# 14          8.947e-04  1.914e-01  y = inv(x₁ + (physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)) / x₂...
#                                   ))
# 16          8.576e-04  2.118e-02  y = inv(x₁ + (physics(cube(x₂) + x₂, (x₀ / 2.5939) - cube(x₂))...
#                                    / x₂))
# 18          8.308e-04  1.590e-02  y = inv(x₁ + (physics(cube(x₂) + x₂, ((x₀ / 2.5939) - cube(x₂)...
#                                   ) + -0.75627) / x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.710e+04
# Head worker occupation: 0.8%
# Progress: 457 / 2000 total iterations (22.850%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25483 ^ x₂)
# 4           2.044e-03  4.351e-06  y = cube(0.63378 ^ x₂)
# 5           2.028e-03  7.786e-03  y = physics(0.49624, x₂ ^ x₂)
# 6           1.847e-03  9.383e-02  y = ((inv(x₂) - 0.28918) * 0.35678)
# 8           1.794e-03  1.436e-02  y = inv(x₁ + square(physics(cube(x₂), x₀)))
# 9           1.680e-03  6.563e-02  y = (inv(physics(cube(x₂), x₀) + 1.6133) * 0.22119)
# 10          1.644e-03  2.182e-02  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 11          1.644e-03  3.236e-04  y = (inv(physics(cube(x₂), x₀) - inv(-0.90341)) * square(-0.39...
#                                   698))
# 12          1.312e-03  2.253e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)))
# 14          8.947e-04  1.914e-01  y = inv(x₁ + (physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)) / x₂...
#                                   ))
# 16          8.570e-04  2.158e-02  y = inv(x₁ + (physics(cube(x₂) - -0.82742, (x₀ / 2.5939) - cub...
#                                   e(x₂)) / x₂))
# 18          8.308e-04  1.551e-02  y = inv(x₁ + (physics(cube(x₂) + x₂, ((x₀ / 2.5939) - cube(x₂)...
#                                   ) + -0.75627) / x₂))
# 20          7.644e-04  4.166e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / physics(2.5939, x₂)) - ...
#                                   (cube(x₂) + x₂)) / x₂) + 1.1785))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.680e+04
# Head worker occupation: 0.8%
# Progress: 502 / 2000 total iterations (25.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25483 ^ x₂)
# 4           2.044e-03  4.351e-06  y = cube(0.63378 ^ x₂)
# 5           2.028e-03  7.786e-03  y = physics(0.49624, x₂ ^ x₂)
# 6           1.847e-03  9.383e-02  y = ((inv(x₂) - 0.28918) * 0.35678)
# 8           1.777e-03  1.909e-02  y = (((inv(x₂) ^ 1.0475) - 0.28918) * 0.35678)
# 9           1.677e-03  5.811e-02  y = (inv(physics(cube(x₂), x₀) + 1.6133) * 0.20769)
# 10          1.644e-03  1.988e-02  y = (inv(physics(cube(x₂), x₀) - -1.0377) * square(-0.39698))
# 11          1.644e-03  3.236e-04  y = (inv(physics(cube(x₂), x₀) - inv(-0.90341)) * square(-0.39...
#                                   698))
# 12          1.312e-03  2.253e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)))
# 13          1.227e-03  6.685e-02  y = ((inv(sqrt(physics(cube(x₂), x₀) + sqrt(1.7571))) - 0.3183...
#                                   6) * 0.22119)
# 14          8.947e-04  3.159e-01  y = inv(x₁ + (physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)) / x₂...
#                                   ))
# 15          8.849e-04  1.108e-02  y = ((inv(cube(cube(physics(x₂, 0.12871) / x₀)) + sqrt(x₂)) - ...
#                                   0.31836) * 0.22119)
# 16          8.570e-04  3.208e-02  y = inv(x₁ + (physics(cube(x₂) - -0.82742, (x₀ / 2.5939) - cub...
#                                   e(x₂)) / x₂))
# 17          8.470e-04  1.174e-02  y = inv(x₁ + (physics(cube(x₂) + sqrt(x₂), (x₀ / 2.5939) - cub...
#                                   e(x₂)) / x₂))
# 18          8.178e-04  3.498e-02  y = inv(x₁ + (physics(cube(x₂) + x₂, (x₀ / 2.5939) - (cube(x₂)...
#                                    - -1.2178)) / x₂))
# 20          7.644e-04  3.381e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / physics(2.5939, x₂)) - ...
#                                   (cube(x₂) + x₂)) / x₂) + 1.1785))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.840e+04
# Head worker occupation: 0.8%
# Progress: 552 / 2000 total iterations (27.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25483 ^ x₂)
# 4           2.044e-03  4.351e-06  y = cube(0.63378 ^ x₂)
# 5           2.028e-03  7.786e-03  y = physics(0.49624, x₂ ^ x₂)
# 6           1.847e-03  9.383e-02  y = ((inv(x₂) - 0.28918) * 0.35678)
# 8           1.777e-03  1.909e-02  y = (((inv(x₂) ^ 1.0475) - 0.28918) * 0.35678)
# 9           1.677e-03  5.811e-02  y = (inv(physics(cube(x₂), x₀) + 1.6133) * 0.20769)
# 10          1.632e-03  2.732e-02  y = inv(x₁ + square(physics(cube(x₂) + 2.1727, x₀)))
# 12          1.312e-03  1.091e-01  y = inv(x₁ + physics(cube(x₂), (x₀ / 2.5939) - cube(x₂)))
# 13          1.074e-03  2.005e-01  y = (((inv(square(x₂)) - physics(x₂, x₀ + 0.22119)) * x₂) * 0....
#                                   22119)
# 14          8.896e-04  1.880e-01  y = ((inv(cube(physics(x₂, 0.12871) / x₀) + sqrt(x₂)) - 0.3183...
#                                   6) * 0.22119)
# 15          7.844e-04  1.258e-01  y = ((inv(cube(square(physics(x₂, 0.12871) / x₀)) + sqrt(x₂)) ...
#                                   - 0.31836) * 0.22119)
# 18          7.844e-04  0.000e+00  y = ((inv(cube(square(sqrt(physics(physics(x₂, 0.12871), x₀) /...
#                                    x₀))) + sqrt(x₂)) - 0.31836) * 0.22119)
# 20          7.644e-04  1.297e-02  y = inv(x₁ + ((physics(cube(x₂), (x₀ / physics(2.5939, x₂)) - ...
#                                   (cube(x₂) + x₂)) / x₂) + 1.1785))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.870e+04
# Head worker occupation: 0.9%
# Progress: 590 / 2000 total iterations (29.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25483 ^ x₂)
# 4           2.044e-03  4.351e-06  y = cube(0.63378 ^ x₂)
# 5           2.028e-03  7.786e-03  y = physics(0.49624, x₂ ^ x₂)
# 6           1.847e-03  9.383e-02  y = ((inv(x₂) - 0.28918) * 0.35678)
# 8           1.777e-03  1.909e-02  y = (((inv(x₂) ^ 1.0475) - 0.28918) * 0.35678)
# 9           1.677e-03  5.811e-02  y = (inv(physics(cube(x₂), x₀) + 1.6133) * 0.20769)
# 10          1.632e-03  2.732e-02  y = inv(x₁ + square(physics(cube(x₂) + 2.1727, x₀)))
# 11          7.582e-04  7.665e-01  y = ((inv(x₂) - physics(sqrt(x₂) + x₂, x₀)) * 0.22119)
# 13          7.501e-04  5.383e-03  y = ((inv(x₂) - physics(sqrt(x₂ - -0.30005) + x₂, x₀)) * 0.221...
#                                   19)
# 19          7.494e-04  1.450e-04  y = ((inv(cube(cube(((physics(x₂, 0.12871) - -1.6834) / x₀) ^ ...
#                                   0.63613)) + sqrt(x₂)) - 0.31836) * 0.22119)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.110e+04
# Head worker occupation: 0.9%
# Progress: 643 / 2000 total iterations (32.150%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.947e-03  2.444e-02  y = ((0.31836 ^ x₂) + -0.042074)
# 6           1.847e-03  5.274e-02  y = ((inv(x₂) - 0.28918) * 0.35678)
# 8           1.777e-03  1.909e-02  y = (((inv(x₂) ^ 1.0475) - 0.28918) * 0.35678)
# 9           1.677e-03  5.811e-02  y = (inv(physics(cube(x₂), x₀) + 1.6133) * 0.20769)
# 10          1.435e-03  1.561e-01  y = ((inv(x₂) - physics(x₂ - -0.76084, x₀)) * 0.19942)
# 11          7.582e-04  6.378e-01  y = ((inv(x₂) - physics(sqrt(x₂) + x₂, x₀)) * 0.22119)
# 13          7.501e-04  5.383e-03  y = ((inv(x₂) - physics(sqrt(x₂ - -0.30005) + x₂, x₀)) * 0.221...
#                                   19)
# 14          5.850e-04  2.486e-01  y = ((sqrt(inv(x₂)) - physics(sqrt(x₂) + (x₂ / 0.67671), x₀)) ...
#                                   * 0.22119)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.250e+04
# Head worker occupation: 0.9%
# Progress: 692 / 2000 total iterations (34.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.947e-03  2.444e-02  y = ((0.31836 ^ x₂) + -0.042074)
# 6           1.737e-03  1.141e-01  y = ((0.39522 * inv(x₂)) - 0.1289)
# 9           1.044e-03  1.696e-01  y = ((inv(x₂) - (cube(x₂) / x₀)) * 0.17607)
# 11          7.195e-04  1.863e-01  y = ((inv(x₂) - physics(sqrt(x₂) + x₂, x₀)) * 0.25465)
# 14          5.850e-04  6.901e-02  y = ((sqrt(inv(x₂)) - physics(sqrt(x₂) + (x₂ / 0.67671), x₀)) ...
#                                   * 0.22119)
# 17          5.834e-04  8.683e-04  y = ((sqrt(inv(x₂)) - (physics(sqrt(square(x₂)) + (1.2159 + x₂...
#                                   ), x₀) / 1.2159)) * 0.22119)
# 18          5.471e-04  6.440e-02  y = ((sqrt(inv(x₂)) - (physics(sqrt(square(x₂)) + (sqrt(1.2159...
#                                   ) + x₂), x₀) / 1.2159)) * 0.22119)
# 19          5.404e-04  1.226e-02  y = ((sqrt(inv(x₂)) - (physics(sqrt(square(x₂)) + (sqrt(sqrt(1...
#                                   .2159)) + x₂), x₀) / 1.2159)) * 0.22119)
# 20          4.723e-04  1.347e-01  y = ((sqrt(inv(x₂)) - (physics(sqrt(square(x₂)) + (sqrt(sqrt(x...
#                                   ₁)) + x₂), x₀) / square(1.2159))) * 0.22119)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.110e+04
# Head worker occupation: 0.9%
# Progress: 732 / 2000 total iterations (36.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.947e-03  2.444e-02  y = ((0.31836 ^ x₂) + -0.042074)
# 6           1.737e-03  1.141e-01  y = ((0.39522 * inv(x₂)) - 0.1289)
# 9           1.044e-03  1.696e-01  y = ((inv(x₂) - (cube(x₂) / x₀)) * 0.17607)
# 11          6.692e-04  2.225e-01  y = ((inv(x₂) - physics(inv(0.49426) + x₂, x₀)) * 0.25465)
# 12          6.387e-04  4.659e-02  y = ((inv(x₂) - physics(inv(square(0.72973)) + x₂, x₀)) * 0.25...
#                                   465)
# 13          5.924e-04  7.527e-02  y = ((inv(x₂) - physics(inv(0.72973) + x₂, x₀ - x₁)) * 0.25465...
#                                   )
# 14          4.428e-04  2.912e-01  y = ((sqrt(inv(x₂)) - physics((1.3933 + x₂) + sqrt(x₂), x₀)) *...
#                                    0.22119)
# 17          3.872e-04  4.469e-02  y = ((sqrt(inv(sqrt(x₂))) - physics((x₂ + (sqrt(x₂) * 1.3933))...
#                                    + 1.6872, x₀)) * 0.22119)
# 18          3.678e-04  5.135e-02  y = ((sqrt(inv(x₂)) - physics((x₂ + sqrt(1.457 * inv(inv(1.457...
#                                   )))) + 1.8145, x₀)) * 0.26116)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.310e+04
# Head worker occupation: 1.0%
# Progress: 783 / 2000 total iterations (39.150%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.842e-03  5.200e-02  y = physics(0.060528, physics(x₂, x₀))
# 6           1.737e-03  5.892e-02  y = ((0.39522 * inv(x₂)) - 0.1289)
# 7           1.715e-03  1.280e-02  y = (physics(0.060528, physics(x₂, x₀)) + -0.020179)
# 9           1.044e-03  2.479e-01  y = ((inv(x₂) - (cube(x₂) / x₀)) * 0.17607)
# 10          6.264e-04  5.112e-01  y = ((inv(x₂) - physics(x₂ + 1.8145, x₀)) * 0.26116)
# 13          3.678e-04  1.775e-01  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.130e+04
# Head worker occupation: 1.0%
# Progress: 819 / 2000 total iterations (40.950%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.842e-03  5.200e-02  y = physics(0.060528, physics(x₂, x₀))
# 6           1.737e-03  5.892e-02  y = ((0.39522 * inv(x₂)) - 0.1289)
# 7           1.715e-03  1.280e-02  y = (physics(0.060528, physics(x₂, x₀)) + -0.020179)
# 9           1.044e-03  2.479e-01  y = ((inv(x₂) - (cube(x₂) / x₀)) * 0.17607)
# 10          6.264e-04  5.112e-01  y = ((inv(x₂) - physics(x₂ + 1.8145, x₀)) * 0.26116)
# 12          6.010e-04  2.069e-02  y = ((inv(x₂) - physics(x₂ + 1.8145, x₀ - x₂)) * 0.26116)
# 13          3.678e-04  4.910e-01  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.940e+04
# Head worker occupation: 0.9%
# Progress: 857 / 2000 total iterations (42.850%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.842e-03  5.200e-02  y = physics(0.060528, physics(x₂, x₀))
# 6           1.737e-03  5.892e-02  y = ((0.39522 * inv(x₂)) - 0.1289)
# 7           1.715e-03  1.280e-02  y = (physics(0.060528, physics(x₂, x₀)) + -0.020179)
# 8           1.570e-03  8.828e-02  y = physics(0.060528, physics(x₂, x₀ - cube(x₂)))
# 9           1.000e-03  4.505e-01  y = ((inv(x₂) - (cube(x₂) / x₀)) * 0.18776)
# 10          6.264e-04  4.682e-01  y = ((inv(x₂) - physics(x₂ + 1.8145, x₀)) * 0.26116)
# 11          4.881e-04  2.494e-01  y = ((0.25465 - physics(x₂ + sqrt(1.3596), x₀)) / inv(0.73787)...
#                                   )
# 12          4.867e-04  2.919e-03  y = ((0.25465 - physics(x₂ + sqrt(inv(0.73787)), x₀)) / inv(0....
#                                   73787))
# 13          3.678e-04  2.801e-01  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.950e+04
# Head worker occupation: 0.9%
# Progress: 898 / 2000 total iterations (44.900%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.842e-03  5.200e-02  y = physics(0.060528, physics(x₂, x₀))
# 6           1.737e-03  5.892e-02  y = ((0.39522 * inv(x₂)) - 0.1289)
# 7           1.715e-03  1.280e-02  y = (physics(0.060528, physics(x₂, x₀)) + -0.020179)
# 8           1.558e-03  9.557e-02  y = (0.25465 - physics(x₂ + sqrt(1.1122), x₀))
# 9           8.724e-04  5.801e-01  y = ((0.25465 - physics(x₂ + 1.1122, x₀)) / 1.1122)
# 10          5.044e-04  5.479e-01  y = ((0.25465 - physics(x₂ + 1.1122, x₀)) / inv(0.77343))
# 11          4.881e-04  3.280e-02  y = ((0.25465 - physics(x₂ + sqrt(1.3596), x₀)) / inv(0.73787)...
#                                   )
# 12          4.867e-04  2.919e-03  y = ((0.25465 - physics(x₂ + sqrt(inv(0.73787)), x₀)) / inv(0....
#                                   73787))
# 13          3.678e-04  2.801e-01  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# 17          3.678e-04  7.823e-06  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀ - (x₀ ...
#                                   ^ -0.99853))) * 0.26116)
# 19          3.678e-04  4.882e-05  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀ - (squ...
#                                   are(cube(-0.80519)) / x₂))) * 0.26116)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.830e+04
# Head worker occupation: 0.9%
# Progress: 934 / 2000 total iterations (46.700%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.842e-03  5.200e-02  y = physics(0.060528, physics(x₂, x₀))
# 6           1.737e-03  5.892e-02  y = ((0.39522 * inv(x₂)) - 0.1289)
# 7           1.464e-03  1.708e-01  y = (0.25465 - physics(x₂ + 1.0928, x₀))
# 8           1.237e-03  1.686e-01  y = (inv(6.3725 + x₂) - physics(x₂, x₀))
# 9           8.724e-04  3.490e-01  y = ((0.25465 - physics(x₂ + 1.1122, x₀)) / 1.1122)
# 10          4.984e-04  5.598e-01  y = ((0.25465 - physics(x₂ + 1.0928, x₀)) / cube(1.0928))
# 11          4.881e-04  2.091e-02  y = ((0.25465 - physics(x₂ + sqrt(1.3596), x₀)) / inv(0.73787)...
#                                   )
# 12          4.703e-04  3.728e-02  y = ((0.25465 - physics(x₂ + (0.71806 ^ cube(-0.74727)), x₀)) ...
#                                   * 0.71806)
# 13          3.678e-04  2.457e-01  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# 17          3.678e-04  7.823e-06  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀ - (x₀ ...
#                                   ^ -0.99853))) * 0.26116)
# 19          3.676e-04  2.430e-04  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀ - (x₂ ...
#                                   ^ (-0.99853 - 0.77862)))) * 0.26116)
# 20          3.675e-04  3.384e-04  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀ - squa...
#                                   re(x₂ ^ (-0.99853 - 0.77862)))) * 0.26116)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.810e+04
# Head worker occupation: 0.9%
# Progress: 976 / 2000 total iterations (48.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.842e-03  5.200e-02  y = physics(0.060528, physics(x₂, x₀))
# 6           1.737e-03  5.892e-02  y = ((0.39522 * inv(x₂)) - 0.1289)
# 7           1.378e-03  2.316e-01  y = (0.25465 - physics(x₂ + 1.181, x₀))
# 8           1.237e-03  1.078e-01  y = (inv(6.3725 + x₂) - physics(x₂, x₀))
# 9           4.617e-04  9.854e-01  y = ((0.25465 - physics(x₂ + 1.1122, x₀)) / 1.4583)
# 10          3.755e-04  2.068e-01  y = ((0.25465 - physics(x₂ + 1.181, x₀)) / sqrt(x₂))
# 13          3.678e-04  6.857e-03  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# 15          3.678e-04  6.378e-06  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀ - 0.04...
#                                   1429)) * 0.26116)
# 17          3.678e-04  9.209e-06  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀ - (x₀ ...
#                                   ^ -0.99853))) * 0.26116)
# 19          3.676e-04  2.430e-04  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀ - (x₂ ...
#                                   ^ (-0.99853 - 0.77862)))) * 0.26116)
# 20          3.675e-04  3.384e-04  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀ - squa...
#                                   re(x₂ ^ (-0.99853 - 0.77862)))) * 0.26116)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.060e+04
# Head worker occupation: 0.9%
# Progress: 1028 / 2000 total iterations (51.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25465 ^ x₂)
# 5           1.842e-03  5.200e-02  y = physics(0.060528, physics(x₂, x₀))
# 6           1.737e-03  5.892e-02  y = ((0.39522 * inv(x₂)) - 0.1289)
# 7           1.378e-03  2.316e-01  y = (0.25465 - physics(x₂ + 1.181, x₀))
# 8           8.422e-04  4.921e-01  y = (0.21576 - physics(x₂ + sqrt(0.79603), x₀))
# 9           4.602e-04  6.044e-01  y = ((0.25465 - physics(x₂ + 1.1122, x₀)) / 1.3741)
# 10          3.731e-04  2.099e-01  y = ((0.25465 - physics(x₂ + 1.1439, x₀)) / sqrt(x₂))
# ...
#                                   v(x₁ / x₂), -0.63251)), x₀)) / sqrt(x₂))
# 20          3.632e-04  5.936e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(square(0.060674 ...
#                                   * x₁) / x₂)), x₀)) / square(sqrt(sqrt(x₂))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+04
# Head worker occupation: 1.0%
# Progress: 1771 / 2000 total iterations (88.550%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25461 ^ x₂)
# 5           5.198e-04  6.846e-01  y = (0.14 - physics(x₂, x₀))
# 7           4.680e-04  5.249e-02  y = (0.15958 - physics(x₂ - -0.25658, x₀))
# 9           4.555e-04  1.359e-02  y = (0.17601 - physics(x₂ + 0.67394, x₀ + x₁))
# 10          3.691e-04  2.104e-01  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(x₂))
# 12          3.688e-04  3.138e-04  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / (sqrt(x₂) ^ 0.9787...
#                                   1))
# 13          3.678e-04  2.783e-03  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# 14          3.678e-04  6.253e-05  y = ((sqrt(x₂ ^ -0.99853) - physics((x₂ + 1.457) + 1.8145, x₀)...
#                                   ) * 0.26116)
# 15          3.678e-04  3.278e-06  y = ((sqrt(inv(x₂) ^ 0.99726) - physics((x₂ + 1.457) + 1.8145,...
#                                    x₀)) * 0.26116)
# 16          3.678e-04  2.784e-05  y = ((sqrt(inv(x₂ + square(-0.048056))) - physics((x₂ + 1.457)...
#                                    + 1.8145, x₀)) * 0.26116)
# 17          3.668e-04  2.730e-03  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(sqrt((x₂ ^ sq...
#                                   rt(x₂)) + inv(1.2457))))
# 18          3.632e-04  9.714e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(square(0.060674 ...
#                                   * x₁) / x₂)), x₀)) / sqrt(x₂))
# 19          3.609e-04  6.428e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(((0.060674 * x₁)...
#                                    / x₂) ^ x₂)), x₀)) / sqrt(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.160e+04
# Head worker occupation: 1.0%
# Progress: 1821 / 2000 total iterations (91.050%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25461 ^ x₂)
# 5           5.198e-04  6.846e-01  y = (0.14 - physics(x₂, x₀))
# 7           4.680e-04  5.249e-02  y = (0.15958 - physics(x₂ - -0.25658, x₀))
# 9           4.555e-04  1.359e-02  y = (0.17601 - physics(x₂ + 0.67394, x₀ + x₁))
# 10          3.691e-04  2.104e-01  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(x₂))
# 12          3.688e-04  3.138e-04  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / (sqrt(x₂) ^ 0.9787...
#                                   1))
# 13          3.678e-04  2.783e-03  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# 14          3.678e-04  6.253e-05  y = ((sqrt(x₂ ^ -0.99853) - physics((x₂ + 1.457) + 1.8145, x₀)...
#                                   ) * 0.26116)
# 15          3.678e-04  3.278e-06  y = ((sqrt(inv(x₂) ^ 0.99726) - physics((x₂ + 1.457) + 1.8145,...
#                                    x₀)) * 0.26116)
# 16          3.678e-04  2.784e-05  y = ((sqrt(inv(x₂ + square(-0.048056))) - physics((x₂ + 1.457)...
#                                    + 1.8145, x₀)) * 0.26116)
# 17          3.668e-04  2.730e-03  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(sqrt((x₂ ^ sq...
#                                   rt(x₂)) + inv(1.2457))))
# 18          3.632e-04  9.714e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(square(0.060674 ...
#                                   * x₁) / x₂)), x₀)) / sqrt(x₂))
# 19          3.609e-04  6.428e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(((0.060674 * x₁)...
#                                    / x₂) ^ x₂)), x₀)) / sqrt(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.140e+04
# Head worker occupation: 1.0%
# Progress: 1867 / 2000 total iterations (93.350%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25461 ^ x₂)
# 5           5.198e-04  6.846e-01  y = (0.14 - physics(x₂, x₀))
# 7           4.680e-04  5.249e-02  y = (0.15958 - physics(x₂ - -0.25658, x₀))
# 9           4.555e-04  1.359e-02  y = (0.17601 - physics(x₂ + 0.67394, x₀ + x₁))
# 10          3.691e-04  2.104e-01  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(x₂))
# 12          3.688e-04  3.138e-04  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / (sqrt(x₂) ^ 0.9787...
#                                   1))
# 13          3.678e-04  2.783e-03  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# 14          3.678e-04  6.253e-05  y = ((sqrt(x₂ ^ -0.99853) - physics((x₂ + 1.457) + 1.8145, x₀)...
#                                   ) * 0.26116)
# 15          3.678e-04  3.278e-06  y = ((sqrt(inv(x₂) ^ 0.99726) - physics((x₂ + 1.457) + 1.8145,...
#                                    x₀)) * 0.26116)
# 16          3.678e-04  2.784e-05  y = ((sqrt(inv(x₂ + square(-0.048056))) - physics((x₂ + 1.457)...
#                                    + 1.8145, x₀)) * 0.26116)
# 17          3.668e-04  2.730e-03  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(sqrt((x₂ ^ sq...
#                                   rt(x₂)) + inv(1.2457))))
# 18          3.632e-04  9.714e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(square(0.060674 ...
#                                   * x₁) / x₂)), x₀)) / sqrt(x₂))
# 19          3.609e-04  6.428e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(((0.060674 * x₁)...
#                                    / x₂) ^ x₂)), x₀)) / sqrt(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.950e+04
# Head worker occupation: 1.0%
# Progress: 1899 / 2000 total iterations (94.950%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25461 ^ x₂)
# 5           5.198e-04  6.846e-01  y = (0.14 - physics(x₂, x₀))
# 7           4.680e-04  5.249e-02  y = (0.15958 - physics(x₂ - -0.25658, x₀))
# 9           4.452e-04  2.500e-02  y = (0.16759 - physics(x₂ + 0.41983, x₀ + x₂))
# 10          3.691e-04  1.875e-01  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(x₂))
# 12          3.688e-04  3.138e-04  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / (sqrt(x₂) ^ 0.9787...
#                                   1))
# 13          3.678e-04  2.783e-03  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# 14          3.678e-04  6.253e-05  y = ((sqrt(x₂ ^ -0.99853) - physics((x₂ + 1.457) + 1.8145, x₀)...
#                                   ) * 0.26116)
# 15          3.678e-04  3.278e-06  y = ((sqrt(inv(x₂) ^ 0.99726) - physics((x₂ + 1.457) + 1.8145,...
#                                    x₀)) * 0.26116)
# 16          3.678e-04  2.784e-05  y = ((sqrt(inv(x₂ + square(-0.048056))) - physics((x₂ + 1.457)...
#                                    + 1.8145, x₀)) * 0.26116)
# 17          3.668e-04  2.730e-03  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(sqrt((x₂ ^ sq...
#                                   rt(x₂)) + inv(1.2457))))
# 18          3.632e-04  9.714e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(square(0.060674 ...
#                                   * x₁) / x₂)), x₀)) / sqrt(x₂))
# 19          3.609e-04  6.428e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(((0.060674 * x₁)...
#                                    / x₂) ^ x₂)), x₀)) / sqrt(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.980e+04
# Head worker occupation: 1.0%
# Progress: 1942 / 2000 total iterations (97.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25461 ^ x₂)
# 5           5.198e-04  6.846e-01  y = (0.14 - physics(x₂, x₀))
# 7           4.680e-04  5.249e-02  y = (0.15958 - physics(x₂ - -0.25658, x₀))
# 9           4.452e-04  2.500e-02  y = (0.16759 - physics(x₂ + 0.41983, x₀ + x₂))
# 10          3.691e-04  1.875e-01  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(x₂))
# 12          3.688e-04  3.138e-04  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / (sqrt(x₂) ^ 0.9787...
#                                   1))
# 13          3.678e-04  2.783e-03  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# 14          3.678e-04  6.253e-05  y = ((sqrt(x₂ ^ -0.99853) - physics((x₂ + 1.457) + 1.8145, x₀)...
#                                   ) * 0.26116)
# 15          3.678e-04  3.278e-06  y = ((sqrt(inv(x₂) ^ 0.99726) - physics((x₂ + 1.457) + 1.8145,...
#                                    x₀)) * 0.26116)
# 16          3.678e-04  2.784e-05  y = ((sqrt(inv(x₂ + square(-0.048056))) - physics((x₂ + 1.457)...
#                                    + 1.8145, x₀)) * 0.26116)
# 17          3.668e-04  2.730e-03  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(sqrt((x₂ ^ sq...
#                                   rt(x₂)) + inv(1.2457))))
# 18          3.632e-04  9.714e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(square(0.060674 ...
#                                   * x₁) / x₂)), x₀)) / sqrt(x₂))
# 19          3.609e-04  6.428e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(((0.060674 * x₁)...
#                                    / x₂) ^ x₂)), x₀)) / sqrt(x₂))
# 20          3.607e-04  5.314e-04  y = ((0.26448 - physics(x₂ + (1.2457 + square(((0.060674 * x₁)...
#                                    / sqrt(x₂)) ^ x₂)), x₀)) / sqrt(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.830e+04
# Head worker occupation: 1.0%
# Progress: 1979 / 2000 total iterations (98.950%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.479e-03  1.594e+01  y = 0.041429
# 3           2.044e-03  3.923e-01  y = (0.25461 ^ x₂)
# 5           5.198e-04  6.846e-01  y = (0.14 - physics(x₂, x₀))
# 7           4.680e-04  5.249e-02  y = (0.15958 - physics(x₂ - -0.25658, x₀))
# 9           4.452e-04  2.500e-02  y = (0.16759 - physics(x₂ + 0.41983, x₀ + x₂))
# 10          3.691e-04  1.875e-01  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(x₂))
# 12          3.688e-04  3.138e-04  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / (sqrt(x₂) ^ 0.9787...
#                                   1))
# 13          3.678e-04  2.783e-03  y = ((sqrt(inv(x₂)) - physics((x₂ + 1.457) + 1.8145, x₀)) * 0....
#                                   26116)
# 14          3.678e-04  6.253e-05  y = ((sqrt(x₂ ^ -0.99853) - physics((x₂ + 1.457) + 1.8145, x₀)...
#                                   ) * 0.26116)
# 15          3.678e-04  3.278e-06  y = ((sqrt(inv(x₂) ^ 0.99726) - physics((x₂ + 1.457) + 1.8145,...
#                                    x₀)) * 0.26116)
# 16          3.678e-04  2.784e-05  y = ((sqrt(inv(x₂ + square(-0.048056))) - physics((x₂ + 1.457)...
#                                    + 1.8145, x₀)) * 0.26116)
# 17          3.668e-04  2.730e-03  y = ((0.26448 - physics(x₂ + 1.2457, x₀)) / sqrt(sqrt((x₂ ^ sq...
#                                   rt(x₂)) + inv(1.2457))))
# 18          3.632e-04  9.714e-03  y = ((0.26448 - physics(x₂ + (1.2457 + square(square(0.060674 ...
#                                   * x₁) / x₂)), x₀)) / sqrt(x₂))
# 19          3.607e-04  6.959e-03  y = ((0.26448 - physics(x₂ + (1.2457 + ((square(0.060674 * x₁)...
#                                    / x₂) ^ x₂)), x₀)) / sqrt(x₂))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          0.9846646
# 	1         0.025030                                  (0.99967515 ^ x0)
# 	2         0.092188                              (0.9304864 ^ inv(x2))
# 	3         0.866715             (physics(-1.634159, x2) ^ -0.20850202)
# 	4         0.207859              (physics(x2, sqrt(x0)) ^ 0.101635255)
# 	5   >>>>  0.740984      (physics(x2 / -0.30944166, x0) ^ 0.117272355)
# 	6         0.160719           (physics(x2 / -0.3109984, x0) ^ inv(x1))
# 	7         0.052336      (physics(x2 / 0.33104002, x0 - x1) ^ inv(x1))
# 	8         0.019117  (physics((x2 / -0.36054888) - 0.6044107, x0 - ...
# 	9         0.009631  (physics(x2 / -0.36054888, x0 - (x1 + x1)) ^ i...
# 	10        0.003253  (physics(x2 / -0.36054888, x0 - (x1 + x1)) ^ i...
# 	11        0.015256  ((physics(x2 / -0.36054888, (x0 - x1) - 2.2625...
# 	12        0.006935  ((physics(x2 / -0.36054888, (x0 - x1) - sqrt(x...
# 	13        0.000097  (physics(x2 / -0.36054888, (x0 - (x1 + square(...
# 	14        0.004501  (physics(x2 / -0.36054888, (x0 - (x1 + square(...
#
# 	        loss  complexity
# 	0   0.006017           1
# 	1   0.005723           3
# 	2   0.005219           4
# 	3   0.002194           5
# 	4   0.001782           6
# 	5   0.000849           7
# 	6   0.000723           8
# 	7   0.000651          10
# 	8   0.000627          12
# 	9   0.000615          14
# 	10  0.000613          15
# 	11  0.000604          16
# 	12  0.000600          17
# 	13  0.000599          18
# 	14  0.000597          19
# ]

# %%
model2.sympy()
# Out:
# 0.1399962 - x2**2/x0

# %%
n_r2_pred = model2.predict(X)

# n_r2_pred =  0.149 - 1.09 * w_oh**2/L
print("Default selection MSE:", np.power(n_r2_pred - y2, 2).mean())
# Out:
# Default selection MSE: 0.0005198363132888174

# %%
x_line = [-0.25, 0.25]
y_line = [-0.25, 0.25]

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_r2, y=n_r2_pred, marker='o', c='none', edgecolor='b', label='Interior Girder')
ax1.plot(x_line, y_line, c = "k")
ax1.set_title('Accuracy')
ax1.legend()
plt.xlim((-0.25, 0.25))
plt.ylim((-0.25, 0.25))
ax1.set_xlabel('Target $n_{r2}$')
ax1.set_ylabel('Predicted $n_{r2}$')
ax1.grid()

# %%
model2.latex()
# Out:
# '0.140 - \\frac{x_{2}^{2}}{x_{0}}'

# %% [markdown]
# $ \frac{x_{1}^{2}}{x_{0} - \frac{x_{3}}{x_{1}}} + 0.167 $
#
# $ \frac{w_{oh}^{2}}{L - \frac{D}{w_{oh}}} + 0.167 $
#
# $ 0.149 - \frac{1.09 x_{1}^{2}}{x_{0}} $
#
# $ 0.149 - \frac{1.09 w_{oh}^{2}}{L} $
#
# $ 0.14 - \frac{w_{oh}^{2}}{L} $
